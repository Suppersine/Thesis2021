# %% [markdown]
# # Data Visualisation & Preparation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !wget https://www.dropbox.com/s/jpw4fyv6mh31ql4/NTP2015-2017fire.txt
# Out:
# --2022-01-02 06:01:07--  https://www.dropbox.com/s/jpw4fyv6mh31ql4/NTP2015-2017fire.txt
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/jpw4fyv6mh31ql4/NTP2015-2017fire.txt [following]
# --2022-01-02 06:01:08--  https://www.dropbox.com/s/raw/jpw4fyv6mh31ql4/NTP2015-2017fire.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucad1b8b45ab173e39fd8ab222c1.dl.dropboxusercontent.com/cd/0/inline/Bc-Z-PWqLwhMWZDT3OQe_1NJVea9a6XeYBr8toXhC-LGtKo_Y-CxyjNIPYsVB4pbWmV4YIQHScgR3CC8pdsVwULMANt7hemcNmISFTtD79PL69MO6tJCRhaxfyWOTT-kVocMyo8etqUId69Ev_2vJ2uq/file# [following]
# --2022-01-02 06:01:08--  https://ucad1b8b45ab173e39fd8ab222c1.dl.dropboxusercontent.com/cd/0/inline/Bc-Z-PWqLwhMWZDT3OQe_1NJVea9a6XeYBr8toXhC-LGtKo_Y-CxyjNIPYsVB4pbWmV4YIQHScgR3CC8pdsVwULMANt7hemcNmISFTtD79PL69MO6tJCRhaxfyWOTT-kVocMyo8etqUId69Ev_2vJ2uq/file
# Resolving ucad1b8b45ab173e39fd8ab222c1.dl.dropboxusercontent.com (ucad1b8b45ab173e39fd8ab222c1.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6033:15::a27d:530f
# Connecting to ucad1b8b45ab173e39fd8ab222c1.dl.dropboxusercontent.com (ucad1b8b45ab173e39fd8ab222c1.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3884193 (3.7M) [text/plain]
# Saving to: ‘NTP2015-2017fire.txt’
#
# NTP2015-2017fire.tx 100%[===================>]   3.70M  21.5MB/s    in 0.2s
#
# 2022-01-02 06:01:08 (21.5 MB/s) - ‘NTP2015-2017fire.txt’ saved [3884193/3884193]

# %%
# %cd /content/
#df = pd.read_csv('/content/gdrive/MyDrive/dlku/NTP2015fire-Jan.txt', sep='\t', header=None)
df = pd.read_csv('NTP2015-2017fire.txt', sep='\t', header=None)
df.columns = ["date", "station", "addr1", "addr2", "longitude", "latitude", "township"]
# Out:
# /content

# %%
df
# Out:
#                    date  station  ...   latitude township
# 0         2015/1/1 0:13  火警-瓦斯漏氣  ...  25.000569   板橋區廣德里
# 1         2015/1/1 0:16    火警-倉庫  ...  25.084172   三重區富華里
# 2         2015/1/1 0:48  火警-查看案件  ...  25.136422   淡水區民權里
# 3         2015/1/1 0:56  火警-查看案件  ...  25.031506   新莊區泰豐里
# 4         2015/1/1 1:04    火警-汽車  ...  24.982273   樹林區和平里
# ...                 ...      ...  ...        ...      ...
# 24085  2017/12/31 17:14  火警-集合住宅  ...  24.990417   中和區錦盛里
# 24086  2017/12/31 18:40  火警-集合住宅  ...  25.048063   汐止區東勢里
# 24087  2017/12/31 20:09  火警-查看案件  ...  25.076529   三重區福隆里
# 24088  2017/12/31 20:44  火警-查看案件  ...  24.997367   永和區民族里
# 24089  2017/12/31 22:09  火警-查看案件  ...  25.000317   板橋區龍安里
#
# [24090 rows x 7 columns]

# %%
#set date time format
df['date'] = pd.to_datetime(df.date, format='%Y-%m-%d %H:%M:%S')

# %%
df
# Out:
#                      date  station  ...   latitude township
# 0     2015-01-01 00:13:00  火警-瓦斯漏氣  ...  25.000569   板橋區廣德里
# 1     2015-01-01 00:16:00    火警-倉庫  ...  25.084172   三重區富華里
# 2     2015-01-01 00:48:00  火警-查看案件  ...  25.136422   淡水區民權里
# 3     2015-01-01 00:56:00  火警-查看案件  ...  25.031506   新莊區泰豐里
# 4     2015-01-01 01:04:00    火警-汽車  ...  24.982273   樹林區和平里
# ...                   ...      ...  ...        ...      ...
# 24085 2017-12-31 17:14:00  火警-集合住宅  ...  24.990417   中和區錦盛里
# 24086 2017-12-31 18:40:00  火警-集合住宅  ...  25.048063   汐止區東勢里
# 24087 2017-12-31 20:09:00  火警-查看案件  ...  25.076529   三重區福隆里
# 24088 2017-12-31 20:44:00  火警-查看案件  ...  24.997367   永和區民族里
# 24089 2017-12-31 22:09:00  火警-查看案件  ...  25.000317   板橋區龍安里
#
# [24090 rows x 7 columns]

# %%
#extract only numerical/quantitative data
dften = df[["date", "longitude", "latitude"]]

# %%
dften
# Out:
#                      date   longitude   latitude
# 0     2015-01-01 00:13:00  121.466281  25.000569
# 1     2015-01-01 00:16:00  121.491579  25.084172
# 2     2015-01-01 00:48:00  121.460224  25.136422
# 3     2015-01-01 00:56:00  121.450333  25.031506
# 4     2015-01-01 01:04:00  121.420005  24.982273
# ...                   ...         ...        ...
# 24085 2017-12-31 17:14:00  121.493909  24.990417
# 24086 2017-12-31 18:40:00  121.621682  25.048063
# 24087 2017-12-31 20:09:00  121.490806  25.076529
# 24088 2017-12-31 20:44:00  121.519391  24.997367
# 24089 2017-12-31 22:09:00  121.442237  25.000317
#
# [24090 rows x 3 columns]

# %%
BBox = ((dften.longitude.min(),   dften.longitude.max(),      
         dften.latitude.min(), dften.latitude.max()))

# %%
#Print out the coordinates, and go to Openstreetmap website to draw a map.
BBox
# Out:
# (121.2868855, 122.0030709, 24.77511693, 25.29717505)

# %%
#let's plot the points
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(dften.longitude, dften.latitude, zorder=1, alpha= 0.2, c='k', s=10)
ax.set_title('Fire Incidents in NTPC, 2015-2017, Spatial Domain')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
# Out:
# (24.77511693, 25.29717505)

# %%
#split dataframe into 3 years
df15 = df[df['date'].dt.year == 2015]
df16 = df[df['date'].dt.year == 2016]
df17 = df[df['date'].dt.year == 2017]

# %%
df15
# Out:
#                     date  station  ...   latitude township
# 0    2015-01-01 00:13:00  火警-瓦斯漏氣  ...  25.000569   板橋區廣德里
# 1    2015-01-01 00:16:00    火警-倉庫  ...  25.084172   三重區富華里
# 2    2015-01-01 00:48:00  火警-查看案件  ...  25.136422   淡水區民權里
# 3    2015-01-01 00:56:00  火警-查看案件  ...  25.031506   新莊區泰豐里
# 4    2015-01-01 01:04:00    火警-汽車  ...  24.982273   樹林區和平里
# ...                  ...      ...  ...        ...      ...
# 9054 2015-12-31 21:41:00   火警-透天厝  ...  24.994490   中和區秀明里
# 9055 2015-12-31 21:46:00  火警-集合住宅  ...  25.016660   樹林區三福里
# 9056 2015-12-31 22:37:00  火警-查看案件  ...  25.070749   林口區東勢里
# 9057 2015-12-31 22:45:00  火警-查看案件  ...  25.097674   蘆洲區保新里
# 9058 2015-12-31 23:32:00  火警-查看案件  ...  24.989496   中和區錦中里
#
# [9059 rows x 7 columns]

# %%
df16
# Out:
#                      date      station  ...   latitude township
# 9059  2016-01-01 01:10:00      火警-查看案件  ...  25.047863   泰山區明志里
# 9060  2016-01-01 01:18:00      火警-查看案件  ...  25.145268   淡水區八勢里
# 9061  2016-01-01 01:27:00      火警-查看案件  ...  25.013844   永和區下溪里
# 9062  2016-01-01 03:30:00      火警-查看案件  ...  25.093751   蘆洲區南港里
# 9063  2016-01-01 03:47:00        火警-汽車  ...  24.994834   樹林區潭底里
# ...                   ...          ...  ...        ...      ...
# 17156 2016-12-31 19:50:00      火警-集合住宅  ...  25.032542   板橋區溪頭里
# 17157 2016-12-31 21:51:00      火警-查看案件  ...  24.997751   板橋區崑崙里
# 17158 2016-12-31 22:30:00      火警-集合住宅  ...  25.018254   板橋區新民里
# 17159 2016-12-31 22:52:00      火警-查看案件  ...  25.072460   林口區西林里
# 17160 2016-12-31 23:13:00  火警-山林田野(平地)  ...  25.145268   淡水區八勢里
#
# [8102 rows x 7 columns]

# %%
df17
# Out:
#                      date      station  ...   latitude township
# 17161 2017-01-01 00:13:00  火警-山林田野(平地)  ...  24.936866   鶯歌區二甲里
# 17162 2017-01-01 00:15:00      火警-集合住宅  ...  24.929874   三峽區介壽里
# 17163 2017-01-01 00:54:00      火警-集合住宅  ...  25.007928   板橋區流芳里
# 17164 2017-01-01 01:44:00      火警-集合住宅  ...  25.062100   汐止區文化里
# 17165 2017-01-01 01:59:00     火警-警報器作響  ...  25.076035   汐止區建成里
# ...                   ...          ...  ...        ...      ...
# 24085 2017-12-31 17:14:00      火警-集合住宅  ...  24.990417   中和區錦盛里
# 24086 2017-12-31 18:40:00      火警-集合住宅  ...  25.048063   汐止區東勢里
# 24087 2017-12-31 20:09:00      火警-查看案件  ...  25.076529   三重區福隆里
# 24088 2017-12-31 20:44:00      火警-查看案件  ...  24.997367   永和區民族里
# 24089 2017-12-31 22:09:00      火警-查看案件  ...  25.000317   板橋區龍安里
#
# [6929 rows x 7 columns]

# %%
#extract only numerical/quantitative data
dfn15 = df15[["date", "longitude", "latitude"]]
dfn16 = df16[["date", "longitude", "latitude"]]
dfn17 = df17[["date", "longitude", "latitude"]]

# %%
#let's plot the points for 2015
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df15.longitude, df15.latitude, zorder=1, alpha= 0.2, c='r', s=10)
ax.set_title('Fire Incidents in NTPC, 2015, Spatial Domain')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
# Out:
# (24.77511693, 25.29717505)

# %%
#let's plot the points for 2016
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df16.longitude, df16.latitude, zorder=1, alpha= 0.2, c='g', s=10)
ax.set_title('Fire Incidents in NTPC, 2016, Spatial Domain')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
# Out:
# (24.77511693, 25.29717505)

# %%
#let's plot the points for 2017
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df17.longitude, df17.latitude, zorder=1, alpha= 0.2, c='b', s=10)
ax.set_title('Fire Incidents in NTPC, 2017, Spatial Domain')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
# Out:
# (24.77511693, 25.29717505)

# %%
#Extraction of the temporal domain
maxlimit = len(df)
ones = np.ones(maxlimit, dtype="uint32")
dftemp = pd.DataFrame(df.date)
dftemp['freq'] = ones

# %%
dftemp
# Out:
#                      date  freq
# 0     2015-01-01 00:13:00     1
# 1     2015-01-01 00:16:00     1
# 2     2015-01-01 00:48:00     1
# 3     2015-01-01 00:56:00     1
# 4     2015-01-01 01:04:00     1
# ...                   ...   ...
# 24085 2017-12-31 17:14:00     1
# 24086 2017-12-31 18:40:00     1
# 24087 2017-12-31 20:09:00     1
# 24088 2017-12-31 20:44:00     1
# 24089 2017-12-31 22:09:00     1
#
# [24090 rows x 2 columns]

# %%
#when running this block, we will obtain the monthly frequency to be used in the temporal domain (a.k.a. time series).
dftempday = dftemp.groupby(pd.Grouper(key="date", freq="1D")).count()
dftempweek = dftemp.groupby(pd.Grouper(key="date", freq="1W")).count()
dftempmonth = dftemp.groupby(pd.Grouper(key="date", freq="1M")).count()

# %%
dftempday
# Out:
#             freq
# date
# 2015-01-01    34
# 2015-01-02    25
# 2015-01-03    24
# 2015-01-04    34
# 2015-01-05    28
# ...          ...
# 2017-12-27    13
# 2017-12-28    19
# 2017-12-29    19
# 2017-12-30     6
# 2017-12-31     8
#
# [1096 rows x 1 columns]

# %%
dftempweek
# Out:
#             freq
# date
# 2015-01-04   117
# 2015-01-11   163
# 2015-01-18   141
# 2015-01-25   210
# 2015-02-01   174
# ...          ...
# 2017-12-03   125
# 2017-12-10   109
# 2017-12-17   105
# 2017-12-24   139
# 2017-12-31   100
#
# [157 rows x 1 columns]

# %%
dftempmonth
# Out:
#             freq
# date
# 2015-01-31   778
# 2015-02-28   776
# 2015-03-31   733
# 2015-04-30   844
# 2015-05-31   681
# 2015-06-30   677
# 2015-07-31   718
# 2015-08-31  1030
# 2015-09-30   792
# 2015-10-31   699
# 2015-11-30   680
# 2015-12-31   651
# 2016-01-31   688
# 2016-02-29   711
# 2016-03-31   752
# 2016-04-30   671
# 2016-05-31   652
# 2016-06-30   663
# 2016-07-31   666
# 2016-08-31   748
# 2016-09-30   674
# 2016-10-31   666
# 2016-11-30   635
# 2016-12-31   576
# 2017-01-31   638
# 2017-02-28   564
# 2017-03-31   519
# 2017-04-30   646
# 2017-05-31   509
# 2017-06-30   541
# 2017-07-31   610
# 2017-08-31   740
# 2017-09-30   576
# 2017-10-31   527
# 2017-11-30   553
# 2017-12-31   506

# %%
y = dftempmonth['freq']
x = dftempmonth.index
plt.rcParams["figure.figsize"] = (16,9)
plt.plot(x, y, color='r', label='monthly frequency') 
plt.xlabel('date')
plt.ylabel('incidents')
plt.title('Monthly Temporal Domain')
plt.legend() 
plt.show()

# %%
y = dftempweek['freq']
x = dftempweek.index
plt.rcParams["figure.figsize"] = (16,9)
plt.plot(x, y, color='g', label='weekly frequency')
plt.xlabel('date')
plt.ylabel('incidents')
plt.title('Weekly Temporal Domain')
plt.legend() 
plt.show()

# %%
y = dftempday['freq']
x = dftempday.index
plt.rcParams["figure.figsize"] = (16,9)
plt.plot(x, y, color='b', label='daily frequency') 
plt.xlabel('date')
plt.ylabel('incidents')
plt.title('Daily Temporal Domain')
plt.legend() 
plt.show()

# %%
BBox
# Out:
# (121.2868855, 122.0030709, 24.77511693, 25.29717505)

# %% [markdown]
# Generate heatmap cells and convert hotspots to raster data using the "cytogenesis" function

# %%
def cytogenesis(df, nc, mapedges):
  #def calculate_cellsize(nc, mapedges):
  def calculate_cellsize():
    global lonmin
    global lonmax
    global latmin
    global latmax
    lonmin = mapedges[0]
    lonmax = mapedges[1]
    latmin = mapedges[2]
    latmax = mapedges[3]
    global csize_lon
    global csize_lat
    csize_lon = (lonmax - lonmin)/nc
    csize_lat = (latmax - latmin)/nc
    #print(csize_lon)
    #print(csize_lat)
    return csize_lon, csize_lat, lonmin, lonmax, latmin, latmax

  #call the 1st subfunction
  #csize_lon, csize_lat = calculate_cellsize(nc, mapedges)
  csize_lon, csize_lat, lonmin, lonmax, latmin, latmax = calculate_cellsize()
  
  #def draw_lines(nc,csize_lon,csize_lat):
  def draw_lines():
    global pixgrade_lon_left
    global pixgrade_lon_right
    global pixgrade_lat_bottom
    global pixgrade_lat_top

    pixgrade_lon_left = np.zeros(nc, dtype="float64")
    pixgrade_lon_right = np.zeros(nc, dtype="float64")
    pixgrade_lat_bottom = np.zeros(nc, dtype="float64")
    pixgrade_lat_top = np.zeros(nc, dtype="float64")
    #draw block boundaries
    for i in range (0,nc,1):

      pixgrade_lon_left[i] = lonmin + ((i)*(csize_lon))
      pixgrade_lon_right[i] = lonmin + ((i+1)*(csize_lon))
      pixgrade_lat_bottom[i] = latmin + ((i)*(csize_lat))
      pixgrade_lat_top[i] = latmin + ((i+1)*(csize_lat))
    
    #print(pixgrade_lon_left)
    #print(pixgrade_lon_right)
    #print(pixgrade_lat_bottom)
    #print(pixgrade_lat_top)
    return pixgrade_lon_left, pixgrade_lon_right, pixgrade_lat_bottom, pixgrade_lat_top

  #pixgrade_lon_left, pixgrade_lon_right, pixgrade_lat_bottom, pixgrade_lat_top = draw_lines(nc,csize_lon,csize_lat)
  pixgrade_lon_left, pixgrade_lon_right, pixgrade_lat_bottom, pixgrade_lat_top = draw_lines()

  #def cell_loader(df, nc, csize_lon, csize_lat, pixgrade_lon_left, pixgrade_lon_right, pixgrade_lat_bottom, pixgrade_lat_top):
  def cell_loader():  
    #create a board
    block = np.zeros((nc, nc), dtype="float32")
    point = np.zeros([len(df),2])

    for i in range (0,len(df),1):
      point[i,0] = df.longitude[i]
      point[i,1] = df.latitude[i]
      #the inner nested loop considers where to place each point into a cell
      for j in range (0,nc,1):
        for k in range (0,nc,1):
          if ((point[i,0] >= pixgrade_lon_left[j]) & (point[i,0] < pixgrade_lon_right[j]) & (point[i,1] >= pixgrade_lat_bottom[k]) & (point[i,1] < pixgrade_lat_top[k])):
            block[j,k] += 1
    #orgaise the cell tablet for proper visualisation
    global bq
    bq = np.rot90(block, k=1)
    bq = bq.astype(np.uint8)

    def heatmap2d(arr: np.ndarray):
      plt.imshow(arr, cmap='viridis')
      plt.colorbar()
      plt.show()

    heatmap2d(bq)
    return bq

  bq = cell_loader()
  return bq

#cytogenesis(dften, 28, BBox)

# %%
def dozenisation(dff, BBox=BBox):

  figtensor = np.zeros([12,28,28])
  for i in range(0,12,1):
    timeframe = (dff['date'].dt.month == i+1)
    df00 = dff.loc[timeframe]
    df00 = df00.reset_index(drop=True)
    df00.head()
    fig0 = cytogenesis(df00, 28, BBox)
    figtensor[i] = fig0
  return figtensor

figtensor15 = dozenisation(df15)
figtensor16 = dozenisation(df16)
figtensor17 = dozenisation(df17)
figtensor = np.concatenate((figtensor15, figtensor16, figtensor17), axis=0)

# %%
maxcolour = figtensor.max()
maxcolour
# Out:
# 44.0

# %%
figtensor.shape
# Out:
# (36, 28, 28)

# %%
def ttsplit(dataarray):
  trainarr = np.zeros([24,28,28], dtype='uint8')
  testarr = np.zeros([12,28,28], dtype='uint8')
  j = 0
  k = 0
  for i in range (0, len(dataarray), 1):
    if (i % 3 == 2):
      testarr[j,:,:] = dataarray[i,:,:]
      j+=1
    else:
      trainarr[k,:,:] = dataarray[i,:,:]
      k+=1
  return trainarr, testarr

traindata, testdata = ttsplit(figtensor)

def colour_normalisation(nparray): #In autoencoders, the last (output layer's) activation function is in the decoder
  maxcolour = figtensor.max()      #in this case, it's sigmoid
  #halfbound = float(maxcolour / 2)
  nparray = nparray.astype('float32')
  new_arr = nparray / maxcolour
  return new_arr

trainarray = colour_normalisation(traindata)
testarray = colour_normalisation(testdata)
print(trainarray.shape)
print(testarray.shape)
# Out:
# (24, 28, 28)
# (12, 28, 28)

# %%
trainarray.shape #check dataset dimensions
# Out:
# (24, 28, 28)

# %%
testarray.shape #check dataset dimensions
# Out:
# (12, 28, 28)

# %%
for i in range(0, len(trainarray),1):
  plt.imshow(trainarray[i], cmap='gray', vmin=0, vmax=1)
  plt.show()

# %%
for i in range(0, len(testarray),1):
  plt.imshow(testarray[i], cmap='gray', vmin=0, vmax=1)
  plt.show()

# %% [markdown]
# #Data Figure Save
# If you do not want to save data, skip this subsection (4 cells below)

# %%
'''%mkdir datafig
# %cd datafig
# %mkdir train
# %mkdir test'''
# Out:
# '%mkdir datafig\n%cd datafig\n%mkdir train\n%mkdir test'

# %%
'''%cd /content/datafig/train
j = 0
for i in range(0, len(trainarray), 1):
  j+=1
  im = Image.fromarray(trainarray[i])
  im.save("train"+str(j)+".png")'''
# Out:
# '%cd /content/datafig/train\nj = 0\nfor i in range(0, len(trainarray), 1):\n  j+=1\n  im = Image.fromarray(trainarray[i])\n  im.save("train"+str(j)+".png")'

# %%
'''%cd /content/datafig/test
j = 0
for i in range(0, len(testarray), 1):
  j+=1
  im = Image.fromarray(trainarray[i])
  im.save("test"+str(j)+".png")'''
# Out:
# '%cd /content/datafig/test\nj = 0\nfor i in range(0, len(testarray), 1):\n  j+=1\n  im = Image.fromarray(trainarray[i])\n  im.save("test"+str(j)+".png")'

# %%
#at this step, you need to download the figures in the files console to the left, in order to be used by spatial models.
'''
from google.colab import files
# !zip -r /content/datafig.zip /content/datafig
files.download("/content/datafig.zip")
'''
# Out:
# '\nfrom google.colab import files\n!zip -r /content/datafig.zip /content/datafig\nfiles.download("/content/datafig.zip")\n'

# %% [markdown]
# #The Spatial Generative Model (Variational-Autoencoder) VAE
# Using tensorflow-keras, we need to prepare the data to check its dimensionality before feeding it to a neural network (Variational autoencoder).

# %% [markdown]
# **Setup**

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn import metrics
from math import sqrt

# %% [markdown]
# **Create a sampling layer**

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %% [markdown]
# **Encoder**

# %%
latent_dim = 2

encoder_inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(32, 3, activation="relu", strides=2, padding="same")(encoder_inputs)
x = layers.Conv2D(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Flatten()(x)
x = layers.Dense(16, activation="relu")(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 28, 28, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 14, 14, 32)   320         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 7, 7, 64)     18496       ['conv2d[0][0]']
#
#  flatten (Flatten)              (None, 3136)         0           ['conv2d_1[0][0]']
#
#  dense (Dense)                  (None, 16)           50192       ['flatten[0][0]']
#
#  z_mean (Dense)                 (None, 2)            34          ['dense[0][0]']
#
#  z_log_var (Dense)              (None, 2)            34          ['dense[0][0]']
#
#  sampling (Sampling)            (None, 2)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 69,076
# Trainable params: 69,076
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# **Decoder**

# %%
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(7 * 7 * 64, activation="relu")(latent_inputs)
x = layers.Reshape((7, 7, 64))(x)
x = layers.Conv2DTranspose(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
decoder_outputs = layers.Conv2DTranspose(1, 3, activation="sigmoid", padding="same")(x)
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_1 (Dense)             (None, 3136)              9408
#
#  reshape (Reshape)           (None, 7, 7, 64)          0
#
#  conv2d_transpose (Conv2DTra  (None, 14, 14, 64)       36928
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 28, 28, 32)       18464
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 28, 28, 1)        289
#  ranspose)
#
# =================================================================
# Total params: 65,089
# Trainable params: 65,089
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Define the VAE as a `Model` with a custom `train_step`

# %%
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            recon = reconstruction
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.binary_crossentropy(data, reconstruction), axis=(1, 2)
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss

        mse = tf.keras.metrics.MeanSquaredError()
        mse.update_state(data, recon)
        mse = mse.result().numpy()
        print('MSE =', mse)

        mae = tf.keras.metrics.MeanAbsoluteError()
        mae.update_state(data, recon)
        mae = mae.result().numpy()
        print('MAE =', mae)

        mape = tf.keras.metrics.MeanAbsolutePercentageError()
        mape.update_state(data, recon)
        mape = mape.result().numpy()
        print('MAPE =', mape)

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %% [markdown]
# ## Train the VAE

# %%
x_train = trainarray
x_test = testarray

maxcolour = figtensor.max()

# %%
mnist_digits = np.concatenate([x_train, x_test], axis=0)
mnist_digits = np.expand_dims(mnist_digits, -1).astype("float32")

vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam(), run_eagerly=True )
vae.fit(mnist_digits, epochs=100, batch_size=12)
# Out:
# Epoch 1/100
# MSE = 0.23627472
# MAE = 0.48161966
# MAPE = 426054660.0
# 1/3 [=========>....................] - ETA: 0s - loss: 542.9168 - reconstruction_loss: 542.9167 - kl_loss: 3.8505e-05MSE = 0.23390011
# MAE = 0.47910097
# MAPE = 422577300.0
# 2/3 [===================>..........] - ETA: 0s - loss: 542.0782 - reconstruction_loss: 541.2394 - kl_loss: 1.2817e-04MSE = 0.2324622
# MAE = 0.47798467
# MAPE = 421219870.0
# 3/3 [==============================] - 1s 143ms/step - loss: 540.7849 - reconstruction_loss: 539.4914 - kl_loss: 3.2576e-04
# Epoch 2/100
# MSE = 0.2291251
# MAE = 0.47410792
# MAPE = 417050180.0
# 1/3 [=========>....................] - ETA: 0s - loss: 532.3121 - reconstruction_loss: 532.3099 - kl_loss: 0.0021MSE = 0.22519422
# MAE = 0.47027323
# MAPE = 418164770.0
# 2/3 [===================>..........] - ETA: 0s - loss: 530.4431 - reconstruction_loss: 528.5709 - kl_loss: 0.0031MSE = 0.2222862
# MAE = 0.4670921
# MAPE = 411356640.0
# 3/3 [==============================] - 0s 166ms/step - loss: 528.1640 - reconstruction_loss: 525.8802 - kl_loss: 0.0046
# Epoch 3/100
# MSE = 0.2144745
# MAE = 0.45867312
# MAPE = 404124670.0
# 1/3 [=========>....................] - ETA: 0s - loss: 508.5771 - reconstruction_loss: 508.5647 - kl_loss: 0.0124MSE = 0.20994774
# MAE = 0.45376074
# MAPE = 402284700.0
# 2/3 [===================>..........] - ETA: 0s - loss: 506.7538 - reconstruction_loss: 504.9138 - kl_loss: 0.0167MSE = 0.20689563
# MAE = 0.45033026
# MAPE = 398424480.0
# MAPE = 2803120.8
# 1/3 [=========>....................] - ETA: 0s - loss: 43.3502 - reconstruction_loss: 43.2061 - kl_loss: 0.1441MSE = 0.00080780155
# MAE = 0.009908573
# MAPE = 2940104.2
# 2/3 [===================>..........] - ETA: 0s - loss: 42.4740 - reconstruction_loss: 41.4590 - kl_loss: 0.1389MSE = 0.00092229305
# MAE = 0.010267936
# MAPE = 3072748.0
# 3/3 [==============================] - 0s 83ms/step - loss: 41.8729 - reconstruction_loss: 41.1349 - kl_loss: 0.1369
# Epoch 99/100
# MSE = 0.0011011017
# MAE = 0.010874617
# MAPE = 2956780.8
# 1/3 [=========>....................] - ETA: 0s - loss: 41.6684 - reconstruction_loss: 41.5331 - kl_loss: 0.1353MSE = 0.0009408873
# MAE = 0.010131903
# MAPE = 2591482.2
# 2/3 [===================>..........] - ETA: 0s - loss: 41.5557 - reconstruction_loss: 41.3096 - kl_loss: 0.1335MSE = 0.00095204613
# MAE = 0.009750528
# MAPE = 2365628.5
# 3/3 [==============================] - 0s 88ms/step - loss: 41.3861 - reconstruction_loss: 41.0836 - kl_loss: 0.1329
# Epoch 100/100
# MSE = 0.0009343505
# MAE = 0.010008457
# MAPE = 2613898.5
# 1/3 [=========>....................] - ETA: 0s - loss: 40.5637 - reconstruction_loss: 40.4353 - kl_loss: 0.1284MSE = 0.001140552
# MAE = 0.010740585
# MAPE = 2569873.5
# 2/3 [===================>..........] - ETA: 0s - loss: 41.0399 - reconstruction_loss: 41.3854 - kl_loss: 0.1307MSE = 0.00082212215
# MAE = 0.009470482
# MAPE = 2425976.5
# 3/3 [==============================] - 0s 88ms/step - loss: 41.0695 - reconstruction_loss: 40.9707 - kl_loss: 0.1283

# %% [markdown]
# ## Display a grid of sampled digits

# %%
import matplotlib.pyplot as plt


def plot_latent_space(vae, n=12, figsize=12):
    # display a n*n 2D manifold of digits
    digit_size = 28
    scale = 1.0
    figure = np.zeros((digit_size * n, digit_size * n))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            z_sample = np.array([[xi, yi]])
            x_decoded = vae.decoder.predict(z_sample)
            digit = x_decoded[0].reshape(digit_size, digit_size)
            figure[
                i * digit_size : (i + 1) * digit_size,
                j * digit_size : (j + 1) * digit_size,
            ] = digit

    plt.figure(figsize=(figsize, figsize))
    start_range = digit_size // 2
    end_range = n * digit_size + start_range
    pixel_range = np.arange(start_range, end_range, digit_size)
    sample_range_x = np.round(grid_x, 1)
    sample_range_y = np.round(grid_y, 1)
    plt.xticks(pixel_range, sample_range_x)
    plt.yticks(pixel_range, sample_range_y)
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.imshow(figure, cmap="Greys_r")
    plt.show()


plot_latent_space(vae)

# %% [markdown]
# ## Calculate test metrics

# %%
gt = x_test
gt2 = gt.reshape(12,784)
gt2.shape
# Out:
# (12, 784)

# %%
def prediction(x_test):
  encoded, _, _ = vae.encoder.predict(x_test) #in this model, always drop other 2 tensors before decoding
  decoded = vae.decoder.predict(encoded)
  return decoded

xpred = prediction(x_test)
xpred = xpred.squeeze()
xpred2 = xpred.reshape(12,784)
xpred2.shape
# Out:
# (12, 784)

# %%
mse = metrics.mean_squared_error(gt2, xpred2)
rmse = sqrt(mse)
mae = metrics.mean_absolute_error(gt2, xpred2)
mape = metrics.mean_absolute_percentage_error(gt2, xpred2)

# %%
print("Test MSE =", mse)
print("Test RMSE =", rmse)
print("Test MAE =", mae)
print("Test MAPE =", mape)
# Out:
# Test MSE = 0.0007967191
# Test RMSE = 0.028226213082574725
# Test MAE = 0.009872467
# Test MAPE = 14313473000000.0
