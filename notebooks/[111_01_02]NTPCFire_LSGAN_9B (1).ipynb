# %% [markdown]
# #Read the data

# %%
from zipfile import ZipFile
import os, glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from google.colab.patches import cv2_imshow

# %%
# !wget https://www.dropbox.com/s/gtvw3nqbderxigb/datafig28.zip
# Out:
# --2022-01-02 09:58:12--  https://www.dropbox.com/s/gtvw3nqbderxigb/datafig28.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/gtvw3nqbderxigb/datafig28.zip [following]
# --2022-01-02 09:58:13--  https://www.dropbox.com/s/raw/gtvw3nqbderxigb/datafig28.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc81929d6472d9f6f17b8cc48fdc.dl.dropboxusercontent.com/cd/0/inline/BdB-MRomcoXZLyIvoye0w3oRY-4bMnGssChbuDSitFo2D-pLkDbfZ5b4VUOWKTZY2ayGjlIoo75E_OAN6IEpHLikDehnep84pZQJXvxp-ynDJEfIq8oE4f7B9M0slLzBcbYZqU-vTnKlfTRoVVjqlR8x/file# [following]
# --2022-01-02 09:58:13--  https://uc81929d6472d9f6f17b8cc48fdc.dl.dropboxusercontent.com/cd/0/inline/BdB-MRomcoXZLyIvoye0w3oRY-4bMnGssChbuDSitFo2D-pLkDbfZ5b4VUOWKTZY2ayGjlIoo75E_OAN6IEpHLikDehnep84pZQJXvxp-ynDJEfIq8oE4f7B9M0slLzBcbYZqU-vTnKlfTRoVVjqlR8x/file
# Resolving uc81929d6472d9f6f17b8cc48fdc.dl.dropboxusercontent.com (uc81929d6472d9f6f17b8cc48fdc.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:601b:15::a27d:80f
# Connecting to uc81929d6472d9f6f17b8cc48fdc.dl.dropboxusercontent.com (uc81929d6472d9f6f17b8cc48fdc.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BdA7uZUD4UxubOVZXVye7B53o-VrBnaEjSdGvsQ84GRpvWRgsM631Kg2YNHdElW5J-s5F9ZIqfQwPHNp-razaMn6z2R7jASMDsqF8_wxCKxzsJtpT4qUMhnaf6MpWA4DpOx00vBZyKLfOz1unzS1FIy5heQzWzrUP1W6Je5Mxd_vO62vLpEej9z7U14WZQu7esK5gVAktzLGuqZhE9M_2_NkPRTDc8qlqxxnU0O3K5cZTPQkNV03bcExlEwjHq7z8gPEMgPhiXSdFrziqYCnyRIwNOn-6xXcYxcPI_qfRqSewTzvn4jUkALtZoPjeldRpjhpIVlbvWorRSSgrkzPUglB1gfiHzF0g_XDWcbR8wAeMGtc7jXDqz1DMjEpcn4jeO8/file [following]
# --2022-01-02 09:58:13--  https://uc81929d6472d9f6f17b8cc48fdc.dl.dropboxusercontent.com/cd/0/inline2/BdA7uZUD4UxubOVZXVye7B53o-VrBnaEjSdGvsQ84GRpvWRgsM631Kg2YNHdElW5J-s5F9ZIqfQwPHNp-razaMn6z2R7jASMDsqF8_wxCKxzsJtpT4qUMhnaf6MpWA4DpOx00vBZyKLfOz1unzS1FIy5heQzWzrUP1W6Je5Mxd_vO62vLpEej9z7U14WZQu7esK5gVAktzLGuqZhE9M_2_NkPRTDc8qlqxxnU0O3K5cZTPQkNV03bcExlEwjHq7z8gPEMgPhiXSdFrziqYCnyRIwNOn-6xXcYxcPI_qfRqSewTzvn4jUkALtZoPjeldRpjhpIVlbvWorRSSgrkzPUglB1gfiHzF0g_XDWcbR8wAeMGtc7jXDqz1DMjEpcn4jeO8/file
# Reusing existing connection to uc81929d6472d9f6f17b8cc48fdc.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 34548 (34K) [application/zip]
# Saving to: ‘datafig28.zip’
#
# datafig28.zip       100%[===================>]  33.74K  --.-KB/s    in 0.02s
#
# 2022-01-02 09:58:13 (1.64 MB/s) - ‘datafig28.zip’ saved [34548/34548]

# %%
with ZipFile("datafig28.zip","r") as zip_ref:
    zip_ref.extractall()

# %%
def imageread(directory, mode=all):
  if mode == "all":
    directory = directory+'all/'
  elif mode == "train":
    directory = directory+'train/'
  elif mode == "test":
    directory = directory+'test/'
  else:
    print("ERROR, You did not select a mode; must be one of these: all, train, test")

  modelen = next(os.walk(directory))[2] #dir is your directory path as string
  modelen = len(modelen)
  print(modelen)
  picmat = np.zeros([modelen,28,28])
  i = 0

  if mode != None:
    for files in os.scandir(directory):
      #print(files.path)
      imageArray = cv2.imread(files.path, cv2.COLOR_BGR2GRAY)
      picmat[i] = imageArray
      #cv2_imshow(picmat[i])
      i+=1

  return picmat
    
all3darr = imageread('/content/datafig28/', 'all')
train3darr = imageread('/content/datafig28/', 'train')
test3darr = imageread('/content/datafig28/', 'test')
plt.imshow(all3darr[0])
# Out:
# 36
# 24
# 12

# %% [markdown]
# #Define the model (TFK-LSGAN)

# %%
# example of lsgan for mnist
from numpy import expand_dims
from numpy import zeros
from numpy import ones
from numpy.random import randn
from numpy.random import randint
import tensorflow as tf
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.initializers import RandomNormal
from matplotlib import pyplot

# define the standalone discriminator model
def define_discriminator(in_shape=(28,28,1)):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# define model
	model = Sequential()
	# downsample to 14x14
	model.add(Conv2D(64, (4,4), strides=(2,2), padding='same', kernel_initializer=init, input_shape=in_shape))
	model.add(BatchNormalization())
	model.add(LeakyReLU(alpha=0.2))
	# downsample to 7x7
	model.add(Conv2D(128, (4,4), strides=(2,2), padding='same', kernel_initializer=init))
	model.add(BatchNormalization())
	model.add(LeakyReLU(alpha=0.2))
	# classifier
	model.add(Flatten())
	model.add(Dense(1, activation='linear', kernel_initializer=init))
	# compile model with L2 loss
	model.compile(loss='mse', optimizer=Adam(learning_rate=0.001, beta_1=0.5))
	return model

# define the standalone generator model
def define_generator(latent_dim):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# define model
	model = Sequential()
	# foundation for 7x7 image
	n_nodes = 256 * 7 * 7
	model.add(Dense(n_nodes, kernel_initializer=init, input_dim=latent_dim))
	model.add(BatchNormalization())
	model.add(Activation('relu'))
	model.add(Reshape((7, 7, 256)))
	# upsample to 14x14
	model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same', kernel_initializer=init))
	model.add(BatchNormalization())
	model.add(Activation('relu'))
	# upsample to 28x28
	model.add(Conv2DTranspose(64, (4,4), strides=(2,2), padding='same', kernel_initializer=init))
	model.add(BatchNormalization())
	model.add(Activation('relu'))
	# output 28x28x1
	model.add(Conv2D(1, (7,7), padding='same', kernel_initializer=init))
	model.add(Activation('tanh'))
	return model

# define the combined generator and discriminator model, for updating the generator
def define_gan(generator, discriminator):
	# make weights in the discriminator not trainable
	for layer in discriminator.layers:
		if not isinstance(layer, BatchNormalization):
			layer.trainable = False
	# connect them
	model = Sequential()
	# add generator
	model.add(generator)
	# add the discriminator
	model.add(discriminator)
	# compile model with L2 loss
	model.compile(loss='mse', optimizer=Adam(learning_rate=0.001, beta_1=0.5))
	return model

# load our images #LOAD RAW IMAGES
def load_real_samples():
	# load dataset
	trainX = train3darr
	# expand to 3d, e.g. add channels
	X = expand_dims(trainX, axis=-1)
	# convert from ints to floats
	X = X.astype('float32')
	# scale from [0,255] to [-1,1]
	X = (X - 127.5) / 127.5
	return X

# # select real samples
def generate_real_samples(dataset, n_samples):
	# choose random instances
	ix = randint(0, dataset.shape[0], n_samples)
	# select images
	X = dataset[ix]
	# generate class labels
	y = ones((n_samples, 1))
	return X, y

# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples):
	# generate points in the latent space
	x_input = randn(latent_dim * n_samples)
	# reshape into a batch of inputs for the network
	x_input = x_input.reshape(n_samples, latent_dim)
	return x_input

# use the generator to generate n fake examples, with class labels
def generate_fake_samples(generator, latent_dim, n_samples):
	# generate points in latent space
	x_input = generate_latent_points(latent_dim, n_samples)
	# predict outputs
	X = generator.predict(x_input)
	# create class labels
	y = zeros((n_samples, 1))
	return X, y

# generate samples and save as a plot and save the model
def summarize_performance(step, g_model, latent_dim, n_samples=12):
	# prepare fake examples
	X, _ = generate_fake_samples(g_model, latent_dim, n_samples)
	# scale from [-1,1] to [0,1]
	X = (X + 1) / 2.0
	# plot images
	for i in range(3 * 4):
		# define subplot
		pyplot.subplot(3, 4, 1 + i)
		# turn off axis
		pyplot.axis('off')
		# plot raw pixel data
		pyplot.imshow(X[i, :, :, 0], cmap='gray_r')
	# save plot to file
	filename1 = 'generated_plot_%06d.png' % (step+1)
	pyplot.savefig(filename1)
	pyplot.close()
	# save the generator model
	filename2 = 'model_%06d.h5' % (step+1)
	g_model.save(filename2)
	print('Saved %s and %s' % (filename1, filename2))
  

# create a line plot of loss for the gan and save to file
def plot_history(d1_hist, d2_hist, g_hist):
	pyplot.plot(d1_hist, label='dloss1')
	pyplot.plot(d2_hist, label='dloss2')
	pyplot.plot(g_hist, label='gloss')
	pyplot.legend()
	filename = 'plot_line_plot_loss.png'
	pyplot.savefig(filename)
	pyplot.close()
	print('Saved %s' % (filename))

# train the generator and discriminator
def train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs=100, n_batch=9):
	# calculate the number of batches per training epoch
	bat_per_epo = int(dataset.shape[0] / n_batch)
	# calculate the number of training iterations
	n_steps = bat_per_epo * n_epochs
	# calculate the size of half a batch of samples
	half_batch = int(n_batch / 2)
	# lists for storing loss, for plotting later
	d1_hist, d2_hist, g_hist = list(), list(), list()
	# manually enumerate epochs
	for i in range(n_steps):
		# prepare real and fake samples
		X_real, y_real = generate_real_samples(dataset, half_batch)
		X_fake, y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
		print(X_fake.shape)
		# update discriminator model
		d_loss1 = d_model.train_on_batch(X_real, y_real)
		d_loss2 = d_model.train_on_batch(X_fake, y_fake)
		# update the generator via the discriminator's error
		z_input = generate_latent_points(latent_dim, n_batch)
		y_real2 = ones((n_batch, 1))
		g_loss = gan_model.train_on_batch(z_input, y_real2)
		# summarize loss on this batch
		print('>%d, d1=%.3f, d2=%.3f g=%.3f' % (i+1, d_loss1, d_loss2, g_loss))
		# record history
		d1_hist.append(d_loss1)
		d2_hist.append(d_loss2)
		g_hist.append(g_loss)
		# evaluate the model performance every 'epoch'
		if (i+1) % (bat_per_epo * 1) == 0:
			summarize_performance(i, g_model, latent_dim)
	# create line plot of training history
	plot_history(d1_hist, d2_hist, g_hist)

# size of the latent space
latent_dim = 100
# create the discriminator
discriminator = define_discriminator()
# create the generator
generator = define_generator(latent_dim)
# create the gan
gan_model = define_gan(generator, discriminator)
# load image data
dataset = load_real_samples()
print(dataset.shape)
# train model
train(generator, discriminator, gan_model, dataset, latent_dim)
# Out:
# (24, 28, 28, 1)
# (4, 28, 28, 1)
# >1, d1=1.192, d2=0.881 g=1.524
# (4, 28, 28, 1)
# >2, d1=306.146, d2=2.629 g=3.131
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000002.png and model_000002.h5
# (4, 28, 28, 1)
# >3, d1=2.459, d2=0.612 g=3.284
# (4, 28, 28, 1)
# >4, d1=24.423, d2=3.053 g=5.057
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000004.png and model_000004.h5
# (4, 28, 28, 1)
# >5, d1=0.877, d2=8.434 g=3.122
# (4, 28, 28, 1)
# >6, d1=1.071, d2=14.101 g=5.878
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000006.png and model_000006.h5
# (4, 28, 28, 1)
# >7, d1=0.067, d2=4.877 g=0.404
# (4, 28, 28, 1)
# >8, d1=0.076, d2=3.286 g=0.297
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000008.png and model_000008.h5
# (4, 28, 28, 1)
# >9, d1=0.054, d2=2.419 g=0.464
# (4, 28, 28, 1)
# >10, d1=0.011, d2=1.705 g=0.146
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000010.png and model_000010.h5
# (4, 28, 28, 1)
# >11, d1=0.012, d2=0.870 g=0.073
# (4, 28, 28, 1)
# >12, d1=0.009, d2=0.202 g=0.075
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000012.png and model_000012.h5
# (4, 28, 28, 1)
# >13, d1=0.114, d2=0.038 g=0.147
# (4, 28, 28, 1)
# >14, d1=0.075, d2=0.127 g=0.095
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000014.png and model_000014.h5
# (4, 28, 28, 1)
# >15, d1=0.128, d2=0.089 g=0.041
# (4, 28, 28, 1)
# >16, d1=0.014, d2=0.026 g=0.044
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000016.png and model_000016.h5
# (4, 28, 28, 1)
# >17, d1=0.156, d2=0.047 g=0.046
# (4, 28, 28, 1)
# >18, d1=0.402, d2=0.203 g=0.070
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000018.png and model_000018.h5
# (4, 28, 28, 1)
# >19, d1=0.187, d2=0.113 g=0.083
# (4, 28, 28, 1)
# >20, d1=0.015, d2=0.010 g=0.060
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000020.png and model_000020.h5
# (4, 28, 28, 1)
# >21, d1=0.009, d2=0.072 g=0.119
# (4, 28, 28, 1)
# >22, d1=0.089, d2=0.065 g=0.036
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000022.png and model_000022.h5
# (4, 28, 28, 1)
# >23, d1=0.133, d2=0.009 g=0.080
# (4, 28, 28, 1)
# >24, d1=0.160, d2=0.040 g=0.041
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000024.png and model_000024.h5
# (4, 28, 28, 1)
# >25, d1=0.089, d2=0.165 g=0.072
# (4, 28, 28, 1)
# >26, d1=0.038, d2=0.451 g=0.489
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000026.png and model_000026.h5
# (4, 28, 28, 1)
# >27, d1=0.025, d2=1.846 g=1.928
# (4, 28, 28, 1)
# >28, d1=0.081, d2=7.113 g=6.260
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000028.png and model_000028.h5
# (4, 28, 28, 1)
# >29, d1=1.067, d2=16.032 g=2.755
# (4, 28, 28, 1)
# >30, d1=4.074, d2=17.284 g=6.166
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000030.png and model_000030.h5
# (4, 28, 28, 1)
# >31, d1=7.879, d2=7.292 g=0.124
# (4, 28, 28, 1)
# >32, d1=5.635, d2=0.606 g=0.516
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000032.png and model_000032.h5
# (4, 28, 28, 1)
# >33, d1=1.760, d2=0.072 g=0.378
# (4, 28, 28, 1)
# >34, d1=0.018, d2=0.017 g=0.582
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000034.png and model_000034.h5
# (4, 28, 28, 1)
# >35, d1=0.332, d2=0.369 g=0.146
# (4, 28, 28, 1)
# >36, d1=0.231, d2=0.407 g=0.113
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000036.png and model_000036.h5
# (4, 28, 28, 1)
# >37, d1=0.052, d2=0.036 g=0.298
# (4, 28, 28, 1)
# >38, d1=0.064, d2=0.111 g=0.067
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000038.png and model_000038.h5
# (4, 28, 28, 1)
# >39, d1=0.008, d2=0.152 g=0.144
# (4, 28, 28, 1)
# >40, d1=0.192, d2=0.012 g=0.085
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000040.png and model_000040.h5
# (4, 28, 28, 1)
# >41, d1=0.229, d2=0.048 g=0.069
# (4, 28, 28, 1)
# >42, d1=0.116, d2=0.243 g=0.255
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000042.png and model_000042.h5
# (4, 28, 28, 1)
# >43, d1=0.028, d2=0.305 g=0.029
# (4, 28, 28, 1)
# >44, d1=0.011, d2=0.241 g=0.076
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000044.png and model_000044.h5
# (4, 28, 28, 1)
# >45, d1=0.086, d2=0.171 g=0.065
# (4, 28, 28, 1)
# >46, d1=0.108, d2=0.099 g=0.024
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000046.png and model_000046.h5
# (4, 28, 28, 1)
# >47, d1=0.197, d2=0.043 g=0.094
# (4, 28, 28, 1)
# >48, d1=0.341, d2=0.158 g=0.063
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000048.png and model_000048.h5
# (4, 28, 28, 1)
# >49, d1=0.253, d2=0.291 g=0.027
# (4, 28, 28, 1)
# >50, d1=0.066, d2=0.192 g=0.014
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000050.png and model_000050.h5
# (4, 28, 28, 1)
# >51, d1=0.008, d2=0.047 g=0.015
# (4, 28, 28, 1)
# >52, d1=0.155, d2=0.019 g=0.039
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000052.png and model_000052.h5
# (4, 28, 28, 1)
# >53, d1=0.226, d2=0.024 g=0.057
# (4, 28, 28, 1)
# >54, d1=0.249, d2=0.078 g=0.019
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000054.png and model_000054.h5
# (4, 28, 28, 1)
# >55, d1=0.479, d2=0.135 g=0.037
# (4, 28, 28, 1)
# >56, d1=0.441, d2=0.274 g=0.044
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000056.png and model_000056.h5
# (4, 28, 28, 1)
# >57, d1=0.272, d2=0.503 g=0.128
# (4, 28, 28, 1)
# >58, d1=0.060, d2=0.770 g=0.122
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000058.png and model_000058.h5
# (4, 28, 28, 1)
# >59, d1=0.027, d2=1.112 g=0.661
# (4, 28, 28, 1)
# >60, d1=0.327, d2=1.375 g=0.424
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000060.png and model_000060.h5
# (4, 28, 28, 1)
# >61, d1=1.051, d2=0.983 g=0.512
# (4, 28, 28, 1)
# >62, d1=1.969, d2=0.141 g=0.051
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000062.png and model_000062.h5
# (4, 28, 28, 1)
# >63, d1=1.921, d2=0.084 g=0.038
# (4, 28, 28, 1)
# >64, d1=1.531, d2=0.643 g=0.072
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000064.png and model_000064.h5
# (4, 28, 28, 1)
# >65, d1=1.009, d2=1.210 g=0.040
# (4, 28, 28, 1)
# >66, d1=0.777, d2=2.138 g=0.432
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000066.png and model_000066.h5
# (4, 28, 28, 1)
# >67, d1=0.092, d2=2.350 g=0.157
# (4, 28, 28, 1)
# >68, d1=0.187, d2=1.460 g=0.488
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000068.png and model_000068.h5
# (4, 28, 28, 1)
# >69, d1=0.841, d2=0.425 g=0.012
# (4, 28, 28, 1)
# >70, d1=1.675, d2=0.030 g=0.166
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000070.png and model_000070.h5
# (4, 28, 28, 1)
# >71, d1=1.770, d2=0.390 g=0.012
# (4, 28, 28, 1)
# >72, d1=0.933, d2=1.210 g=0.267
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000072.png and model_000072.h5
# (4, 28, 28, 1)
# >73, d1=0.274, d2=2.018 g=0.441
# (4, 28, 28, 1)
# >74, d1=0.069, d2=2.583 g=0.218
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000074.png and model_000074.h5
# (4, 28, 28, 1)
# >75, d1=0.067, d2=2.659 g=0.904
# (4, 28, 28, 1)
# >76, d1=0.383, d2=2.545 g=0.465
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000076.png and model_000076.h5
# (4, 28, 28, 1)
# >77, d1=1.402, d2=1.632 g=0.761
# (4, 28, 28, 1)
# >78, d1=2.949, d2=0.257 g=0.057
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000078.png and model_000078.h5
# (4, 28, 28, 1)
# >79, d1=2.646, d2=0.110 g=0.188
# (4, 28, 28, 1)
# >80, d1=1.377, d2=0.578 g=0.119
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000080.png and model_000080.h5
# (4, 28, 28, 1)
# >81, d1=0.203, d2=0.798 g=0.018
# (4, 28, 28, 1)
# >82, d1=0.089, d2=0.620 g=0.423
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000082.png and model_000082.h5
# (4, 28, 28, 1)
# >83, d1=0.490, d2=0.269 g=0.061
# (4, 28, 28, 1)
# >84, d1=1.066, d2=0.048 g=0.177
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000084.png and model_000084.h5
# (4, 28, 28, 1)
# >85, d1=1.000, d2=0.155 g=0.024
# (4, 28, 28, 1)
# >86, d1=0.221, d2=0.290 g=0.039
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000086.png and model_000086.h5
# (4, 28, 28, 1)
# >87, d1=0.010, d2=0.399 g=0.186
# (4, 28, 28, 1)
# >88, d1=0.093, d2=0.339 g=0.069
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000088.png and model_000088.h5
# (4, 28, 28, 1)
# >89, d1=0.214, d2=0.103 g=0.030
# (4, 28, 28, 1)
# >90, d1=0.207, d2=0.014 g=0.034
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000090.png and model_000090.h5
# (4, 28, 28, 1)
# >91, d1=0.119, d2=0.017 g=0.066
# (4, 28, 28, 1)
# >92, d1=0.055, d2=0.041 g=0.018
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000092.png and model_000092.h5
# (4, 28, 28, 1)
# >93, d1=0.007, d2=0.031 g=0.059
# (4, 28, 28, 1)
# >94, d1=0.024, d2=0.080 g=0.063
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000094.png and model_000094.h5
# (4, 28, 28, 1)
# >95, d1=0.141, d2=0.098 g=0.085
# (4, 28, 28, 1)
# >96, d1=0.243, d2=0.014 g=0.039
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000096.png and model_000096.h5
# (4, 28, 28, 1)
# >97, d1=0.365, d2=0.024 g=0.145
# (4, 28, 28, 1)
# >98, d1=0.621, d2=0.036 g=0.014
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000098.png and model_000098.h5
# (4, 28, 28, 1)
# >99, d1=1.005, d2=0.420 g=0.016
# (4, 28, 28, 1)
# >100, d1=1.002, d2=1.838 g=0.856
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000100.png and model_000100.h5
# (4, 28, 28, 1)
# >101, d1=0.157, d2=3.172 g=0.547
# (4, 28, 28, 1)
# >102, d1=0.409, d2=2.557 g=1.878
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000102.png and model_000102.h5
# (4, 28, 28, 1)
# >103, d1=2.082, d2=0.801 g=0.038
# (4, 28, 28, 1)
# >104, d1=2.738, d2=0.011 g=0.342
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000104.png and model_000104.h5
# (4, 28, 28, 1)
# >105, d1=2.990, d2=0.793 g=0.218
# (4, 28, 28, 1)
# >106, d1=1.547, d2=2.283 g=0.040
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000106.png and model_000106.h5
# (4, 28, 28, 1)
# >107, d1=0.175, d2=2.985 g=1.247
# (4, 28, 28, 1)
# >108, d1=0.272, d2=1.928 g=0.030
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000108.png and model_000108.h5
# (4, 28, 28, 1)
# >109, d1=0.978, d2=0.797 g=1.389
# (4, 28, 28, 1)
# >110, d1=1.384, d2=0.055 g=0.040
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000110.png and model_000110.h5
# (4, 28, 28, 1)
# >111, d1=1.475, d2=0.023 g=0.371
# (4, 28, 28, 1)
# >112, d1=1.202, d2=0.671 g=1.478
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000112.png and model_000112.h5
# (4, 28, 28, 1)
# >113, d1=0.208, d2=3.673 g=4.899
# (4, 28, 28, 1)
# >114, d1=0.995, d2=8.809 g=13.981
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000114.png and model_000114.h5
# (4, 28, 28, 1)
# >115, d1=9.291, d2=6.524 g=1.388
# (4, 28, 28, 1)
# >116, d1=14.583, d2=0.778 g=4.525
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000116.png and model_000116.h5
# (4, 28, 28, 1)
# >117, d1=9.731, d2=0.708 g=0.275
# (4, 28, 28, 1)
# >118, d1=0.984, d2=0.274 g=0.729
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000118.png and model_000118.h5
# (4, 28, 28, 1)
# >119, d1=0.026, d2=0.088 g=0.384
# (4, 28, 28, 1)
# >120, d1=0.012, d2=0.006 g=0.240
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000120.png and model_000120.h5
# (4, 28, 28, 1)
# >121, d1=0.036, d2=0.004 g=0.052
# (4, 28, 28, 1)
# >122, d1=0.058, d2=0.003 g=0.178
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000122.png and model_000122.h5
# (4, 28, 28, 1)
# >123, d1=0.067, d2=0.027 g=0.116
# (4, 28, 28, 1)
# >124, d1=0.103, d2=0.082 g=0.116
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000124.png and model_000124.h5
# (4, 28, 28, 1)
# >125, d1=0.095, d2=0.114 g=0.050
# (4, 28, 28, 1)
# >126, d1=0.043, d2=0.180 g=0.009
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000126.png and model_000126.h5
# (4, 28, 28, 1)
# >127, d1=0.001, d2=0.140 g=0.069
# (4, 28, 28, 1)
# >128, d1=0.022, d2=0.031 g=0.024
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000128.png and model_000128.h5
# (4, 28, 28, 1)
# >129, d1=0.014, d2=0.034 g=0.052
# (4, 28, 28, 1)
# >130, d1=0.012, d2=0.031 g=0.019
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000130.png and model_000130.h5
# (4, 28, 28, 1)
# >131, d1=0.042, d2=0.006 g=0.022
# (4, 28, 28, 1)
# >132, d1=0.013, d2=0.007 g=0.011
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000132.png and model_000132.h5
# (4, 28, 28, 1)
# >133, d1=0.010, d2=0.023 g=0.074
# (4, 28, 28, 1)
# >134, d1=0.059, d2=0.002 g=0.013
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000134.png and model_000134.h5
# (4, 28, 28, 1)
# >135, d1=0.154, d2=0.073 g=0.015
# (4, 28, 28, 1)
# >136, d1=0.051, d2=0.177 g=0.088
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000136.png and model_000136.h5
# (4, 28, 28, 1)
# >137, d1=0.020, d2=0.088 g=0.005
# (4, 28, 28, 1)
# >138, d1=0.129, d2=0.011 g=0.127
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000138.png and model_000138.h5
# (4, 28, 28, 1)
# >139, d1=0.061, d2=0.007 g=0.056
# (4, 28, 28, 1)
# >140, d1=0.004, d2=0.006 g=0.060
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000140.png and model_000140.h5
# (4, 28, 28, 1)
# >141, d1=0.013, d2=0.008 g=0.041
# (4, 28, 28, 1)
# >142, d1=0.020, d2=0.004 g=0.069
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000142.png and model_000142.h5
# (4, 28, 28, 1)
# >143, d1=0.012, d2=0.003 g=0.057
# (4, 28, 28, 1)
# >144, d1=0.024, d2=0.020 g=0.027
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000144.png and model_000144.h5
# (4, 28, 28, 1)
# >145, d1=0.047, d2=0.189 g=0.265
# (4, 28, 28, 1)
# >146, d1=0.010, d2=0.221 g=0.006
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000146.png and model_000146.h5
# (4, 28, 28, 1)
# >147, d1=0.111, d2=0.125 g=0.245
# (4, 28, 28, 1)
# >148, d1=0.092, d2=0.041 g=0.014
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000148.png and model_000148.h5
# (4, 28, 28, 1)
# >149, d1=0.053, d2=0.016 g=0.121
# (4, 28, 28, 1)
# >150, d1=0.057, d2=0.008 g=0.068
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000150.png and model_000150.h5
# (4, 28, 28, 1)
# >151, d1=0.027, d2=0.028 g=0.033
# (4, 28, 28, 1)
# >152, d1=0.010, d2=0.041 g=0.222
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000152.png and model_000152.h5
# (4, 28, 28, 1)
# >153, d1=0.057, d2=0.037 g=0.004
# (4, 28, 28, 1)
# >154, d1=0.160, d2=0.002 g=0.124
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000154.png and model_000154.h5
# (4, 28, 28, 1)
# >155, d1=0.082, d2=0.010 g=0.033
# (4, 28, 28, 1)
# >156, d1=0.015, d2=0.002 g=0.046
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000156.png and model_000156.h5
# (4, 28, 28, 1)
# >157, d1=0.027, d2=0.014 g=0.041
# (4, 28, 28, 1)
# >158, d1=0.010, d2=0.024 g=0.060
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000158.png and model_000158.h5
# (4, 28, 28, 1)
# >159, d1=0.010, d2=0.041 g=0.001
# (4, 28, 28, 1)
# >160, d1=0.015, d2=0.039 g=0.097
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000160.png and model_000160.h5
# (4, 28, 28, 1)
# >161, d1=0.045, d2=0.018 g=0.001
# (4, 28, 28, 1)
# >162, d1=0.029, d2=0.048 g=0.246
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000162.png and model_000162.h5
# (4, 28, 28, 1)
# >163, d1=0.068, d2=0.088 g=0.050
# (4, 28, 28, 1)
# >164, d1=0.263, d2=0.035 g=0.212
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000164.png and model_000164.h5
# (4, 28, 28, 1)
# >165, d1=0.424, d2=0.006 g=0.008
# (4, 28, 28, 1)
# >166, d1=0.275, d2=0.118 g=0.024
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000166.png and model_000166.h5
# (4, 28, 28, 1)
# >167, d1=0.015, d2=0.573 g=1.367
# (4, 28, 28, 1)
# >168, d1=0.526, d2=0.706 g=0.487
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000168.png and model_000168.h5
# (4, 28, 28, 1)
# >169, d1=1.959, d2=0.203 g=1.441
# (4, 28, 28, 1)
# >170, d1=1.862, d2=0.002 g=0.009
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000170.png and model_000170.h5
# (4, 28, 28, 1)
# >171, d1=0.643, d2=0.066 g=0.093
# (4, 28, 28, 1)
# >172, d1=0.046, d2=0.050 g=0.124
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000172.png and model_000172.h5
# (4, 28, 28, 1)
# >173, d1=0.030, d2=0.001 g=0.117
# (4, 28, 28, 1)
# >174, d1=0.018, d2=0.025 g=0.006
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000174.png and model_000174.h5
# (4, 28, 28, 1)
# >175, d1=0.008, d2=0.175 g=0.931
# (4, 28, 28, 1)
# >176, d1=0.071, d2=0.556 g=0.361
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000176.png and model_000176.h5
# (4, 28, 28, 1)
# >177, d1=0.577, d2=0.725 g=2.134
# (4, 28, 28, 1)
# >178, d1=1.504, d2=0.378 g=0.429
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000178.png and model_000178.h5
# (4, 28, 28, 1)
# >179, d1=1.697, d2=0.405 g=2.927
# (4, 28, 28, 1)
# >180, d1=2.156, d2=0.353 g=0.288
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000180.png and model_000180.h5
# (4, 28, 28, 1)
# >181, d1=2.553, d2=0.046 g=1.417
# (4, 28, 28, 1)
# >182, d1=1.628, d2=0.066 g=0.203
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000182.png and model_000182.h5
# (4, 28, 28, 1)
# >183, d1=0.305, d2=0.162 g=0.154
# (4, 28, 28, 1)
# >184, d1=0.008, d2=0.196 g=0.975
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000184.png and model_000184.h5
# (4, 28, 28, 1)
# >185, d1=0.239, d2=0.109 g=0.027
# (4, 28, 28, 1)
# >186, d1=0.332, d2=0.070 g=0.993
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000186.png and model_000186.h5
# (4, 28, 28, 1)
# >187, d1=0.203, d2=0.057 g=0.036
# (4, 28, 28, 1)
# >188, d1=0.167, d2=0.099 g=0.873
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000188.png and model_000188.h5
# (4, 28, 28, 1)
# >189, d1=0.253, d2=0.094 g=0.005
# (4, 28, 28, 1)
# >190, d1=0.360, d2=0.154 g=1.389
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000190.png and model_000190.h5
# (4, 28, 28, 1)
# >191, d1=0.579, d2=0.086 g=0.011
# (4, 28, 28, 1)
# >192, d1=0.565, d2=0.050 g=0.926
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000192.png and model_000192.h5
# (4, 28, 28, 1)
# >193, d1=0.324, d2=0.005 g=0.134
# (4, 28, 28, 1)
# >194, d1=0.053, d2=0.020 g=0.507
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000194.png and model_000194.h5
# (4, 28, 28, 1)
# >195, d1=0.010, d2=0.074 g=0.147
# (4, 28, 28, 1)
# >196, d1=0.028, d2=0.388 g=1.549
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000196.png and model_000196.h5
# (4, 28, 28, 1)
# >197, d1=0.059, d2=0.894 g=0.116
# (4, 28, 28, 1)
# >198, d1=0.711, d2=0.745 g=2.275
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000198.png and model_000198.h5
# (4, 28, 28, 1)
# >199, d1=1.419, d2=0.179 g=0.010
# (4, 28, 28, 1)
# >200, d1=1.179, d2=0.013 g=1.211
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000200.png and model_000200.h5
# Saved plot_line_plot_loss.png

# %% [markdown]
# Calculate train metrics

# %%
gt, _ = generate_real_samples(dataset, 6)
pred, _= generate_fake_samples(generator, latent_dim, 6)

# %%
pred = pred.reshape(6,28,28)
fig, axs = plt.subplots(2, 3)
axs[0, 0].imshow(pred[0], cmap='gray')
axs[0, 1].imshow(pred[1], cmap='gray')
axs[0, 2].imshow(pred[2], cmap='gray')
axs[1, 0].imshow(pred[3], cmap='gray')
axs[1, 1].imshow(pred[4], cmap='gray')
axs[1, 2].imshow(pred[5], cmap='gray')

# %%
gt = gt.reshape(6,784)
pred = pred.reshape(6,784)

# %%
from sklearn import metrics
from math import sqrt

mae = metrics.mean_absolute_error(gt, pred)
mse = metrics.mean_squared_error(gt, pred)
mape = metrics.mean_absolute_percentage_error(gt, pred)
rmse = sqrt(mse)

print('MSE=', mse, '...RMSE=', rmse, '...MAE=', mae, '...MAPE=', mape)
# Out:
# MSE= 0.1126827 ...RMSE= 0.33568243945307225 ...MAE= 0.18267849 ...MAPE= 0.57419306

# %% [markdown]
# Calculate test metrics

# %%
def load_test_samples():
	# load dataset
	testX = test3darr
	# expand to 3d, e.g. add channels
	X = expand_dims(testX, axis=-1)
	# convert from ints to floats
	X = X.astype('float32')
	# scale from [0,255] to [-1,1]
	X = (X - 127.5) / 127.5
	return X

# %%
testd = load_test_samples()
print(testd.shape)
# Out:
# (12, 28, 28, 1)

# %%
gt, _ = generate_real_samples(testd, 6)
pred, _= generate_fake_samples(generator, latent_dim, 6)

# %%
pred = pred.reshape(6,28,28)
fig, axs = plt.subplots(2, 3)
axs[0, 0].imshow(pred[0], cmap='gray')
axs[0, 1].imshow(pred[1], cmap='gray')
axs[0, 2].imshow(pred[2], cmap='gray')
axs[1, 0].imshow(pred[3], cmap='gray')
axs[1, 1].imshow(pred[4], cmap='gray')
axs[1, 2].imshow(pred[5], cmap='gray')

# %%
gt = gt.reshape(6,784)
pred = pred.reshape(6,784)

# %%
from sklearn import metrics
from math import sqrt

mae = metrics.mean_absolute_error(gt, pred)
mse = metrics.mean_squared_error(gt, pred)
mape = metrics.mean_absolute_percentage_error(gt, pred)
rmse = sqrt(mse)

print('MSE=', mse, '...RMSE=', rmse, '...MAE=', mae, '...MAPE=', mape)
# Out:
# MSE= 0.10933066 ...RMSE= 0.3306518737204852 ...MAE= 0.18496665 ...MAPE= 0.5471558
