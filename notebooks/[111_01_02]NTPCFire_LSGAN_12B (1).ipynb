# %% [markdown]
# #Read the data

# %%
from zipfile import ZipFile
import os, glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from google.colab.patches import cv2_imshow

# %%
# !wget https://www.dropbox.com/s/gtvw3nqbderxigb/datafig28.zip
# Out:
# --2022-01-02 10:01:32--  https://www.dropbox.com/s/gtvw3nqbderxigb/datafig28.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/gtvw3nqbderxigb/datafig28.zip [following]
# --2022-01-02 10:01:32--  https://www.dropbox.com/s/raw/gtvw3nqbderxigb/datafig28.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucf547be2f6fdcf9c9880002e275.dl.dropboxusercontent.com/cd/0/inline/BdAdsRnvm67_dEg8hIZP6K9dNft8WmhFGjkrOLUP-hXrHqvIrNjx_HWIFRXrI_2b-QnNI1PZbEsueYl7jNKCjufp-fpmVba7gqoZonMF8m7cUBisadTko7xTJ-a3CFwa3wNC6KtF3gt-q6VrsRV-nnsO/file# [following]
# --2022-01-02 10:01:33--  https://ucf547be2f6fdcf9c9880002e275.dl.dropboxusercontent.com/cd/0/inline/BdAdsRnvm67_dEg8hIZP6K9dNft8WmhFGjkrOLUP-hXrHqvIrNjx_HWIFRXrI_2b-QnNI1PZbEsueYl7jNKCjufp-fpmVba7gqoZonMF8m7cUBisadTko7xTJ-a3CFwa3wNC6KtF3gt-q6VrsRV-nnsO/file
# Resolving ucf547be2f6fdcf9c9880002e275.dl.dropboxusercontent.com (ucf547be2f6fdcf9c9880002e275.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6018:15::a27d:30f
# Connecting to ucf547be2f6fdcf9c9880002e275.dl.dropboxusercontent.com (ucf547be2f6fdcf9c9880002e275.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BdB2z_LXasATKGxlQMZC4yvA9CtTAiM1AS-LgZkhAcK0ot4O2vL2q2c75Kmbc3G1nOVJ93j8ZRJqYz70eUUSanljdSowDmRT3R2zZndw5LTInOSs3ouqtk2KeGEWBueQvwVZG08LFSSG7aZa_1aSCbMo11emeozR4HXKbhjzEGr4iOwWDnpY-DpazHlbtLzyCeSehE2lDJoDL4wn86XEhmW7n2sYTiu-N5SSekOhoIdVjq7kGcR7G4JB10qo8LTEj5Etfdi_nb_uPgXKtm6S9HrAUeUpIadVtQsmeFQByMBrsmqY2e_t7DrFbK-OGrb2gRaVynhgnUuCEzhD1dRcMgGwK2VTJ0zWLLLRmSjoYOTpTvssFc6rmGiE2JvwFlBrr2U/file [following]
# --2022-01-02 10:01:33--  https://ucf547be2f6fdcf9c9880002e275.dl.dropboxusercontent.com/cd/0/inline2/BdB2z_LXasATKGxlQMZC4yvA9CtTAiM1AS-LgZkhAcK0ot4O2vL2q2c75Kmbc3G1nOVJ93j8ZRJqYz70eUUSanljdSowDmRT3R2zZndw5LTInOSs3ouqtk2KeGEWBueQvwVZG08LFSSG7aZa_1aSCbMo11emeozR4HXKbhjzEGr4iOwWDnpY-DpazHlbtLzyCeSehE2lDJoDL4wn86XEhmW7n2sYTiu-N5SSekOhoIdVjq7kGcR7G4JB10qo8LTEj5Etfdi_nb_uPgXKtm6S9HrAUeUpIadVtQsmeFQByMBrsmqY2e_t7DrFbK-OGrb2gRaVynhgnUuCEzhD1dRcMgGwK2VTJ0zWLLLRmSjoYOTpTvssFc6rmGiE2JvwFlBrr2U/file
# Reusing existing connection to ucf547be2f6fdcf9c9880002e275.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 34548 (34K) [application/zip]
# Saving to: ‘datafig28.zip’
#
# datafig28.zip       100%[===================>]  33.74K  --.-KB/s    in 0.02s
#
# 2022-01-02 10:01:33 (1.39 MB/s) - ‘datafig28.zip’ saved [34548/34548]

# %%
with ZipFile("datafig28.zip","r") as zip_ref:
    zip_ref.extractall()

# %%
def imageread(directory, mode=all):
  if mode == "all":
    directory = directory+'all/'
  elif mode == "train":
    directory = directory+'train/'
  elif mode == "test":
    directory = directory+'test/'
  else:
    print("ERROR, You did not select a mode; must be one of these: all, train, test")

  modelen = next(os.walk(directory))[2] #dir is your directory path as string
  modelen = len(modelen)
  print(modelen)
  picmat = np.zeros([modelen,28,28])
  i = 0

  if mode != None:
    for files in os.scandir(directory):
      #print(files.path)
      imageArray = cv2.imread(files.path, cv2.COLOR_BGR2GRAY)
      picmat[i] = imageArray
      #cv2_imshow(picmat[i])
      i+=1

  return picmat
    
all3darr = imageread('/content/datafig28/', 'all')
train3darr = imageread('/content/datafig28/', 'train')
test3darr = imageread('/content/datafig28/', 'test')
plt.imshow(all3darr[0])
# Out:
# 36
# 24
# 12

# %% [markdown]
# #Define the model (TFK-LSGAN)

# %%
# example of lsgan for mnist
from numpy import expand_dims
from numpy import zeros
from numpy import ones
from numpy.random import randn
from numpy.random import randint
import tensorflow as tf
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.initializers import RandomNormal
from matplotlib import pyplot

# define the standalone discriminator model
def define_discriminator(in_shape=(28,28,1)):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# define model
	model = Sequential()
	# downsample to 14x14
	model.add(Conv2D(64, (4,4), strides=(2,2), padding='same', kernel_initializer=init, input_shape=in_shape))
	model.add(BatchNormalization())
	model.add(LeakyReLU(alpha=0.2))
	# downsample to 7x7
	model.add(Conv2D(128, (4,4), strides=(2,2), padding='same', kernel_initializer=init))
	model.add(BatchNormalization())
	model.add(LeakyReLU(alpha=0.2))
	# classifier
	model.add(Flatten())
	model.add(Dense(1, activation='linear', kernel_initializer=init))
	# compile model with L2 loss
	model.compile(loss='mse', optimizer=Adam(learning_rate=0.001, beta_1=0.5))
	return model

# define the standalone generator model
def define_generator(latent_dim):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# define model
	model = Sequential()
	# foundation for 7x7 image
	n_nodes = 256 * 7 * 7
	model.add(Dense(n_nodes, kernel_initializer=init, input_dim=latent_dim))
	model.add(BatchNormalization())
	model.add(Activation('relu'))
	model.add(Reshape((7, 7, 256)))
	# upsample to 14x14
	model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same', kernel_initializer=init))
	model.add(BatchNormalization())
	model.add(Activation('relu'))
	# upsample to 28x28
	model.add(Conv2DTranspose(64, (4,4), strides=(2,2), padding='same', kernel_initializer=init))
	model.add(BatchNormalization())
	model.add(Activation('relu'))
	# output 28x28x1
	model.add(Conv2D(1, (7,7), padding='same', kernel_initializer=init))
	model.add(Activation('tanh'))
	return model

# define the combined generator and discriminator model, for updating the generator
def define_gan(generator, discriminator):
	# make weights in the discriminator not trainable
	for layer in discriminator.layers:
		if not isinstance(layer, BatchNormalization):
			layer.trainable = False
	# connect them
	model = Sequential()
	# add generator
	model.add(generator)
	# add the discriminator
	model.add(discriminator)
	# compile model with L2 loss
	model.compile(loss='mse', optimizer=Adam(learning_rate=0.001, beta_1=0.5))
	return model

# load our images #LOAD RAW IMAGES
def load_real_samples():
	# load dataset
	trainX = train3darr
	# expand to 3d, e.g. add channels
	X = expand_dims(trainX, axis=-1)
	# convert from ints to floats
	X = X.astype('float32')
	# scale from [0,255] to [-1,1]
	X = (X - 127.5) / 127.5
	return X

# # select real samples
def generate_real_samples(dataset, n_samples):
	# choose random instances
	ix = randint(0, dataset.shape[0], n_samples)
	# select images
	X = dataset[ix]
	# generate class labels
	y = ones((n_samples, 1))
	return X, y

# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples):
	# generate points in the latent space
	x_input = randn(latent_dim * n_samples)
	# reshape into a batch of inputs for the network
	x_input = x_input.reshape(n_samples, latent_dim)
	return x_input

# use the generator to generate n fake examples, with class labels
def generate_fake_samples(generator, latent_dim, n_samples):
	# generate points in latent space
	x_input = generate_latent_points(latent_dim, n_samples)
	# predict outputs
	X = generator.predict(x_input)
	# create class labels
	y = zeros((n_samples, 1))
	return X, y

# generate samples and save as a plot and save the model
def summarize_performance(step, g_model, latent_dim, n_samples=12):
	# prepare fake examples
	X, _ = generate_fake_samples(g_model, latent_dim, n_samples)
	# scale from [-1,1] to [0,1]
	X = (X + 1) / 2.0
	# plot images
	for i in range(3 * 4):
		# define subplot
		pyplot.subplot(3, 4, 1 + i)
		# turn off axis
		pyplot.axis('off')
		# plot raw pixel data
		pyplot.imshow(X[i, :, :, 0], cmap='gray_r')
	# save plot to file
	filename1 = 'generated_plot_%06d.png' % (step+1)
	pyplot.savefig(filename1)
	pyplot.close()
	# save the generator model
	filename2 = 'model_%06d.h5' % (step+1)
	g_model.save(filename2)
	print('Saved %s and %s' % (filename1, filename2))
  

# create a line plot of loss for the gan and save to file
def plot_history(d1_hist, d2_hist, g_hist):
	pyplot.plot(d1_hist, label='dloss1')
	pyplot.plot(d2_hist, label='dloss2')
	pyplot.plot(g_hist, label='gloss')
	pyplot.legend()
	filename = 'plot_line_plot_loss.png'
	pyplot.savefig(filename)
	pyplot.close()
	print('Saved %s' % (filename))

# train the generator and discriminator
def train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs=100, n_batch=12):
	# calculate the number of batches per training epoch
	bat_per_epo = int(dataset.shape[0] / n_batch)
	# calculate the number of training iterations
	n_steps = bat_per_epo * n_epochs
	# calculate the size of half a batch of samples
	half_batch = int(n_batch / 2)
	# lists for storing loss, for plotting later
	d1_hist, d2_hist, g_hist = list(), list(), list()
	# manually enumerate epochs
	for i in range(n_steps):
		# prepare real and fake samples
		X_real, y_real = generate_real_samples(dataset, half_batch)
		X_fake, y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
		print(X_fake.shape)
		# update discriminator model
		d_loss1 = d_model.train_on_batch(X_real, y_real)
		d_loss2 = d_model.train_on_batch(X_fake, y_fake)
		# update the generator via the discriminator's error
		z_input = generate_latent_points(latent_dim, n_batch)
		y_real2 = ones((n_batch, 1))
		g_loss = gan_model.train_on_batch(z_input, y_real2)
		# summarize loss on this batch
		print('>%d, d1=%.3f, d2=%.3f g=%.3f' % (i+1, d_loss1, d_loss2, g_loss))
		# record history
		d1_hist.append(d_loss1)
		d2_hist.append(d_loss2)
		g_hist.append(g_loss)
		# evaluate the model performance every 'epoch'
		if (i+1) % (bat_per_epo * 1) == 0:
			summarize_performance(i, g_model, latent_dim)
	# create line plot of training history
	plot_history(d1_hist, d2_hist, g_hist)

# size of the latent space
latent_dim = 100
# create the discriminator
discriminator = define_discriminator()
# create the generator
generator = define_generator(latent_dim)
# create the gan
gan_model = define_gan(generator, discriminator)
# load image data
dataset = load_real_samples()
print(dataset.shape)
# train model
train(generator, discriminator, gan_model, dataset, latent_dim)
# Out:
# (24, 28, 28, 1)
# (6, 28, 28, 1)
# >1, d1=3.339, d2=0.262 g=1.734
# (6, 28, 28, 1)
# >2, d1=319.623, d2=4.500 g=0.961
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000002.png and model_000002.h5
# (6, 28, 28, 1)
# >3, d1=1.095, d2=1.329 g=1.198
# (6, 28, 28, 1)
# >4, d1=20.059, d2=3.230 g=0.424
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000004.png and model_000004.h5
# (6, 28, 28, 1)
# >5, d1=0.308, d2=1.967 g=0.664
# (6, 28, 28, 1)
# >6, d1=1.284, d2=2.915 g=6.241
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000006.png and model_000006.h5
# (6, 28, 28, 1)
# >7, d1=0.357, d2=11.626 g=1.261
# (6, 28, 28, 1)
# >8, d1=0.448, d2=25.551 g=1.898
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000008.png and model_000008.h5
# (6, 28, 28, 1)
# >9, d1=0.751, d2=12.507 g=0.439
# (6, 28, 28, 1)
# >10, d1=0.227, d2=1.668 g=0.050
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000010.png and model_000010.h5
# (6, 28, 28, 1)
# >11, d1=0.081, d2=0.142 g=1.034
# (6, 28, 28, 1)
# >12, d1=0.223, d2=0.315 g=0.368
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000012.png and model_000012.h5
# (6, 28, 28, 1)
# >13, d1=0.029, d2=0.074 g=0.210
# (6, 28, 28, 1)
# >14, d1=0.032, d2=0.077 g=0.240
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000014.png and model_000014.h5
# (6, 28, 28, 1)
# >15, d1=0.016, d2=0.051 g=0.084
# (6, 28, 28, 1)
# >16, d1=0.080, d2=0.191 g=0.062
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000016.png and model_000016.h5
# (6, 28, 28, 1)
# >17, d1=0.149, d2=0.074 g=0.207
# (6, 28, 28, 1)
# >18, d1=0.234, d2=0.064 g=0.072
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000018.png and model_000018.h5
# (6, 28, 28, 1)
# >19, d1=0.075, d2=0.172 g=0.021
# (6, 28, 28, 1)
# >20, d1=0.011, d2=0.131 g=0.124
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000020.png and model_000020.h5
# (6, 28, 28, 1)
# >21, d1=0.049, d2=0.115 g=0.005
# (6, 28, 28, 1)
# >22, d1=0.041, d2=0.176 g=0.096
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000022.png and model_000022.h5
# (6, 28, 28, 1)
# >23, d1=0.037, d2=0.349 g=0.065
# (6, 28, 28, 1)
# >24, d1=0.034, d2=0.706 g=0.172
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000024.png and model_000024.h5
# (6, 28, 28, 1)
# >25, d1=0.070, d2=0.891 g=0.099
# (6, 28, 28, 1)
# >26, d1=0.159, d2=0.949 g=0.222
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000026.png and model_000026.h5
# (6, 28, 28, 1)
# >27, d1=0.350, d2=0.543 g=0.021
# (6, 28, 28, 1)
# >28, d1=0.382, d2=0.313 g=0.173
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000028.png and model_000028.h5
# (6, 28, 28, 1)
# >29, d1=0.269, d2=0.204 g=0.015
# (6, 28, 28, 1)
# >30, d1=0.146, d2=0.177 g=0.040
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000030.png and model_000030.h5
# (6, 28, 28, 1)
# >31, d1=0.040, d2=0.135 g=0.046
# (6, 28, 28, 1)
# >32, d1=0.253, d2=0.112 g=0.032
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000032.png and model_000032.h5
# (6, 28, 28, 1)
# >33, d1=0.447, d2=0.106 g=0.130
# (6, 28, 28, 1)
# >34, d1=0.669, d2=0.116 g=0.004
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000034.png and model_000034.h5
# (6, 28, 28, 1)
# >35, d1=0.949, d2=0.210 g=0.044
# (6, 28, 28, 1)
# >36, d1=0.908, d2=0.783 g=0.115
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000036.png and model_000036.h5
# (6, 28, 28, 1)
# >37, d1=0.865, d2=2.771 g=0.615
# (6, 28, 28, 1)
# >38, d1=0.345, d2=5.936 g=0.947
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000038.png and model_000038.h5
# (6, 28, 28, 1)
# >39, d1=0.019, d2=6.709 g=0.403
# (6, 28, 28, 1)
# >40, d1=1.152, d2=4.278 g=0.904
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000040.png and model_000040.h5
# (6, 28, 28, 1)
# >41, d1=3.639, d2=0.840 g=0.104
# (6, 28, 28, 1)
# >42, d1=6.309, d2=0.138 g=0.284
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000042.png and model_000042.h5
# (6, 28, 28, 1)
# >43, d1=5.286, d2=1.322 g=0.001
# (6, 28, 28, 1)
# >44, d1=3.469, d2=1.971 g=0.189
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000044.png and model_000044.h5
# (6, 28, 28, 1)
# >45, d1=1.138, d2=1.476 g=0.053
# (6, 28, 28, 1)
# >46, d1=0.248, d2=0.627 g=0.091
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000046.png and model_000046.h5
# (6, 28, 28, 1)
# >47, d1=0.044, d2=0.171 g=0.032
# (6, 28, 28, 1)
# >48, d1=0.011, d2=0.089 g=0.030
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000048.png and model_000048.h5
# (6, 28, 28, 1)
# >49, d1=0.017, d2=0.085 g=0.067
# (6, 28, 28, 1)
# >50, d1=0.017, d2=0.063 g=0.026
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000050.png and model_000050.h5
# (6, 28, 28, 1)
# >51, d1=0.009, d2=0.111 g=0.125
# (6, 28, 28, 1)
# >52, d1=0.010, d2=0.175 g=0.002
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000052.png and model_000052.h5
# (6, 28, 28, 1)
# >53, d1=0.021, d2=0.164 g=0.052
# (6, 28, 28, 1)
# >54, d1=0.064, d2=0.059 g=0.024
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000054.png and model_000054.h5
# (6, 28, 28, 1)
# >55, d1=0.052, d2=0.006 g=0.017
# (6, 28, 28, 1)
# >56, d1=0.023, d2=0.026 g=0.016
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000056.png and model_000056.h5
# (6, 28, 28, 1)
# >57, d1=0.003, d2=0.041 g=0.025
# (6, 28, 28, 1)
# >58, d1=0.044, d2=0.049 g=0.025
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000058.png and model_000058.h5
# (6, 28, 28, 1)
# >59, d1=0.054, d2=0.021 g=0.025
# (6, 28, 28, 1)
# >60, d1=0.074, d2=0.017 g=0.047
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000060.png and model_000060.h5
# (6, 28, 28, 1)
# >61, d1=0.154, d2=0.002 g=0.044
# (6, 28, 28, 1)
# >62, d1=0.276, d2=0.035 g=0.013
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000062.png and model_000062.h5
# (6, 28, 28, 1)
# >63, d1=0.282, d2=0.162 g=0.016
# (6, 28, 28, 1)
# >64, d1=0.145, d2=0.183 g=0.013
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000064.png and model_000064.h5
# (6, 28, 28, 1)
# >65, d1=0.045, d2=0.147 g=0.015
# (6, 28, 28, 1)
# >66, d1=0.023, d2=0.151 g=0.035
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000066.png and model_000066.h5
# (6, 28, 28, 1)
# >67, d1=0.017, d2=0.169 g=0.149
# (6, 28, 28, 1)
# >68, d1=0.146, d2=0.182 g=0.123
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000068.png and model_000068.h5
# (6, 28, 28, 1)
# >69, d1=0.372, d2=0.079 g=0.169
# (6, 28, 28, 1)
# >70, d1=0.678, d2=0.007 g=0.029
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000070.png and model_000070.h5
# (6, 28, 28, 1)
# >71, d1=1.009, d2=0.097 g=0.139
# (6, 28, 28, 1)
# >72, d1=1.179, d2=0.640 g=0.080
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000072.png and model_000072.h5
# (6, 28, 28, 1)
# >73, d1=1.069, d2=1.677 g=0.062
# (6, 28, 28, 1)
# >74, d1=0.466, d2=3.452 g=1.033
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000074.png and model_000074.h5
# (6, 28, 28, 1)
# >75, d1=0.013, d2=4.318 g=0.616
# (6, 28, 28, 1)
# >76, d1=1.262, d2=2.500 g=1.254
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000076.png and model_000076.h5
# (6, 28, 28, 1)
# >77, d1=4.267, d2=0.325 g=0.245
# (6, 28, 28, 1)
# >78, d1=7.591, d2=0.497 g=0.216
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000078.png and model_000078.h5
# (6, 28, 28, 1)
# >79, d1=6.252, d2=3.420 g=0.103
# (6, 28, 28, 1)
# >80, d1=2.688, d2=5.108 g=0.012
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000080.png and model_000080.h5
# (6, 28, 28, 1)
# >81, d1=0.163, d2=3.579 g=0.318
# (6, 28, 28, 1)
# >82, d1=0.522, d2=1.008 g=0.008
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000082.png and model_000082.h5
# (6, 28, 28, 1)
# >83, d1=0.891, d2=0.054 g=0.091
# (6, 28, 28, 1)
# >84, d1=0.541, d2=0.090 g=0.065
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000084.png and model_000084.h5
# (6, 28, 28, 1)
# >85, d1=0.157, d2=0.179 g=0.034
# (6, 28, 28, 1)
# >86, d1=0.022, d2=0.049 g=0.025
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000086.png and model_000086.h5
# (6, 28, 28, 1)
# >87, d1=0.148, d2=0.047 g=0.037
# (6, 28, 28, 1)
# >88, d1=0.153, d2=0.130 g=0.030
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000088.png and model_000088.h5
# (6, 28, 28, 1)
# >89, d1=0.033, d2=0.122 g=0.172
# (6, 28, 28, 1)
# >90, d1=0.142, d2=0.050 g=0.005
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000090.png and model_000090.h5
# (6, 28, 28, 1)
# >91, d1=0.308, d2=0.008 g=0.060
# (6, 28, 28, 1)
# >92, d1=0.104, d2=0.025 g=0.023
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000092.png and model_000092.h5
# (6, 28, 28, 1)
# >93, d1=0.022, d2=0.015 g=0.004
# (6, 28, 28, 1)
# >94, d1=0.062, d2=0.008 g=0.025
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000094.png and model_000094.h5
# (6, 28, 28, 1)
# >95, d1=0.030, d2=0.042 g=0.059
# (6, 28, 28, 1)
# >96, d1=0.009, d2=0.068 g=0.020
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000096.png and model_000096.h5
# (6, 28, 28, 1)
# >97, d1=0.027, d2=0.103 g=0.082
# (6, 28, 28, 1)
# >98, d1=0.012, d2=0.142 g=0.044
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000098.png and model_000098.h5
# (6, 28, 28, 1)
# >99, d1=0.059, d2=0.102 g=0.068
# (6, 28, 28, 1)
# >100, d1=0.181, d2=0.018 g=0.012
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000100.png and model_000100.h5
# (6, 28, 28, 1)
# >101, d1=0.432, d2=0.077 g=0.008
# (6, 28, 28, 1)
# >102, d1=0.567, d2=0.413 g=0.028
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000102.png and model_000102.h5
# (6, 28, 28, 1)
# >103, d1=0.549, d2=1.083 g=0.160
# (6, 28, 28, 1)
# >104, d1=0.207, d2=1.638 g=0.444
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000104.png and model_000104.h5
# (6, 28, 28, 1)
# >105, d1=0.006, d2=1.800 g=0.096
# (6, 28, 28, 1)
# >106, d1=0.177, d2=1.275 g=0.384
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000106.png and model_000106.h5
# (6, 28, 28, 1)
# >107, d1=0.637, d2=0.373 g=0.043
# (6, 28, 28, 1)
# >108, d1=0.955, d2=0.010 g=0.073
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000108.png and model_000108.h5
# (6, 28, 28, 1)
# >109, d1=0.816, d2=0.268 g=0.022
# (6, 28, 28, 1)
# >110, d1=0.503, d2=0.704 g=0.030
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000110.png and model_000110.h5
# (6, 28, 28, 1)
# >111, d1=0.063, d2=0.932 g=0.236
# (6, 28, 28, 1)
# >112, d1=0.084, d2=0.531 g=0.031
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000112.png and model_000112.h5
# (6, 28, 28, 1)
# >113, d1=0.354, d2=0.229 g=0.277
# (6, 28, 28, 1)
# >114, d1=0.748, d2=0.030 g=0.032
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000114.png and model_000114.h5
# (6, 28, 28, 1)
# >115, d1=1.099, d2=0.091 g=0.096
# (6, 28, 28, 1)
# >116, d1=0.877, d2=0.413 g=0.054
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000116.png and model_000116.h5
# (6, 28, 28, 1)
# >117, d1=0.528, d2=0.826 g=0.013
# (6, 28, 28, 1)
# >118, d1=0.132, d2=0.964 g=0.135
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000118.png and model_000118.h5
# (6, 28, 28, 1)
# >119, d1=0.030, d2=0.638 g=0.136
# (6, 28, 28, 1)
# >120, d1=0.300, d2=0.376 g=0.368
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000120.png and model_000120.h5
# (6, 28, 28, 1)
# >121, d1=0.693, d2=0.117 g=0.077
# (6, 28, 28, 1)
# >122, d1=1.044, d2=0.024 g=0.073
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000122.png and model_000122.h5
# (6, 28, 28, 1)
# >123, d1=0.835, d2=0.404 g=0.107
# (6, 28, 28, 1)
# >124, d1=0.387, d2=1.293 g=0.279
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000124.png and model_000124.h5
# (6, 28, 28, 1)
# >125, d1=0.006, d2=1.795 g=0.639
# (6, 28, 28, 1)
# >126, d1=0.456, d2=0.972 g=0.159
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000126.png and model_000126.h5
# (6, 28, 28, 1)
# >127, d1=1.203, d2=0.235 g=0.439
# (6, 28, 28, 1)
# >128, d1=1.333, d2=0.013 g=0.008
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000128.png and model_000128.h5
# (6, 28, 28, 1)
# >129, d1=0.901, d2=0.364 g=0.005
# (6, 28, 28, 1)
# >130, d1=0.299, d2=1.080 g=0.506
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000130.png and model_000130.h5
# (6, 28, 28, 1)
# >131, d1=0.017, d2=1.023 g=0.248
# (6, 28, 28, 1)
# >132, d1=0.380, d2=0.316 g=0.484
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000132.png and model_000132.h5
# (6, 28, 28, 1)
# >133, d1=0.776, d2=0.043 g=0.043
# (6, 28, 28, 1)
# >134, d1=0.930, d2=0.056 g=0.117
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000134.png and model_000134.h5
# (6, 28, 28, 1)
# >135, d1=0.663, d2=0.400 g=0.134
# (6, 28, 28, 1)
# >136, d1=0.355, d2=0.942 g=0.151
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000136.png and model_000136.h5
# (6, 28, 28, 1)
# >137, d1=0.037, d2=1.309 g=0.600
# (6, 28, 28, 1)
# >138, d1=0.328, d2=1.018 g=0.184
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000138.png and model_000138.h5
# (6, 28, 28, 1)
# >139, d1=1.271, d2=0.483 g=1.232
# (6, 28, 28, 1)
# >140, d1=2.089, d2=0.018 g=0.004
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000140.png and model_000140.h5
# (6, 28, 28, 1)
# >141, d1=1.906, d2=0.156 g=0.224
# (6, 28, 28, 1)
# >142, d1=0.979, d2=0.917 g=0.537
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000142.png and model_000142.h5
# (6, 28, 28, 1)
# >143, d1=0.150, d2=2.003 g=1.229
# (6, 28, 28, 1)
# >144, d1=0.257, d2=3.791 g=5.788
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000144.png and model_000144.h5
# (6, 28, 28, 1)
# >145, d1=2.714, d2=3.330 g=2.050
# (6, 28, 28, 1)
# >146, d1=6.984, d2=1.625 g=5.523
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000146.png and model_000146.h5
# (6, 28, 28, 1)
# >147, d1=8.108, d2=0.396 g=0.144
# (6, 28, 28, 1)
# >148, d1=6.065, d2=0.053 g=2.066
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000148.png and model_000148.h5
# (6, 28, 28, 1)
# >149, d1=2.329, d2=0.026 g=0.453
# (6, 28, 28, 1)
# >150, d1=0.488, d2=0.058 g=0.377
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000150.png and model_000150.h5
# (6, 28, 28, 1)
# >151, d1=0.046, d2=0.620 g=4.700
# (6, 28, 28, 1)
# >152, d1=0.190, d2=0.799 g=0.399
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000152.png and model_000152.h5
# (6, 28, 28, 1)
# >153, d1=0.835, d2=3.153 g=11.802
# (6, 28, 28, 1)
# >154, d1=3.271, d2=5.337 g=1.458
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000154.png and model_000154.h5
# (6, 28, 28, 1)
# >155, d1=7.511, d2=3.226 g=7.045
# (6, 28, 28, 1)
# >156, d1=7.048, d2=0.745 g=0.073
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000156.png and model_000156.h5
# (6, 28, 28, 1)
# >157, d1=2.747, d2=1.079 g=4.409
# (6, 28, 28, 1)
# >158, d1=1.078, d2=1.150 g=0.087
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000158.png and model_000158.h5
# (6, 28, 28, 1)
# >159, d1=0.773, d2=1.981 g=4.105
# (6, 28, 28, 1)
# >160, d1=1.193, d2=0.515 g=0.026
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000160.png and model_000160.h5
# (6, 28, 28, 1)
# >161, d1=0.547, d2=0.853 g=3.763
# (6, 28, 28, 1)
# >162, d1=0.607, d2=0.929 g=0.190
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000162.png and model_000162.h5
# (6, 28, 28, 1)
# >163, d1=0.596, d2=1.523 g=3.969
# (6, 28, 28, 1)
# >164, d1=1.022, d2=0.637 g=0.019
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000164.png and model_000164.h5
# (6, 28, 28, 1)
# >165, d1=0.473, d2=1.240 g=4.651
# (6, 28, 28, 1)
# >166, d1=0.634, d2=2.303 g=1.356
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000166.png and model_000166.h5
# (6, 28, 28, 1)
# >167, d1=1.626, d2=6.522 g=16.191
# (6, 28, 28, 1)
# >168, d1=4.901, d2=8.579 g=2.194
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000168.png and model_000168.h5
# (6, 28, 28, 1)
# >169, d1=6.601, d2=6.786 g=9.816
# (6, 28, 28, 1)
# >170, d1=4.348, d2=5.047 g=0.014
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000170.png and model_000170.h5
# (6, 28, 28, 1)
# >171, d1=2.774, d2=2.575 g=2.926
# (6, 28, 28, 1)
# >172, d1=0.732, d2=1.263 g=0.454
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000172.png and model_000172.h5
# (6, 28, 28, 1)
# >173, d1=0.126, d2=0.691 g=1.394
# (6, 28, 28, 1)
# >174, d1=0.056, d2=0.251 g=0.716
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000174.png and model_000174.h5
# (6, 28, 28, 1)
# >175, d1=0.060, d2=0.123 g=1.089
# (6, 28, 28, 1)
# >176, d1=0.011, d2=0.045 g=0.788
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000176.png and model_000176.h5
# (6, 28, 28, 1)
# >177, d1=0.011, d2=0.039 g=1.006
# (6, 28, 28, 1)
# >178, d1=0.018, d2=0.014 g=0.829
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000178.png and model_000178.h5
# (6, 28, 28, 1)
# >179, d1=0.015, d2=0.007 g=0.992
# (6, 28, 28, 1)
# >180, d1=0.019, d2=0.002 g=0.859
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000180.png and model_000180.h5
# (6, 28, 28, 1)
# >181, d1=0.020, d2=0.007 g=1.034
# (6, 28, 28, 1)
# >182, d1=0.008, d2=0.007 g=0.846
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000182.png and model_000182.h5
# (6, 28, 28, 1)
# >183, d1=0.019, d2=0.001 g=0.985
# (6, 28, 28, 1)
# >184, d1=0.013, d2=0.000 g=0.941
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000184.png and model_000184.h5
# (6, 28, 28, 1)
# >185, d1=0.027, d2=0.001 g=0.924
# (6, 28, 28, 1)
# >186, d1=0.000, d2=0.001 g=0.983
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000186.png and model_000186.h5
# (6, 28, 28, 1)
# >187, d1=0.011, d2=0.005 g=0.881
# (6, 28, 28, 1)
# >188, d1=0.003, d2=0.014 g=1.009
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000188.png and model_000188.h5
# (6, 28, 28, 1)
# >189, d1=0.013, d2=0.007 g=0.809
# (6, 28, 28, 1)
# >190, d1=0.027, d2=0.004 g=1.039
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000190.png and model_000190.h5
# (6, 28, 28, 1)
# >191, d1=0.027, d2=0.003 g=0.819
# (6, 28, 28, 1)
# >192, d1=0.002, d2=0.011 g=1.075
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000192.png and model_000192.h5
# (6, 28, 28, 1)
# >193, d1=0.008, d2=0.015 g=0.804
# (6, 28, 28, 1)
# >194, d1=0.007, d2=0.036 g=1.116
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000194.png and model_000194.h5
# (6, 28, 28, 1)
# >195, d1=0.001, d2=0.045 g=0.720
# (6, 28, 28, 1)
# >196, d1=0.008, d2=0.066 g=1.274
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000196.png and model_000196.h5
# (6, 28, 28, 1)
# >197, d1=0.015, d2=0.063 g=0.628
# (6, 28, 28, 1)
# >198, d1=0.028, d2=0.096 g=1.375
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000198.png and model_000198.h5
# (6, 28, 28, 1)
# >199, d1=0.033, d2=0.085 g=0.554
# (6, 28, 28, 1)
# >200, d1=0.028, d2=0.126 g=1.409
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000200.png and model_000200.h5
# Saved plot_line_plot_loss.png

# %% [markdown]
# Calculate Train Metrics

# %%
gt, _ = generate_real_samples(dataset, 6)
pred, _= generate_fake_samples(generator, latent_dim, 6)

# %%
pred = pred.reshape(6,28,28)
fig, axs = plt.subplots(2, 3)
axs[0, 0].imshow(pred[0], cmap='gray')
axs[0, 1].imshow(pred[1], cmap='gray')
axs[0, 2].imshow(pred[2], cmap='gray')
axs[1, 0].imshow(pred[3], cmap='gray')
axs[1, 1].imshow(pred[4], cmap='gray')
axs[1, 2].imshow(pred[5], cmap='gray')

# %%
gt = gt.reshape(6,784)
pred = pred.reshape(6,784)

# %%
from sklearn import metrics
from math import sqrt

mae = metrics.mean_absolute_error(gt, pred)
mse = metrics.mean_squared_error(gt, pred)
mape = metrics.mean_absolute_percentage_error(gt, pred)
rmse = sqrt(mse)

print('MSE=', mse, '...RMSE=', rmse, '...MAE=', mae, '...MAPE=', mape)
# Out:
# MSE= 0.40772453 ...RMSE= 0.6385331076027115 ...MAE= 0.24995048 ...MAPE= 0.571586

# %% [markdown]
# Calculate Test Metrics

# %%
def load_test_samples():
	# load dataset
	testX = test3darr
	# expand to 3d, e.g. add channels
	X = expand_dims(testX, axis=-1)
	# convert from ints to floats
	X = X.astype('float32')
	# scale from [0,255] to [-1,1]
	X = (X - 127.5) / 127.5
	return X

# %%
testd = load_test_samples()
print(testd.shape)
# Out:
# (12, 28, 28, 1)

# %%
gt, _ = generate_real_samples(testd, 6)
pred, _= generate_fake_samples(generator, latent_dim, 6)

# %%
pred = pred.reshape(6,28,28)
fig, axs = plt.subplots(2, 3)
axs[0, 0].imshow(pred[0], cmap='gray')
axs[0, 1].imshow(pred[1], cmap='gray')
axs[0, 2].imshow(pred[2], cmap='gray')
axs[1, 0].imshow(pred[3], cmap='gray')
axs[1, 1].imshow(pred[4], cmap='gray')
axs[1, 2].imshow(pred[5], cmap='gray')

# %%
gt = gt.reshape(6,784)
pred = pred.reshape(6,784)

# %%
from sklearn import metrics
from math import sqrt

mae = metrics.mean_absolute_error(gt, pred)
mse = metrics.mean_squared_error(gt, pred)
mape = metrics.mean_absolute_percentage_error(gt, pred)
rmse = sqrt(mse)

print('MSE=', mse, '...RMSE=', rmse, '...MAE=', mae, '...MAPE=', mape)
# Out:
# MSE= 0.41008073 ...RMSE= 0.6403754608938959 ...MAE= 0.24851514 ...MAPE= 0.6259666
