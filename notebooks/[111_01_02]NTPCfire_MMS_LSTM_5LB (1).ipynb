# %% [markdown]
# # Data Import & Manipulation
# Here, we import the required modules and read (+organise) the dataset

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.tsa.stattools as ts


import csv
import math
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import random
import statsmodels.api as sm
import statsmodels.formula.api as smf

from math import sqrt
from numpy.random import seed
seed(1)
from pandas import DataFrame
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.stattools import adfuller
from tensorflow.keras.layers import Dense
from tensorflow.keras import layers
from tensorflow.keras.layers import LSTM
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# !wget https://www.dropbox.com/s/jpw4fyv6mh31ql4/NTP2015-2017fire.txt
# Out:
# --2022-01-02 15:00:09--  https://www.dropbox.com/s/jpw4fyv6mh31ql4/NTP2015-2017fire.txt
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/jpw4fyv6mh31ql4/NTP2015-2017fire.txt [following]
# --2022-01-02 15:00:09--  https://www.dropbox.com/s/raw/jpw4fyv6mh31ql4/NTP2015-2017fire.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc0d613e1766269972499865bd94.dl.dropboxusercontent.com/cd/0/inline/BdArUP1F5R8OmScHWTkqVLRAxO9RZopMl0dDFmuG4i2wxKPeBKMZGnWY1rtWwTqM0m8XJQ6muQg6sb9HUW10KdFNSYJGqI7C9J3pvZsu7oV32TVBO31CyEdgcuXlOwCNjkvyQcKbiNrBn1FG5FkxbQBB/file# [following]
# --2022-01-02 15:00:09--  https://uc0d613e1766269972499865bd94.dl.dropboxusercontent.com/cd/0/inline/BdArUP1F5R8OmScHWTkqVLRAxO9RZopMl0dDFmuG4i2wxKPeBKMZGnWY1rtWwTqM0m8XJQ6muQg6sb9HUW10KdFNSYJGqI7C9J3pvZsu7oV32TVBO31CyEdgcuXlOwCNjkvyQcKbiNrBn1FG5FkxbQBB/file
# Resolving uc0d613e1766269972499865bd94.dl.dropboxusercontent.com (uc0d613e1766269972499865bd94.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:601b:15::a27d:80f
# Connecting to uc0d613e1766269972499865bd94.dl.dropboxusercontent.com (uc0d613e1766269972499865bd94.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3884193 (3.7M) [text/plain]
# Saving to: ‘NTP2015-2017fire.txt’
#
# NTP2015-2017fire.tx 100%[===================>]   3.70M  --.-KB/s    in 0.1s
#
# 2022-01-02 15:00:10 (26.6 MB/s) - ‘NTP2015-2017fire.txt’ saved [3884193/3884193]

# %%
# %cd /content/
#df = pd.read_csv('/content/gdrive/MyDrive/dlku/NTP2015fire-Jan.txt', sep='\t', header=None)
df = pd.read_csv('NTP2015-2017fire.txt', sep='\t', header=None)
df.columns = ["date", "station", "addr1", "addr2", "longitude", "latitude", "township"]
# Out:
# /content

# %%
df
# Out:
#                    date  station  ...   latitude township
# 0         2015/1/1 0:13  火警-瓦斯漏氣  ...  25.000569   板橋區廣德里
# 1         2015/1/1 0:16    火警-倉庫  ...  25.084172   三重區富華里
# 2         2015/1/1 0:48  火警-查看案件  ...  25.136422   淡水區民權里
# 3         2015/1/1 0:56  火警-查看案件  ...  25.031506   新莊區泰豐里
# 4         2015/1/1 1:04    火警-汽車  ...  24.982273   樹林區和平里
# ...                 ...      ...  ...        ...      ...
# 24085  2017/12/31 17:14  火警-集合住宅  ...  24.990417   中和區錦盛里
# 24086  2017/12/31 18:40  火警-集合住宅  ...  25.048063   汐止區東勢里
# 24087  2017/12/31 20:09  火警-查看案件  ...  25.076529   三重區福隆里
# 24088  2017/12/31 20:44  火警-查看案件  ...  24.997367   永和區民族里
# 24089  2017/12/31 22:09  火警-查看案件  ...  25.000317   板橋區龍安里
#
# [24090 rows x 7 columns]

# %%
#set date time format
df['date'] = pd.to_datetime(df.date, format='%Y-%m-%d %H:%M:%S')

# %%
df
# Out:
#                      date  station  ...   latitude township
# 0     2015-01-01 00:13:00  火警-瓦斯漏氣  ...  25.000569   板橋區廣德里
# 1     2015-01-01 00:16:00    火警-倉庫  ...  25.084172   三重區富華里
# 2     2015-01-01 00:48:00  火警-查看案件  ...  25.136422   淡水區民權里
# 3     2015-01-01 00:56:00  火警-查看案件  ...  25.031506   新莊區泰豐里
# 4     2015-01-01 01:04:00    火警-汽車  ...  24.982273   樹林區和平里
# ...                   ...      ...  ...        ...      ...
# 24085 2017-12-31 17:14:00  火警-集合住宅  ...  24.990417   中和區錦盛里
# 24086 2017-12-31 18:40:00  火警-集合住宅  ...  25.048063   汐止區東勢里
# 24087 2017-12-31 20:09:00  火警-查看案件  ...  25.076529   三重區福隆里
# 24088 2017-12-31 20:44:00  火警-查看案件  ...  24.997367   永和區民族里
# 24089 2017-12-31 22:09:00  火警-查看案件  ...  25.000317   板橋區龍安里
#
# [24090 rows x 7 columns]

# %%
#extract only numerical/quantitative data
dften = df[["date", "longitude", "latitude"]]

# %%
dften
# Out:
#                      date   longitude   latitude
# 0     2015-01-01 00:13:00  121.466281  25.000569
# 1     2015-01-01 00:16:00  121.491579  25.084172
# 2     2015-01-01 00:48:00  121.460224  25.136422
# 3     2015-01-01 00:56:00  121.450333  25.031506
# 4     2015-01-01 01:04:00  121.420005  24.982273
# ...                   ...         ...        ...
# 24085 2017-12-31 17:14:00  121.493909  24.990417
# 24086 2017-12-31 18:40:00  121.621682  25.048063
# 24087 2017-12-31 20:09:00  121.490806  25.076529
# 24088 2017-12-31 20:44:00  121.519391  24.997367
# 24089 2017-12-31 22:09:00  121.442237  25.000317
#
# [24090 rows x 3 columns]

# %%
BBox = ((dften.longitude.min(),   dften.longitude.max(),      
         dften.latitude.min(), dften.latitude.max()))

# %%
#Print out the coordinates, and go to Openstreetmap website to draw a map.
BBox
# Out:
# (121.2868855, 122.0030709, 24.77511693, 25.29717505)

# %%
#download the map we have just drawn
# !wget https://www.dropbox.com/s/dw6dp3zyx063zjt/ntpcmap.png
# !wget https://www.dropbox.com/s/vb5g8ndd3l2o0eh/ntpcmaplrg.png
# Out:
# --2022-01-02 15:00:10--  https://www.dropbox.com/s/dw6dp3zyx063zjt/ntpcmap.png
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/dw6dp3zyx063zjt/ntpcmap.png [following]
# --2022-01-02 15:00:11--  https://www.dropbox.com/s/raw/dw6dp3zyx063zjt/ntpcmap.png
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc793d40b66f9b8cfc355504bd82.dl.dropboxusercontent.com/cd/0/inline/BdDJc_LaQLdagwNhpZfkwSPyWLkRwSvRha8VtCf5-DZAalDL1KtI4TxHc7QrizBEZH__Il7PA0nINAOeqMlfpuP7RoQpb6Kse6pb79twrgptSLf07Nh8w5_z1MzbngnZEWHe1Y6FsTAwxY0uv0nge7-c/file# [following]
# --2022-01-02 15:00:11--  https://uc793d40b66f9b8cfc355504bd82.dl.dropboxusercontent.com/cd/0/inline/BdDJc_LaQLdagwNhpZfkwSPyWLkRwSvRha8VtCf5-DZAalDL1KtI4TxHc7QrizBEZH__Il7PA0nINAOeqMlfpuP7RoQpb6Kse6pb79twrgptSLf07Nh8w5_z1MzbngnZEWHe1Y6FsTAwxY0uv0nge7-c/file
# Resolving uc793d40b66f9b8cfc355504bd82.dl.dropboxusercontent.com (uc793d40b66f9b8cfc355504bd82.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:601b:15::a27d:80f
# Connecting to uc793d40b66f9b8cfc355504bd82.dl.dropboxusercontent.com (uc793d40b66f9b8cfc355504bd82.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1828678 (1.7M) [image/png]
# Saving to: ‘ntpcmap.png’
#
# ntpcmap.png         100%[===================>]   1.74M  --.-KB/s    in 0.1s
#
# 2022-01-02 15:00:11 (14.3 MB/s) - ‘ntpcmap.png’ saved [1828678/1828678]
#
# --2022-01-02 15:00:12--  https://www.dropbox.com/s/vb5g8ndd3l2o0eh/ntpcmaplrg.png
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/vb5g8ndd3l2o0eh/ntpcmaplrg.png [following]
# --2022-01-02 15:00:12--  https://www.dropbox.com/s/raw/vb5g8ndd3l2o0eh/ntpcmaplrg.png
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc584a2262f6f356fa63a0987371.dl.dropboxusercontent.com/cd/0/inline/BdBVWkTlZdmJ_IYt0umBT8BqNME8J8222xc_jUf8XFp0XPk_gGB-abFOBP886xEsN2P4PZrWNeCuNaxR4oAkMHk5zMQa0qFt1sC-C2E-W05FjjVmiLpHyorCVa8NWUmhaArArEHBSG-uefaHUmXQfOPR/file# [following]
# --2022-01-02 15:00:12--  https://uc584a2262f6f356fa63a0987371.dl.dropboxusercontent.com/cd/0/inline/BdBVWkTlZdmJ_IYt0umBT8BqNME8J8222xc_jUf8XFp0XPk_gGB-abFOBP886xEsN2P4PZrWNeCuNaxR4oAkMHk5zMQa0qFt1sC-C2E-W05FjjVmiLpHyorCVa8NWUmhaArArEHBSG-uefaHUmXQfOPR/file
# Resolving uc584a2262f6f356fa63a0987371.dl.dropboxusercontent.com (uc584a2262f6f356fa63a0987371.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:601b:15::a27d:80f
# Connecting to uc584a2262f6f356fa63a0987371.dl.dropboxusercontent.com (uc584a2262f6f356fa63a0987371.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1237701 (1.2M) [image/png]
# Saving to: ‘ntpcmaplrg.png’
#
# ntpcmaplrg.png      100%[===================>]   1.18M  --.-KB/s    in 0.1s
#
# 2022-01-02 15:00:12 (9.33 MB/s) - ‘ntpcmaplrg.png’ saved [1237701/1237701]

# %%
map = plt.imread('ntpcmap.png')
maplrg =  plt.imread('ntpcmaplrg.png')

# %%
f, axarr = plt.subplots(2)
axarr[0].imshow(map)
axarr[1].imshow(maplrg)

# %%
#let's plot the points
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(dften.longitude, dften.latitude, zorder=1, alpha= 0.2, c='k', s=10)
ax.set_title('Fire Incidents in NTPC, 2015-2017, Spatial Domain')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
# Out:
# (24.77511693, 25.29717505)

# %%
#split dataframe into 3 years
df15 = df[df['date'].dt.year == 2015]
df16 = df[df['date'].dt.year == 2016]
df17 = df[df['date'].dt.year == 2017]

# %%
df15
# Out:
#                     date  station  ...   latitude township
# 0    2015-01-01 00:13:00  火警-瓦斯漏氣  ...  25.000569   板橋區廣德里
# 1    2015-01-01 00:16:00    火警-倉庫  ...  25.084172   三重區富華里
# 2    2015-01-01 00:48:00  火警-查看案件  ...  25.136422   淡水區民權里
# 3    2015-01-01 00:56:00  火警-查看案件  ...  25.031506   新莊區泰豐里
# 4    2015-01-01 01:04:00    火警-汽車  ...  24.982273   樹林區和平里
# ...                  ...      ...  ...        ...      ...
# 9054 2015-12-31 21:41:00   火警-透天厝  ...  24.994490   中和區秀明里
# 9055 2015-12-31 21:46:00  火警-集合住宅  ...  25.016660   樹林區三福里
# 9056 2015-12-31 22:37:00  火警-查看案件  ...  25.070749   林口區東勢里
# 9057 2015-12-31 22:45:00  火警-查看案件  ...  25.097674   蘆洲區保新里
# 9058 2015-12-31 23:32:00  火警-查看案件  ...  24.989496   中和區錦中里
#
# [9059 rows x 7 columns]

# %%
df16
# Out:
#                      date      station  ...   latitude township
# 9059  2016-01-01 01:10:00      火警-查看案件  ...  25.047863   泰山區明志里
# 9060  2016-01-01 01:18:00      火警-查看案件  ...  25.145268   淡水區八勢里
# 9061  2016-01-01 01:27:00      火警-查看案件  ...  25.013844   永和區下溪里
# 9062  2016-01-01 03:30:00      火警-查看案件  ...  25.093751   蘆洲區南港里
# 9063  2016-01-01 03:47:00        火警-汽車  ...  24.994834   樹林區潭底里
# ...                   ...          ...  ...        ...      ...
# 17156 2016-12-31 19:50:00      火警-集合住宅  ...  25.032542   板橋區溪頭里
# 17157 2016-12-31 21:51:00      火警-查看案件  ...  24.997751   板橋區崑崙里
# 17158 2016-12-31 22:30:00      火警-集合住宅  ...  25.018254   板橋區新民里
# 17159 2016-12-31 22:52:00      火警-查看案件  ...  25.072460   林口區西林里
# 17160 2016-12-31 23:13:00  火警-山林田野(平地)  ...  25.145268   淡水區八勢里
#
# [8102 rows x 7 columns]

# %%
df17
# Out:
#                      date      station  ...   latitude township
# 17161 2017-01-01 00:13:00  火警-山林田野(平地)  ...  24.936866   鶯歌區二甲里
# 17162 2017-01-01 00:15:00      火警-集合住宅  ...  24.929874   三峽區介壽里
# 17163 2017-01-01 00:54:00      火警-集合住宅  ...  25.007928   板橋區流芳里
# 17164 2017-01-01 01:44:00      火警-集合住宅  ...  25.062100   汐止區文化里
# 17165 2017-01-01 01:59:00     火警-警報器作響  ...  25.076035   汐止區建成里
# ...                   ...          ...  ...        ...      ...
# 24085 2017-12-31 17:14:00      火警-集合住宅  ...  24.990417   中和區錦盛里
# 24086 2017-12-31 18:40:00      火警-集合住宅  ...  25.048063   汐止區東勢里
# 24087 2017-12-31 20:09:00      火警-查看案件  ...  25.076529   三重區福隆里
# 24088 2017-12-31 20:44:00      火警-查看案件  ...  24.997367   永和區民族里
# 24089 2017-12-31 22:09:00      火警-查看案件  ...  25.000317   板橋區龍安里
#
# [6929 rows x 7 columns]

# %%
#let's plot the points for 2015
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df15.longitude, df15.latitude, zorder=1, alpha= 0.2, c='r', s=10)
ax.set_title('Fire Incidents in NTPC, 2015, Spatial Domain')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
# Out:
# (24.77511693, 25.29717505)

# %%
#let's plot the points for 2016
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df16.longitude, df16.latitude, zorder=1, alpha= 0.2, c='g', s=10)
ax.set_title('Fire Incidents in NTPC, 2016, Spatial Domain')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
# Out:
# (24.77511693, 25.29717505)

# %%
#let's plot the points for 2017
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df17.longitude, df17.latitude, zorder=1, alpha= 0.2, c='b', s=10)
ax.set_title('Fire Incidents in NTPC, 2017, Spatial Domain')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
# Out:
# (24.77511693, 25.29717505)

# %%
#Extraction of the temporal domain
maxlimit = len(df)
ones = np.ones(maxlimit, dtype="uint32")
dftemp = pd.DataFrame(df.date)
dftemp['freq'] = ones

# %%
dftemp
# Out:
#                      date  freq
# 0     2015-01-01 00:13:00     1
# 1     2015-01-01 00:16:00     1
# 2     2015-01-01 00:48:00     1
# 3     2015-01-01 00:56:00     1
# 4     2015-01-01 01:04:00     1
# ...                   ...   ...
# 24085 2017-12-31 17:14:00     1
# 24086 2017-12-31 18:40:00     1
# 24087 2017-12-31 20:09:00     1
# 24088 2017-12-31 20:44:00     1
# 24089 2017-12-31 22:09:00     1
#
# [24090 rows x 2 columns]

# %%
#when running this block, we will obtain the monthly frequency to be used in the temporal domain (a.k.a. time series).
dftempday = dftemp.groupby(pd.Grouper(key="date", freq="1D")).count()
dftempweek = dftemp.groupby(pd.Grouper(key="date", freq="1W")).count()
dftempmonth = dftemp.groupby(pd.Grouper(key="date", freq="1M")).count()

# %%
dftempday
# Out:
#             freq
# date
# 2015-01-01    34
# 2015-01-02    25
# 2015-01-03    24
# 2015-01-04    34
# 2015-01-05    28
# ...          ...
# 2017-12-27    13
# 2017-12-28    19
# 2017-12-29    19
# 2017-12-30     6
# 2017-12-31     8
#
# [1096 rows x 1 columns]

# %%
dftempweek
# Out:
#             freq
# date
# 2015-01-04   117
# 2015-01-11   163
# 2015-01-18   141
# 2015-01-25   210
# 2015-02-01   174
# ...          ...
# 2017-12-03   125
# 2017-12-10   109
# 2017-12-17   105
# 2017-12-24   139
# 2017-12-31   100
#
# [157 rows x 1 columns]

# %%
dftempmonth
# Out:
#             freq
# date
# 2015-01-31   778
# 2015-02-28   776
# 2015-03-31   733
# 2015-04-30   844
# 2015-05-31   681
# 2015-06-30   677
# 2015-07-31   718
# 2015-08-31  1030
# 2015-09-30   792
# 2015-10-31   699
# 2015-11-30   680
# 2015-12-31   651
# 2016-01-31   688
# 2016-02-29   711
# 2016-03-31   752
# 2016-04-30   671
# 2016-05-31   652
# 2016-06-30   663
# 2016-07-31   666
# 2016-08-31   748
# 2016-09-30   674
# 2016-10-31   666
# 2016-11-30   635
# 2016-12-31   576
# 2017-01-31   638
# 2017-02-28   564
# 2017-03-31   519
# 2017-04-30   646
# 2017-05-31   509
# 2017-06-30   541
# 2017-07-31   610
# 2017-08-31   740
# 2017-09-30   576
# 2017-10-31   527
# 2017-11-30   553
# 2017-12-31   506

# %%
y = dftempmonth['freq']
x = dftempmonth.index
plt.rcParams["figure.figsize"] = (16,9)
plt.plot(x, y, color='r', label='monthly frequency') 
plt.xlabel('date')
plt.ylabel('incidents')
plt.title('Monthly Temporal Domain')
plt.legend() 
plt.show()

# %%
y = dftempweek['freq']
x = dftempweek.index
plt.rcParams["figure.figsize"] = (16,9)
plt.plot(x, y, color='g', label='weekly frequency')
plt.xlabel('date')
plt.ylabel('incidents')
plt.title('Weekly Temporal Domain')
plt.legend() 
plt.show()

# %%
y = dftempday['freq']
x = dftempday.index
plt.rcParams["figure.figsize"] = (16,9)
plt.plot(x, y, color='b', label='daily frequency') 
plt.xlabel('date')
plt.ylabel('incidents')
plt.title('Daily Temporal Domain')
plt.legend() 
plt.show()

# %% [markdown]
# #Keras LSTM MODEL

# %%
# LSTM for international airline passengers problem with regression framing
import numpy
import matplotlib.pyplot as plt
import pandas as pd
import math
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Convert dataset to matrix

# %%
tseries = dftempday['freq'].to_numpy()
tseries
# Out:
# array([34, 25, 24, ..., 19,  6,  8])

# %%
plt.plot(tseries)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
plt.ylabel('#of incidents')
plt.title('Number of daily fire incidents in NTPC Taiwan, 2015-2017')
plt.show()

# %%
dftensor=pd.DataFrame(tseries) #forward dataframe
dftensor=np.array(dftensor) #convert to tensor
dftensor #display dataframe
# Out:
# array([[34],
#        [25],
#        [24],
#        ...,
#        [19],
#        [ 6],
#        [ 8]])

# %%
dftensor=np.array(dftensor)

# %% [markdown]
# Train-test split

# %%
train_size = int(len(dftensor) * 0.8)
test_size = len(dftensor) - train_size
train, test = dftensor[0:train_size,:], dftensor[train_size:len(dftensor),:]

# %% [markdown]
# Form dataset matrix

# %%
def create_dataset(df, previous=1):
    dataX, dataY = [], []
    for i in range(len(df)-previous-1):
        a = df[i:(i+previous), 0]
        dataX.append(a)
        dataY.append(df[i + previous, 0])
    return np.array(dataX), np.array(dataY)

# %%
dftensor
# Out:
# array([[34],
#        [25],
#        [24],
#        ...,
#        [19],
#        [ 6],
#        [ 8]])

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
train = scaler.fit_transform(train)
train
# Out:
# array([[0.14427861],
#        [0.09950249],
#        [0.09452736],
#        [0.14427861],
#        [0.11442786],
#        [0.08955224],
#        [0.09452736],
#        [0.09950249],
#        [0.06965174],
#        [0.08955224],
#        [0.07960199],
#        [0.12437811],
#        [0.06965174],
#        [0.06965174],
#        [0.06467662],
#        [0.08457711],
#        [0.03482587],
#        [0.07960199],
#        [0.13432836],
#        [0.11940299],
#        [0.09950249],
#        [0.08955224],
#        [0.13432836],
#        [0.1840796 ],
#        [0.10945274],
#        [0.12437811],
#        [0.10447761],
#        [0.07960199],
#        [0.11442786],
#        [0.11442786],
#        [0.04477612],
#        [0.10945274],
#        [0.06467662],
#        [0.10447761],
#        [0.06467662],
#        [0.02487562],
#        [0.06467662],
#        [0.05970149],
#        [0.08457711],
#        [0.13930348],
#        [0.06467662],
#        [0.13930348],
#        [0.09452736],
#        [0.08955224],
#        [0.15422886],
#        [0.15422886],
#        [0.13930348],
#        [0.15920398],
#        [0.18905473],
#        [0.1641791 ],
#        [0.17910448],
#        [0.17412935],
#        [0.14427861],
#        [0.13432836],
#        [0.11940299],
#        [0.05472637],
#        [0.09452736],
#        [0.08457711],
#        [0.11442786],
#        [0.039801  ],
#        [0.09452736],
#        [0.039801  ],
#        [0.11442786],
#        [0.08955224],
#        [0.05472637],
#        [0.08457711],
#        [0.09950249],
#        [0.05472637],
#        [0.07462687],
#        [0.09950249],
#        [0.11940299],
#        [0.09452736],
#        [0.09452736],
#        [0.11940299],
#        [0.08457711],
#        [0.12935323],
#        [0.07960199],
#        [0.07462687],
#        [0.11442786],
#        [0.10945274],
#        [0.15920398],
#        [0.07960199],
#        [0.08457711],
#        [0.09452736],
#        [0.11940299],
#        [0.10945274],
#        [0.07960199],
#        [0.12935323],
#        [0.07462687],
#        [0.07960199],
#        [0.13930348],
#        [0.1641791 ],
#        [0.15422886],
#        [0.1840796 ],
#        [0.26368159],
#        [0.23383085],
#        [0.09950249],
#        [0.0199005 ],
#        [0.04975124],
#        [0.09950249],
#        [0.06965174],
#        [0.12437811],
#        [0.08457711],
#        [0.10447761],
#        [0.15422886],
#        [0.10945274],
#        [0.12437811],
#        [0.11442786],
#        [0.13432836],
#        [0.11442786],
#        [0.09950249],
#        [0.08457711],
#        [0.039801  ],
#        [0.11442786],
#        [0.09950249],
#        [0.08457711],
#        [0.07960199],
#        [0.12437811],
#        [0.12437811],
#        [0.05970149],
#        [0.07960199],
#        [0.11442786],
#        [0.07960199],
#        [0.039801  ],
#        [0.07960199],
#        [0.07960199],
#        [0.06965174],
#        [0.07960199],
#        [0.09950249],
#        [0.05970149],
#        [0.10945274],
#        [0.09950249],
#        [0.08955224],
#        [0.09452736],
#        [0.10945274],
#        [0.15422886],
#        [0.08457711],
#        [0.07462687],
#        [0.09452736],
#        [0.09452736],
#        [0.03482587],
#        [0.07462687],
#        [0.09452736],
#        [0.10447761],
#        [0.05970149],
#        [0.08955224],
#        [0.09452736],
#        [0.07462687],
#        [0.05970149],
#        [0.08955224],
#        [0.05472637],
#        [0.10447761],
#        [0.11442786],
#        [0.10945274],
#        [0.039801  ],
#        [0.06965174],
#        [0.07462687],
#        [0.10447761],
#        [0.039801  ],
#        [0.06965174],
#        [0.06965174],
#        [0.04975124],
#        [0.07462687],
#        [0.09950249],
#        [0.10447761],
#        [0.13432836],
#        [0.06467662],
#        [0.09950249],
#        [0.07960199],
#        [0.14427861],
#        [0.09950249],
#        [0.04975124],
#        [0.08955224],
#        [0.09452736],
#        [0.09452736],
#        [0.06965174],
#        [0.09452736],
#        [0.05970149],
#        [0.12437811],
#        [0.09950249],
#        [0.09950249],
#        [0.08955224],
#        [0.06965174],
#        [0.07960199],
#        [0.10945274],
#        [0.10945274],
#        [0.07960199],
#        [0.10447761],
#        [0.14427861],
#        [0.05970149],
#        [0.14427861],
#        [0.05472637],
#        [0.05472637],
#        [0.08955224],
#        [0.11442786],
#        [0.05472637],
#        [0.10945274],
#        [0.08955224],
#        [0.11940299],
#        [0.10447761],
#        [0.05970149],
#        [0.07960199],
#        [0.06467662],
#        [0.08955224],
#        [0.02487562],
#        [0.06965174],
#        [0.14925373],
#        [0.10447761],
#        [0.05970149],
#        [0.06467662],
#        [0.10945274],
#        [0.14427861],
#        [0.14427861],
#        [0.11442786],
#        [0.10447761],
#        [0.10945274],
#        [0.11442786],
#        [0.14427861],
#        [0.10945274],
#        [1.        ],
#        [0.31840796],
#        [0.2039801 ],
#        [0.12935323],
#        [0.10945274],
#        [0.10447761],
#        [0.10945274],
#        [0.04975124],
#        [0.09452736],
#        [0.08955224],
#        [0.12437811],
#        [0.10945274],
#        [0.14925373],
#        [0.09950249],
#        [0.10945274],
#        [0.07960199],
#        [0.04477612],
#        [0.05472637],
#        [0.04477612],
#        [0.10447761],
#        [0.14925373],
#        [0.12437811],
#        [0.07462687],
#        [0.03482587],
#        [0.05472637],
#        [0.05970149],
#        [0.11442786],
#        [0.11442786],
#        [0.09452736],
#        [0.12935323],
#        [0.05970149],
#        [0.05472637],
#        [0.04975124],
#        [0.09950249],
#        [0.09950249],
#        [0.08457711],
#        [0.08457711],
#        [0.10447761],
#        [0.10945274],
#        [0.02985075],
#        [0.04975124],
#        [0.05472637],
#        [0.12437811],
#        [0.16915423],
#        [0.10945274],
#        [0.08955224],
#        [0.11442786],
#        [0.08955224],
#        [0.06467662],
#        [0.10945274],
#        [0.14925373],
#        [0.3681592 ],
#        [0.26368159],
#        [0.09452736],
#        [0.10447761],
#        [0.05970149],
#        [0.08955224],
#        [0.08955224],
#        [0.09452736],
#        [0.07462687],
#        [0.08955224],
#        [0.16915423],
#        [0.06467662],
#        [0.06965174],
#        [0.06467662],
#        [0.039801  ],
#        [0.12437811],
#        [0.10447761],
#        [0.07462687],
#        [0.06965174],
#        [0.06965174],
#        [0.11442786],
#        [0.05472637],
#        [0.10945274],
#        [0.10945274],
#        [0.07960199],
#        [0.10945274],
#        [0.09950249],
#        [0.09950249],
#        [0.09950249],
#        [0.08955224],
#        [0.04477612],
#        [0.06965174],
#        [0.09452736],
#        [0.07960199],
#        [0.07462687],
#        [0.05472637],
#        [0.09452736],
#        [0.05472637],
#        [0.07462687],
#        [0.10447761],
#        [0.08457711],
#        [0.10447761],
#        [0.07462687],
#        [0.05970149],
#        [0.11940299],
#        [0.06467662],
#        [0.07960199],
#        [0.09452736],
#        [0.08955224],
#        [0.11442786],
#        [0.05970149],
#        [0.09452736],
#        [0.08955224],
#        [0.11442786],
#        [0.04975124],
#        [0.06965174],
#        [0.05970149],
#        [0.08457711],
#        [0.09950249],
#        [0.13432836],
#        [0.10945274],
#        [0.12935323],
#        [0.10447761],
#        [0.09452736],
#        [0.08955224],
#        [0.08457711],
#        [0.09950249],
#        [0.04975124],
#        [0.06467662],
#        [0.08955224],
#        [0.0199005 ],
#        [0.06467662],
#        [0.12437811],
#        [0.05970149],
#        [0.08457711],
#        [0.08457711],
#        [0.07462687],
#        [0.039801  ],
#        [0.06467662],
#        [0.05970149],
#        [0.09950249],
#        [0.07960199],
#        [0.05970149],
#        [0.12935323],
#        [0.12437811],
#        [0.14427861],
#        [0.09452736],
#        [0.11442786],
#        [0.04477612],
#        [0.06467662],
#        [0.06965174],
#        [0.07960199],
#        [0.06467662],
#        [0.06467662],
#        [0.07960199],
#        [0.10945274],
#        [0.08955224],
#        [0.09950249],
#        [0.14427861],
#        [0.08457711],
#        [0.06965174],
#        [0.05970149],
#        [0.06965174],
#        [0.04477612],
#        [0.12437811],
#        [0.09452736],
#        [0.03482587],
#        [0.039801  ],
#        [0.05472637],
#        [0.07462687],
#        [0.02487562],
#        [0.06965174],
#        [0.06965174],
#        [0.05472637],
#        [0.05970149],
#        [0.15920398],
#        [0.07960199],
#        [0.05472637],
#        [0.08955224],
#        [0.13432836],
#        [0.10447761],
#        [0.11442786],
#        [0.11442786],
#        [0.10945274],
#        [0.11442786],
#        [0.10447761],
#        [0.06965174],
#        [0.07960199],
#        [0.06467662],
#        [0.12935323],
#        [0.10447761],
#        [0.08955224],
#        [0.14925373],
#        [0.22885572],
#        [0.16915423],
#        [0.18905473],
#        [0.11940299],
#        [0.17910448],
#        [0.14925373],
#        [0.07462687],
#        [0.04477612],
#        [0.07960199],
#        [0.04975124],
#        [0.09950249],
#        [0.06467662],
#        [0.05970149],
#        [0.06467662],
#        [0.10447761],
#        [0.05970149],
#        [0.02985075],
#        [0.05472637],
#        [0.05472637],
#        [0.10945274],
#        [0.08955224],
#        [0.05472637],
#        [0.10447761],
#        [0.09950249],
#        [0.11442786],
#        [0.10945274],
#        [0.10945274],
#        [0.17412935],
#        [0.05472637],
#        [0.08457711],
#        [0.10945274],
#        [0.05472637],
#        [0.0199005 ],
#        [0.07960199],
#        [0.17412935],
#        [0.06965174],
#        [0.06467662],
#        [0.08955224],
#        [0.07462687],
#        [0.17910448],
#        [0.24378109],
#        [0.09452736],
#        [0.04477612],
#        [0.10447761],
#        [0.08457711],
#        [0.07462687],
#        [0.03482587],
#        [0.06467662],
#        [0.08955224],
#        [0.08955224],
#        [0.09452736],
#        [0.06965174],
#        [0.11442786],
#        [0.07462687],
#        [0.17412935],
#        [0.19402985],
#        [0.10447761],
#        [0.08457711],
#        [0.10447761],
#        [0.039801  ],
#        [0.10447761],
#        [0.10945274],
#        [0.06965174],
#        [0.02985075],
#        [0.08955224],
#        [0.05472637],
#        [0.06467662],
#        [0.05970149],
#        [0.09452736],
#        [0.08457711],
#        [0.06467662],
#        [0.04975124],
#        [0.11940299],
#        [0.09452736],
#        [0.09950249],
#        [0.07462687],
#        [0.07960199],
#        [0.10945274],
#        [0.07462687],
#        [0.10447761],
#        [0.05472637],
#        [0.07462687],
#        [0.05472637],
#        [0.07462687],
#        [0.12437811],
#        [0.07960199],
#        [0.03482587],
#        [0.07960199],
#        [0.09950249],
#        [0.09950249],
#        [0.05970149],
#        [0.07960199],
#        [0.04975124],
#        [0.05472637],
#        [0.10447761],
#        [0.08457711],
#        [0.11442786],
#        [0.09452736],
#        [0.09452736],
#        [0.06467662],
#        [0.07462687],
#        [0.04477612],
#        [0.09452736],
#        [0.09950249],
#        [0.10447761],
#        [0.06965174],
#        [0.05970149],
#        [0.05970149],
#        [0.04477612],
#        [0.07960199],
#        [0.09452736],
#        [0.09452736],
#        [0.07960199],
#        [0.07960199],
#        [0.08457711],
#        [0.09950249],
#        [0.05472637],
#        [0.08457711],
#        [0.10447761],
#        [0.07462687],
#        [0.08955224],
#        [0.09452736],
#        [0.13432836],
#        [0.039801  ],
#        [0.06467662],
#        [0.13432836],
#        [0.05970149],
#        [0.04975124],
#        [0.08457711],
#        [0.14925373],
#        [0.08955224],
#        [0.07960199],
#        [0.07462687],
#        [0.08457711],
#        [0.07462687],
#        [0.07960199],
#        [0.05472637],
#        [0.07462687],
#        [0.09452736],
#        [0.07462687],
#        [0.08457711],
#        [0.10447761],
#        [0.09452736],
#        [0.08457711],
#        [0.06965174],
#        [0.04477612],
#        [0.15422886],
#        [0.07462687],
#        [0.10945274],
#        [0.07462687],
#        [0.09452736],
#        [0.05472637],
#        [0.03482587],
#        [0.06467662],
#        [0.06965174],
#        [0.039801  ],
#        [0.07960199],
#        [0.05472637],
#        [0.05472637],
#        [0.07462687],
#        [0.09452736],
#        [0.06467662],
#        [0.07960199],
#        [0.03482587],
#        [0.09950249],
#        [0.09452736],
#        [0.08955224],
#        [0.13930348],
#        [0.09950249],
#        [0.08457711],
#        [0.06965174],
#        [0.11940299],
#        [0.08955224],
#        [0.13930348],
#        [0.09452736],
#        [0.07960199],
#        [0.10447761],
#        [0.05970149],
#        [0.10945274],
#        [0.09950249],
#        [0.09950249],
#        [0.14925373],
#        [0.14925373],
#        [0.09950249],
#        [0.09950249],
#        [0.09452736],
#        [0.10447761],
#        [0.10945274],
#        [0.15422886],
#        [0.10447761],
#        [0.08457711],
#        [0.09950249],
#        [0.06965174],
#        [0.06965174],
#        [0.05472637],
#        [0.10945274],
#        [0.10447761],
#        [0.09950249],
#        [0.05472637],
#        [0.09950249],
#        [0.06467662],
#        [0.10945274],
#        [0.07960199],
#        [0.07960199],
#        [0.04477612],
#        [0.10945274],
#        [0.08955224],
#        [0.09452736],
#        [0.09950249],
#        [0.06467662],
#        [0.07462687],
#        [0.08955224],
#        [0.05472637],
#        [0.05970149],
#        [0.04975124],
#        [0.08457711],
#        [0.06467662],
#        [0.05472637],
#        [0.02985075],
#        [0.08457711],
#        [0.10447761],
#        [0.07960199],
#        [0.07960199],
#        [0.09452736],
#        [0.04975124],
#        [0.07960199],
#        [0.05472637],
#        [0.039801  ],
#        [0.05970149],
#        [0.04975124],
#        [0.09452736],
#        [0.08457711],
#        [0.35820896],
#        [0.1641791 ],
#        [0.14427861],
#        [0.07462687],
#        [0.09950249],
#        [0.10447761],
#        [0.11442786],
#        [0.04975124],
#        [0.04975124],
#        [0.10447761],
#        [0.11940299],
#        [0.10945274],
#        [0.10447761],
#        [0.09950249],
#        [0.08457711],
#        [0.04477612],
#        [0.06965174],
#        [0.04477612],
#        [0.08955224],
#        [0.07960199],
#        [0.03482587],
#        [0.05970149],
#        [0.05472637],
#        [0.07960199],
#        [0.11442786],
#        [0.05472637],
#        [0.11442786],
#        [0.07960199],
#        [0.07960199],
#        [0.08955224],
#        [0.09452736],
#        [0.09950249],
#        [0.05472637],
#        [0.07462687],
#        [0.08955224],
#        [0.04975124],
#        [0.06467662],
#        [0.09452736],
#        [0.05472637],
#        [0.08457711],
#        [0.11442786],
#        [0.10447761],
#        [0.08457711],
#        [0.08955224],
#        [0.07960199],
#        [0.06467662],
#        [0.11940299],
#        [0.11442786],
#        [0.13432836],
#        [0.07960199],
#        [0.02985075],
#        [0.08457711],
#        [0.12935323],
#        [0.08955224],
#        [0.11940299],
#        [0.07960199],
#        [0.05472637],
#        [0.04975124],
#        [0.08955224],
#        [0.039801  ],
#        [0.07462687],
#        [0.08955224],
#        [0.04477612],
#        [0.06965174],
#        [0.03482587],
#        [0.02985075],
#        [0.07960199],
#        [0.05472637],
#        [0.07960199],
#        [0.039801  ],
#        [0.06467662],
#        [0.07462687],
#        [0.05472637],
#        [0.0199005 ],
#        [0.13930348],
#        [0.06467662],
#        [0.08457711],
#        [0.06965174],
#        [0.08457711],
#        [0.0199005 ],
#        [0.09950249],
#        [0.07960199],
#        [0.09452736],
#        [0.03482587],
#        [0.06467662],
#        [0.09950249],
#        [0.04477612],
#        [0.03482587],
#        [0.06467662],
#        [0.09452736],
#        [0.10447761],
#        [0.07960199],
#        [0.04975124],
#        [0.05970149],
#        [0.05970149],
#        [0.06965174],
#        [0.11940299],
#        [0.09950249],
#        [0.07462687],
#        [0.04975124],
#        [0.08955224],
#        [0.07462687],
#        [0.07462687],
#        [0.039801  ],
#        [0.07960199],
#        [0.02985075],
#        [0.01492537],
#        [0.06467662],
#        [0.08955224],
#        [0.05970149],
#        [0.039801  ],
#        [0.03482587],
#        [0.07462687],
#        [0.07960199],
#        [0.07960199],
#        [0.05970149],
#        [0.05970149],
#        [0.11442786],
#        [0.00995025],
#        [0.07462687],
#        [0.10447761],
#        [0.08457711],
#        [0.20895522],
#        [0.15422886],
#        [0.11940299],
#        [0.05472637],
#        [0.08955224],
#        [0.08457711],
#        [0.06467662],
#        [0.07960199],
#        [0.07462687],
#        [0.10945274],
#        [0.06965174],
#        [0.05472637],
#        [0.02487562],
#        [0.05970149],
#        [0.04477612],
#        [0.09950249],
#        [0.06467662],
#        [0.06965174],
#        [0.05472637],
#        [0.09452736],
#        [0.07462687],
#        [0.10447761],
#        [0.07960199],
#        [0.15920398],
#        [0.10945274],
#        [0.06467662],
#        [0.07960199],
#        [0.        ],
#        [0.08955224],
#        [0.10447761],
#        [0.07462687],
#        [0.05472637],
#        [0.06467662],
#        [0.07960199],
#        [0.03482587],
#        [0.039801  ],
#        [0.08457711],
#        [0.08955224],
#        [0.0199005 ],
#        [0.05472637],
#        [0.039801  ],
#        [0.02985075],
#        [0.05970149],
#        [0.07960199],
#        [0.12935323],
#        [0.08955224],
#        [0.05970149],
#        [0.05970149],
#        [0.07462687],
#        [0.00995025],
#        [0.03482587],
#        [0.08457711],
#        [0.04477612],
#        [0.02985075],
#        [0.05970149],
#        [0.06965174],
#        [0.04975124],
#        [0.04975124],
#        [0.0199005 ],
#        [0.07462687],
#        [0.07462687],
#        [0.05472637],
#        [0.06965174],
#        [0.05970149],
#        [0.02487562],
#        [0.1840796 ],
#        [0.25373134],
#        [0.22885572],
#        [0.09452736],
#        [0.04477612],
#        [0.04477612],
#        [0.10945274],
#        [0.09950249],
#        [0.13930348],
#        [0.06467662],
#        [0.03482587],
#        [0.04477612],
#        [0.10945274],
#        [0.09950249],
#        [0.08457711],
#        [0.08457711],
#        [0.05472637],
#        [0.07462687],
#        [0.039801  ],
#        [0.01492537],
#        [0.05472637],
#        [0.039801  ],
#        [0.07960199],
#        [0.04975124],
#        [0.0199005 ],
#        [0.0199005 ],
#        [0.08457711],
#        [0.11442786],
#        [0.07462687],
#        [0.06965174],
#        [0.08457711],
#        [0.05970149],
#        [0.02985075],
#        [0.07462687],
#        [0.04975124],
#        [0.04975124],
#        [0.07960199],
#        [0.05970149],
#        [0.04975124],
#        [0.06965174],
#        [0.05970149],
#        [0.04975124],
#        [0.05970149],
#        [0.04975124],
#        [0.03482587],
#        [0.039801  ],
#        [0.02985075],
#        [0.06467662],
#        [0.04975124],
#        [0.07462687],
#        [0.03482587],
#        [0.04975124],
#        [0.07462687],
#        [0.04477612]])

# %%
test = scaler.fit_transform(test)
test
# Out:
# array([[0.21666667],
#        [0.16666667],
#        [0.1       ],
#        [0.13333333],
#        [0.26666667],
#        [0.25      ],
#        [0.26666667],
#        [0.21666667],
#        [0.31666667],
#        [0.45      ],
#        [0.25      ],
#        [0.1       ],
#        [0.21666667],
#        [0.16666667],
#        [0.16666667],
#        [0.21666667],
#        [0.1       ],
#        [0.13333333],
#        [0.25      ],
#        [0.08333333],
#        [0.11666667],
#        [0.4       ],
#        [0.16666667],
#        [0.21666667],
#        [0.13333333],
#        [0.06666667],
#        [0.25      ],
#        [0.1       ],
#        [0.06666667],
#        [0.26666667],
#        [0.16666667],
#        [0.25      ],
#        [0.23333333],
#        [0.18333333],
#        [0.2       ],
#        [0.26666667],
#        [0.26666667],
#        [0.18333333],
#        [0.13333333],
#        [0.15      ],
#        [0.21666667],
#        [0.23333333],
#        [0.01666667],
#        [0.1       ],
#        [0.21666667],
#        [0.05      ],
#        [0.13333333],
#        [0.15      ],
#        [0.25      ],
#        [0.31666667],
#        [0.26666667],
#        [0.26666667],
#        [0.18333333],
#        [0.16666667],
#        [0.3       ],
#        [0.28333333],
#        [0.23333333],
#        [0.31666667],
#        [0.43333333],
#        [0.31666667],
#        [0.11666667],
#        [0.23333333],
#        [0.26666667],
#        [0.3       ],
#        [0.56666667],
#        [0.21666667],
#        [0.18333333],
#        [0.15      ],
#        [0.21666667],
#        [0.26666667],
#        [0.2       ],
#        [0.28333333],
#        [0.28333333],
#        [0.28333333],
#        [0.15      ],
#        [0.28333333],
#        [0.25      ],
#        [0.28333333],
#        [0.36666667],
#        [0.26666667],
#        [0.26666667],
#        [1.        ],
#        [0.36666667],
#        [0.3       ],
#        [0.26666667],
#        [0.35      ],
#        [0.4       ],
#        [0.28333333],
#        [0.13333333],
#        [0.2       ],
#        [0.28333333],
#        [0.36666667],
#        [0.31666667],
#        [0.51666667],
#        [0.16666667],
#        [0.33333333],
#        [0.18333333],
#        [0.21666667],
#        [0.16666667],
#        [0.15      ],
#        [0.35      ],
#        [0.3       ],
#        [0.3       ],
#        [0.31666667],
#        [0.16666667],
#        [0.25      ],
#        [0.28333333],
#        [0.13333333],
#        [0.15      ],
#        [0.21666667],
#        [0.06666667],
#        [0.05      ],
#        [0.18333333],
#        [0.08333333],
#        [0.08333333],
#        [0.23333333],
#        [0.28333333],
#        [0.36666667],
#        [0.3       ],
#        [0.2       ],
#        [0.25      ],
#        [0.36666667],
#        [0.23333333],
#        [0.23333333],
#        [0.28333333],
#        [0.25      ],
#        [0.1       ],
#        [0.25      ],
#        [0.26666667],
#        [0.28333333],
#        [0.16666667],
#        [0.16666667],
#        [0.16666667],
#        [0.15      ],
#        [0.03333333],
#        [0.13333333],
#        [0.18333333],
#        [0.25      ],
#        [0.1       ],
#        [0.18333333],
#        [0.15      ],
#        [0.31666667],
#        [0.26666667],
#        [0.18333333],
#        [0.21666667],
#        [0.08333333],
#        [0.18333333],
#        [0.23333333],
#        [0.03333333],
#        [0.28333333],
#        [0.16666667],
#        [0.03333333],
#        [0.1       ],
#        [0.26666667],
#        [0.26666667],
#        [0.31666667],
#        [0.13333333],
#        [0.2       ],
#        [0.16666667],
#        [0.16666667],
#        [0.33333333],
#        [0.25      ],
#        [0.11666667],
#        [0.15      ],
#        [0.25      ],
#        [0.28333333],
#        [0.25      ],
#        [0.13333333],
#        [0.2       ],
#        [0.13333333],
#        [0.35      ],
#        [0.45      ],
#        [0.15      ],
#        [0.16666667],
#        [0.06666667],
#        [0.21666667],
#        [0.26666667],
#        [0.21666667],
#        [0.11666667],
#        [0.08333333],
#        [0.11666667],
#        [0.15      ],
#        [0.2       ],
#        [0.28333333],
#        [0.31666667],
#        [0.31666667],
#        [0.21666667],
#        [0.18333333],
#        [0.08333333],
#        [0.16666667],
#        [0.3       ],
#        [0.11666667],
#        [0.05      ],
#        [0.08333333],
#        [0.16666667],
#        [0.13333333],
#        [0.26666667],
#        [0.18333333],
#        [0.23333333],
#        [0.11666667],
#        [0.21666667],
#        [0.05      ],
#        [0.15      ],
#        [0.13333333],
#        [0.2       ],
#        [0.18333333],
#        [0.35      ],
#        [0.23333333],
#        [0.08333333],
#        [0.15      ],
#        [0.38333333],
#        [0.28333333],
#        [0.13333333],
#        [0.21666667],
#        [0.16666667],
#        [0.11666667],
#        [0.21666667],
#        [0.21666667],
#        [0.        ],
#        [0.03333333]])

# %% [markdown]
# Configure LSTM model

# %%
# Lookback period
lookback = 5
X_train, Y_train = create_dataset(train, lookback)
X_test, Y_test = create_dataset(test, lookback)

# %%
X_train
# Out:
# array([[0.14427861, 0.09950249, 0.09452736, 0.14427861, 0.11442786],
#        [0.09950249, 0.09452736, 0.14427861, 0.11442786, 0.08955224],
#        [0.09452736, 0.14427861, 0.11442786, 0.08955224, 0.09452736],
#        ...,
#        [0.039801  , 0.02985075, 0.06467662, 0.04975124, 0.07462687],
#        [0.02985075, 0.06467662, 0.04975124, 0.07462687, 0.03482587],
#        [0.06467662, 0.04975124, 0.07462687, 0.03482587, 0.04975124]])

# %%
Y_train
# Out:
# array([0.08955224, 0.09452736, 0.09950249, 0.06965174, 0.08955224,
#        0.07960199, 0.12437811, 0.06965174, 0.06965174, 0.06467662,
#        0.08457711, 0.03482587, 0.07960199, 0.13432836, 0.11940299,
#        0.09950249, 0.08955224, 0.13432836, 0.1840796 , 0.10945274,
#        0.12437811, 0.10447761, 0.07960199, 0.11442786, 0.11442786,
#        0.04477612, 0.10945274, 0.06467662, 0.10447761, 0.06467662,
#        0.02487562, 0.06467662, 0.05970149, 0.08457711, 0.13930348,
#        0.06467662, 0.13930348, 0.09452736, 0.08955224, 0.15422886,
#        0.15422886, 0.13930348, 0.15920398, 0.18905473, 0.1641791 ,
#        0.17910448, 0.17412935, 0.14427861, 0.13432836, 0.11940299,
#        0.05472637, 0.09452736, 0.08457711, 0.11442786, 0.039801  ,
#        0.09452736, 0.039801  , 0.11442786, 0.08955224, 0.05472637,
#        0.08457711, 0.09950249, 0.05472637, 0.07462687, 0.09950249,
#        0.11940299, 0.09452736, 0.09452736, 0.11940299, 0.08457711,
#        0.12935323, 0.07960199, 0.07462687, 0.11442786, 0.10945274,
#        0.15920398, 0.07960199, 0.08457711, 0.09452736, 0.11940299,
#        0.10945274, 0.07960199, 0.12935323, 0.07462687, 0.07960199,
#        0.13930348, 0.1641791 , 0.15422886, 0.1840796 , 0.26368159,
#        0.23383085, 0.09950249, 0.0199005 , 0.04975124, 0.09950249,
#        0.06965174, 0.12437811, 0.08457711, 0.10447761, 0.15422886,
#        0.10945274, 0.12437811, 0.11442786, 0.13432836, 0.11442786,
#        0.09950249, 0.08457711, 0.039801  , 0.11442786, 0.09950249,
#        0.08457711, 0.07960199, 0.12437811, 0.12437811, 0.05970149,
#        0.07960199, 0.11442786, 0.07960199, 0.039801  , 0.07960199,
#        0.07960199, 0.06965174, 0.07960199, 0.09950249, 0.05970149,
#        0.10945274, 0.09950249, 0.08955224, 0.09452736, 0.10945274,
#        0.15422886, 0.08457711, 0.07462687, 0.09452736, 0.09452736,
#        0.03482587, 0.07462687, 0.09452736, 0.10447761, 0.05970149,
#        0.08955224, 0
#        0.07960199, 0.03482587, 0.039801  , 0.08457711, 0.08955224,
#        0.0199005 , 0.05472637, 0.039801  , 0.02985075, 0.05970149,
#        0.07960199, 0.12935323, 0.08955224, 0.05970149, 0.05970149,
#        0.07462687, 0.00995025, 0.03482587, 0.08457711, 0.04477612,
#        0.02985075, 0.05970149, 0.06965174, 0.04975124, 0.04975124,
#        0.0199005 , 0.07462687, 0.07462687, 0.05472637, 0.06965174,
#        0.05970149, 0.02487562, 0.1840796 , 0.25373134, 0.22885572,
#        0.09452736, 0.04477612, 0.04477612, 0.10945274, 0.09950249,
#        0.13930348, 0.06467662, 0.03482587, 0.04477612, 0.10945274,
#        0.09950249, 0.08457711, 0.08457711, 0.05472637, 0.07462687,
#        0.039801  , 0.01492537, 0.05472637, 0.039801  , 0.07960199,
#        0.04975124, 0.0199005 , 0.0199005 , 0.08457711, 0.11442786,
#        0.07462687, 0.06965174, 0.08457711, 0.05970149, 0.02985075,
#        0.07462687, 0.04975124, 0.04975124, 0.07960199, 0.05970149,
#        0.04975124, 0.06965174, 0.05970149, 0.04975124, 0.05970149,
#        0.04975124, 0.03482587, 0.039801  , 0.02985075, 0.06467662,
#        0.04975124, 0.07462687, 0.03482587, 0.04975124, 0.07462687])

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
X_train.shape[0]
# Out:
# 870

# %%
X_train.shape[1]
# Out:
# 1

# %%
X_train.shape
# Out:
# (870, 1, 5)

# %% [markdown]
# #LSTM - The model
# We have reached the final step - design, fit, and train the LSTM model. Our LSTM layer is 4-noded 1-layered, plus a dense output layer with MSE as loss function, adam as the optimiser, and trained for 100 epochs.

# %%
# Generate LSTM network
model = tf.keras.Sequential()
model.add(LSTM(4, input_shape=(1, lookback)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
history=model.fit(X_train, Y_train, validation_split=0.2, epochs=100, batch_size=1, verbose=2)

# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# Epoch 1/100
# 696/696 - 10s - loss: 0.0026 - val_loss: 0.0013 - 10s/epoch - 15ms/step
# Epoch 2/100
# 696/696 - 3s - loss: 0.0025 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 3/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 4/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 5/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 6/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0023 - 2s/epoch - 4ms/step
# Epoch 7/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 8/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 9/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 10/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 11/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 12/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 13/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 14/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 15/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 16/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 17/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 18/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 19/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 20/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 21/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 22/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 23/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 24/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 25/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 26/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 27/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 28/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 29/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0011 - 3s/epoch - 4ms/step
# Epoch 30/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 31/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 32/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 33/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 34/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 35/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 36/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 37/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 38/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 39/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 40/100
# 696/696 - 3s - loss: 0.0023 - val_loss: 0.0012 - 3s/epoch - 5ms/step
# Epoch 41/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 42/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 43/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 44/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 45/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 46/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 47/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 48/100
# 696/696 - 3s - loss: 0.0023 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 49/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 50/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 51/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 52/100
# 696/696 - 3s - loss: 0.0023 - val_loss: 0.0011 - 3s/epoch - 4ms/step
# Epoch 53/100
# 696/696 - 4s - loss: 0.0024 - val_loss: 0.0012 - 4s/epoch - 6ms/step
# Epoch 54/100
# 696/696 - 4s - loss: 0.0024 - val_loss: 0.0013 - 4s/epoch - 6ms/step
# Epoch 55/100
# 696/696 - 4s - loss: 0.0023 - val_loss: 0.0012 - 4s/epoch - 6ms/step
# Epoch 56/100
# 696/696 - 4s - loss: 0.0024 - val_loss: 0.0011 - 4s/epoch - 6ms/step
# Epoch 57/100
# 696/696 - 4s - loss: 0.0024 - val_loss: 0.0012 - 4s/epoch - 6ms/step
# Epoch 58/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 5ms/step
# Epoch 59/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 60/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 61/100
# 696/696 - 3s - loss: 0.0023 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 62/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 63/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 64/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 65/100
# 696/696 - 3s - loss: 0.0023 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 66/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 67/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 68/100
# 696/696 - 3s - loss: 0.0023 - val_loss: 0.0024 - 3s/epoch - 4ms/step
# Epoch 69/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 70/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 71/100
# 696/696 - 3s - loss: 0.0023 - val_loss: 0.0020 - 3s/epoch - 4ms/step
# Epoch 72/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 73/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 74/100
# 696/696 - 3s - loss: 0.0023 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 75/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 76/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 77/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 78/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 79/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 80/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 81/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 82/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 83/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 84/100
# 696/696 - 3s - loss: 0.0023 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 85/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0018 - 2s/epoch - 4ms/step
# Epoch 86/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0019 - 3s/epoch - 4ms/step
# Epoch 87/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 88/100
# 696/696 - 3s - loss: 0.0023 - val_loss: 0.0020 - 3s/epoch - 4ms/step
# Epoch 89/100
# 696/696 - 3s - loss: 0.0023 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 90/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 91/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 92/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 93/100
# 696/696 - 3s - loss: 0.0023 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 94/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 95/100
# 696/696 - 4s - loss: 0.0024 - val_loss: 0.0013 - 4s/epoch - 5ms/step
# Epoch 96/100
# 696/696 - 3s - loss: 0.0023 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 97/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 98/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 99/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 100/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# dict_keys(['loss', 'val_loss'])

# %% [markdown]
# #LSTM - Prediction
# Once we have trained our model, we can start doing predictions. Then, manipulate the post-action data.

# %%
# Generate predictions
trainpred = model.predict(X_train)
testpred = model.predict(X_test)

# %%
trainpred
# Out:
# array([[0.10372536],
#        [0.09207787],
#        [0.09521824],
#        [0.09592076],
#        [0.08480784],
#        [0.08893121],
#        [0.08806895],
#        [0.09955549],
#        [0.0867609 ],
#        [0.08106647],
#        [0.08313684],
#        [0.08580697],
#        [0.07101899],
#        [0.08064962],
#        [0.1041593 ],
#        [0.10008201],
#        [0.09445731],
#        [0.09365291],
#        [0.1069636 ],
#        [0.12529323],
#        [0.10395616],
#        [0.10513346],
#        [0.10342702],
#        [0.08968364],
#        [0.09985559],
#        [0.10173519],
#        [0.07695917],
#        [0.09453197],
#        [0.08624636],
#        [0.08983657],
#        [0.08483574],
#        [0.06546981],
#        [0.07809576],
#        [0.07786104],
#        [0.08156311],
#        [0.10420745],
#        [0.08427785],
#        [0.10341313],
#        [0.09926506],
#        [0.08868182],
#        [0.11433809],
#        [0.11705881],
#        [0.11100288],
#        [0.12014638],
#        [0.1313381 ],
#        [0.12460209],
#        [0.12836118],
#        [0.12937933],
#        [0.11820259],
#        [0.11366753],
#        [0.10819262],
#        [0.08467252],
#        [0.09203908],
#        [0.09176384],
#        [0.09575431],
#        [0.07645389],
#        [0.08722627],
#        [0.0768986 ],
#        [0.0907874 ],
#        [0.09296665],
#        [0.0751361 ],
#        [0.08725141],
#        [0.09377792],
#        [0.07751614],
#        [0.0818843 ],
#        [0.0934057 ],
#        [0.09873665],
#        [0.09305289],
#        [0.09259177],
#        [0.10239289],
#        [0.09163034],
#        [0.10291867],
#        [0.0923473 ],
#        [0.08399108],
#        [0.09990168],
#        [0.09864711],
#        [0.11325695],
#        [0.09402129],
#        [0.08851862],
#        [0.09612504],
#        [0.10031556],
#        [0.09880581],
#        [0.08867276],
#        [0.10426743],
#        [0.0903379 ],
#        [0.08478861],
#        [0.10837313],
#        [0.11794358],
#        [0.11606717],
#        [0.12832148],
#        [0.1567895 ],
#        [0.15199867],
#        [0.10800884],
#        [0.07670063],
#        [0.08092561],
#        [0.09287228],
#        [0.08040724],
#        [0.0964738 ],
#        [0.09222642],
#        [0.09303252],
#        [0.11469041],
#        [0.10177143],
#        [0.10351285],
#        [0.10500014],
#        [0.10810803],
#        [0.10402773],
#        [0.09685203],
#        [0.09224434],
#        [0.07559473],
#        [0.09527712],
#        [0.09597997],
#        [0.0856327 ],
#        [0.08795331],
#        [0.10174157],
#        [0.10435324],
#        [0.08235505],
#        [0.0865524 ],
#        [0.10041253],
#        [0.08754156],
#        [0.07213351],
#        [0.08478626],
#        [0.08645558],
#        [0.07952997],
#        [0.08452599],
#        [0.09225409],
#        [0.08018357],
#        [0.0934022 ],
#        [0.09615214],
#        [0.0889042 ],
#        [0.09299675],
#        [0.09800998],
#        [0.11296941],
#        [0.09408584],
#        [0.08563696],
#        [0.09502386],
#        [0.09267226],
#        [0.07188978],
#        [0.08115242],
#        [0.09177046],
#        [0.09197772],
#        [0.08041176],
#        [0.08795218],
#        [0.0933451 ],
#        [0.08394998],
#        [0.07915071],
#        [0.08841637],
#        [0.07847944],
#        [0.09005469],
#        [0.09984639],
#        [0.09628345],
#        [0.07631005],
#        [0.08134582],
#        [0.08598419],
#        [0.09083877],
#        [0.07392927],
#        [0.0783202 ],
#        [0.08376786],
#        [0.07259317],
#        [0.08061756],
#        [0.09130289],
#        [0.09328239],
#        [0.10472569],
#        [0.08632088],
#        [0.09209144],
#        [0.09115675],
#        [0.10581623],
#        [0.09864561],
#        [0.07685255],
#        [0.09057096],
#        [0.09348063],
#        [0.08966619],
#        [0.08396531],
#        [0.09061219],
#        [0.08170948],
#        [0.0977997 ],
#        [0.09698127],
#        [0.09190557],
#        [0.09314805],
#        [0.08464406],
#        [0.08622304],
#        [0.09631011],
#        [0.09723289],
#        [0.08769149],
#        [0.09543669],
#        [0.11082139],
#        [0.08444845],
#        [0.10612175],
#        [0.08728214],
#        [0.0735523 ],
#        [0.09129541],
#        [0.09691184],
#        [0.078436  ],
#        [0.09342983],
#        [0.09399083],
#        [0.09755538],
#        [0.0987134 ],
#        [0.08160841],
#        [0.08650588],
#        [0.08304324],
#        [0.08641408],
#        [0.06886083],
#        [0.07657956],
#        [0.10859643],
#        [0.09599116],
#        [0.07924089],
#        [0.08348182],
#        [0.09652627],
#        [0.10814045],
#        [0.11050081],
#        [0.10337839],
#        [0.10011062],
#        [0.10140223],
#        [0.10175816],
#        [0.11101204],
#        [0.10228294],
#        [0.32222062],
#        [0.20804025],
#        [0.13280632],
#        [0.1115564 ],
#        [0.10476588],
#        [0.10323003],
#        [0.10082466],
#        [0.08041234],
#        [0.08961307],
#        [0.09263523],
#        [0.09898081],
#        [0.09973422],
#        [0.11100949],
#        [0.10033225],
#        [0.09841247],
#        [0.09243432],
#        [0.07577038],
#        [0.07691225],
#        [0.07301414],
#        [0.08856851],
#        [0.10872598],
#        [0.10309964],
#        [0.08834126],
#        [0.07489517],
#        [0.077468  ],
#        [0.07774781],
#        [0.09229058],
#        [0.09802849],
#        [0.09138601],
#        [0.1048969 ],
#        [0.08559573],
#        [0.07653021],
#        [0.07763729],
#        [0.0889343 ],
#        [0.0922616 ],
#        [0.08634683],
#        [0.08862071],
#        [0.09558581],
#        [0.09783618],
#        [0.07207616],
#        [0.07324331],
#        [0.07798776],
#        [0.09512901],
#        [0.11623344],
#        [0.10031896],
#        [0.09314691],
#        [0.10326622],
#        [0.09410685],
#        [0.0820647 ],
#        [0.09646122],
#        [0.11176823],
#        [0.18117973],
#        [0.16630538],
#        [0.10556797],
#        [0.10775044],
#        [0.09129006],
#        [0.08908954],
#        [0.0917346 ],
#        [0.09000061],
#        [0.08571155],
#        [0.08905949],
#        [0.11666597],
#        [0.08791241],
#        [0.08067356],
#        [0.08595543],
#        [0.07130696],
#        [0.09623647],
#        [0.09687173],
#        [0.08250745],
#        [0.08452374],
#        [0.08367826],
#        [0.09612078],
#        [0.07993525],
#        [0.0920723 ],
#        [0.100294  ],
#        [0.08625813],
#        [0.09691294],
#        [0.09673126],
#        [0.09360673],
#        [0.09553295],
#        [0.09182712],
#        [0.07642829],
#        [0.08094407],
#        [0.09094878],
#        [0.08465262],
#        [0.08287356],
#        [0.07814879],
#        [0.08861484],
#        [0.07884907],
#        [0.07988004],
#        [0.09446648],
#        [0.08780484],
#        [0.09332666],
#        [0.08768685],
#        [0.07897485],
#        [0.09876257],
#        [0.08427303],
#        [0.0823823 ],
#        [0.0932195 ],
#        [0.08940436],
#        [0.09752654],
#        [0.08298394],
#        [0.08923282],
#        [0.09273574],
#        [0.09648896],
#        [0.0796348 ],
#        [0.08029398],
#        [0.08119007],
#        [0.08386421],
#        [0.0918535 ],
#        [0.10358015],
#        [0.09983887],
#        [0.10502932],
#        [0.10101694],
#        [0.09423742],
#        [0.09325816],
#        [0.08990812],
#        [0.09361121],
#        [0.0783686 ],
#        [0.07848264],
#        [0.08942291],
#        [0.06546514],
#        [0.07428627],
#        [0.10019988],
#        [0.07903659],
#        [0.08347272],
#        [0.09079716],
#        [0.0833351 ],
#        [0.072488  ],
#        [0.07794389],
#        [0.07818171],
#        [0.08767932],
#        [0.0862233 ],
#        [0.07737712],
#        [0.10143913],
#        [0.10467176],
#        [0.10841967],
#        [0.09833832],
#        [0.10067302],
#        [0.08140697],
#        [0.0789332 ],
#        [0.08409297],
#        [0.08280618],
#        [0.07960626],
#        [0.07873314],
#        [0.08452885],
#        [0.09449854],
#        [0.09023775],
#        [0.09248441],
#        [0.1101671 ],
#        [0.09320974],
#        [0.0834366 ],
#        [0.08271035],
#        [0.08173294],
#        [0.07315466],
#        [0.09590302],
#        [0.09384881],
#        [0.06913039],
#        [0.07176061],
#        [0.07625889],
#        [0.07932996],
#        [0.06459007],
#        [0.07565789],
#        [0.08175015],
#        [0.07277522],
#        [0.07607415],
#        [0.10937697],
#        [0.09083528],
#        [0.07481803],
#        [0.09198476],
#        [0.10512365],
#        [0.09646374],
#        [0.09891988],
#        [0.10309431],
#        [0.0997566 ],
#        [0.10145435],
#        [0.09872232],
#        [0.08624386],
#        [0.08709165],
#        [0.0828799 ],
#        [0.10009301],
#        [0.0979728 ],
#        [0.08926164],
#        [0.11203683],
#        [0.14094965],
#        [0.12647589],
#        [0.13107187],
#        [0.11419503],
#        [0.12570773],
#        [0.12180746],
#        [0.09141859],
#        [0.07964556],
#        [0.08800779],
#        [0.07669045],
#        [0.08700012],
#        [0.08260977],
#        [0.07547091],
#        [0.08052024],
#        [0.09185195],
#        [0.07999191],
#        [0.06627333],
#        [0.0753455 ],
#        [0.07498073],
#        [0.08970172],
#        [0.08955722],
#        [0.07601804],
#        [0.09348405],
#        [0.0953722 ],
#        [0.09664878],
#        [0.09949999],
#        [0.09888709],
#        [0.12081595],
#        [0.08707372],
#        [0.08629538],
#        [0.10199183],
#        [0.07902375],
#        [0.06401504],
#        [0.08313596],
#        [0.1155139 ],
#        [0.08604832],
#        [0.07832056],
#        [0.09380876],
#        [0.08511484],
#        [0.11636248],
#        [0.1468324 ],
#        [0.10232581],
#        [0.07998793],
#        [0.10076171],
#        [0.09188274],
#        [0.08171026],
#        [0.07216537],
#        [0.07767959],
#        [0.08790154],
#        [0.0866529 ],
#        [0.08980986],
#        [0.08413126],
#        [0.09675119],
#        [0.08813854],
#        [0.11502785],
#        [0.13221782],
#        [0.10173672],
#        [0.09402236],
#        [0.10114686],
#        [0.07715251],
#        [0.09067277],
#        [0.09953298],
#        [0.08194045],
#        [0.06979469],
#        [0.08715172],
#        [0.07868616],
#        [0.07473302],
#        [0.078594  ],
#        [0.08731993],
#        [0.08753978],
#        [0.07948756],
#        [0.07557727],
#        [0.09676528],
#        [0.09323402],
#        [0.09059672],
#        [0.08798551],
#        [0.08629373],
#        [0.09688045],
#        [0.08634625],
#        [0.09293623],
#        [0.08172449],
#        [0.08149316],
#        [0.07917453],
#        [0.08041522],
#        [0.09954543],
#        [0.08771893],
#        [0.06998214],
#        [0.08502372],
#        [0.09303485],
#        [0.09058386],
#        [0.08028278],
#        [0.08515242],
#        [0.07776096],
#        [0.07378678],
#        [0.09186827],
#        [0.0876024 ],
#        [0.09507245],
#        [0.09482216],
#        [0.09181984],
#        [0.08423582],
#        [0.08389209],
#        [0.07530898],
#        [0.08669607],
#        [0.09333944],
#        [0.09269322],
#        [0.08503539],
#        [0.07953181],
#        [0.07953979],
#        [0.07247508],
#        [0.08145219],
#        [0.08937435],
#        [0.08910206],
#        [0.08646482],
#        [0.08650869],
#        [0.08841201],
#        [0.09265497],
#        [0.07919589],
#        [0.08530532],
#        [0.09582973],
#        [0.08447264],
#        [0.0883455 ],
#        [0.09310676],
#        [0.10440485],
#        [0.07776593],
#        [0.07790907],
#        [0.10629141],
#        [0.08173169],
#        [0.07213978],
#        [0.08864012],
#        [0.10810561],
#        [0.09244839],
#        [0.08574419],
#        [0.08850174],
#        [0.0880391 ],
#        [0.08460519],
#        [0.08483098],
#        [0.07797593],
#        [0.08164425],
#        [0.0903675 ],
#        [0.08360575],
#        [0.08613136],
#        [0.09520538],
#        [0.09228554],
#        [0.08851464],
#        [0.08438873],
#        [0.07469133],
#        [0.10762888],
#        [0.09011839],
#        [0.091335  ],
#        [0.09109113],
#        [0.0898804 ],
#        [0.08088179],
#        [0.06871955],
#        [0.0784146 ],
#        [0.08013166],
#        [0.06861269],
#        [0.0809646 ],
#        [0.0773185 ],
#        [0.07243752],
#        [0.08195657],
#        [0.08863876],
#        [0.08016872],
#        [0.08367408],
#        [0.07236993],
#        [0.08740896],
#        [0.09260224],
#        [0.08662748],
#        [0.10678524],
#        [0.09802085],
#        [0.08893757],
#        [0.08658813],
#        [0.09947667],
#        [0.09279782],
#        [0.10478012],
#        [0.09777482],
#        [0.08704685],
#        [0.09755509],
#        [0.08268875],
#        [0.09352181],
#        [0.09646781],
#        [0.09218335],
#        [0.11157355],
#        [0.11511976],
#        [0.09838318],
#        [0.09755719],
#        [0.0966529 ],
#        [0.09650256],
#        [0.09869467],
#        [0.11318643],
#        [0.10116915],
#        [0.09053624],
#        [0.09720221],
#        [0.08615312],
#        [0.0818636 ],
#        [0.07831096],
#        [0.09286353],
#        [0.09577698],
#        [0.09198393],
#        [0.08079067],
#        [0.09176012],
#        [0.08431523],
#        [0.09222566],
#        [0.08948849],
#        [0.08434267],
#        [0.07631866],
#        [0.09269771],
#        [0.09181909],
#        [0.08843093],
#        [0.09503432],
#        [0.08316223],
#        [0.08366303],
#        [0.09013345],
#        [0.07760841],
#        [0.07650795],
#        [0.0753156 ],
#        [0.08330071],
#        [0.08002171],
#        [0.07390526],
#        [0.06780396],
#        [0.08236411],
#        [0.09289765],
#        [0.08386897],
#        [0.08534241],
#        [0.09224075],
#        [0.07742152],
#        [0.08297208],
#        [0.07902171],
#        [0.06859457],
#        [0.07594623],
#        [0.07306716],
#        [0.0850708 ],
#        [0.08718118],
#        [0.17255609],
#        [0.13516453],
#        [0.11049845],
#        [0.1014819 ],
#        [0.09713204],
#        [0.09992803],
#        [0.098891  ],
#        [0.07986012],
#        [0.07490597],
#        [0.0941684 ],
#        [0.09925554],
#        [0.09603941],
#        [0.09723444],
#        [0.09657939],
#        [0.09084536],
#        [0.07641208],
#        [0.08104168],
#        [0.07453085],
#        [0.08355518],
#        [0.08596428],
#        [0.06838937],
#        [0.07590602],
#        [0.07661402],
#        [0.08050853],
#        [0.09548952],
#        [0.07862101],
#        [0.09432779],
#        [0.09111691],
#        [0.08365441],
#        [0.09109199],
#        [0.09159335],
#        [0.09324843],
#        [0.07974041],
#        [0.08284125],
#        [0.09025238],
#        [0.07528789],
#        [0.07762473],
#        [0.09028588],
#        [0.07702893],
#        [0.08366993],
#        [0.09858289],
#        [0.09497155],
#        [0.08908039],
#        [0.0913917 ],
#        [0.08833238],
#        [0.08121184],
#        [0.09809885],
#        [0.10051568],
#        [0.1048274 ],
#        [0.09223929],
#        [0.07139377],
#        [0.08713377],
#        [0.10323005],
#        [0.08948568],
#        [0.09886613],
#        [0.09204673],
#        [0.07806138],
#        [0.07671605],
#        [0.0870311 ],
#        [0.07228114],
#        [0.07810722],
#        [0.08941858],
#        [0.07249822],
#        [0.07870129],
#        [0.07147176],
#        [0.06339608],
#        [0.08100879],
#        [0.07496645],
#        [0.07939437],
#        [0.07272081],
#        [0.07561673],
#        [0.08310369],
#        [0.07448319],
#        [0.06292078],
#        [0.09989904],
#        [0.08493786],
#        [0.08040211],
#        [0.08658822],
#        [0.08577804],
#        [0.06715814],
#        [0.08637165],
#        [0.08833662],
#        [0.08584138],
#        [0.07336335],
#        [0.07701103],
#        [0.09244558],
#        [0.07319516],
#        [0.06648253],
#        [0.07880728],
#        [0.0875089 ],
#        [0.09165403],
#        [0.08615637],
#        [0.07658838],
#        [0.07856075],
#        [0.07814041],
#        [0.07884863],
#        [0.09633635],
#        [0.09404521],
#        [0.08433326],
#        [0.07796405],
#        [0.08814567],
#        [0.08508955],
#        [0.08128115],
#        [0.07289955],
#        [0.08210861],
#        [0.0697474 ],
#        [0.05748891],
#        [0.07566584],
#        [0.08485807],
#        [0.0749831 ],
#        [0.06933924],
#        [0.06869343],
#        [0.07943331],
#        [0.08277492],
#        [0.08208421],
#        [0.0785078 ],
#        [0.07750015],
#        [0.0955651 ],
#        [0.06503025],
#        [0.07603174],
#        [0.09627175],
#        [0.08468301],
#        [0.12695351],
#        [0.12158749],
#        [0.10354726],
#        [0.08772092],
#        [0.09187082],
#        [0.09148446],
#        [0.0796337 ],
#        [0.08487509],
#        [0.08466372],
#        [0.09393346],
#        [0.08488519],
#        [0.07598829],
#        [0.0680559 ],
#        [0.07445782],
#        [0.07158457],
#        [0.0850745 ],
#        [0.08109826],
#        [0.07815402],
#        [0.07808883],
#        [0.08764578],
#        [0.08481523],
#        [0.09126961],
#        [0.08863297],
#        [0.11103442],
#        [0.10341224],
#        [0.08234935],
#        [0.08932853],
#        [0.06276271],
#        [0.08132935],
#        [0.09538776],
#        [0.08008438],
#        [0.07698918],
#        [0.08061178],
#        [0.0845862 ],
#        [0.06955621],
#        [0.0676828 ],
#        [0.08437461],
#        [0.08661961],
#        [0.06383673],
#        [0.07250597],
#        [0.07223749],
#        [0.06211185],
#        [0.07313046],
#        [0.08149274],
#        [0.09808607],
#        [0.09129044],
#        [0.07922171],
#        [0.08081329],
#        [0.08371122],
#        [0.06171044],
#        [0.06367683],
#        [0.08384654],
#        [0.07026791],
#        [0.06250716],
#        [0.07546679],
#        [0.07894644],
#        [0.07141379],
#        [0.0717174 ],
#        [0.06339337],
#        [0.07706676],
#        [0.0820078 ],
#        [0.07249783],
#        [0.07956794],
#        [0.07831766],
#        [0.06456807],
#        [0.1143743 ],
#        [0.14894983],
#        [0.14294425],
#        [0.10638481],
#        [0.08405519],
#        [0.08092628],
#        [0.095002  ],
#        [0.09277827],
#        [0.1036122 ],
#        [0.08725182],
#        [0.07064886],
#        [0.07503815],
#        [0.09245182],
#        [0.09178786],
#        [0.08566941],
#        [0.08926658],
#        [0.07950897],
#        [0.08240392],
#        [0.07308866],
#        [0.05967275],
#        [0.07209272],
#        [0.06863594],
#        [0.07726076],
#        [0.07417681],
#        [0.06063246],
#        [0.06142733],
#        [0.08078982],
#        [0.09352021],
#        [0.08202474],
#        [0.08149472],
#        [0.08891513],
#        [0.07968241],
#        [0.06705394],
#        [0.08040944],
#        [0.07489885],
#        [0.06958823],
#        [0.0827582 ],
#        [0.07743903],
#        [0.07184868],
#        [0.07994627],
#        [0.07735682],
#        [0.07208118],
#        [0.07599275],
#        [0.07320147],
#        [0.06655057],
#        [0.06767649],
#        [0.0644559 ],
#        [0.0734731 ],
#        [0.07208174],
#        [0.07759868],
#        [0.06968304],
#        [0.06990435]], dtype=float32)

# %%
testpred
# Out:
# array([[0.1547131 ],
#        [0.15521295],
#        [0.16007012],
#        [0.15050226],
#        [0.17672233],
#        [0.21848264],
#        [0.16711447],
#        [0.11188286],
#        [0.1435504 ],
#        [0.13084069],
#        [0.12107849],
#        [0.14329259],
#        [0.10726413],
#        [0.10907415],
#        [0.15162767],
#        [0.10172617],
#        [0.09981887],
#        [0.19630292],
#        [0.13808776],
#        [0.1363659 ],
#        [0.12461682],
#        [0.08977512],
#        [0.14737222],
#        [0.10950945],
#        [0.08000418],
#        [0.15411241],
#        [0.13020174],
#        [0.14510207],
#        [0.15525034],
#        [0.1338704 ],
#        [0.13984023],
#        [0.16061059],
#        [0.16284111],
#        [0.13752636],
#        [0.11875488],
#        [0.12128209],
#        [0.1407001 ],
#        [0.1481183 ],
#        [0.08016119],
#        [0.09476659],
#        [0.14000058],
#        [0.08425294],
#        [0.10032274],
#        [0.12048514],
#        [0.14445332],
#        [0.1757814 ],
#        [0.16488627],
#        [0.16519603],
#        [0.14012225],
#        [0.12864454],
#        [0.16968381],
#        [0.1695532 ],
#        [0.15269986],
#        [0.17975128],
#        [0.2136068 ],
#        [0.18569106],
#        [0.12087086],
#        [0.14946625],
#        [0.16210009],
#        [0.16985649],
#        [0.24910983],
#        [0.16334055],
#        [0.13518217],
#        [0.12602079],
#        [0.14001407],
#        [0.16025741],
#        [0.1411964 ],
#        [0.16561584],
#        [0.17084584],
#        [0.16866468],
#        [0.13030678],
#        [0.16406631],
#        [0.16062748],
#        [0.1649903 ],
#        [0.19617422],
#        [0.16865428],
#        [0.16489051],
#        [0.33012533],
#        [0.21004935],
#        [0.17548236],
#        [0.14636444],
#        [0.17629854],
#        [0.20488547],
#        [0.17478053],
#        [0.12494412],
#        [0.13895212],
#        [0.1655159 ],
#        [0.1912262 ],
#        [0.18401456],
#        [0.23813012],
#        [0.14559384],
#        [0.17987496],
#        [0.14136018],
#        [0.13877021],
#        [0.13362437],
#        [0.11973701],
#        [0.1827273 ],
#        [0.17701991],
#        [0.173355  ],
#        [0.18357828],
#        [0.13594927],
#        [0.15480399],
#        [0.16908135],
#        [0.12109047],
#        [0.12041597],
#        [0.14399303],
#        [0.09539808],
#        [0.07815376],
#        [0.12535827],
#        [0.09598199],
#        [0.08347283],
#        [0.14165659],
#        [0.16272052],
#        [0.19005997],
#        [0.18045035],
#        [0.14607868],
#        [0.15783995],
#        [0.19208972],
#        [0.15784417],
#        [0.15242697],
#        [0.16954249],
#        [0.1587593 ],
#        [0.11071335],
#        [0.15150934],
#        [0.16353017],
#        [0.16431224],
#        [0.13549644],
#        [0.12802069],
#        [0.12913959],
#        [0.11970568],
#        [0.08085672],
#        [0.10480136],
#        [0.12831305],
#        [0.14567336],
#        [0.10774532],
#        [0.12605661],
#        [0.124654  ],
#        [0.16756089],
#        [0.16653776],
#        [0.1349719 ],
#        [0.14720163],
#        [0.10510163],
#        [0.12500872],
#        [0.14954785],
#        [0.08264728],
#        [0.15376298],
#        [0.1358399 ],
#        [0.07197654],
#        [0.10000078],
#        [0.15286611],
#        [0.15735509],
#        [0.17492808],
#        [0.12741484],
#        [0.13643053],
#        [0.13188195],
#        [0.12304662],
#        [0.17832483],
#        [0.16144677],
#        [0.11299998],
#        [0.12264444],
#        [0.15296787],
#        [0.16471647],
#        [0.15782548],
#        [0.12245549],
#        [0.13745739],
#        [0.11994268],
#        [0.17815202],
#        [0.21957125],
#        [0.13506752],
#        [0.13027857],
#        [0.10002847],
#        [0.13319905],
#        [0.160115  ],
#        [0.14243035],
#        [0.114108  ],
#        [0.09867921],
#        [0.1060119 ],
#        [0.1144767 ],
#        [0.1303514 ],
#        [0.1616623 ],
#        [0.17819996],
#        [0.18136917],
#        [0.15267351],
#        [0.1370095 ],
#        [0.10397682],
#        [0.12138629],
#        [0.16754574],
#        [0.11471241],
#        [0.08192696],
#        [0.09646524],
#        [0.11801215],
#        [0.10852547],
#        [0.14961444],
#        [0.13747714],
#        [0.14501703],
#        [0.11742215],
#        [0.13781114],
#        [0.0945722 ],
#        [0.10782842],
#        [0.11636358],
#        [0.12704971],
#        [0.1321203 ],
#        [0.18139102],
#        [0.15860988],
#        [0.10143812],
#        [0.12115914],
#        [0.1915426 ],
#        [0.17154591],
#        [0.11961676],
#        [0.1462573 ],
#        [0.13149741],
#        [0.10673258],
#        [0.14001867],
#        [0.14451477]], dtype=float32)

# %%
# Convert predictions back to normal values
trainpred = scaler.inverse_transform(trainpred)
Y_train = scaler.inverse_transform([Y_train])
testpred = scaler.inverse_transform(testpred)
Y_test = scaler.inverse_transform([Y_test])
predictions = testpred

# %%
Y_train.shape
# Out:
# (1, 870)

# %%
Y_test.shape
# Out:
# (1, 214)

# %%
X_train.shape
# Out:
# (870, 1, 5)

# %%
X_test.shape
# Out:
# (214, 1, 5)

# %%
Y_train
# Out:
# array([[11.37313433, 11.67164179, 11.97014925, 10.17910448, 11.37313433,
#         10.7761194 , 13.46268657, 10.17910448, 10.17910448,  9.88059701,
#         11.07462687,  8.08955224, 10.7761194 , 14.05970149, 13.1641791 ,
#         11.97014925, 11.37313433, 14.05970149, 17.04477612, 12.56716418,
#         13.46268657, 12.26865672, 10.7761194 , 12.86567164, 12.86567164,
#          8.68656716, 12.56716418,  9.88059701, 12.26865672,  9.88059701,
#          7.49253731,  9.88059701,  9.58208955, 11.07462687, 14.35820896,
#          9.88059701, 14.35820896, 11.67164179, 11.37313433, 15.25373134,
#         15.25373134, 14.35820896, 15.55223881, 17.34328358, 15.85074627,
#         16.74626866, 16.44776119, 14.65671642, 14.05970149, 13.1641791 ,
#          9.28358209, 11.67164179, 11.07462687, 12.86567164,  8.3880597 ,
#         11.67164179,  8.3880597 , 12.86567164, 11.37313433,  9.28358209,
#         11.07462687, 11.97014925,  9.28358209, 10.47761194, 11.97014925,
#         13.1641791 , 11.67164179, 11.67164179, 13.1641791 , 11.07462687,
#         13.76119403, 10.7761194 , 10.47761194, 12.86567164, 12.56716418,
#         15.55223881, 10.7761194 , 11.07462687, 11.67164179, 13.1641791 ,
#         12.56716418, 10.7761194 , 13.76119403, 10.47761194, 10.7761194 ,
#         14.35820896, 15.85074627, 15.25373134, 17.04477612, 21.82089552,
#         20.02985075, 11.97014925,  7.19402985,  8.98507463, 11.97014925,
#         19., 10.,  9., 17., 11., 11., 20., 23., 28., 24., 18., 21., 28.,
#         20., 20., 23., 21., 12., 21., 22., 23., 16., 16., 16., 15.,  8.,
#         14., 17., 21., 12., 17., 15., 25., 22., 17., 19., 11., 17., 20.,
#          8., 23., 16.,  8., 12., 22., 22., 25., 14., 18., 16., 16., 26.,
#         21., 13., 15., 21., 23., 21., 14., 18., 14., 27., 33., 15., 16.,
#         10., 19., 22., 19., 13., 11., 13., 15., 18., 23., 25., 25., 19.,
#         17., 11., 16., 24., 13.,  9., 11., 16., 14., 22., 17., 20., 13.,
#         19.,  9., 15., 14., 18., 17., 27., 20., 11., 15., 29., 23., 14.,
#         19., 16., 13., 19., 19.,  6.]])

# %% [markdown]
# #Screen Prediction Accuracy on Test Data
# Once we have reviewed the input train-test data for the prediction - we can carry it out now.

# %%
# calculate RMSE
trainScore = math.sqrt(mean_squared_error(Y_train[0], trainpred[:,0]))
print('Train Score: %f RMSE' % (trainScore))
valScore = math.sqrt(mean_squared_error(Y_test[0], testpred[:,0]))
print('Test Score: %f RMSE' % (valScore))
# Out:
# Train Score: 2.753628 RMSE
# Test Score: 7.595554 RMSE

# %%
# Train predictions
trainpredPlot = np.empty_like(dftempday)
trainpredPlot[:, :] = np.nan
trainpredPlot[lookback:len(trainpred)+lookback, :] = trainpred

# %%
# Test predictions
testpredPlot = np.empty_like(dftempday)
testpredPlot[:, :] = np.nan
testpredPlot[len(trainpred)+(lookback*2)+1:len(dftempday)-1, :] = testpred

# %%
Y_test=Y_test.reshape(-1)
Y_test.shape
Y_test=pd.Series(Y_test)

# %%
Y_test
# Out:
# 0      21.0
# 1      22.0
# 2      19.0
# 3      25.0
# 4      33.0
#        ...
# 209    16.0
# 210    13.0
# 211    19.0
# 212    19.0
# 213     6.0
# Length: 214, dtype: float64

# %%
predictions=predictions.reshape(-1)
predictions.shape
predictions=pd.Series(predictions)

# %%
predictions
# Out:
# 0      15.282785
# 1      15.312778
# 2      15.604207
# 3      15.030135
# 4      16.603340
#          ...
# 209    14.775437
# 210    13.889845
# 211    12.403955
# 212    14.401120
# 213    14.670886
# Length: 214, dtype: float32

# %% [markdown]
# #LSTM - Finalisation
# As we have just carried out the prediction, let's evaluate the performance in terms of several metrics (mda, rmse) and visualise the prediction graph

# %%
import numpy as np

def mda(actual: np.ndarray, predicted: np.ndarray):
    """ Mean Directional Accuracy """
    return np.mean((np.sign(actual[1:] - actual[:-1]) == np.sign(predicted[1:] - predicted[:-1])).astype(int))

# %%
mda(Y_test, predictions)
# Out:
# 0.9906542056074766

# %% [markdown]
# Test metrics

# %%
# https://machinelearningmastery.com/time-series-forecasting-performance-measures-with-python/

mse = mean_squared_error(Y_test, predictions)
mae = metrics.mean_absolute_error(Y_test, predictions)
mape = metrics.mean_absolute_percentage_error(Y_test, predictions)
rmse = sqrt(mse)
print('RMSE: %f' % rmse)
print('MSE: %f' % mse)
print('MAE: %f' % mae)
print('MAPE: %f' % mape)
# Out:
# RMSE: 7.595554
# MSE: 57.692435
# MAE: 5.705590
# MAPE: 0.283949

# %% [markdown]
# train metrics

# %%
trmse = mean_squared_error(Y_train[0], trainpred[:,0])
trmae = metrics.mean_absolute_error(Y_train[0], trainpred[:,0])
trmape = metrics.mean_absolute_percentage_error(Y_train[0], trainpred[:,0])
trrmse = sqrt(trmse)
print('RMSE: %f' % trrmse)
print('MSE: %f' % trmse)
print('MAE: %f' % trmae)
print('MAPE: %f' % trmape)
# Out:
# RMSE: 2.753628
# MSE: 7.582465
# MAE: 1.559106
# MAPE: 0.138684

# %%
np.mean(Y_test)
# Out:
# 19.0

# %%
plt.plot(Y_test)
plt.plot(predictions)
plt.xlabel('Days since Jan 1, 2015')
plt.ylabel('# of daily incidents')
plt.title("Test vs. Prediction")
plt.show()
