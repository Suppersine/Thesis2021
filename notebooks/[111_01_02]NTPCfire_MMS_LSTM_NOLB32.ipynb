# %% [markdown]
# # Data Import & Manipulation
# Here, we import the required modules and read (+organise) the dataset

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.tsa.stattools as ts


import csv
import math
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import random
import statsmodels.api as sm
import statsmodels.formula.api as smf

from math import sqrt
from numpy.random import seed
seed(1)
from pandas import DataFrame
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.stattools import adfuller
from tensorflow.keras.layers import Dense
from tensorflow.keras import layers
from tensorflow.keras.layers import LSTM
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# !wget https://www.dropbox.com/s/jpw4fyv6mh31ql4/NTP2015-2017fire.txt
# Out:
# --2022-01-02 14:49:39--  https://www.dropbox.com/s/jpw4fyv6mh31ql4/NTP2015-2017fire.txt
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.85.18, 2620:100:6030:18::a27d:5012
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.85.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/jpw4fyv6mh31ql4/NTP2015-2017fire.txt [following]
# --2022-01-02 14:49:40--  https://www.dropbox.com/s/raw/jpw4fyv6mh31ql4/NTP2015-2017fire.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc77f13b40051fb02def7de7fce.dl.dropboxusercontent.com/cd/0/inline/BdDgg2NjTeb8BTNzxLka8cauAwQiFy94l1y3CaeggKCoky1P69j-1fOz7aRusAQhKRBRC7y443XOsM6haOobnwTFNJGi0sJOyMTIGWxWv0pDH1V4h05i1AnUMoDTp7pJ9bGqRP-DX_Pglq9nZlVZzNSI/file# [following]
# --2022-01-02 14:49:40--  https://ucc77f13b40051fb02def7de7fce.dl.dropboxusercontent.com/cd/0/inline/BdDgg2NjTeb8BTNzxLka8cauAwQiFy94l1y3CaeggKCoky1P69j-1fOz7aRusAQhKRBRC7y443XOsM6haOobnwTFNJGi0sJOyMTIGWxWv0pDH1V4h05i1AnUMoDTp7pJ9bGqRP-DX_Pglq9nZlVZzNSI/file
# Resolving ucc77f13b40051fb02def7de7fce.dl.dropboxusercontent.com (ucc77f13b40051fb02def7de7fce.dl.dropboxusercontent.com)... 162.125.80.15, 2620:100:6031:15::a27d:510f
# Connecting to ucc77f13b40051fb02def7de7fce.dl.dropboxusercontent.com (ucc77f13b40051fb02def7de7fce.dl.dropboxusercontent.com)|162.125.80.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3884193 (3.7M) [text/plain]
# Saving to: ‘NTP2015-2017fire.txt’
#
# NTP2015-2017fire.tx 100%[===================>]   3.70M  5.44MB/s    in 0.7s
#
# 2022-01-02 14:49:41 (5.44 MB/s) - ‘NTP2015-2017fire.txt’ saved [3884193/3884193]

# %%
# %cd /content/
#df = pd.read_csv('/content/gdrive/MyDrive/dlku/NTP2015fire-Jan.txt', sep='\t', header=None)
df = pd.read_csv('NTP2015-2017fire.txt', sep='\t', header=None)
df.columns = ["date", "station", "addr1", "addr2", "longitude", "latitude", "township"]
# Out:
# /content

# %%
df
# Out:
#                    date  station  ...   latitude township
# 0         2015/1/1 0:13  火警-瓦斯漏氣  ...  25.000569   板橋區廣德里
# 1         2015/1/1 0:16    火警-倉庫  ...  25.084172   三重區富華里
# 2         2015/1/1 0:48  火警-查看案件  ...  25.136422   淡水區民權里
# 3         2015/1/1 0:56  火警-查看案件  ...  25.031506   新莊區泰豐里
# 4         2015/1/1 1:04    火警-汽車  ...  24.982273   樹林區和平里
# ...                 ...      ...  ...        ...      ...
# 24085  2017/12/31 17:14  火警-集合住宅  ...  24.990417   中和區錦盛里
# 24086  2017/12/31 18:40  火警-集合住宅  ...  25.048063   汐止區東勢里
# 24087  2017/12/31 20:09  火警-查看案件  ...  25.076529   三重區福隆里
# 24088  2017/12/31 20:44  火警-查看案件  ...  24.997367   永和區民族里
# 24089  2017/12/31 22:09  火警-查看案件  ...  25.000317   板橋區龍安里
#
# [24090 rows x 7 columns]

# %%
#set date time format
df['date'] = pd.to_datetime(df.date, format='%Y-%m-%d %H:%M:%S')

# %%
df
# Out:
#                      date  station  ...   latitude township
# 0     2015-01-01 00:13:00  火警-瓦斯漏氣  ...  25.000569   板橋區廣德里
# 1     2015-01-01 00:16:00    火警-倉庫  ...  25.084172   三重區富華里
# 2     2015-01-01 00:48:00  火警-查看案件  ...  25.136422   淡水區民權里
# 3     2015-01-01 00:56:00  火警-查看案件  ...  25.031506   新莊區泰豐里
# 4     2015-01-01 01:04:00    火警-汽車  ...  24.982273   樹林區和平里
# ...                   ...      ...  ...        ...      ...
# 24085 2017-12-31 17:14:00  火警-集合住宅  ...  24.990417   中和區錦盛里
# 24086 2017-12-31 18:40:00  火警-集合住宅  ...  25.048063   汐止區東勢里
# 24087 2017-12-31 20:09:00  火警-查看案件  ...  25.076529   三重區福隆里
# 24088 2017-12-31 20:44:00  火警-查看案件  ...  24.997367   永和區民族里
# 24089 2017-12-31 22:09:00  火警-查看案件  ...  25.000317   板橋區龍安里
#
# [24090 rows x 7 columns]

# %%
#extract only numerical/quantitative data
dften = df[["date", "longitude", "latitude"]]

# %%
dften
# Out:
#                      date   longitude   latitude
# 0     2015-01-01 00:13:00  121.466281  25.000569
# 1     2015-01-01 00:16:00  121.491579  25.084172
# 2     2015-01-01 00:48:00  121.460224  25.136422
# 3     2015-01-01 00:56:00  121.450333  25.031506
# 4     2015-01-01 01:04:00  121.420005  24.982273
# ...                   ...         ...        ...
# 24085 2017-12-31 17:14:00  121.493909  24.990417
# 24086 2017-12-31 18:40:00  121.621682  25.048063
# 24087 2017-12-31 20:09:00  121.490806  25.076529
# 24088 2017-12-31 20:44:00  121.519391  24.997367
# 24089 2017-12-31 22:09:00  121.442237  25.000317
#
# [24090 rows x 3 columns]

# %%
BBox = ((dften.longitude.min(),   dften.longitude.max(),      
         dften.latitude.min(), dften.latitude.max()))

# %%
#Print out the coordinates, and go to Openstreetmap website to draw a map.
BBox
# Out:
# (121.2868855, 122.0030709, 24.77511693, 25.29717505)

# %%
#download the map we have just drawn
# !wget https://www.dropbox.com/s/dw6dp3zyx063zjt/ntpcmap.png
# !wget https://www.dropbox.com/s/vb5g8ndd3l2o0eh/ntpcmaplrg.png
# Out:
# --2022-01-02 14:49:42--  https://www.dropbox.com/s/dw6dp3zyx063zjt/ntpcmap.png
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.85.18, 2620:100:6030:18::a27d:5012
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.85.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/dw6dp3zyx063zjt/ntpcmap.png [following]
# --2022-01-02 14:49:43--  https://www.dropbox.com/s/raw/dw6dp3zyx063zjt/ntpcmap.png
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc4eebd006a00aaeaba30abf99cc.dl.dropboxusercontent.com/cd/0/inline/BdC5xBuVNO-PrG8JyEDoJ2D8h5uBYYZ2OLBn5VzvdkJ6idbT0_i2eFMEcvVxnkZEWyF0B0fC75JW-hd1FFN5t5JCEgIn9tW5t-EoLnBGlvR6LGoVqod78PrHJ9NJlG4OTME03x4MGIVvw7FOiCn4shga/file# [following]
# --2022-01-02 14:49:43--  https://uc4eebd006a00aaeaba30abf99cc.dl.dropboxusercontent.com/cd/0/inline/BdC5xBuVNO-PrG8JyEDoJ2D8h5uBYYZ2OLBn5VzvdkJ6idbT0_i2eFMEcvVxnkZEWyF0B0fC75JW-hd1FFN5t5JCEgIn9tW5t-EoLnBGlvR6LGoVqod78PrHJ9NJlG4OTME03x4MGIVvw7FOiCn4shga/file
# Resolving uc4eebd006a00aaeaba30abf99cc.dl.dropboxusercontent.com (uc4eebd006a00aaeaba30abf99cc.dl.dropboxusercontent.com)... 162.125.7.15, 2620:100:6031:15::a27d:510f
# Connecting to uc4eebd006a00aaeaba30abf99cc.dl.dropboxusercontent.com (uc4eebd006a00aaeaba30abf99cc.dl.dropboxusercontent.com)|162.125.7.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1828678 (1.7M) [image/png]
# Saving to: ‘ntpcmap.png’
#
# ntpcmap.png         100%[===================>]   1.74M  1.92MB/s    in 0.9s
#
# 2022-01-02 14:49:45 (1.92 MB/s) - ‘ntpcmap.png’ saved [1828678/1828678]
#
# --2022-01-02 14:49:45--  https://www.dropbox.com/s/vb5g8ndd3l2o0eh/ntpcmaplrg.png
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.85.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.85.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/vb5g8ndd3l2o0eh/ntpcmaplrg.png [following]
# --2022-01-02 14:49:45--  https://www.dropbox.com/s/raw/vb5g8ndd3l2o0eh/ntpcmaplrg.png
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uccb6f3421233e7e8bbab094d287.dl.dropboxusercontent.com/cd/0/inline/BdAgzI5uVsniwbqjlqNDZgCInVDoXLWewsOX4q1LUHWKT_O5BdHislLlRJjgvUJVaCnpMAJLJ5qik0Nv_VnQw3yabUS43MgRDo9kNzPACB6OpQIrvchlwSwIVomSzK4LA82oWNf3bDw4tw92M-qSWnYp/file# [following]
# --2022-01-02 14:49:45--  https://uccb6f3421233e7e8bbab094d287.dl.dropboxusercontent.com/cd/0/inline/BdAgzI5uVsniwbqjlqNDZgCInVDoXLWewsOX4q1LUHWKT_O5BdHislLlRJjgvUJVaCnpMAJLJ5qik0Nv_VnQw3yabUS43MgRDo9kNzPACB6OpQIrvchlwSwIVomSzK4LA82oWNf3bDw4tw92M-qSWnYp/file
# Resolving uccb6f3421233e7e8bbab094d287.dl.dropboxusercontent.com (uccb6f3421233e7e8bbab094d287.dl.dropboxusercontent.com)... 162.125.85.15, 2620:100:6031:15::a27d:510f
# Connecting to uccb6f3421233e7e8bbab094d287.dl.dropboxusercontent.com (uccb6f3421233e7e8bbab094d287.dl.dropboxusercontent.com)|162.125.85.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1237701 (1.2M) [image/png]
# Saving to: ‘ntpcmaplrg.png’
#
# ntpcmaplrg.png      100%[===================>]   1.18M  1.78MB/s    in 0.7s
#
# 2022-01-02 14:49:47 (1.78 MB/s) - ‘ntpcmaplrg.png’ saved [1237701/1237701]

# %%
map = plt.imread('ntpcmap.png')
maplrg =  plt.imread('ntpcmaplrg.png')

# %%
f, axarr = plt.subplots(2)
axarr[0].imshow(map)
axarr[1].imshow(maplrg)

# %%
#let's plot the points
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(dften.longitude, dften.latitude, zorder=1, alpha= 0.2, c='k', s=10)
ax.set_title('Fire Incidents in NTPC, 2015-2017, Spatial Domain')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
# Out:
# (24.77511693, 25.29717505)

# %%
#split dataframe into 3 years
df15 = df[df['date'].dt.year == 2015]
df16 = df[df['date'].dt.year == 2016]
df17 = df[df['date'].dt.year == 2017]

# %%
df15
# Out:
#                     date  station  ...   latitude township
# 0    2015-01-01 00:13:00  火警-瓦斯漏氣  ...  25.000569   板橋區廣德里
# 1    2015-01-01 00:16:00    火警-倉庫  ...  25.084172   三重區富華里
# 2    2015-01-01 00:48:00  火警-查看案件  ...  25.136422   淡水區民權里
# 3    2015-01-01 00:56:00  火警-查看案件  ...  25.031506   新莊區泰豐里
# 4    2015-01-01 01:04:00    火警-汽車  ...  24.982273   樹林區和平里
# ...                  ...      ...  ...        ...      ...
# 9054 2015-12-31 21:41:00   火警-透天厝  ...  24.994490   中和區秀明里
# 9055 2015-12-31 21:46:00  火警-集合住宅  ...  25.016660   樹林區三福里
# 9056 2015-12-31 22:37:00  火警-查看案件  ...  25.070749   林口區東勢里
# 9057 2015-12-31 22:45:00  火警-查看案件  ...  25.097674   蘆洲區保新里
# 9058 2015-12-31 23:32:00  火警-查看案件  ...  24.989496   中和區錦中里
#
# [9059 rows x 7 columns]

# %%
df16
# Out:
#                      date      station  ...   latitude township
# 9059  2016-01-01 01:10:00      火警-查看案件  ...  25.047863   泰山區明志里
# 9060  2016-01-01 01:18:00      火警-查看案件  ...  25.145268   淡水區八勢里
# 9061  2016-01-01 01:27:00      火警-查看案件  ...  25.013844   永和區下溪里
# 9062  2016-01-01 03:30:00      火警-查看案件  ...  25.093751   蘆洲區南港里
# 9063  2016-01-01 03:47:00        火警-汽車  ...  24.994834   樹林區潭底里
# ...                   ...          ...  ...        ...      ...
# 17156 2016-12-31 19:50:00      火警-集合住宅  ...  25.032542   板橋區溪頭里
# 17157 2016-12-31 21:51:00      火警-查看案件  ...  24.997751   板橋區崑崙里
# 17158 2016-12-31 22:30:00      火警-集合住宅  ...  25.018254   板橋區新民里
# 17159 2016-12-31 22:52:00      火警-查看案件  ...  25.072460   林口區西林里
# 17160 2016-12-31 23:13:00  火警-山林田野(平地)  ...  25.145268   淡水區八勢里
#
# [8102 rows x 7 columns]

# %%
df17
# Out:
#                      date      station  ...   latitude township
# 17161 2017-01-01 00:13:00  火警-山林田野(平地)  ...  24.936866   鶯歌區二甲里
# 17162 2017-01-01 00:15:00      火警-集合住宅  ...  24.929874   三峽區介壽里
# 17163 2017-01-01 00:54:00      火警-集合住宅  ...  25.007928   板橋區流芳里
# 17164 2017-01-01 01:44:00      火警-集合住宅  ...  25.062100   汐止區文化里
# 17165 2017-01-01 01:59:00     火警-警報器作響  ...  25.076035   汐止區建成里
# ...                   ...          ...  ...        ...      ...
# 24085 2017-12-31 17:14:00      火警-集合住宅  ...  24.990417   中和區錦盛里
# 24086 2017-12-31 18:40:00      火警-集合住宅  ...  25.048063   汐止區東勢里
# 24087 2017-12-31 20:09:00      火警-查看案件  ...  25.076529   三重區福隆里
# 24088 2017-12-31 20:44:00      火警-查看案件  ...  24.997367   永和區民族里
# 24089 2017-12-31 22:09:00      火警-查看案件  ...  25.000317   板橋區龍安里
#
# [6929 rows x 7 columns]

# %%
#let's plot the points for 2015
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df15.longitude, df15.latitude, zorder=1, alpha= 0.2, c='r', s=10)
ax.set_title('Fire Incidents in NTPC, 2015, Spatial Domain')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
# Out:
# (24.77511693, 25.29717505)

# %%
#let's plot the points for 2016
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df16.longitude, df16.latitude, zorder=1, alpha= 0.2, c='g', s=10)
ax.set_title('Fire Incidents in NTPC, 2016, Spatial Domain')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
# Out:
# (24.77511693, 25.29717505)

# %%
#let's plot the points for 2017
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df17.longitude, df17.latitude, zorder=1, alpha= 0.2, c='b', s=10)
ax.set_title('Fire Incidents in NTPC, 2017, Spatial Domain')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
# Out:
# (24.77511693, 25.29717505)

# %%
#Extraction of the temporal domain
maxlimit = len(df)
ones = np.ones(maxlimit, dtype="uint32")
dftemp = pd.DataFrame(df.date)
dftemp['freq'] = ones

# %%
dftemp
# Out:
#                      date  freq
# 0     2015-01-01 00:13:00     1
# 1     2015-01-01 00:16:00     1
# 2     2015-01-01 00:48:00     1
# 3     2015-01-01 00:56:00     1
# 4     2015-01-01 01:04:00     1
# ...                   ...   ...
# 24085 2017-12-31 17:14:00     1
# 24086 2017-12-31 18:40:00     1
# 24087 2017-12-31 20:09:00     1
# 24088 2017-12-31 20:44:00     1
# 24089 2017-12-31 22:09:00     1
#
# [24090 rows x 2 columns]

# %%
#when running this block, we will obtain the monthly frequency to be used in the temporal domain (a.k.a. time series).
dftempday = dftemp.groupby(pd.Grouper(key="date", freq="1D")).count()
dftempweek = dftemp.groupby(pd.Grouper(key="date", freq="1W")).count()
dftempmonth = dftemp.groupby(pd.Grouper(key="date", freq="1M")).count()

# %%
dftempday
# Out:
#             freq
# date
# 2015-01-01    34
# 2015-01-02    25
# 2015-01-03    24
# 2015-01-04    34
# 2015-01-05    28
# ...          ...
# 2017-12-27    13
# 2017-12-28    19
# 2017-12-29    19
# 2017-12-30     6
# 2017-12-31     8
#
# [1096 rows x 1 columns]

# %%
dftempweek
# Out:
#             freq
# date
# 2015-01-04   117
# 2015-01-11   163
# 2015-01-18   141
# 2015-01-25   210
# 2015-02-01   174
# ...          ...
# 2017-12-03   125
# 2017-12-10   109
# 2017-12-17   105
# 2017-12-24   139
# 2017-12-31   100
#
# [157 rows x 1 columns]

# %%
dftempmonth
# Out:
#             freq
# date
# 2015-01-31   778
# 2015-02-28   776
# 2015-03-31   733
# 2015-04-30   844
# 2015-05-31   681
# 2015-06-30   677
# 2015-07-31   718
# 2015-08-31  1030
# 2015-09-30   792
# 2015-10-31   699
# 2015-11-30   680
# 2015-12-31   651
# 2016-01-31   688
# 2016-02-29   711
# 2016-03-31   752
# 2016-04-30   671
# 2016-05-31   652
# 2016-06-30   663
# 2016-07-31   666
# 2016-08-31   748
# 2016-09-30   674
# 2016-10-31   666
# 2016-11-30   635
# 2016-12-31   576
# 2017-01-31   638
# 2017-02-28   564
# 2017-03-31   519
# 2017-04-30   646
# 2017-05-31   509
# 2017-06-30   541
# 2017-07-31   610
# 2017-08-31   740
# 2017-09-30   576
# 2017-10-31   527
# 2017-11-30   553
# 2017-12-31   506

# %%
y = dftempmonth['freq']
x = dftempmonth.index
plt.rcParams["figure.figsize"] = (16,9)
plt.plot(x, y, color='r', label='monthly frequency') 
plt.xlabel('date')
plt.ylabel('incidents')
plt.title('Monthly Temporal Domain')
plt.legend() 
plt.show()

# %%
y = dftempweek['freq']
x = dftempweek.index
plt.rcParams["figure.figsize"] = (16,9)
plt.plot(x, y, color='g', label='weekly frequency')
plt.xlabel('date')
plt.ylabel('incidents')
plt.title('Weekly Temporal Domain')
plt.legend() 
plt.show()

# %%
y = dftempday['freq']
x = dftempday.index
plt.rcParams["figure.figsize"] = (16,9)
plt.plot(x, y, color='b', label='daily frequency') 
plt.xlabel('date')
plt.ylabel('incidents')
plt.title('Daily Temporal Domain')
plt.legend() 
plt.show()

# %% [markdown]
# #Keras LSTM MODEL

# %%
# LSTM for international airline passengers problem with regression framing
import numpy
import matplotlib.pyplot as plt
import pandas as pd
import math
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Convert dataset to matrix

# %%
tseries = dftempday['freq'].to_numpy()
tseries
# Out:
# array([34, 25, 24, ..., 19,  6,  8])

# %%
plt.plot(tseries)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
plt.ylabel('#of incidents')
plt.title('Number of daily fire incidents in NTPC Taiwan, 2015-2017')
plt.show()

# %%
dftensor=pd.DataFrame(tseries) #forward dataframe
dftensor=np.array(dftensor) #convert to tensor
dftensor #display dataframe
# Out:
# array([[34],
#        [25],
#        [24],
#        ...,
#        [19],
#        [ 6],
#        [ 8]])

# %%
dftensor=np.array(dftensor)

# %% [markdown]
# Train-test split

# %%
train_size = int(len(dftensor) * 0.8)
test_size = len(dftensor) - train_size
train, test = dftensor[0:train_size,:], dftensor[train_size:len(dftensor),:]

# %% [markdown]
# Form dataset matrix

# %%
def create_dataset(df, previous=1):
    dataX, dataY = [], []
    for i in range(len(df)-previous-1):
        a = df[i:(i+previous), 0]
        dataX.append(a)
        dataY.append(df[i + previous, 0])
    return np.array(dataX), np.array(dataY)

# %%
dftensor
# Out:
# array([[34],
#        [25],
#        [24],
#        ...,
#        [19],
#        [ 6],
#        [ 8]])

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
train = scaler.fit_transform(train)
train
# Out:
# array([[0.14427861],
#        [0.09950249],
#        [0.09452736],
#        [0.14427861],
#        [0.11442786],
#        [0.08955224],
#        [0.09452736],
#        [0.09950249],
#        [0.06965174],
#        [0.08955224],
#        [0.07960199],
#        [0.12437811],
#        [0.06965174],
#        [0.06965174],
#        [0.06467662],
#        [0.08457711],
#        [0.03482587],
#        [0.07960199],
#        [0.13432836],
#        [0.11940299],
#        [0.09950249],
#        [0.08955224],
#        [0.13432836],
#        [0.1840796 ],
#        [0.10945274],
#        [0.12437811],
#        [0.10447761],
#        [0.07960199],
#        [0.11442786],
#        [0.11442786],
#        [0.04477612],
#        [0.10945274],
#        [0.06467662],
#        [0.10447761],
#        [0.06467662],
#        [0.02487562],
#        [0.06467662],
#        [0.05970149],
#        [0.08457711],
#        [0.13930348],
#        [0.06467662],
#        [0.13930348],
#        [0.09452736],
#        [0.08955224],
#        [0.15422886],
#        [0.15422886],
#        [0.13930348],
#        [0.15920398],
#        [0.18905473],
#        [0.1641791 ],
#        [0.17910448],
#        [0.17412935],
#        [0.14427861],
#        [0.13432836],
#        [0.11940299],
#        [0.05472637],
#        [0.09452736],
#        [0.08457711],
#        [0.11442786],
#        [0.039801  ],
#        [0.09452736],
#        [0.039801  ],
#        [0.11442786],
#        [0.08955224],
#        [0.05472637],
#        [0.08457711],
#        [0.09950249],
#        [0.05472637],
#        [0.07462687],
#        [0.09950249],
#        [0.11940299],
#        [0.09452736],
#        [0.09452736],
#        [0.11940299],
#        [0.08457711],
#        [0.12935323],
#        [0.07960199],
#        [0.07462687],
#        [0.11442786],
#        [0.10945274],
#        [0.15920398],
#        [0.07960199],
#        [0.08457711],
#        [0.09452736],
#        [0.11940299],
#        [0.10945274],
#        [0.07960199],
#        [0.12935323],
#        [0.07462687],
#        [0.07960199],
#        [0.13930348],
#        [0.1641791 ],
#        [0.15422886],
#        [0.1840796 ],
#        [0.26368159],
#        [0.23383085],
#        [0.09950249],
#        [0.0199005 ],
#        [0.04975124],
#        [0.09950249],
#        [0.06965174],
#        [0.12437811],
#        [0.08457711],
#        [0.10447761],
#        [0.15422886],
#        [0.10945274],
#        [0.12437811],
#        [0.11442786],
#        [0.13432836],
#        [0.11442786],
#        [0.09950249],
#        [0.08457711],
#        [0.039801  ],
#        [0.11442786],
#        [0.09950249],
#        [0.08457711],
#        [0.07960199],
#        [0.12437811],
#        [0.12437811],
#        [0.05970149],
#        [0.07960199],
#        [0.11442786],
#        [0.07960199],
#        [0.039801  ],
#        [0.07960199],
#        [0.07960199],
#        [0.06965174],
#        [0.07960199],
#        [0.09950249],
#        [0.05970149],
#        [0.10945274],
#        [0.09950249],
#        [0.08955224],
#        [0.09452736],
#        [0.10945274],
#        [0.15422886],
#        [0.08457711],
#        [0.07462687],
#        [0.09452736],
#        [0.09452736],
#        [0.03482587],
#        [0.07462687],
#        [0.09452736],
#        [0.10447761],
#        [0.05970149],
#        [0.08955224],
#        [0.09452736],
#        [0.07462687],
#        [0.05970149],
#        [0.08955224],
#        [0.05472637],
#        [0.10447761],
#        [0.11442786],
#        [0.10945274],
#        [0.039801  ],
#        [0.06965174],
#        [0.07462687],
#        [0.10447761],
#        [0.039801  ],
#        [0.06965174],
#        [0.06965174],
#        [0.04975124],
#        [0.07462687],
#        [0.09950249],
#        [0.10447761],
#        [0.13432836],
#        [0.06467662],
#        [0.09950249],
#        [0.07960199],
#        [0.14427861],
#        [0.09950249],
#        [0.04975124],
#        [0.08955224],
#        [0.09452736],
#        [0.09452736],
#        [0.06965174],
#        [0.09452736],
#        [0.05970149],
#        [0.12437811],
#        [0.09950249],
#        [0.09950249],
#        [0.08955224],
#        [0.06965174],
#        [0.07960199],
#        [0.10945274],
#        [0.10945274],
#        [0.07960199],
#        [0.10447761],
#        [0.14427861],
#        [0.05970149],
#        [0.14427861],
#        [0.05472637],
#        [0.05472637],
#        [0.08955224],
#        [0.11442786],
#        [0.05472637],
#        [0.10945274],
#        [0.08955224],
#        [0.11940299],
#        [0.10447761],
#        [0.05970149],
#        [0.07960199],
#        [0.06467662],
#        [0.08955224],
#        [0.02487562],
#        [0.06965174],
#        [0.14925373],
#        [0.10447761],
#        [0.05970149],
#        [0.06467662],
#        [0.10945274],
#        [0.14427861],
#        [0.14427861],
#        [0.11442786],
#        [0.10447761],
#        [0.10945274],
#        [0.11442786],
#        [0.14427861],
#        [0.10945274],
#        [1.        ],
#        [0.31840796],
#        [0.2039801 ],
#        [0.12935323],
#        [0.10945274],
#        [0.10447761],
#        [0.10945274],
#        [0.04975124],
#        [0.09452736],
#        [0.08955224],
#        [0.12437811],
#        [0.10945274],
#        [0.14925373],
#        [0.09950249],
#        [0.10945274],
#        [0.07960199],
#        [0.04477612],
#        [0.05472637],
#        [0.04477612],
#        [0.10447761],
#        [0.14925373],
#        [0.12437811],
#        [0.07462687],
#        [0.03482587],
#        [0.05472637],
#        [0.05970149],
#        [0.11442786],
#        [0.11442786],
#        [0.09452736],
#        [0.12935323],
#        [0.05970149],
#        [0.05472637],
#        [0.04975124],
#        [0.09950249],
#        [0.09950249],
#        [0.08457711],
#        [0.08457711],
#        [0.10447761],
#        [0.10945274],
#        [0.02985075],
#        [0.04975124],
#        [0.05472637],
#        [0.12437811],
#        [0.16915423],
#        [0.10945274],
#        [0.08955224],
#        [0.11442786],
#        [0.08955224],
#        [0.06467662],
#        [0.10945274],
#        [0.14925373],
#        [0.3681592 ],
#        [0.26368159],
#        [0.09452736],
#        [0.10447761],
#        [0.05970149],
#        [0.08955224],
#        [0.08955224],
#        [0.09452736],
#        [0.07462687],
#        [0.08955224],
#        [0.16915423],
#        [0.06467662],
#        [0.06965174],
#        [0.06467662],
#        [0.039801  ],
#        [0.12437811],
#        [0.10447761],
#        [0.07462687],
#        [0.06965174],
#        [0.06965174],
#        [0.11442786],
#        [0.05472637],
#        [0.10945274],
#        [0.10945274],
#        [0.07960199],
#        [0.10945274],
#        [0.09950249],
#        [0.09950249],
#        [0.09950249],
#        [0.08955224],
#        [0.04477612],
#        [0.06965174],
#        [0.09452736],
#        [0.07960199],
#        [0.07462687],
#        [0.05472637],
#        [0.09452736],
#        [0.05472637],
#        [0.07462687],
#        [0.10447761],
#        [0.08457711],
#        [0.10447761],
#        [0.07462687],
#        [0.05970149],
#        [0.11940299],
#        [0.06467662],
#        [0.07960199],
#        [0.09452736],
#        [0.08955224],
#        [0.11442786],
#        [0.05970149],
#        [0.09452736],
#        [0.08955224],
#        [0.11442786],
#        [0.04975124],
#        [0.06965174],
#        [0.05970149],
#        [0.08457711],
#        [0.09950249],
#        [0.13432836],
#        [0.10945274],
#        [0.12935323],
#        [0.10447761],
#        [0.09452736],
#        [0.08955224],
#        [0.08457711],
#        [0.09950249],
#        [0.04975124],
#        [0.06467662],
#        [0.08955224],
#        [0.0199005 ],
#        [0.06467662],
#        [0.12437811],
#        [0.05970149],
#        [0.08457711],
#        [0.08457711],
#        [0.07462687],
#        [0.039801  ],
#        [0.06467662],
#        [0.05970149],
#        [0.09950249],
#        [0.07960199],
#        [0.05970149],
#        [0.12935323],
#        [0.12437811],
#        [0.14427861],
#        [0.09452736],
#        [0.11442786],
#        [0.04477612],
#        [0.06467662],
#        [0.06965174],
#        [0.07960199],
#        [0.06467662],
#        [0.06467662],
#        [0.07960199],
#        [0.10945274],
#        [0.08955224],
#        [0.09950249],
#        [0.14427861],
#        [0.08457711],
#        [0.06965174],
#        [0.05970149],
#        [0.06965174],
#        [0.04477612],
#        [0.12437811],
#        [0.09452736],
#        [0.03482587],
#        [0.039801  ],
#        [0.05472637],
#        [0.07462687],
#        [0.02487562],
#        [0.06965174],
#        [0.06965174],
#        [0.05472637],
#        [0.05970149],
#        [0.15920398],
#        [0.07960199],
#        [0.05472637],
#        [0.08955224],
#        [0.13432836],
#        [0.10447761],
#        [0.11442786],
#        [0.11442786],
#        [0.10945274],
#        [0.11442786],
#        [0.10447761],
#        [0.06965174],
#        [0.07960199],
#        [0.06467662],
#        [0.12935323],
#        [0.10447761],
#        [0.08955224],
#        [0.14925373],
#        [0.22885572],
#        [0.16915423],
#        [0.18905473],
#        [0.11940299],
#        [0.17910448],
#        [0.14925373],
#        [0.07462687],
#        [0.04477612],
#        [0.07960199],
#        [0.04975124],
#        [0.09950249],
#        [0.06467662],
#        [0.05970149],
#        [0.06467662],
#        [0.10447761],
#        [0.05970149],
#        [0.02985075],
#        [0.05472637],
#        [0.05472637],
#        [0.10945274],
#        [0.08955224],
#        [0.05472637],
#        [0.10447761],
#        [0.09950249],
#        [0.11442786],
#        [0.10945274],
#        [0.10945274],
#        [0.17412935],
#        [0.05472637],
#        [0.08457711],
#        [0.10945274],
#        [0.05472637],
#        [0.0199005 ],
#        [0.07960199],
#        [0.17412935],
#        [0.06965174],
#        [0.06467662],
#        [0.08955224],
#        [0.07462687],
#        [0.17910448],
#        [0.24378109],
#        [0.09452736],
#        [0.04477612],
#        [0.10447761],
#        [0.08457711],
#        [0.07462687],
#        [0.03482587],
#        [0.06467662],
#        [0.08955224],
#        [0.08955224],
#        [0.09452736],
#        [0.06965174],
#        [0.11442786],
#        [0.07462687],
#        [0.17412935],
#        [0.19402985],
#        [0.10447761],
#        [0.08457711],
#        [0.10447761],
#        [0.039801  ],
#        [0.10447761],
#        [0.10945274],
#        [0.06965174],
#        [0.02985075],
#        [0.08955224],
#        [0.05472637],
#        [0.06467662],
#        [0.05970149],
#        [0.09452736],
#        [0.08457711],
#        [0.06467662],
#        [0.04975124],
#        [0.11940299],
#        [0.09452736],
#        [0.09950249],
#        [0.07462687],
#        [0.07960199],
#        [0.10945274],
#        [0.07462687],
#        [0.10447761],
#        [0.05472637],
#        [0.07462687],
#        [0.05472637],
#        [0.07462687],
#        [0.12437811],
#        [0.07960199],
#        [0.03482587],
#        [0.07960199],
#        [0.09950249],
#        [0.09950249],
#        [0.05970149],
#        [0.07960199],
#        [0.04975124],
#        [0.05472637],
#        [0.10447761],
#        [0.08457711],
#        [0.11442786],
#        [0.09452736],
#        [0.09452736],
#        [0.06467662],
#        [0.07462687],
#        [0.04477612],
#        [0.09452736],
#        [0.09950249],
#        [0.10447761],
#        [0.06965174],
#        [0.05970149],
#        [0.05970149],
#        [0.04477612],
#        [0.07960199],
#        [0.09452736],
#        [0.09452736],
#        [0.07960199],
#        [0.07960199],
#        [0.08457711],
#        [0.09950249],
#        [0.05472637],
#        [0.08457711],
#        [0.10447761],
#        [0.07462687],
#        [0.08955224],
#        [0.09452736],
#        [0.13432836],
#        [0.039801  ],
#        [0.06467662],
#        [0.13432836],
#        [0.05970149],
#        [0.04975124],
#        [0.08457711],
#        [0.14925373],
#        [0.08955224],
#        [0.07960199],
#        [0.07462687],
#        [0.08457711],
#        [0.07462687],
#        [0.07960199],
#        [0.05472637],
#        [0.07462687],
#        [0.09452736],
#        [0.07462687],
#        [0.08457711],
#        [0.10447761],
#        [0.09452736],
#        [0.08457711],
#        [0.06965174],
#        [0.04477612],
#        [0.15422886],
#        [0.07462687],
#        [0.10945274],
#        [0.07462687],
#        [0.09452736],
#        [0.05472637],
#        [0.03482587],
#        [0.06467662],
#        [0.06965174],
#        [0.039801  ],
#        [0.07960199],
#        [0.05472637],
#        [0.05472637],
#        [0.07462687],
#        [0.09452736],
#        [0.06467662],
#        [0.07960199],
#        [0.03482587],
#        [0.09950249],
#        [0.09452736],
#        [0.08955224],
#        [0.13930348],
#        [0.09950249],
#        [0.08457711],
#        [0.06965174],
#        [0.11940299],
#        [0.08955224],
#        [0.13930348],
#        [0.09452736],
#        [0.07960199],
#        [0.10447761],
#        [0.05970149],
#        [0.10945274],
#        [0.09950249],
#        [0.09950249],
#        [0.14925373],
#        [0.14925373],
#        [0.09950249],
#        [0.09950249],
#        [0.09452736],
#        [0.10447761],
#        [0.10945274],
#        [0.15422886],
#        [0.10447761],
#        [0.08457711],
#        [0.09950249],
#        [0.06965174],
#        [0.06965174],
#        [0.05472637],
#        [0.10945274],
#        [0.10447761],
#        [0.09950249],
#        [0.05472637],
#        [0.09950249],
#        [0.06467662],
#        [0.10945274],
#        [0.07960199],
#        [0.07960199],
#        [0.04477612],
#        [0.10945274],
#        [0.08955224],
#        [0.09452736],
#        [0.09950249],
#        [0.06467662],
#        [0.07462687],
#        [0.08955224],
#        [0.05472637],
#        [0.05970149],
#        [0.04975124],
#        [0.08457711],
#        [0.06467662],
#        [0.05472637],
#        [0.02985075],
#        [0.08457711],
#        [0.10447761],
#        [0.07960199],
#        [0.07960199],
#        [0.09452736],
#        [0.04975124],
#        [0.07960199],
#        [0.05472637],
#        [0.039801  ],
#        [0.05970149],
#        [0.04975124],
#        [0.09452736],
#        [0.08457711],
#        [0.35820896],
#        [0.1641791 ],
#        [0.14427861],
#        [0.07462687],
#        [0.09950249],
#        [0.10447761],
#        [0.11442786],
#        [0.04975124],
#        [0.04975124],
#        [0.10447761],
#        [0.11940299],
#        [0.10945274],
#        [0.10447761],
#        [0.09950249],
#        [0.08457711],
#        [0.04477612],
#        [0.06965174],
#        [0.04477612],
#        [0.08955224],
#        [0.07960199],
#        [0.03482587],
#        [0.05970149],
#        [0.05472637],
#        [0.07960199],
#        [0.11442786],
#        [0.05472637],
#        [0.11442786],
#        [0.07960199],
#        [0.07960199],
#        [0.08955224],
#        [0.09452736],
#        [0.09950249],
#        [0.05472637],
#        [0.07462687],
#        [0.08955224],
#        [0.04975124],
#        [0.06467662],
#        [0.09452736],
#        [0.05472637],
#        [0.08457711],
#        [0.11442786],
#        [0.10447761],
#        [0.08457711],
#        [0.08955224],
#        [0.07960199],
#        [0.06467662],
#        [0.11940299],
#        [0.11442786],
#        [0.13432836],
#        [0.07960199],
#        [0.02985075],
#        [0.08457711],
#        [0.12935323],
#        [0.08955224],
#        [0.11940299],
#        [0.07960199],
#        [0.05472637],
#        [0.04975124],
#        [0.08955224],
#        [0.039801  ],
#        [0.07462687],
#        [0.08955224],
#        [0.04477612],
#        [0.06965174],
#        [0.03482587],
#        [0.02985075],
#        [0.07960199],
#        [0.05472637],
#        [0.07960199],
#        [0.039801  ],
#        [0.06467662],
#        [0.07462687],
#        [0.05472637],
#        [0.0199005 ],
#        [0.13930348],
#        [0.06467662],
#        [0.08457711],
#        [0.06965174],
#        [0.08457711],
#        [0.0199005 ],
#        [0.09950249],
#        [0.07960199],
#        [0.09452736],
#        [0.03482587],
#        [0.06467662],
#        [0.09950249],
#        [0.04477612],
#        [0.03482587],
#        [0.06467662],
#        [0.09452736],
#        [0.10447761],
#        [0.07960199],
#        [0.04975124],
#        [0.05970149],
#        [0.05970149],
#        [0.06965174],
#        [0.11940299],
#        [0.09950249],
#        [0.07462687],
#        [0.04975124],
#        [0.08955224],
#        [0.07462687],
#        [0.07462687],
#        [0.039801  ],
#        [0.07960199],
#        [0.02985075],
#        [0.01492537],
#        [0.06467662],
#        [0.08955224],
#        [0.05970149],
#        [0.039801  ],
#        [0.03482587],
#        [0.07462687],
#        [0.07960199],
#        [0.07960199],
#        [0.05970149],
#        [0.05970149],
#        [0.11442786],
#        [0.00995025],
#        [0.07462687],
#        [0.10447761],
#        [0.08457711],
#        [0.20895522],
#        [0.15422886],
#        [0.11940299],
#        [0.05472637],
#        [0.08955224],
#        [0.08457711],
#        [0.06467662],
#        [0.07960199],
#        [0.07462687],
#        [0.10945274],
#        [0.06965174],
#        [0.05472637],
#        [0.02487562],
#        [0.05970149],
#        [0.04477612],
#        [0.09950249],
#        [0.06467662],
#        [0.06965174],
#        [0.05472637],
#        [0.09452736],
#        [0.07462687],
#        [0.10447761],
#        [0.07960199],
#        [0.15920398],
#        [0.10945274],
#        [0.06467662],
#        [0.07960199],
#        [0.        ],
#        [0.08955224],
#        [0.10447761],
#        [0.07462687],
#        [0.05472637],
#        [0.06467662],
#        [0.07960199],
#        [0.03482587],
#        [0.039801  ],
#        [0.08457711],
#        [0.08955224],
#        [0.0199005 ],
#        [0.05472637],
#        [0.039801  ],
#        [0.02985075],
#        [0.05970149],
#        [0.07960199],
#        [0.12935323],
#        [0.08955224],
#        [0.05970149],
#        [0.05970149],
#        [0.07462687],
#        [0.00995025],
#        [0.03482587],
#        [0.08457711],
#        [0.04477612],
#        [0.02985075],
#        [0.05970149],
#        [0.06965174],
#        [0.04975124],
#        [0.04975124],
#        [0.0199005 ],
#        [0.07462687],
#        [0.07462687],
#        [0.05472637],
#        [0.06965174],
#        [0.05970149],
#        [0.02487562],
#        [0.1840796 ],
#        [0.25373134],
#        [0.22885572],
#        [0.09452736],
#        [0.04477612],
#        [0.04477612],
#        [0.10945274],
#        [0.09950249],
#        [0.13930348],
#        [0.06467662],
#        [0.03482587],
#        [0.04477612],
#        [0.10945274],
#        [0.09950249],
#        [0.08457711],
#        [0.08457711],
#        [0.05472637],
#        [0.07462687],
#        [0.039801  ],
#        [0.01492537],
#        [0.05472637],
#        [0.039801  ],
#        [0.07960199],
#        [0.04975124],
#        [0.0199005 ],
#        [0.0199005 ],
#        [0.08457711],
#        [0.11442786],
#        [0.07462687],
#        [0.06965174],
#        [0.08457711],
#        [0.05970149],
#        [0.02985075],
#        [0.07462687],
#        [0.04975124],
#        [0.04975124],
#        [0.07960199],
#        [0.05970149],
#        [0.04975124],
#        [0.06965174],
#        [0.05970149],
#        [0.04975124],
#        [0.05970149],
#        [0.04975124],
#        [0.03482587],
#        [0.039801  ],
#        [0.02985075],
#        [0.06467662],
#        [0.04975124],
#        [0.07462687],
#        [0.03482587],
#        [0.04975124],
#        [0.07462687],
#        [0.04477612]])

# %%
test = scaler.fit_transform(test)
test
# Out:
# array([[0.21666667],
#        [0.16666667],
#        [0.1       ],
#        [0.13333333],
#        [0.26666667],
#        [0.25      ],
#        [0.26666667],
#        [0.21666667],
#        [0.31666667],
#        [0.45      ],
#        [0.25      ],
#        [0.1       ],
#        [0.21666667],
#        [0.16666667],
#        [0.16666667],
#        [0.21666667],
#        [0.1       ],
#        [0.13333333],
#        [0.25      ],
#        [0.08333333],
#        [0.11666667],
#        [0.4       ],
#        [0.16666667],
#        [0.21666667],
#        [0.13333333],
#        [0.06666667],
#        [0.25      ],
#        [0.1       ],
#        [0.06666667],
#        [0.26666667],
#        [0.16666667],
#        [0.25      ],
#        [0.23333333],
#        [0.18333333],
#        [0.2       ],
#        [0.26666667],
#        [0.26666667],
#        [0.18333333],
#        [0.13333333],
#        [0.15      ],
#        [0.21666667],
#        [0.23333333],
#        [0.01666667],
#        [0.1       ],
#        [0.21666667],
#        [0.05      ],
#        [0.13333333],
#        [0.15      ],
#        [0.25      ],
#        [0.31666667],
#        [0.26666667],
#        [0.26666667],
#        [0.18333333],
#        [0.16666667],
#        [0.3       ],
#        [0.28333333],
#        [0.23333333],
#        [0.31666667],
#        [0.43333333],
#        [0.31666667],
#        [0.11666667],
#        [0.23333333],
#        [0.26666667],
#        [0.3       ],
#        [0.56666667],
#        [0.21666667],
#        [0.18333333],
#        [0.15      ],
#        [0.21666667],
#        [0.26666667],
#        [0.2       ],
#        [0.28333333],
#        [0.28333333],
#        [0.28333333],
#        [0.15      ],
#        [0.28333333],
#        [0.25      ],
#        [0.28333333],
#        [0.36666667],
#        [0.26666667],
#        [0.26666667],
#        [1.        ],
#        [0.36666667],
#        [0.3       ],
#        [0.26666667],
#        [0.35      ],
#        [0.4       ],
#        [0.28333333],
#        [0.13333333],
#        [0.2       ],
#        [0.28333333],
#        [0.36666667],
#        [0.31666667],
#        [0.51666667],
#        [0.16666667],
#        [0.33333333],
#        [0.18333333],
#        [0.21666667],
#        [0.16666667],
#        [0.15      ],
#        [0.35      ],
#        [0.3       ],
#        [0.3       ],
#        [0.31666667],
#        [0.16666667],
#        [0.25      ],
#        [0.28333333],
#        [0.13333333],
#        [0.15      ],
#        [0.21666667],
#        [0.06666667],
#        [0.05      ],
#        [0.18333333],
#        [0.08333333],
#        [0.08333333],
#        [0.23333333],
#        [0.28333333],
#        [0.36666667],
#        [0.3       ],
#        [0.2       ],
#        [0.25      ],
#        [0.36666667],
#        [0.23333333],
#        [0.23333333],
#        [0.28333333],
#        [0.25      ],
#        [0.1       ],
#        [0.25      ],
#        [0.26666667],
#        [0.28333333],
#        [0.16666667],
#        [0.16666667],
#        [0.16666667],
#        [0.15      ],
#        [0.03333333],
#        [0.13333333],
#        [0.18333333],
#        [0.25      ],
#        [0.1       ],
#        [0.18333333],
#        [0.15      ],
#        [0.31666667],
#        [0.26666667],
#        [0.18333333],
#        [0.21666667],
#        [0.08333333],
#        [0.18333333],
#        [0.23333333],
#        [0.03333333],
#        [0.28333333],
#        [0.16666667],
#        [0.03333333],
#        [0.1       ],
#        [0.26666667],
#        [0.26666667],
#        [0.31666667],
#        [0.13333333],
#        [0.2       ],
#        [0.16666667],
#        [0.16666667],
#        [0.33333333],
#        [0.25      ],
#        [0.11666667],
#        [0.15      ],
#        [0.25      ],
#        [0.28333333],
#        [0.25      ],
#        [0.13333333],
#        [0.2       ],
#        [0.13333333],
#        [0.35      ],
#        [0.45      ],
#        [0.15      ],
#        [0.16666667],
#        [0.06666667],
#        [0.21666667],
#        [0.26666667],
#        [0.21666667],
#        [0.11666667],
#        [0.08333333],
#        [0.11666667],
#        [0.15      ],
#        [0.2       ],
#        [0.28333333],
#        [0.31666667],
#        [0.31666667],
#        [0.21666667],
#        [0.18333333],
#        [0.08333333],
#        [0.16666667],
#        [0.3       ],
#        [0.11666667],
#        [0.05      ],
#        [0.08333333],
#        [0.16666667],
#        [0.13333333],
#        [0.26666667],
#        [0.18333333],
#        [0.23333333],
#        [0.11666667],
#        [0.21666667],
#        [0.05      ],
#        [0.15      ],
#        [0.13333333],
#        [0.2       ],
#        [0.18333333],
#        [0.35      ],
#        [0.23333333],
#        [0.08333333],
#        [0.15      ],
#        [0.38333333],
#        [0.28333333],
#        [0.13333333],
#        [0.21666667],
#        [0.16666667],
#        [0.11666667],
#        [0.21666667],
#        [0.21666667],
#        [0.        ],
#        [0.03333333]])

# %% [markdown]
# Configure LSTM model

# %%
# Lookback period
lookback = 5
X_train, Y_train = create_dataset(train, lookback)
X_test, Y_test = create_dataset(test, lookback)

# %%
X_train
# Out:
# array([[0.14427861, 0.09950249, 0.09452736, 0.14427861, 0.11442786],
#        [0.09950249, 0.09452736, 0.14427861, 0.11442786, 0.08955224],
#        [0.09452736, 0.14427861, 0.11442786, 0.08955224, 0.09452736],
#        ...,
#        [0.039801  , 0.02985075, 0.06467662, 0.04975124, 0.07462687],
#        [0.02985075, 0.06467662, 0.04975124, 0.07462687, 0.03482587],
#        [0.06467662, 0.04975124, 0.07462687, 0.03482587, 0.04975124]])

# %%
Y_train
# Out:
# array([0.08955224, 0.09452736, 0.09950249, 0.06965174, 0.08955224,
#        0.07960199, 0.12437811, 0.06965174, 0.06965174, 0.06467662,
#        0.08457711, 0.03482587, 0.07960199, 0.13432836, 0.11940299,
#        0.09950249, 0.08955224, 0.13432836, 0.1840796 , 0.10945274,
#        0.12437811, 0.10447761, 0.07960199, 0.11442786, 0.11442786,
#        0.04477612, 0.10945274, 0.06467662, 0.10447761, 0.06467662,
#        0.02487562, 0.06467662, 0.05970149, 0.08457711, 0.13930348,
#        0.06467662, 0.13930348, 0.09452736, 0.08955224, 0.15422886,
#        0.15422886, 0.13930348, 0.15920398, 0.18905473, 0.1641791 ,
#        0.17910448, 0.17412935, 0.14427861, 0.13432836, 0.11940299,
#        0.05472637, 0.09452736, 0.08457711, 0.11442786, 0.039801  ,
#        0.09452736, 0.039801  , 0.11442786, 0.08955224, 0.05472637,
#        0.08457711, 0.09950249, 0.05472637, 0.07462687, 0.09950249,
#        0.11940299, 0.09452736, 0.09452736, 0.11940299, 0.08457711,
#        0.07960199, 0.05472637, 0.04975124, 0.08955224, 0.039801  ,
#        0.07462687, 0.08955224, 0.04477612, 0.06965174, 0.03482587,
#        0.02985075, 0.07960199, 0.05472637, 0.07960199, 0.039801  ,
#        0.06467662, 0.07462687, 0.05472637, 0.0199005 , 0.13930348,
#        0.06467662, 0.08457711, 0.06965174, 0.08457711, 0.0199005 ,
#        0.09950249, 0.07960199, 0.09452736, 0.03482587, 0.06467662,
#        0.09950249, 0.04477612, 0.03482587, 0.06467662, 0.09452736,
#        0.10447761, 0.07960199, 0.04975124, 0.05970149, 0.05970149,
#        0.06965174, 0.11940299, 0.09950249, 0.07462687, 0.04975124,
#        0.08955224, 0.07462687, 0.07462687, 0.039801  , 0.07960199,
#        0.02985075, 0.01492537, 0.06467662, 0.08955224, 0.05970149,
#        0.039801  , 0.03482587, 0.07462687, 0.07960199, 0.07960199,
#        0.05970149, 0.05970149, 0.11442786, 0.00995025, 0.07462687,
#        0.10447761, 0.08457711, 0.20895522, 0.15422886, 0.11940299,
#        0.05472637, 0.08955224, 0.08457711, 0.06467662, 0.07960199,
#        0.07462687, 0.10945274, 0.06965174, 0.05472637, 0.02487562,
#        0.05970149, 0.04477612, 0.09950249, 0.06467662, 0.06965174,
#        0.05472637, 0.09452736, 0.07462687, 0.10447761, 0.07960199,
#        0.15920398, 0.10945274, 0.06467662, 0.07960199, 0.        ,
#        0.08955224, 0.10447761, 0.07462687, 0.05472637, 0.06467662,
#        0.07960199, 0.03482587, 0.039801  , 0.08457711, 0.08955224,
#        0.0199005 , 0.05472637, 0.039801  , 0.02985075, 0.05970149,
#        0.07960199, 0.12935323, 0.08955224, 0.05970149, 0.05970149,
#        0.07462687, 0.00995025, 0.03482587, 0.08457711, 0.04477612,
#        0.02985075, 0.05970149, 0.06965174, 0.04975124, 0.04975124,
#        0.0199005 , 0.07462687, 0.07462687, 0.05472637, 0.06965174,
#        0.05970149, 0.02487562, 0.1840796 , 0.25373134, 0.22885572,
#        0.09452736, 0.04477612, 0.04477612, 0.10945274, 0.09950249,
#        0.13930348, 0.06467662, 0.03482587, 0.04477612, 0.10945274,
#        0.09950249, 0.08457711, 0.08457711, 0.05472637, 0.07462687,
#        0.039801  , 0.01492537, 0.05472637, 0.039801  , 0.07960199,
#        0.04975124, 0.0199005 , 0.0199005 , 0.08457711, 0.11442786,
#        0.07462687, 0.06965174, 0.08457711, 0.05970149, 0.02985075,
#        0.07462687, 0.04975124, 0.04975124, 0.07960199, 0.05970149,
#        0.04975124, 0.06965174, 0.05970149, 0.04975124, 0.05970149,
#        0.04975124, 0.03482587, 0.039801  , 0.02985075, 0.06467662,
#        0.04975124, 0.07462687, 0.03482587, 0.04975124, 0.07462687])

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
X_train.shape[0]
# Out:
# 870

# %%
X_train.shape[1]
# Out:
# 1

# %%
X_train.shape
# Out:
# (870, 1, 5)

# %% [markdown]
# #LSTM - The model
# We have reached the final step - design, fit, and train the LSTM model. Our LSTM layer is 32-noded 1-layered, plus a dense output layer with MSE as loss function, adam as the optimiser, and trained for 100 epochs.

# %%
# Generate LSTM network
model = tf.keras.Sequential()
model.add(LSTM(32, input_shape=(1, lookback)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
history=model.fit(X_train, Y_train, validation_split=0.2, epochs=100, batch_size=1, verbose=2)

# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# Epoch 1/100
# 696/696 - 9s - loss: 0.0027 - val_loss: 0.0013 - 9s/epoch - 12ms/step
# Epoch 2/100
# 696/696 - 2s - loss: 0.0025 - val_loss: 0.0015 - 2s/epoch - 3ms/step
# Epoch 3/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 4/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 5/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0012 - 2s/epoch - 3ms/step
# Epoch 6/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 7/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 8/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 9/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0012 - 2s/epoch - 3ms/step
# Epoch 10/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0012 - 2s/epoch - 3ms/step
# Epoch 11/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 12/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 13/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0017 - 2s/epoch - 3ms/step
# Epoch 14/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 15/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 16/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 17/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 18/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 19/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0012 - 2s/epoch - 3ms/step
# Epoch 20/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 21/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 22/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 23/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 24/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 25/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0012 - 2s/epoch - 3ms/step
# Epoch 26/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 27/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 28/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 29/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0012 - 2s/epoch - 3ms/step
# Epoch 30/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 31/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 32/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 33/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0015 - 2s/epoch - 3ms/step
# Epoch 34/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 35/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0016 - 3s/epoch - 4ms/step
# Epoch 36/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 37/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 38/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 39/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0012 - 2s/epoch - 3ms/step
# Epoch 40/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0026 - 3s/epoch - 4ms/step
# Epoch 41/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 42/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0016 - 2s/epoch - 3ms/step
# Epoch 43/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 44/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0012 - 2s/epoch - 3ms/step
# Epoch 45/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 46/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 47/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0012 - 2s/epoch - 3ms/step
# Epoch 48/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 49/100
# 696/696 - 3s - loss: 0.0023 - val_loss: 0.0011 - 3s/epoch - 4ms/step
# Epoch 50/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 51/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0012 - 2s/epoch - 3ms/step
# Epoch 52/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0012 - 2s/epoch - 3ms/step
# Epoch 53/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 54/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 55/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0012 - 2s/epoch - 3ms/step
# Epoch 56/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 57/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 58/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0014 - 2s/epoch - 3ms/step
# Epoch 59/100
# 696/696 - 2s - loss: 0.0023 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 60/100
# 696/696 - 2s - loss: 0.0023 - val_loss: 0.0014 - 2s/epoch - 3ms/step
# Epoch 61/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0014 - 2s/epoch - 3ms/step
# Epoch 62/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 63/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 64/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 65/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 66/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 67/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 68/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0014 - 2s/epoch - 3ms/step
# Epoch 69/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0014 - 2s/epoch - 3ms/step
# Epoch 70/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 71/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0012 - 2s/epoch - 3ms/step
# Epoch 72/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0012 - 2s/epoch - 3ms/step
# Epoch 73/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0014 - 2s/epoch - 3ms/step
# Epoch 74/100
# 696/696 - 3s - loss: 0.0023 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 75/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 76/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 77/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 78/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0012 - 2s/epoch - 3ms/step
# Epoch 79/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 80/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0015 - 2s/epoch - 3ms/step
# Epoch 81/100
# 696/696 - 2s - loss: 0.0023 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 82/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 83/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 84/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 85/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0012 - 2s/epoch - 3ms/step
# Epoch 86/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0015 - 2s/epoch - 3ms/step
# Epoch 87/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 88/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0016 - 2s/epoch - 3ms/step
# Epoch 89/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 90/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 91/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 92/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 93/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 94/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 95/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 96/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0014 - 2s/epoch - 3ms/step
# Epoch 97/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0012 - 2s/epoch - 3ms/step
# Epoch 98/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0012 - 2s/epoch - 3ms/step
# Epoch 99/100
# 696/696 - 3s - loss: 0.0023 - val_loss: 0.0021 - 3s/epoch - 4ms/step
# Epoch 100/100
# 696/696 - 2s - loss: 0.0024 - val_loss: 0.0012 - 2s/epoch - 3ms/step
# dict_keys(['loss', 'val_loss'])

# %% [markdown]
# #LSTM - Prediction
# Once we have trained our model, we can start doing predictions. Then, manipulate the post-action data.

# %%
# Generate predictions
trainpred = model.predict(X_train)
testpred = model.predict(X_test)

# %%
trainpred
# Out:
# array([[0.09672323],
#        [0.08674663],
#        [0.08810751],
#        [0.08881944],
#        [0.07857323],
#        [0.08309209],
#        [0.08119662],
#        [0.09386706],
#        [0.08021104],
#        [0.07626765],
#        [0.07584953],
#        [0.07973357],
#        [0.06507722],
#        [0.07591668],
#        [0.0966728 ],
#        [0.09416083],
#        [0.08963294],
#        [0.0869401 ],
#        [0.10005061],
#        [0.11803705],
#        [0.09783974],
#        [0.09930915],
#        [0.0951702 ],
#        [0.0830318 ],
#        [0.09308814],
#        [0.09458882],
#        [0.0713792 ],
#        [0.08861947],
#        [0.07814652],
#        [0.08560418],
#        [0.07781223],
#        [0.06051042],
#        [0.07169211],
#        [0.07079822],
#        [0.07714015],
#        [0.09793474],
#        [0.07840683],
#        [0.09883115],
#        [0.09118371],
#        [0.08408663],
#        [0.10710096],
#        [0.10982371],
#        [0.10551651],
#        [0.11335966],
#        [0.12434043],
#        [0.11802004],
#        [0.12188112],
#        [0.12224755],
#        [0.11136706],
#        [0.10633221],
#        [0.10050499],
#        [0.07700793],
#        [0.08503229],
#        [0.08380502],
#        [0.09046887],
#        [0.07013787],
#        [0.08225428],
#        [0.06893683],
#        [0.08657816],
#        [0.0854244 ],
#        [0.07118566],
#        [0.0810735 ],
#        [0.08663756],
#        [0.07218594],
#        [0.07677984],
#        [0.08630991],
#        [0.09273794],
#        [0.08741486],
#        [0.08692238],
#        [0.09551015],
#        [0.0850702 ],
#        [0.09726945],
#        [0.08507185],
#        [0.07880618],
#        [0.09266752],
#        [0.09185027],
#        [0.10757586],
#        [0.08726118],
#        [0.08306916],
#        [0.08799693],
#        [0.0938132 ],
#        [0.0926041 ],
#        [0.08297254],
#        [0.09779143],
#        [0.08302066],
#        [0.07989505],
#        [0.10097761],
#        [0.11080141],
#        [0.11026125],
#        [0.12186219],
#        [0.14991283],
#        [0.14574814],
#        [0.10091224],
#        [0.06327531],
#        [0.06831974],
#        [0.08407324],
#        [0.07474289],
#        [0.09221064],
#        [0.08526626],
#        [0.08827431],
#        [0.10741301],
#        [0.09526651],
#        [0.09814931],
#        [0.09750347],
#        [0.10171553],
#        [0.09717163],
#        [0.09063379],
#        [0.08522398],
#        [0.06855855],
#        [0.08898437],
#        [0.08827595],
#        [0.08150417],
#        [0.08176405],
#        [0.0951215 ],
#        [0.09754317],
#        [0.07706218],
#        [0.08037195],
#        [0.09262611],
#        [0.08143898],
#        [0.06725406],
#        [0.07819087],
#        [0.07921051],
#        [0.07479189],
#        [0.07901921],
#        [0.0860123 ],
#        [0.07436857],
#        [0.08818705],
#        [0.0888816 ],
#        [0.0839368 ],
#        [0.08675639],
#        [0.09144615],
#        [0.1064505 ],
#        [0.08770994],
#        [0.0802069 ],
#        [0.08710691],
#        [0.08585645],
#        [0.06633695],
#        [0.07560564],
#        [0.08419835],
#        [0.0866594 ],
#        [0.07512005],
#        [0.08241679],
#        [0.0860889 ],
#        [0.07852288],
#        [0.07355083],
#        [0.08207511],
#        [0.0719948 ],
#        [0.08522758],
#        [0.09270158],
#        [0.09106249],
#        [0.07039957],
#        [0.07509633],
#        [0.07814433],
#        [0.08545745],
#        [0.06826214],
#        [0.07370309],
#        [0.07632822],
#        [0.06754994],
#        [0.07540189],
#        [0.08485254],
#        [0.08766812],
#        [0.09902863],
#        [0.08001201],
#        [0.08661728],
#        [0.08324558],
#        [0.10023662],
#        [0.09159862],
#        [0.07208934],
#        [0.08339995],
#        [0.08579037],
#        [0.08446093],
#        [0.07823153],
#        [0.0846525 ],
#        [0.07492391],
#        [0.09251378],
#        [0.08969268],
#        [0.08731582],
#        [0.08645052],
#        [0.07824755],
#        [0.07994431],
#        [0.08967228],
#        [0.09102934],
#        [0.08227566],
#        [0.0893482 ],
#        [0.10363117],
#        [0.07831574],
#        [0.1009259 ],
#        [0.07881884],
#        [0.06952178],
#        [0.08342315],
#        [0.09023738],
#        [0.07330392],
#        [0.08841377],
#        [0.08628114],
#        [0.09262109],
#        [0.09198379],
#        [0.0759113 ],
#        [0.0800646 ],
#        [0.07569852],
#        [0.08103207],
#        [0.06265908],
#        [0.07201574],
#        [0.10073061],
#        [0.08977374],
#        [0.07548862],
#        [0.07618219],
#        [0.08912376],
#        [0.1013817 ],
#        [0.10458568],
#        [0.09752187],
#        [0.09333289],
#        [0.09405175],
#        [0.09491025],
#        [0.10451894],
#        [0.09568758],
#        [0.31796712],
#        [0.1988468 ],
#        [0.11231494],
#        [0.08288128],
#        [0.08651374],
#        [0.09369875],
#        [0.09345055],
#        [0.07360821],
#        [0.08367574],
#        [0.084933  ],
#        [0.09374954],
#        [0.09326441],
#        [0.10526375],
#        [0.09336826],
#        [0.09268989],
#        [0.08477237],
#        [0.06932219],
#        [0.07021508],
#        [0.06620204],
#        [0.08323865],
#        [0.10164416],
#        [0.09756439],
#        [0.08306849],
#        [0.06731311],
#        [0.06975964],
#        [0.07067563],
#        [0.08694568],
#        [0.09168023],
#        [0.08659927],
#        [0.09869925],
#        [0.07849465],
#        [0.07111149],
#        [0.06989542],
#        [0.08279403],
#        [0.0858452 ],
#        [0.08170731],
#        [0.08278428],
#        [0.08905099],
#        [0.09144767],
#        [0.06629629],
#        [0.06750574],
#        [0.07006825],
#        [0.08951357],
#        [0.10899657],
#        [0.09498485],
#        [0.08760221],
#        [0.0953671 ],
#        [0.08685693],
#        [0.07638934],
#        [0.08985333],
#        [0.10444474],
#        [0.17270198],
#        [0.15733612],
#        [0.09940238],
#        [0.09194925],
#        [0.07858613],
#        [0.08210987],
#        [0.08448658],
#        [0.08456644],
#        [0.07977736],
#        [0.08320643],
#        [0.10967496],
#        [0.08129671],
#        [0.07652199],
#        [0.0773155 ],
#        [0.06494913],
#        [0.09055819],
#        [0.08947445],
#        [0.07877587],
#        [0.07820418],
#        [0.07671963],
#        [0.08989983],
#        [0.07370937],
#        [0.08759749],
#        [0.09262551],
#        [0.08123862],
#        [0.09095912],
#        [0.08960959],
#        [0.08799779],
#        [0.0890905 ],
#        [0.08547703],
#        [0.07015801],
#        [0.07482857],
#        [0.08378258],
#        [0.07912271],
#        [0.07791524],
#        [0.07196614],
#        [0.08269652],
#        [0.07228192],
#        [0.07547602],
#        [0.08763968],
#        [0.08197528],
#        [0.088208  ],
#        [0.08105463],
#        [0.07339256],
#        [0.0921187 ],
#        [0.07736697],
#        [0.07831969],
#        [0.08602323],
#        [0.08342487],
#        [0.09184127],
#        [0.07660823],
#        [0.08392359],
#        [0.08525995],
#        [0.09103886],
#        [0.0734008 ],
#        [0.07505645],
#        [0.07363567],
#        [0.07848527],
#        [0.08568648],
#        [0.0977879 ],
#        [0.09367315],
#        [0.09939247],
#        [0.09391961],
#        [0.08805245],
#        [0.08626069],
#        [0.08325966],
#        [0.0873014 ],
#        [0.07202829],
#        [0.07313094],
#        [0.08231067],
#        [0.05976656],
#        [0.07006503],
#        [0.09242111],
#        [0.0735774 ],
#        [0.07984386],
#        [0.08331902],
#        [0.07774532],
#        [0.06680119],
#        [0.07213208],
#        [0.07147768],
#        [0.08264533],
#        [0.08015253],
#        [0.07274985],
#        [0.09513918],
#        [0.09732674],
#        [0.10339113],
#        [0.09170677],
#        [0.09443233],
#        [0.07346752],
#        [0.0730835 ],
#        [0.07642788],
#        [0.07730091],
#        [0.07414977],
#        [0.07343544],
#        [0.0784613 ],
#        [0.08842525],
#        [0.08439881],
#        [0.08725313],
#        [0.10334656],
#        [0.0867053 ],
#        [0.07821792],
#        [0.07496938],
#        [0.07512988],
#        [0.06711239],
#        [0.09054587],
#        [0.08664232],
#        [0.06544531],
#        [0.06532415],
#        [0.06876424],
#        [0.07369337],
#        [0.05969579],
#        [0.07141194],
#        [0.07473865],
#        [0.06843773],
#        [0.07097091],
#        [0.10282725],
#        [0.08388571],
#        [0.07170334],
#        [0.08418059],
#        [0.09780926],
#        [0.09059891],
#        [0.09380539],
#        [0.09601595],
#        [0.09335944],
#        [0.09498796],
#        [0.09208227],
#        [0.07984613],
#        [0.08060578],
#        [0.0758081 ],
#        [0.0942554 ],
#        [0.0910062 ],
#        [0.0847226 ],
#        [0.10522574],
#        [0.13326347],
#        [0.11990578],
#        [0.12515323],
#        [0.10604495],
#        [0.11884925],
#        [0.11406188],
#        [0.0851166 ],
#        [0.07115935],
#        [0.07947184],
#        [0.06944735],
#        [0.08243746],
#        [0.0759384 ],
#        [0.07123464],
#        [0.07412016],
#        [0.08573191],
#        [0.07405519],
#        [0.06188071],
#        [0.06877629],
#        [0.06832852],
#        [0.08472245],
#        [0.08339015],
#        [0.07177766],
#        [0.08731632],
#        [0.08806328],
#        [0.09160819],
#        [0.09313845],
#        [0.09279169],
#        [0.11408012],
#        [0.08008785],
#        [0.081204  ],
#        [0.09319252],
#        [0.07291459],
#        [0.05904569],
#        [0.07621936],
#        [0.10753244],
#        [0.08027865],
#        [0.07510411],
#        [0.08532259],
#        [0.07829805],
#        [0.11054298],
#        [0.13812174],
#        [0.09687054],
#        [0.07213479],
#        [0.09011657],
#        [0.08345771],
#        [0.0773399 ],
#        [0.06597003],
#        [0.07173198],
#        [0.0809627 ],
#        [0.08133439],
#        [0.08468585],
#        [0.07817294],
#        [0.09087974],
#        [0.08119423],
#        [0.10973746],
#        [0.12395035],
#        [0.09666808],
#        [0.08683728],
#        [0.09224228],
#        [0.06951524],
#        [0.08538688],
#        [0.09162373],
#        [0.07730639],
#        [0.06417076],
#        [0.08036399],
#        [0.07133554],
#        [0.07109913],
#        [0.07233718],
#        [0.08179498],
#        [0.08141567],
#        [0.07465018],
#        [0.06967413],
#        [0.09041066],
#        [0.08622272],
#        [0.08642813],
#        [0.08138429],
#        [0.08019991],
#        [0.09016208],
#        [0.08011635],
#        [0.08778919],
#        [0.07470244],
#        [0.07638508],
#        [0.07207315],
#        [0.07520646],
#        [0.09304519],
#        [0.0817485 ],
#        [0.06553502],
#        [0.07818168],
#        [0.08552945],
#        [0.08547175],
#        [0.07503357],
#        [0.07931869],
#        [0.07067113],
#        [0.06868396],
#        [0.08546209],
#        [0.08136614],
#        [0.09047888],
#        [0.08816734],
#        [0.08628141],
#        [0.07756099],
#        [0.07779218],
#        [0.06854748],
#        [0.08132526],
#        [0.08639382],
#        [0.08777932],
#        [0.079212  ],
#        [0.07358611],
#        [0.07270704],
#        [0.06636093],
#        [0.07605541],
#        [0.0830283 ],
#        [0.08398117],
#        [0.08101318],
#        [0.08055037],
#        [0.08199099],
#        [0.08653496],
#        [0.07324675],
#        [0.07998814],
#        [0.08862563],
#        [0.07894496],
#        [0.08311713],
#        [0.08627622],
#        [0.09833623],
#        [0.07147763],
#        [0.07297306],
#        [0.09804259],
#        [0.07535037],
#        [0.06865219],
#        [0.08111239],
#        [0.1010791 ],
#        [0.08650621],
#        [0.08140649],
#        [0.08086922],
#        [0.08141283],
#        [0.0784565 ],
#        [0.07925085],
#        [0.07187586],
#        [0.07612321],
#        [0.08381969],
#        [0.07806249],
#        [0.08097341],
#        [0.08868602],
#        [0.08621424],
#        [0.08295585],
#        [0.07806896],
#        [0.06834662],
#        [0.10127746],
#        [0.08249001],
#        [0.08843378],
#        [0.08323578],
#        [0.08436395],
#        [0.07396887],
#        [0.0632981 ],
#        [0.07192197],
#        [0.07368448],
#        [0.06404025],
#        [0.07605272],
#        [0.07073364],
#        [0.06820506],
#        [0.07597031],
#        [0.08266854],
#        [0.07484986],
#        [0.0786508 ],
#        [0.06571745],
#        [0.08227436],
#        [0.08522008],
#        [0.08229007],
#        [0.10059166],
#        [0.09122986],
#        [0.08381869],
#        [0.0793315 ],
#        [0.09281141],
#        [0.08592313],
#        [0.09973652],
#        [0.09064113],
#        [0.08179072],
#        [0.09031821],
#        [0.07573918],
#        [0.08826319],
#        [0.08910089],
#        [0.08714344],
#        [0.10502085],
#        [0.10816755],
#        [0.09271822],
#        [0.09075829],
#        [0.08885163],
#        [0.08995742],
#        [0.09221372],
#        [0.10681839],
#        [0.09452648],
#        [0.08495244],
#        [0.08961236],
#        [0.07902171],
#        [0.07622105],
#        [0.07166615],
#        [0.08699789],
#        [0.08897203],
#        [0.08722202],
#        [0.07463068],
#        [0.08558939],
#        [0.07692223],
#        [0.08749276],
#        [0.08254725],
#        [0.07949641],
#        [0.06968186],
#        [0.08686242],
#        [0.084557  ],
#        [0.0841409 ],
#        [0.08860025],
#        [0.07695983],
#        [0.07786917],
#        [0.08325229],
#        [0.07176594],
#        [0.07142553],
#        [0.06874927],
#        [0.07780546],
#        [0.07396421],
#        [0.06944042],
#        [0.0618903 ],
#        [0.07671678],
#        [0.08599544],
#        [0.07927756],
#        [0.08026882],
#        [0.08561095],
#        [0.07120263],
#        [0.07775248],
#        [0.07197148],
#        [0.0638109 ],
#        [0.0700839 ],
#        [0.06702314],
#        [0.08022086],
#        [0.08096199],
#        [0.16467237],
#        [0.1250866 ],
#        [0.10770478],
#        [0.08925592],
#        [0.08800436],
#        [0.09177577],
#        [0.09287879],
#        [0.07371737],
#        [0.06901526],
#        [0.08665811],
#        [0.09243009],
#        [0.09106759],
#        [0.09140714],
#        [0.08992637],
#        [0.08427722],
#        [0.06993397],
#        [0.07477473],
#        [0.06753179],
#        [0.07874216],
#        [0.0794342 ],
#        [0.06396949],
#        [0.07044771],
#        [0.06965308],
#        [0.07562424],
#        [0.08944819],
#        [0.07316593],
#        [0.08961019],
#        [0.0834329 ],
#        [0.07913522],
#        [0.08439948],
#        [0.08531434],
#        [0.08736733],
#        [0.07375412],
#        [0.07712489],
#        [0.08311787],
#        [0.06973147],
#        [0.07267672],
#        [0.08346767],
#        [0.07131947],
#        [0.07910579],
#        [0.09154353],
#        [0.08918216],
#        [0.08377859],
#        [0.08500612],
#        [0.08155664],
#        [0.07524484],
#        [0.09191401],
#        [0.09353235],
#        [0.09963876],
#        [0.08570351],
#        [0.06501483],
#        [0.07968948],
#        [0.09535408],
#        [0.0842151 ],
#        [0.09405847],
#        [0.08477253],
#        [0.07236977],
#        [0.06971915],
#        [0.08045573],
#        [0.06616785],
#        [0.07410339],
#        [0.08239119],
#        [0.06746521],
#        [0.07392778],
#        [0.06453928],
#        [0.05878113],
#        [0.0749723 ],
#        [0.06889577],
#        [0.07566848],
#        [0.06661298],
#        [0.07096927],
#        [0.07646094],
#        [0.0694193 ],
#        [0.05800968],
#        [0.093948  ],
#        [0.07705791],
#        [0.07844493],
#        [0.07914864],
#        [0.08008659],
#        [0.06093122],
#        [0.08145685],
#        [0.08045182],
#        [0.08212543],
#        [0.06724976],
#        [0.07175365],
#        [0.08504631],
#        [0.06780349],
#        [0.06238425],
#        [0.07199837],
#        [0.08114962],
#        [0.08630779],
#        [0.08105043],
#        [0.07096129],
#        [0.07205591],
#        [0.07147357],
#        [0.07350172],
#        [0.09047569],
#        [0.08783762],
#        [0.07964953],
#        [0.0714267 ],
#        [0.08152403],
#        [0.0782509 ],
#        [0.0766293 ],
#        [0.06690359],
#        [0.07656403],
#        [0.06297921],
#        [0.05352447],
#        [0.06945345],
#        [0.07832772],
#        [0.07076096],
#        [0.06500445],
#        [0.06249099],
#        [0.07341628],
#        [0.07675954],
#        [0.07757936],
#        [0.07313291],
#        [0.07187068],
#        [0.08920489],
#        [0.05876733],
#        [0.07262859],
#        [0.08777499],
#        [0.07983437],
#        [0.12099071],
#        [0.11357135],
#        [0.0992742 ],
#        [0.07890699],
#        [0.08369216],
#        [0.08343019],
#        [0.07437757],
#        [0.07914681],
#        [0.07817233],
#        [0.08833012],
#        [0.07863858],
#        [0.07110365],
#        [0.06119244],
#        [0.068518  ],
#        [0.06516583],
#        [0.0807087 ],
#        [0.07487657],
#        [0.07422633],
#        [0.07164539],
#        [0.0819795 ],
#        [0.07841189],
#        [0.08648904],
#        [0.08211259],
#        [0.10541724],
#        [0.09605204],
#        [0.07778022],
#        [0.08178137],
#        [0.05462043],
#        [0.07646602],
#        [0.08696835],
#        [0.07634726],
#        [0.07210682],
#        [0.0740172 ],
#        [0.07811976],
#        [0.06406786],
#        [0.0629952 ],
#        [0.0777648 ],
#        [0.08051462],
#        [0.05963359],
#        [0.06763785],
#        [0.0646758 ],
#        [0.0578364 ],
#        [0.06799334],
#        [0.07559188],
#        [0.09273095],
#        [0.08545925],
#        [0.07458342],
#        [0.07379908],
#        [0.07684195],
#        [0.05581783],
#        [0.05924703],
#        [0.07670337],
#        [0.06493936],
#        [0.05937225],
#        [0.06941559],
#        [0.07274085],
#        [0.06688445],
#        [0.06698135],
#        [0.05749908],
#        [0.07202622],
#        [0.07535159],
#        [0.06860865],
#        [0.07445161],
#        [0.07206495],
#        [0.05946298],
#        [0.10829638],
#        [0.13853216],
#        [0.13664094],
#        [0.09955171],
#        [0.07178516],
#        [0.06885567],
#        [0.08706426],
#        [0.08605285],
#        [0.09897608],
#        [0.08072347],
#        [0.06511534],
#        [0.06706326],
#        [0.08553354],
#        [0.08542507],
#        [0.08159408],
#        [0.08317926],
#        [0.07289758],
#        [0.07657912],
#        [0.06643208],
#        [0.05479411],
#        [0.06619617],
#        [0.06232493],
#        [0.07340623],
#        [0.06838842],
#        [0.05664602],
#        [0.05569088],
#        [0.07466322],
#        [0.08696778],
#        [0.07779405],
#        [0.07681484],
#        [0.08199237],
#        [0.07336479],
#        [0.06184935],
#        [0.07443456],
#        [0.06817423],
#        [0.06571881],
#        [0.07688729],
#        [0.07157988],
#        [0.06741069],
#        [0.0740912 ],
#        [0.07132693],
#        [0.0672648 ],
#        [0.07046151],
#        [0.06740522],
#        [0.06159509],
#        [0.06238374],
#        [0.05887507],
#        [0.06866316],
#        [0.0664392 ],
#        [0.07346958],
#        [0.06392598],
#        [0.06551191]], dtype=float32)

# %%
testpred
# Out:
# array([[0.14739716],
#        [0.14780684],
#        [0.15438175],
#        [0.14394653],
#        [0.17198151],
#        [0.21768224],
#        [0.16479154],
#        [0.09621867],
#        [0.12977098],
#        [0.12406133],
#        [0.11609907],
#        [0.13587365],
#        [0.09994175],
#        [0.10210343],
#        [0.14388013],
#        [0.09462245],
#        [0.09455492],
#        [0.18900558],
#        [0.12996405],
#        [0.13217522],
#        [0.11535025],
#        [0.08025753],
#        [0.13938564],
#        [0.1008433 ],
#        [0.07719489],
#        [0.14531067],
#        [0.12173441],
#        [0.1413309 ],
#        [0.14829439],
#        [0.12819727],
#        [0.13225272],
#        [0.15487808],
#        [0.15765683],
#        [0.13137594],
#        [0.10923721],
#        [0.1119058 ],
#        [0.13375567],
#        [0.14151305],
#        [0.07293298],
#        [0.08458102],
#        [0.13084027],
#        [0.07762441],
#        [0.09698747],
#        [0.11139984],
#        [0.13848858],
#        [0.16748914],
#        [0.15913507],
#        [0.15899059],
#        [0.13294502],
#        [0.1198303 ],
#        [0.16405708],
#        [0.16485786],
#        [0.14750688],
#        [0.17393854],
#        [0.21418588],
#        [0.18480693],
#        [0.1083654 ],
#        [0.13497907],
#        [0.15969545],
#        [0.1659673 ],
#        [0.2448055 ],
#        [0.16289982],
#        [0.11729197],
#        [0.11227129],
#        [0.133856  ],
#        [0.15406731],
#        [0.1353966 ],
#        [0.15936065],
#        [0.16654804],
#        [0.1645205 ],
#        [0.12258916],
#        [0.15680173],
#        [0.156817  ],
#        [0.16090536],
#        [0.19199234],
#        [0.16600326],
#        [0.15837649],
#        [0.33964697],
#        [0.22568569],
#        [0.14393325],
#        [0.1374    ],
#        [0.18345042],
#        [0.20735702],
#        [0.17290206],
#        [0.11212521],
#        [0.12589456],
#        [0.16182245],
#        [0.18694891],
#        [0.17909475],
#        [0.23654819],
#        [0.14478438],
#        [0.16730654],
#        [0.14027411],
#        [0.13341309],
#        [0.12555195],
#        [0.11251807],
#        [0.17646797],
#        [0.17146306],
#        [0.16862562],
#        [0.17904702],
#        [0.12955101],
#        [0.1462238 ],
#        [0.16586232],
#        [0.11512828],
#        [0.11075141],
#        [0.13643426],
#        [0.08778286],
#        [0.07105689],
#        [0.11616201],
#        [0.08762458],
#        [0.08106489],
#        [0.13329174],
#        [0.15417099],
#        [0.18279931],
#        [0.17504168],
#        [0.1385831 ],
#        [0.14946684],
#        [0.1914766 ],
#        [0.15440464],
#        [0.14479885],
#        [0.1647895 ],
#        [0.15521653],
#        [0.10217598],
#        [0.14259121],
#        [0.15867546],
#        [0.15986684],
#        [0.12836759],
#        [0.11862911],
#        [0.1207052 ],
#        [0.1126519 ],
#        [0.07265233],
#        [0.09715198],
#        [0.11934359],
#        [0.13917029],
#        [0.10135584],
#        [0.11909893],
#        [0.11639102],
#        [0.16226676],
#        [0.1594288 ],
#        [0.12966734],
#        [0.1383428 ],
#        [0.09539963],
#        [0.11755486],
#        [0.14198494],
#        [0.07651748],
#        [0.14694746],
#        [0.1279791 ],
#        [0.06937884],
#        [0.08864797],
#        [0.14454786],
#        [0.14847982],
#        [0.16838919],
#        [0.12006564],
#        [0.1265243 ],
#        [0.12420578],
#        [0.11710209],
#        [0.17154142],
#        [0.15559678],
#        [0.10646643],
#        [0.11040539],
#        [0.14654514],
#        [0.15862384],
#        [0.15195   ],
#        [0.11433104],
#        [0.12819731],
#        [0.11178187],
#        [0.17294401],
#        [0.21354376],
#        [0.13018702],
#        [0.11246342],
#        [0.08469731],
#        [0.12644199],
#        [0.15181991],
#        [0.13708779],
#        [0.1063999 ],
#        [0.08720608],
#        [0.09632091],
#        [0.106919  ],
#        [0.12371742],
#        [0.15427943],
#        [0.17156261],
#        [0.17635134],
#        [0.14669731],
#        [0.12740627],
#        [0.09188642],
#        [0.11255155],
#        [0.16031127],
#        [0.10820296],
#        [0.07453644],
#        [0.08391747],
#        [0.10964349],
#        [0.10170575],
#        [0.14361599],
#        [0.129924  ],
#        [0.13988823],
#        [0.1092166 ],
#        [0.13115238],
#        [0.0852357 ],
#        [0.10235286],
#        [0.10726113],
#        [0.12200119],
#        [0.12473121],
#        [0.17520289],
#        [0.15260783],
#        [0.09335228],
#        [0.10775068],
#        [0.18735811],
#        [0.16433981],
#        [0.11374728],
#        [0.13416253],
#        [0.12456858],
#        [0.10037683],
#        [0.13235037],
#        [0.13752186]], dtype=float32)

# %%
# Convert predictions back to normal values
trainpred = scaler.inverse_transform(trainpred)
Y_train = scaler.inverse_transform([Y_train])
testpred = scaler.inverse_transform(testpred)
Y_test = scaler.inverse_transform([Y_test])
predictions = testpred

# %%
Y_train.shape
# Out:
# (1, 870)

# %%
Y_test.shape
# Out:
# (1, 214)

# %%
X_train.shape
# Out:
# (870, 1, 5)

# %%
X_test.shape
# Out:
# (214, 1, 5)

# %%
Y_train
# Out:
# array([[11.37313433, 11.67164179, 11.97014925, 10.17910448, 11.37313433,
#         10.7761194 , 13.46268657, 10.17910448, 10.17910448,  9.88059701,
#         11.07462687,  8.08955224, 10.7761194 , 14.05970149, 13.1641791 ,
#         11.97014925, 11.37313433, 14.05970149, 17.04477612, 12.56716418,
#         13.46268657, 12.26865672, 10.7761194 , 12.86567164, 12.86567164,
#          8.68656716, 12.56716418,  9.88059701, 12.26865672,  9.88059701,
#          7.49253731,  9.88059701,  9.58208955, 11.07462687, 14.35820896,
#          9.88059701, 14.35820896, 11.67164179, 11.37313433, 15.25373134,
#         15.25373134, 14.35820896, 15.55223881, 17.34328358, 15.85074627,
#         16.74626866, 16.44776119, 14.65671642, 14.05970149, 13.1641791 ,
#          9.28358209, 11.67164179, 11.07462687, 12.86567164,  8.3880597 ,
#         11.67164179,  8.3880597 , 12.86567164, 11.37313433,  9.28358209,
#         11.07462687, 11.97014925,  9.28358209, 10.47761194, 11.97014925,
#         13.1641791 , 11.67164179, 11.67164179, 13.1641791 , 11.07462687,
#         13.76119403, 10.7761194 , 10.47761194, 12.86567164, 12.56716418,
#         15.55223881, 10.7761194 , 11.07462687, 11.67164179, 13.1641791 ,
#         12.56716418, 10.7761194 , 13.76119403, 10.47761194, 10.7761194 ,
#         14.35820896, 15.85074627, 15.25373134, 17.04477612, 21.82089552,
#         20.02985075, 11.97014925,  7.19402985,  8.98507463, 11.97014925,
#         10.17910448, 13.46268657, 11.07462687, 12.26865672, 15.25373134,
#         12.56716418, 13.46268657, 12.86567164, 14.05970149, 12.86567164,
#         11.97014925, 11.07462687,  8.3880597 , 12.86567164, 11.97014925,
#         11.07462687, 10.7761194 , 13.46268657, 13.46268657,  9.58208955,
#         10.7761194 , 12.86567164, 10.7761194 ,  8.3880597 , 10.7761194 ,
#         10.7761194 , 10.17910448, 10.7761194 , 11.97014925,  9.58208955,
#         12.56716418, 11.97014925, 11.37313433, 11.67164179, 12.56716418,
#         15.25373134, 11.07462687, 10.47761194, 11.67164179, 11.67164179,
#          8.08955224, 10.47761194, 11.67164179, 12.26865672,  9.58208955,
#         11.37313433, 11
#         19.,  9., 15., 14., 18., 17., 27., 20., 11., 15., 29., 23., 14.,
#         19., 16., 13., 19., 19.,  6.]])

# %% [markdown]
# #Screen Prediction Accuracy on Test Data
# Once we have reviewed the input train-test data for the prediction - we can carry it out now.

# %%
# calculate RMSE
trainScore = math.sqrt(mean_squared_error(Y_train[0], trainpred[:,0]))
print('Train Score: %f RMSE' % (trainScore))
valScore = math.sqrt(mean_squared_error(Y_test[0], testpred[:,0]))
print('Test Score: %f RMSE' % (valScore))
# Out:
# Train Score: 2.771125 RMSE
# Test Score: 7.838240 RMSE

# %%
# Train predictions
trainpredPlot = np.empty_like(dftempday)
trainpredPlot[:, :] = np.nan
trainpredPlot[lookback:len(trainpred)+lookback, :] = trainpred

# %%
# Test predictions
testpredPlot = np.empty_like(dftempday)
testpredPlot[:, :] = np.nan
testpredPlot[len(trainpred)+(lookback*2)+1:len(dftempday)-1, :] = testpred

# %%
Y_test=Y_test.reshape(-1)
Y_test.shape
Y_test=pd.Series(Y_test)

# %%
Y_test
# Out:
# 0      21.0
# 1      22.0
# 2      19.0
# 3      25.0
# 4      33.0
#        ...
# 209    16.0
# 210    13.0
# 211    19.0
# 212    19.0
# 213     6.0
# Length: 214, dtype: float64

# %%
predictions=predictions.reshape(-1)
predictions.shape
predictions=pd.Series(predictions)

# %%
predictions
# Out:
# 0      14.843829
# 1      14.868410
# 2      15.262905
# 3      14.636791
# 4      16.318890
#          ...
# 209    14.049751
# 210    13.474114
# 211    12.022610
# 212    13.941022
# 213    14.251311
# Length: 214, dtype: float32

# %% [markdown]
# #LSTM - Finalisation
# As we have just carried out the prediction, let's evaluate the performance in terms of several metrics (mda, rmse) and visualise the prediction graph

# %%
import numpy as np

def mda(actual: np.ndarray, predicted: np.ndarray):
    """ Mean Directional Accuracy """
    return np.mean((np.sign(actual[1:] - actual[:-1]) == np.sign(predicted[1:] - predicted[:-1])).astype(int))

# %%
mda(Y_test, predictions)
# Out:
# 0.9906542056074766

# %% [markdown]
# test metrics

# %%
# https://machinelearningmastery.com/time-series-forecasting-performance-measures-with-python/

mse = mean_squared_error(Y_test, predictions)
mae = metrics.mean_absolute_error(Y_test, predictions)
mape = metrics.mean_absolute_percentage_error(Y_test, predictions)
rmse = sqrt(mse)
print('RMSE: %f' % rmse)
print('MSE: %f' % mse)
print('MAE: %f' % mae)
print('MAPE: %f' % mape)
# Out:
# RMSE: 7.838240
# MSE: 61.438013
# MAE: 5.954068
# MAPE: 0.293690

# %% [markdown]
# train metrics

# %%
trmse = mean_squared_error(Y_train[0], trainpred[:,0])
trmae = metrics.mean_absolute_error(Y_train[0], trainpred[:,0])
trmape = metrics.mean_absolute_percentage_error(Y_train[0], trainpred[:,0])
trrmse = sqrt(trmse)
print('RMSE: %f' % trrmse)
print('MSE: %f' % trmse)
print('MAE: %f' % trmae)
print('MAPE: %f' % trmape)
# Out:
# RMSE: 2.771125
# MSE: 7.679134
# MAE: 1.556069
# MAPE: 0.133908

# %%
np.mean(Y_test)
# Out:
# 19.0

# %%
plt.plot(Y_test)
plt.plot(predictions)
plt.xlabel('Days since Jan 1, 2015')
plt.ylabel('# of daily incidents')
plt.title("Test vs. Prediction")
plt.show()
