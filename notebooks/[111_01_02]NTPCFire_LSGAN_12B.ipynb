# %% [markdown]
# #Read the data

# %%
from zipfile import ZipFile
import os, glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from google.colab.patches import cv2_imshow

# %%
# !wget https://www.dropbox.com/s/gtvw3nqbderxigb/datafig28.zip
# Out:
# --2022-01-02 09:55:19--  https://www.dropbox.com/s/gtvw3nqbderxigb/datafig28.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.68.18, 2620:100:6020:18::a27d:4012
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.68.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/gtvw3nqbderxigb/datafig28.zip [following]
# --2022-01-02 09:55:19--  https://www.dropbox.com/s/raw/gtvw3nqbderxigb/datafig28.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc951a330e2675d1eaa68081376e.dl.dropboxusercontent.com/cd/0/inline/BdD_gf8Wf2kkRWYcFNbBIHlGD_mgOAmAn2haKZ_BxrCMj3riAz4im-kJBlTudtSG3zfeOMbpB2FfH5ugDXZ-UmFbGq71zqgdtEu-027gvnBZ7i4NIdy3pIilB3MjMFo0bhQzn33Q-VkYSPr_JXF3bJud/file# [following]
# --2022-01-02 09:55:20--  https://uc951a330e2675d1eaa68081376e.dl.dropboxusercontent.com/cd/0/inline/BdD_gf8Wf2kkRWYcFNbBIHlGD_mgOAmAn2haKZ_BxrCMj3riAz4im-kJBlTudtSG3zfeOMbpB2FfH5ugDXZ-UmFbGq71zqgdtEu-027gvnBZ7i4NIdy3pIilB3MjMFo0bhQzn33Q-VkYSPr_JXF3bJud/file
# Resolving uc951a330e2675d1eaa68081376e.dl.dropboxusercontent.com (uc951a330e2675d1eaa68081376e.dl.dropboxusercontent.com)... 162.125.68.15, 2620:100:6020:15::a27d:400f
# Connecting to uc951a330e2675d1eaa68081376e.dl.dropboxusercontent.com (uc951a330e2675d1eaa68081376e.dl.dropboxusercontent.com)|162.125.68.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BdDNjdaXIdEfjOvhdfZi6Bx5XeCTHngEt4rGX3-kqjwt8KEmPb1Dkew5Pb0EyN7RBDu-JjQSsv6wfG9Pika5MVxRdjPsb3scUZZKQq3WU1gCgu5Xzqc2_DlQBiKS4v-Ermgrulyt-iFKekWXnEkOZwWBQrPxQq7o_KZ1ftawdul5AKGBJAP6YYqfa13UxQ2QuOdrjy-7XBsEza9EXY24QXfsAW39H8jt5kS1vts571J4uVA2nxG1X6PrS4s9e5tmindJdTVJnzH9iXsneSAdrLbrVI944eTWHtz1LPO5hJVWS6On1vlbNG9Eybok7EX0crNd5M0aQpsDxSw_98gdfPcWonQNyQa_dCXo9729c3Q5rIKK7_EF16uWCtaR451Cw-A/file [following]
# --2022-01-02 09:55:20--  https://uc951a330e2675d1eaa68081376e.dl.dropboxusercontent.com/cd/0/inline2/BdDNjdaXIdEfjOvhdfZi6Bx5XeCTHngEt4rGX3-kqjwt8KEmPb1Dkew5Pb0EyN7RBDu-JjQSsv6wfG9Pika5MVxRdjPsb3scUZZKQq3WU1gCgu5Xzqc2_DlQBiKS4v-Ermgrulyt-iFKekWXnEkOZwWBQrPxQq7o_KZ1ftawdul5AKGBJAP6YYqfa13UxQ2QuOdrjy-7XBsEza9EXY24QXfsAW39H8jt5kS1vts571J4uVA2nxG1X6PrS4s9e5tmindJdTVJnzH9iXsneSAdrLbrVI944eTWHtz1LPO5hJVWS6On1vlbNG9Eybok7EX0crNd5M0aQpsDxSw_98gdfPcWonQNyQa_dCXo9729c3Q5rIKK7_EF16uWCtaR451Cw-A/file
# Reusing existing connection to uc951a330e2675d1eaa68081376e.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 34548 (34K) [application/zip]
# Saving to: ‘datafig28.zip’
#
# datafig28.zip       100%[===================>]  33.74K  --.-KB/s    in 0.03s
#
# 2022-01-02 09:55:20 (1.15 MB/s) - ‘datafig28.zip’ saved [34548/34548]

# %%
with ZipFile("datafig28.zip","r") as zip_ref:
    zip_ref.extractall()

# %%
def imageread(directory, mode=all):
  if mode == "all":
    directory = directory+'all/'
  elif mode == "train":
    directory = directory+'train/'
  elif mode == "test":
    directory = directory+'test/'
  else:
    print("ERROR, You did not select a mode; must be one of these: all, train, test")

  modelen = next(os.walk(directory))[2] #dir is your directory path as string
  modelen = len(modelen)
  print(modelen)
  picmat = np.zeros([modelen,28,28])
  i = 0

  if mode != None:
    for files in os.scandir(directory):
      #print(files.path)
      imageArray = cv2.imread(files.path, cv2.COLOR_BGR2GRAY)
      picmat[i] = imageArray
      #cv2_imshow(picmat[i])
      i+=1

  return picmat
    
all3darr = imageread('/content/datafig28/', 'all')
train3darr = imageread('/content/datafig28/', 'train')
test3darr = imageread('/content/datafig28/', 'test')
plt.imshow(all3darr[0])
# Out:
# 36
# 24
# 12

# %% [markdown]
# #Define the model (TFK-LSGAN)

# %%
# example of lsgan for mnist
from numpy import expand_dims
from numpy import zeros
from numpy import ones
from numpy.random import randn
from numpy.random import randint
import tensorflow as tf
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.initializers import RandomNormal
from matplotlib import pyplot

# define the standalone discriminator model
def define_discriminator(in_shape=(28,28,1)):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# define model
	model = Sequential()
	# downsample to 14x14
	model.add(Conv2D(64, (4,4), strides=(2,2), padding='same', kernel_initializer=init, input_shape=in_shape))
	model.add(BatchNormalization())
	model.add(LeakyReLU(alpha=0.2))
	# downsample to 7x7
	model.add(Conv2D(128, (4,4), strides=(2,2), padding='same', kernel_initializer=init))
	model.add(BatchNormalization())
	model.add(LeakyReLU(alpha=0.2))
	# classifier
	model.add(Flatten())
	model.add(Dense(1, activation='linear', kernel_initializer=init))
	# compile model with L2 loss
	model.compile(loss='mse', optimizer=Adam(learning_rate=0.001, beta_1=0.5))
	return model

# define the standalone generator model
def define_generator(latent_dim):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# define model
	model = Sequential()
	# foundation for 7x7 image
	n_nodes = 256 * 7 * 7
	model.add(Dense(n_nodes, kernel_initializer=init, input_dim=latent_dim))
	model.add(BatchNormalization())
	model.add(Activation('relu'))
	model.add(Reshape((7, 7, 256)))
	# upsample to 14x14
	model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same', kernel_initializer=init))
	model.add(BatchNormalization())
	model.add(Activation('relu'))
	# upsample to 28x28
	model.add(Conv2DTranspose(64, (4,4), strides=(2,2), padding='same', kernel_initializer=init))
	model.add(BatchNormalization())
	model.add(Activation('relu'))
	# output 28x28x1
	model.add(Conv2D(1, (7,7), padding='same', kernel_initializer=init))
	model.add(Activation('tanh'))
	return model

# define the combined generator and discriminator model, for updating the generator
def define_gan(generator, discriminator):
	# make weights in the discriminator not trainable
	for layer in discriminator.layers:
		if not isinstance(layer, BatchNormalization):
			layer.trainable = False
	# connect them
	model = Sequential()
	# add generator
	model.add(generator)
	# add the discriminator
	model.add(discriminator)
	# compile model with L2 loss
	model.compile(loss='mse', optimizer=Adam(learning_rate=0.001, beta_1=0.5))
	return model

# load our images #LOAD RAW IMAGES
def load_real_samples():
	# load dataset
	trainX = train3darr
	# expand to 3d, e.g. add channels
	X = expand_dims(trainX, axis=-1)
	# convert from ints to floats
	X = X.astype('float32')
	# scale from [0,255] to [-1,1]
	X = (X - 127.5) / 127.5
	return X

# # select real samples
def generate_real_samples(dataset, n_samples):
	# choose random instances
	ix = randint(0, dataset.shape[0], n_samples)
	# select images
	X = dataset[ix]
	# generate class labels
	y = ones((n_samples, 1))
	return X, y

# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples):
	# generate points in the latent space
	x_input = randn(latent_dim * n_samples)
	# reshape into a batch of inputs for the network
	x_input = x_input.reshape(n_samples, latent_dim)
	return x_input

# use the generator to generate n fake examples, with class labels
def generate_fake_samples(generator, latent_dim, n_samples):
	# generate points in latent space
	x_input = generate_latent_points(latent_dim, n_samples)
	# predict outputs
	X = generator.predict(x_input)
	# create class labels
	y = zeros((n_samples, 1))
	return X, y

# generate samples and save as a plot and save the model
def summarize_performance(step, g_model, latent_dim, n_samples=12):
	# prepare fake examples
	X, _ = generate_fake_samples(g_model, latent_dim, n_samples)
	# scale from [-1,1] to [0,1]
	X = (X + 1) / 2.0
	# plot images
	for i in range(3 * 4):
		# define subplot
		pyplot.subplot(3, 4, 1 + i)
		# turn off axis
		pyplot.axis('off')
		# plot raw pixel data
		pyplot.imshow(X[i, :, :, 0], cmap='gray_r')
	# save plot to file
	filename1 = 'generated_plot_%06d.png' % (step+1)
	pyplot.savefig(filename1)
	pyplot.close()
	# save the generator model
	filename2 = 'model_%06d.h5' % (step+1)
	g_model.save(filename2)
	print('Saved %s and %s' % (filename1, filename2))
  

# create a line plot of loss for the gan and save to file
def plot_history(d1_hist, d2_hist, g_hist):
	pyplot.plot(d1_hist, label='dloss1')
	pyplot.plot(d2_hist, label='dloss2')
	pyplot.plot(g_hist, label='gloss')
	pyplot.legend()
	filename = 'plot_line_plot_loss.png'
	pyplot.savefig(filename)
	pyplot.close()
	print('Saved %s' % (filename))

# train the generator and discriminator
def train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs=100, n_batch=12):
	# calculate the number of batches per training epoch
	bat_per_epo = int(dataset.shape[0] / n_batch)
	# calculate the number of training iterations
	n_steps = bat_per_epo * n_epochs
	# calculate the size of half a batch of samples
	half_batch = int(n_batch / 2)
	# lists for storing loss, for plotting later
	d1_hist, d2_hist, g_hist = list(), list(), list()
	# manually enumerate epochs
	for i in range(n_steps):
		# prepare real and fake samples
		X_real, y_real = generate_real_samples(dataset, half_batch)
		X_fake, y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
		print(X_fake.shape)
		# update discriminator model
		d_loss1 = d_model.train_on_batch(X_real, y_real)
		d_loss2 = d_model.train_on_batch(X_fake, y_fake)
		# update the generator via the discriminator's error
		z_input = generate_latent_points(latent_dim, n_batch)
		y_real2 = ones((n_batch, 1))
		g_loss = gan_model.train_on_batch(z_input, y_real2)
		# summarize loss on this batch
		print('>%d, d1=%.3f, d2=%.3f g=%.3f' % (i+1, d_loss1, d_loss2, g_loss))
		# record history
		d1_hist.append(d_loss1)
		d2_hist.append(d_loss2)
		g_hist.append(g_loss)
		# evaluate the model performance every 'epoch'
		if (i+1) % (bat_per_epo * 1) == 0:
			summarize_performance(i, g_model, latent_dim)
	# create line plot of training history
	plot_history(d1_hist, d2_hist, g_hist)

# size of the latent space
latent_dim = 100
# create the discriminator
discriminator = define_discriminator()
# create the generator
generator = define_generator(latent_dim)
# create the gan
gan_model = define_gan(generator, discriminator)
# load image data
dataset = load_real_samples()
print(dataset.shape)
# train model
train(generator, discriminator, gan_model, dataset, latent_dim)
# Out:
# (24, 28, 28, 1)
# (6, 28, 28, 1)
# >1, d1=0.382, d2=0.629 g=1.788
# (6, 28, 28, 1)
# >2, d1=359.128, d2=1.581 g=1.946
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000002.png and model_000002.h5
# (6, 28, 28, 1)
# >3, d1=0.390, d2=2.957 g=2.567
# (6, 28, 28, 1)
# >4, d1=20.283, d2=9.648 g=0.528
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000004.png and model_000004.h5
# (6, 28, 28, 1)
# >5, d1=0.803, d2=2.583 g=0.363
# (6, 28, 28, 1)
# >6, d1=1.077, d2=0.513 g=0.185
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000006.png and model_000006.h5
# (6, 28, 28, 1)
# >7, d1=0.236, d2=0.127 g=0.516
# (6, 28, 28, 1)
# >8, d1=0.127, d2=0.410 g=0.647
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000008.png and model_000008.h5
# (6, 28, 28, 1)
# >9, d1=0.071, d2=0.705 g=0.498
# (6, 28, 28, 1)
# >10, d1=0.055, d2=1.544 g=0.562
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000010.png and model_000010.h5
# (6, 28, 28, 1)
# >11, d1=0.205, d2=3.585 g=2.299
# (6, 28, 28, 1)
# >12, d1=0.709, d2=8.415 g=2.736
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000012.png and model_000012.h5
# (6, 28, 28, 1)
# >13, d1=1.548, d2=11.513 g=1.092
# (6, 28, 28, 1)
# >14, d1=1.366, d2=5.222 g=0.032
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000014.png and model_000014.h5
# (6, 28, 28, 1)
# >15, d1=0.425, d2=1.102 g=0.031
# (6, 28, 28, 1)
# >16, d1=0.067, d2=0.148 g=0.152
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000016.png and model_000016.h5
# (6, 28, 28, 1)
# >17, d1=0.157, d2=0.111 g=0.028
# (6, 28, 28, 1)
# >18, d1=0.233, d2=0.039 g=0.079
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000018.png and model_000018.h5
# (6, 28, 28, 1)
# >19, d1=0.141, d2=0.055 g=0.047
# (6, 28, 28, 1)
# >20, d1=0.019, d2=0.141 g=0.071
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000020.png and model_000020.h5
# (6, 28, 28, 1)
# >21, d1=0.079, d2=0.140 g=0.011
# (6, 28, 28, 1)
# >22, d1=0.014, d2=0.098 g=0.013
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000022.png and model_000022.h5
# (6, 28, 28, 1)
# >23, d1=0.007, d2=0.051 g=0.032
# (6, 28, 28, 1)
# >24, d1=0.020, d2=0.102 g=0.018
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000024.png and model_000024.h5
# (6, 28, 28, 1)
# >25, d1=0.034, d2=0.155 g=0.073
# (6, 28, 28, 1)
# >26, d1=0.124, d2=0.331 g=0.014
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000026.png and model_000026.h5
# (6, 28, 28, 1)
# >27, d1=0.046, d2=0.227 g=0.019
# (6, 28, 28, 1)
# >28, d1=0.029, d2=0.034 g=0.022
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000028.png and model_000028.h5
# (6, 28, 28, 1)
# >29, d1=0.058, d2=0.096 g=0.034
# (6, 28, 28, 1)
# >30, d1=0.054, d2=0.070 g=0.028
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000030.png and model_000030.h5
# (6, 28, 28, 1)
# >31, d1=0.024, d2=0.104 g=0.010
# (6, 28, 28, 1)
# >32, d1=0.009, d2=0.184 g=0.014
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000032.png and model_000032.h5
# (6, 28, 28, 1)
# >33, d1=0.024, d2=0.093 g=0.050
# (6, 28, 28, 1)
# >34, d1=0.082, d2=0.039 g=0.030
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000034.png and model_000034.h5
# (6, 28, 28, 1)
# >35, d1=0.076, d2=0.312 g=0.148
# (6, 28, 28, 1)
# >36, d1=0.021, d2=0.488 g=0.094
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000036.png and model_000036.h5
# (6, 28, 28, 1)
# >37, d1=0.338, d2=0.286 g=0.228
# (6, 28, 28, 1)
# >38, d1=0.903, d2=0.084 g=0.056
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000038.png and model_000038.h5
# (6, 28, 28, 1)
# >39, d1=1.318, d2=0.422 g=0.016
# (6, 28, 28, 1)
# >40, d1=0.803, d2=1.690 g=0.454
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000040.png and model_000040.h5
# (6, 28, 28, 1)
# >41, d1=0.109, d2=4.105 g=1.238
# (6, 28, 28, 1)
# >42, d1=0.609, d2=5.130 g=1.950
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000042.png and model_000042.h5
# (6, 28, 28, 1)
# >43, d1=4.986, d2=1.637 g=1.097
# (6, 28, 28, 1)
# >44, d1=10.814, d2=0.069 g=1.038
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000044.png and model_000044.h5
# (6, 28, 28, 1)
# >45, d1=8.041, d2=2.164 g=0.011
# (6, 28, 28, 1)
# >46, d1=3.344, d2=3.746 g=0.057
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000046.png and model_000046.h5
# (6, 28, 28, 1)
# >47, d1=0.168, d2=2.748 g=0.489
# (6, 28, 28, 1)
# >48, d1=0.242, d2=0.848 g=0.043
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000048.png and model_000048.h5
# (6, 28, 28, 1)
# >49, d1=0.289, d2=0.447 g=0.324
# (6, 28, 28, 1)
# >50, d1=0.182, d2=0.500 g=0.219
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000050.png and model_000050.h5
# (6, 28, 28, 1)
# >51, d1=0.162, d2=1.015 g=0.847
# (6, 28, 28, 1)
# >52, d1=0.294, d2=1.757 g=0.391
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000052.png and model_000052.h5
# (6, 28, 28, 1)
# >53, d1=0.680, d2=1.543 g=0.750
# (6, 28, 28, 1)
# >54, d1=0.949, d2=0.723 g=0.048
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000054.png and model_000054.h5
# (6, 28, 28, 1)
# >55, d1=0.913, d2=0.404 g=0.597
# (6, 28, 28, 1)
# >56, d1=0.686, d2=0.068 g=0.028
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000056.png and model_000056.h5
# (6, 28, 28, 1)
# >57, d1=0.280, d2=0.013 g=0.049
# (6, 28, 28, 1)
# >58, d1=0.057, d2=0.098 g=0.154
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000058.png and model_000058.h5
# (6, 28, 28, 1)
# >59, d1=0.010, d2=0.238 g=0.074
# (6, 28, 28, 1)
# >60, d1=0.067, d2=0.500 g=0.485
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000060.png and model_000060.h5
# (6, 28, 28, 1)
# >61, d1=0.351, d2=0.303 g=0.035
# (6, 28, 28, 1)
# >62, d1=0.640, d2=0.210 g=0.593
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000062.png and model_000062.h5
# (6, 28, 28, 1)
# >63, d1=0.872, d2=0.067 g=0.081
# (6, 28, 28, 1)
# >64, d1=0.974, d2=0.017 g=0.227
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000064.png and model_000064.h5
# (6, 28, 28, 1)
# >65, d1=0.666, d2=0.124 g=0.027
# (6, 28, 28, 1)
# >66, d1=0.358, d2=0.288 g=0.092
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000066.png and model_000066.h5
# (6, 28, 28, 1)
# >67, d1=0.054, d2=0.772 g=1.128
# (6, 28, 28, 1)
# >68, d1=0.149, d2=1.119 g=0.494
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000068.png and model_000068.h5
# (6, 28, 28, 1)
# >69, d1=0.879, d2=0.668 g=0.739
# (6, 28, 28, 1)
# >70, d1=1.621, d2=0.407 g=0.666
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000070.png and model_000070.h5
# (6, 28, 28, 1)
# >71, d1=2.147, d2=0.046 g=0.177
# (6, 28, 28, 1)
# >72, d1=1.636, d2=0.217 g=0.010
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000072.png and model_000072.h5
# (6, 28, 28, 1)
# >73, d1=0.677, d2=0.868 g=0.221
# (6, 28, 28, 1)
# >74, d1=0.007, d2=1.146 g=0.434
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000074.png and model_000074.h5
# (6, 28, 28, 1)
# >75, d1=0.562, d2=0.748 g=0.334
# (6, 28, 28, 1)
# >76, d1=1.271, d2=0.290 g=0.581
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000076.png and model_000076.h5
# (6, 28, 28, 1)
# >77, d1=1.241, d2=0.011 g=0.043
# (6, 28, 28, 1)
# >78, d1=0.468, d2=0.133 g=0.099
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000078.png and model_000078.h5
# (6, 28, 28, 1)
# >79, d1=0.029, d2=0.215 g=0.324
# (6, 28, 28, 1)
# >80, d1=0.093, d2=0.130 g=0.230
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000080.png and model_000080.h5
# (6, 28, 28, 1)
# >81, d1=0.195, d2=0.020 g=0.005
# (6, 28, 28, 1)
# >82, d1=0.028, d2=0.062 g=0.042
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000082.png and model_000082.h5
# (6, 28, 28, 1)
# >83, d1=0.010, d2=0.085 g=0.016
# (6, 28, 28, 1)
# >84, d1=0.043, d2=0.034 g=0.029
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000084.png and model_000084.h5
# (6, 28, 28, 1)
# >85, d1=0.132, d2=0.006 g=0.009
# (6, 28, 28, 1)
# >86, d1=0.078, d2=0.045 g=0.009
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000086.png and model_000086.h5
# (6, 28, 28, 1)
# >87, d1=0.005, d2=0.063 g=0.044
# (6, 28, 28, 1)
# >88, d1=0.038, d2=0.072 g=0.099
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000088.png and model_000088.h5
# (6, 28, 28, 1)
# >89, d1=0.105, d2=0.023 g=0.017
# (6, 28, 28, 1)
# >90, d1=0.106, d2=0.025 g=0.028
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000090.png and model_000090.h5
# (6, 28, 28, 1)
# >91, d1=0.007, d2=0.055 g=0.011
# (6, 28, 28, 1)
# >92, d1=0.024, d2=0.022 g=0.007
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000092.png and model_000092.h5
# (6, 28, 28, 1)
# >93, d1=0.023, d2=0.013 g=0.035
# (6, 28, 28, 1)
# >94, d1=0.048, d2=0.012 g=0.053
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000094.png and model_000094.h5
# (6, 28, 28, 1)
# >95, d1=0.115, d2=0.007 g=0.008
# (6, 28, 28, 1)
# >96, d1=0.128, d2=0.046 g=0.001
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000096.png and model_000096.h5
# (6, 28, 28, 1)
# >97, d1=0.050, d2=0.106 g=0.036
# (6, 28, 28, 1)
# >98, d1=0.004, d2=0.146 g=0.100
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000098.png and model_000098.h5
# (6, 28, 28, 1)
# >99, d1=0.099, d2=0.090 g=0.060
# (6, 28, 28, 1)
# >100, d1=0.196, d2=0.005 g=0.004
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000100.png and model_000100.h5
# (6, 28, 28, 1)
# >101, d1=0.142, d2=0.117 g=0.108
# (6, 28, 28, 1)
# >102, d1=0.024, d2=0.475 g=0.363
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000102.png and model_000102.h5
# (6, 28, 28, 1)
# >103, d1=0.095, d2=0.789 g=0.696
# (6, 28, 28, 1)
# >104, d1=0.894, d2=0.582 g=0.670
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000104.png and model_000104.h5
# (6, 28, 28, 1)
# >105, d1=2.481, d2=0.011 g=0.138
# (6, 28, 28, 1)
# >106, d1=2.996, d2=0.669 g=0.003
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000106.png and model_000106.h5
# (6, 28, 28, 1)
# >107, d1=1.117, d2=3.106 g=2.208
# (6, 28, 28, 1)
# >108, d1=0.158, d2=4.524 g=1.895
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000108.png and model_000108.h5
# (6, 28, 28, 1)
# >109, d1=4.791, d2=1.490 g=2.865
# (6, 28, 28, 1)
# >110, d1=8.404, d2=0.375 g=0.644
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000110.png and model_000110.h5
# (6, 28, 28, 1)
# >111, d1=4.497, d2=3.758 g=0.057
# (6, 28, 28, 1)
# >112, d1=0.097, d2=7.308 g=7.305
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000112.png and model_000112.h5
# (6, 28, 28, 1)
# >113, d1=2.271, d2=4.260 g=1.370
# (6, 28, 28, 1)
# >114, d1=5.201, d2=3.911 g=14.593
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000114.png and model_000114.h5
# (6, 28, 28, 1)
# >115, d1=5.886, d2=5.654 g=1.267
# (6, 28, 28, 1)
# >116, d1=6.901, d2=3.994 g=7.185
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000116.png and model_000116.h5
# (6, 28, 28, 1)
# >117, d1=5.253, d2=1.064 g=0.254
# (6, 28, 28, 1)
# >118, d1=2.498, d2=0.584 g=3.294
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000118.png and model_000118.h5
# (6, 28, 28, 1)
# >119, d1=0.862, d2=0.045 g=0.219
# (6, 28, 28, 1)
# >120, d1=0.077, d2=0.318 g=0.778
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000120.png and model_000120.h5
# (6, 28, 28, 1)
# >121, d1=0.174, d2=0.280 g=0.052
# (6, 28, 28, 1)
# >122, d1=0.298, d2=0.168 g=0.732
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000122.png and model_000122.h5
# (6, 28, 28, 1)
# >123, d1=0.252, d2=0.010 g=1.010
# (6, 28, 28, 1)
# >124, d1=0.016, d2=0.124 g=0.017
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000124.png and model_000124.h5
# (6, 28, 28, 1)
# >125, d1=0.136, d2=0.904 g=5.107
# (6, 28, 28, 1)
# >126, d1=0.794, d2=2.830 g=1.106
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000126.png and model_000126.h5
# (6, 28, 28, 1)
# >127, d1=2.475, d2=4.424 g=9.257
# (6, 28, 28, 1)
# >128, d1=3.728, d2=5.506 g=1.098
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000128.png and model_000128.h5
# (6, 28, 28, 1)
# >129, d1=3.439, d2=8.715 g=12.606
# (6, 28, 28, 1)
# >130, d1=3.271, d2=6.229 g=0.132
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000130.png and model_000130.h5
# (6, 28, 28, 1)
# >131, d1=2.481, d2=2.349 g=1.941
# (6, 28, 28, 1)
# >132, d1=0.894, d2=0.425 g=0.203
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000132.png and model_000132.h5
# (6, 28, 28, 1)
# >133, d1=0.331, d2=0.330 g=1.279
# (6, 28, 28, 1)
# >134, d1=0.212, d2=0.078 g=0.406
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000134.png and model_000134.h5
# (6, 28, 28, 1)
# >135, d1=0.439, d2=0.018 g=0.931
# (6, 28, 28, 1)
# >136, d1=0.214, d2=0.009 g=0.647
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000136.png and model_000136.h5
# (6, 28, 28, 1)
# >137, d1=0.024, d2=0.001 g=0.617
# (6, 28, 28, 1)
# >138, d1=0.103, d2=0.048 g=0.457
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000138.png and model_000138.h5
# (6, 28, 28, 1)
# >139, d1=0.094, d2=0.321 g=1.107
# (6, 28, 28, 1)
# >140, d1=0.046, d2=0.236 g=0.332
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000140.png and model_000140.h5
# (6, 28, 28, 1)
# >141, d1=0.175, d2=0.036 g=0.718
# (6, 28, 28, 1)
# >142, d1=0.059, d2=0.009 g=0.442
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000142.png and model_000142.h5
# (6, 28, 28, 1)
# >143, d1=0.021, d2=0.010 g=0.439
# (6, 28, 28, 1)
# >144, d1=0.090, d2=0.115 g=0.200
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000144.png and model_000144.h5
# (6, 28, 28, 1)
# >145, d1=0.017, d2=0.213 g=0.526
# (6, 28, 28, 1)
# >146, d1=0.044, d2=0.070 g=0.268
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000146.png and model_000146.h5
# (6, 28, 28, 1)
# >147, d1=0.159, d2=0.006 g=0.406
# (6, 28, 28, 1)
# >148, d1=0.071, d2=0.087 g=0.854
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000148.png and model_000148.h5
# (6, 28, 28, 1)
# >149, d1=0.015, d2=0.154 g=0.141
# (6, 28, 28, 1)
# >150, d1=0.147, d2=0.082 g=0.670
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000150.png and model_000150.h5
# (6, 28, 28, 1)
# >151, d1=0.252, d2=0.019 g=0.371
# (6, 28, 28, 1)
# >152, d1=0.069, d2=0.012 g=0.490
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000152.png and model_000152.h5
# (6, 28, 28, 1)
# >153, d1=0.006, d2=0.005 g=0.300
# (6, 28, 28, 1)
# >154, d1=0.005, d2=0.004 g=0.366
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000154.png and model_000154.h5
# (6, 28, 28, 1)
# >155, d1=0.004, d2=0.006 g=0.615
# (6, 28, 28, 1)
# >156, d1=0.075, d2=0.015 g=0.231
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000156.png and model_000156.h5
# (6, 28, 28, 1)
# >157, d1=0.096, d2=0.005 g=0.411
# (6, 28, 28, 1)
# >158, d1=0.029, d2=0.066 g=0.784
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000158.png and model_000158.h5
# (6, 28, 28, 1)
# >159, d1=0.049, d2=0.061 g=0.093
# (6, 28, 28, 1)
# >160, d1=0.136, d2=0.242 g=2.384
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000160.png and model_000160.h5
# (6, 28, 28, 1)
# >161, d1=0.297, d2=0.358 g=0.264
# (6, 28, 28, 1)
# >162, d1=0.324, d2=2.004 g=14.861
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000162.png and model_000162.h5
# (6, 28, 28, 1)
# >163, d1=1.677, d2=8.881 g=5.883
# (6, 28, 28, 1)
# >164, d1=8.912, d2=7.719 g=16.136
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000164.png and model_000164.h5
# (6, 28, 28, 1)
# >165, d1=11.233, d2=2.612 g=0.554
# (6, 28, 28, 1)
# >166, d1=5.159, d2=2.294 g=7.350
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000166.png and model_000166.h5
# (6, 28, 28, 1)
# >167, d1=2.002, d2=2.267 g=0.072
# (6, 28, 28, 1)
# >168, d1=0.964, d2=1.415 g=2.358
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000168.png and model_000168.h5
# (6, 28, 28, 1)
# >169, d1=0.494, d2=0.106 g=0.593
# (6, 28, 28, 1)
# >170, d1=0.017, d2=0.223 g=1.123
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000170.png and model_000170.h5
# (6, 28, 28, 1)
# >171, d1=0.034, d2=0.060 g=0.579
# (6, 28, 28, 1)
# >172, d1=0.026, d2=0.186 g=1.998
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000172.png and model_000172.h5
# (6, 28, 28, 1)
# >173, d1=0.221, d2=0.006 g=0.631
# (6, 28, 28, 1)
# >174, d1=0.048, d2=0.131 g=3.179
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000174.png and model_000174.h5
# (6, 28, 28, 1)
# >175, d1=0.059, d2=1.156 g=1.798
# (6, 28, 28, 1)
# >176, d1=0.492, d2=4.135 g=19.829
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000176.png and model_000176.h5
# (6, 28, 28, 1)
# >177, d1=2.174, d2=3.669 g=0.760
# (6, 28, 28, 1)
# >178, d1=2.518, d2=0.030 g=1.642
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000178.png and model_000178.h5
# (6, 28, 28, 1)
# >179, d1=0.083, d2=0.263 g=0.979
# (6, 28, 28, 1)
# >180, d1=0.036, d2=0.310 g=0.938
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000180.png and model_000180.h5
# (6, 28, 28, 1)
# >181, d1=0.062, d2=0.303 g=1.821
# (6, 28, 28, 1)
# >182, d1=0.216, d2=0.032 g=1.211
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000182.png and model_000182.h5
# (6, 28, 28, 1)
# >183, d1=0.009, d2=0.063 g=0.654
# (6, 28, 28, 1)
# >184, d1=0.098, d2=0.005 g=0.745
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000184.png and model_000184.h5
# (6, 28, 28, 1)
# >185, d1=0.013, d2=0.031 g=1.121
# (6, 28, 28, 1)
# >186, d1=0.020, d2=0.024 g=0.797
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000186.png and model_000186.h5
# (6, 28, 28, 1)
# >187, d1=0.015, d2=0.103 g=1.210
# (6, 28, 28, 1)
# >188, d1=0.026, d2=0.058 g=0.626
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000188.png and model_000188.h5
# (6, 28, 28, 1)
# >189, d1=0.204, d2=0.006 g=1.094
# (6, 28, 28, 1)
# >190, d1=0.116, d2=0.069 g=1.171
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000190.png and model_000190.h5
# (6, 28, 28, 1)
# >191, d1=0.004, d2=0.072 g=0.755
# (6, 28, 28, 1)
# >192, d1=0.028, d2=0.027 g=1.124
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000192.png and model_000192.h5
# (6, 28, 28, 1)
# >193, d1=0.027, d2=0.008 g=0.928
# (6, 28, 28, 1)
# >194, d1=0.021, d2=0.060 g=1.364
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000194.png and model_000194.h5
# (6, 28, 28, 1)
# >195, d1=0.006, d2=0.105 g=0.770
# (6, 28, 28, 1)
# >196, d1=0.101, d2=0.068 g=1.658
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000196.png and model_000196.h5
# (6, 28, 28, 1)
# >197, d1=0.135, d2=0.028 g=0.596
# (6, 28, 28, 1)
# >198, d1=0.095, d2=0.077 g=1.672
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000198.png and model_000198.h5
# (6, 28, 28, 1)
# >199, d1=0.150, d2=0.022 g=0.676
# (6, 28, 28, 1)
# >200, d1=0.170, d2=0.036 g=0.983
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000200.png and model_000200.h5
# Saved plot_line_plot_loss.png

# %% [markdown]
# Calculate Train Metrics

# %%
gt, _ = generate_real_samples(dataset, 6)
pred, _= generate_fake_samples(generator, latent_dim, 6)

# %%
pred = pred.reshape(6,28,28)
fig, axs = plt.subplots(2, 3)
axs[0, 0].imshow(pred[0], cmap='gray')
axs[0, 1].imshow(pred[1], cmap='gray')
axs[0, 2].imshow(pred[2], cmap='gray')
axs[1, 0].imshow(pred[3], cmap='gray')
axs[1, 1].imshow(pred[4], cmap='gray')
axs[1, 2].imshow(pred[5], cmap='gray')

# %%
gt = gt.reshape(6,784)
pred = pred.reshape(6,784)

# %%
from sklearn import metrics
from math import sqrt

mae = metrics.mean_absolute_error(gt, pred)
mse = metrics.mean_squared_error(gt, pred)
mape = metrics.mean_absolute_percentage_error(gt, pred)
rmse = sqrt(mse)

print('MSE=', mse, '...RMSE=', rmse, '...MAE=', mae, '...MAPE=', mape)
# Out:
# MSE= 0.21562257 ...RMSE= 0.46435177838677183 ...MAE= 0.15526982 ...MAPE= 0.6503963

# %% [markdown]
# Calculate Test Metrics

# %%
def load_test_samples():
	# load dataset
	testX = test3darr
	# expand to 3d, e.g. add channels
	X = expand_dims(testX, axis=-1)
	# convert from ints to floats
	X = X.astype('float32')
	# scale from [0,255] to [-1,1]
	X = (X - 127.5) / 127.5
	return X

# %%
testd = load_test_samples()
print(testd.shape)
# Out:
# (12, 28, 28, 1)

# %%
gt, _ = generate_real_samples(testd, 6)
pred, _= generate_fake_samples(generator, latent_dim, 6)

# %%
pred = pred.reshape(6,28,28)
fig, axs = plt.subplots(2, 3)
axs[0, 0].imshow(pred[0], cmap='gray')
axs[0, 1].imshow(pred[1], cmap='gray')
axs[0, 2].imshow(pred[2], cmap='gray')
axs[1, 0].imshow(pred[3], cmap='gray')
axs[1, 1].imshow(pred[4], cmap='gray')
axs[1, 2].imshow(pred[5], cmap='gray')

# %%
gt = gt.reshape(6,784)
pred = pred.reshape(6,784)

# %%
from sklearn import metrics
from math import sqrt

mae = metrics.mean_absolute_error(gt, pred)
mse = metrics.mean_squared_error(gt, pred)
mape = metrics.mean_absolute_percentage_error(gt, pred)
rmse = sqrt(mse)

print('MSE=', mse, '...RMSE=', rmse, '...MAE=', mae, '...MAPE=', mape)
# Out:
# MSE= 0.21621737 ...RMSE= 0.4649917943804721 ...MAE= 0.15541388 ...MAPE= 0.39386585
