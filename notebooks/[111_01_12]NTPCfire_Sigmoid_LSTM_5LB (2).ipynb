# %% [markdown]
# # Data Import & Manipulation
# Here, we import the required modules and read (+organise) the dataset

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.tsa.stattools as ts


import csv
import math
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import random
import statsmodels.api as sm
import statsmodels.formula.api as smf

from math import sqrt
from numpy.random import seed
seed(1)
from pandas import DataFrame
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.stattools import adfuller
from tensorflow.keras.layers import Dense
from tensorflow.keras import layers
from tensorflow.keras.layers import LSTM

# %%
# !wget https://www.dropbox.com/s/jpw4fyv6mh31ql4/NTP2015-2017fire.txt
# Out:
# --2022-01-12 04:49:45--  https://www.dropbox.com/s/jpw4fyv6mh31ql4/NTP2015-2017fire.txt
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/jpw4fyv6mh31ql4/NTP2015-2017fire.txt [following]
# --2022-01-12 04:49:45--  https://www.dropbox.com/s/raw/jpw4fyv6mh31ql4/NTP2015-2017fire.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc7682d9ee6e4eb4b66f4b18a186.dl.dropboxusercontent.com/cd/0/inline/Bdl7BQHPvcbfQvk68bPY0IVAi94eoR49og-uTFCvtg7rnsQy0HEOs2jBTbNdshVFNRqwy_ivyVs3dh2gHA6D8dL4XnP84aKirq_pRhvp819kaGNKgH_IXe51UTRQsHMgs9e64ozGft4TY27bcw3g9N9u/file# [following]
# --2022-01-12 04:49:46--  https://uc7682d9ee6e4eb4b66f4b18a186.dl.dropboxusercontent.com/cd/0/inline/Bdl7BQHPvcbfQvk68bPY0IVAi94eoR49og-uTFCvtg7rnsQy0HEOs2jBTbNdshVFNRqwy_ivyVs3dh2gHA6D8dL4XnP84aKirq_pRhvp819kaGNKgH_IXe51UTRQsHMgs9e64ozGft4TY27bcw3g9N9u/file
# Resolving uc7682d9ee6e4eb4b66f4b18a186.dl.dropboxusercontent.com (uc7682d9ee6e4eb4b66f4b18a186.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:601b:15::a27d:80f
# Connecting to uc7682d9ee6e4eb4b66f4b18a186.dl.dropboxusercontent.com (uc7682d9ee6e4eb4b66f4b18a186.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3884193 (3.7M) [text/plain]
# Saving to: ‘NTP2015-2017fire.txt’
#
# NTP2015-2017fire.tx 100%[===================>]   3.70M  21.8MB/s    in 0.2s
#
# 2022-01-12 04:49:46 (21.8 MB/s) - ‘NTP2015-2017fire.txt’ saved [3884193/3884193]

# %%
# %cd /content/
#df = pd.read_csv('/content/gdrive/MyDrive/dlku/NTP2015fire-Jan.txt', sep='\t', header=None)
df = pd.read_csv('NTP2015-2017fire.txt', sep='\t', header=None)
df.columns = ["date", "station", "addr1", "addr2", "longitude", "latitude", "township"]
# Out:
# /content

# %%
df
# Out:
#                    date  station  ...   latitude township
# 0         2015/1/1 0:13  火警-瓦斯漏氣  ...  25.000569   板橋區廣德里
# 1         2015/1/1 0:16    火警-倉庫  ...  25.084172   三重區富華里
# 2         2015/1/1 0:48  火警-查看案件  ...  25.136422   淡水區民權里
# 3         2015/1/1 0:56  火警-查看案件  ...  25.031506   新莊區泰豐里
# 4         2015/1/1 1:04    火警-汽車  ...  24.982273   樹林區和平里
# ...                 ...      ...  ...        ...      ...
# 24085  2017/12/31 17:14  火警-集合住宅  ...  24.990417   中和區錦盛里
# 24086  2017/12/31 18:40  火警-集合住宅  ...  25.048063   汐止區東勢里
# 24087  2017/12/31 20:09  火警-查看案件  ...  25.076529   三重區福隆里
# 24088  2017/12/31 20:44  火警-查看案件  ...  24.997367   永和區民族里
# 24089  2017/12/31 22:09  火警-查看案件  ...  25.000317   板橋區龍安里
#
# [24090 rows x 7 columns]

# %%
#set date time format
df['date'] = pd.to_datetime(df.date, format='%Y-%m-%d %H:%M:%S')

# %%
df
# Out:
#                      date  station  ...   latitude township
# 0     2015-01-01 00:13:00  火警-瓦斯漏氣  ...  25.000569   板橋區廣德里
# 1     2015-01-01 00:16:00    火警-倉庫  ...  25.084172   三重區富華里
# 2     2015-01-01 00:48:00  火警-查看案件  ...  25.136422   淡水區民權里
# 3     2015-01-01 00:56:00  火警-查看案件  ...  25.031506   新莊區泰豐里
# 4     2015-01-01 01:04:00    火警-汽車  ...  24.982273   樹林區和平里
# ...                   ...      ...  ...        ...      ...
# 24085 2017-12-31 17:14:00  火警-集合住宅  ...  24.990417   中和區錦盛里
# 24086 2017-12-31 18:40:00  火警-集合住宅  ...  25.048063   汐止區東勢里
# 24087 2017-12-31 20:09:00  火警-查看案件  ...  25.076529   三重區福隆里
# 24088 2017-12-31 20:44:00  火警-查看案件  ...  24.997367   永和區民族里
# 24089 2017-12-31 22:09:00  火警-查看案件  ...  25.000317   板橋區龍安里
#
# [24090 rows x 7 columns]

# %%
#extract only numerical/quantitative data
dften = df[["date", "longitude", "latitude"]]

# %%
dften
# Out:
#                      date   longitude   latitude
# 0     2015-01-01 00:13:00  121.466281  25.000569
# 1     2015-01-01 00:16:00  121.491579  25.084172
# 2     2015-01-01 00:48:00  121.460224  25.136422
# 3     2015-01-01 00:56:00  121.450333  25.031506
# 4     2015-01-01 01:04:00  121.420005  24.982273
# ...                   ...         ...        ...
# 24085 2017-12-31 17:14:00  121.493909  24.990417
# 24086 2017-12-31 18:40:00  121.621682  25.048063
# 24087 2017-12-31 20:09:00  121.490806  25.076529
# 24088 2017-12-31 20:44:00  121.519391  24.997367
# 24089 2017-12-31 22:09:00  121.442237  25.000317
#
# [24090 rows x 3 columns]

# %%
BBox = ((dften.longitude.min(),   dften.longitude.max(),      
         dften.latitude.min(), dften.latitude.max()))

# %%
#Print out the coordinates, and go to Openstreetmap website to draw a map.
BBox
# Out:
# (121.2868855, 122.0030709, 24.77511693, 25.29717505)

# %%
#download the map we have just drawn
# !wget https://www.dropbox.com/s/dw6dp3zyx063zjt/ntpcmap.png
# !wget https://www.dropbox.com/s/vb5g8ndd3l2o0eh/ntpcmaplrg.png
# Out:
# --2022-01-12 04:49:47--  https://www.dropbox.com/s/dw6dp3zyx063zjt/ntpcmap.png
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/dw6dp3zyx063zjt/ntpcmap.png [following]
# --2022-01-12 04:49:47--  https://www.dropbox.com/s/raw/dw6dp3zyx063zjt/ntpcmap.png
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc6ef7e9881f529183e5385c0f87.dl.dropboxusercontent.com/cd/0/inline/Bdm07vdL6COehnG8kPr1gbF_mm5p9FmOM7TJ1Z0LQJWnS9_3Y56zc1nLts5J_oW-RaX0DgaibwyAkKGaP9UDB78-kxsG2w1e5WcZRMacv6O1x59f-SeKaq6nwxbJ24wnanQz5xlZ2R76XLi5JRrS321y/file# [following]
# --2022-01-12 04:49:47--  https://uc6ef7e9881f529183e5385c0f87.dl.dropboxusercontent.com/cd/0/inline/Bdm07vdL6COehnG8kPr1gbF_mm5p9FmOM7TJ1Z0LQJWnS9_3Y56zc1nLts5J_oW-RaX0DgaibwyAkKGaP9UDB78-kxsG2w1e5WcZRMacv6O1x59f-SeKaq6nwxbJ24wnanQz5xlZ2R76XLi5JRrS321y/file
# Resolving uc6ef7e9881f529183e5385c0f87.dl.dropboxusercontent.com (uc6ef7e9881f529183e5385c0f87.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6019:15::a27d:40f
# Connecting to uc6ef7e9881f529183e5385c0f87.dl.dropboxusercontent.com (uc6ef7e9881f529183e5385c0f87.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1828678 (1.7M) [image/png]
# Saving to: ‘ntpcmap.png’
#
# ntpcmap.png         100%[===================>]   1.74M  --.-KB/s    in 0.1s
#
# 2022-01-12 04:49:48 (13.2 MB/s) - ‘ntpcmap.png’ saved [1828678/1828678]
#
# --2022-01-12 04:49:48--  https://www.dropbox.com/s/vb5g8ndd3l2o0eh/ntpcmaplrg.png
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/vb5g8ndd3l2o0eh/ntpcmaplrg.png [following]
# --2022-01-12 04:49:48--  https://www.dropbox.com/s/raw/vb5g8ndd3l2o0eh/ntpcmaplrg.png
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc27904e23839c3ed2a857187a97.dl.dropboxusercontent.com/cd/0/inline/BdntyYm_gL-GaJ6U0We0dtJTVHZ7d7a0ftJ8JYSDDpvShtkiBi7taEa-mkIZ-zb4v3-IEXpSQq8d2_Lv91iu8p7F4gnml9dbwFe7Lpb9sRVFAWbzQLX9-i-4bAT9VkfXStYuoktu8dkOS946_dNvLNQa/file# [following]
# --2022-01-12 04:49:48--  https://uc27904e23839c3ed2a857187a97.dl.dropboxusercontent.com/cd/0/inline/BdntyYm_gL-GaJ6U0We0dtJTVHZ7d7a0ftJ8JYSDDpvShtkiBi7taEa-mkIZ-zb4v3-IEXpSQq8d2_Lv91iu8p7F4gnml9dbwFe7Lpb9sRVFAWbzQLX9-i-4bAT9VkfXStYuoktu8dkOS946_dNvLNQa/file
# Resolving uc27904e23839c3ed2a857187a97.dl.dropboxusercontent.com (uc27904e23839c3ed2a857187a97.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6018:15::a27d:30f
# Connecting to uc27904e23839c3ed2a857187a97.dl.dropboxusercontent.com (uc27904e23839c3ed2a857187a97.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1237701 (1.2M) [image/png]
# Saving to: ‘ntpcmaplrg.png’
#
# ntpcmaplrg.png      100%[===================>]   1.18M  --.-KB/s    in 0.1s
#
# 2022-01-12 04:49:49 (9.22 MB/s) - ‘ntpcmaplrg.png’ saved [1237701/1237701]

# %%
map = plt.imread('ntpcmap.png')
maplrg =  plt.imread('ntpcmaplrg.png')

# %%
f, axarr = plt.subplots(2)
axarr[0].imshow(map)
axarr[1].imshow(maplrg)

# %%
#let's plot the points
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(dften.longitude, dften.latitude, zorder=1, alpha= 0.2, c='k', s=10)
ax.set_title('Fire Incidents in NTPC, 2015-2017, Spatial Domain')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
# Out:
# (24.77511693, 25.29717505)

# %%
#split dataframe into 3 years
df15 = df[df['date'].dt.year == 2015]
df16 = df[df['date'].dt.year == 2016]
df17 = df[df['date'].dt.year == 2017]

# %%
df15
# Out:
#                     date  station  ...   latitude township
# 0    2015-01-01 00:13:00  火警-瓦斯漏氣  ...  25.000569   板橋區廣德里
# 1    2015-01-01 00:16:00    火警-倉庫  ...  25.084172   三重區富華里
# 2    2015-01-01 00:48:00  火警-查看案件  ...  25.136422   淡水區民權里
# 3    2015-01-01 00:56:00  火警-查看案件  ...  25.031506   新莊區泰豐里
# 4    2015-01-01 01:04:00    火警-汽車  ...  24.982273   樹林區和平里
# ...                  ...      ...  ...        ...      ...
# 9054 2015-12-31 21:41:00   火警-透天厝  ...  24.994490   中和區秀明里
# 9055 2015-12-31 21:46:00  火警-集合住宅  ...  25.016660   樹林區三福里
# 9056 2015-12-31 22:37:00  火警-查看案件  ...  25.070749   林口區東勢里
# 9057 2015-12-31 22:45:00  火警-查看案件  ...  25.097674   蘆洲區保新里
# 9058 2015-12-31 23:32:00  火警-查看案件  ...  24.989496   中和區錦中里
#
# [9059 rows x 7 columns]

# %%
df16
# Out:
#                      date      station  ...   latitude township
# 9059  2016-01-01 01:10:00      火警-查看案件  ...  25.047863   泰山區明志里
# 9060  2016-01-01 01:18:00      火警-查看案件  ...  25.145268   淡水區八勢里
# 9061  2016-01-01 01:27:00      火警-查看案件  ...  25.013844   永和區下溪里
# 9062  2016-01-01 03:30:00      火警-查看案件  ...  25.093751   蘆洲區南港里
# 9063  2016-01-01 03:47:00        火警-汽車  ...  24.994834   樹林區潭底里
# ...                   ...          ...  ...        ...      ...
# 17156 2016-12-31 19:50:00      火警-集合住宅  ...  25.032542   板橋區溪頭里
# 17157 2016-12-31 21:51:00      火警-查看案件  ...  24.997751   板橋區崑崙里
# 17158 2016-12-31 22:30:00      火警-集合住宅  ...  25.018254   板橋區新民里
# 17159 2016-12-31 22:52:00      火警-查看案件  ...  25.072460   林口區西林里
# 17160 2016-12-31 23:13:00  火警-山林田野(平地)  ...  25.145268   淡水區八勢里
#
# [8102 rows x 7 columns]

# %%
df17
# Out:
#                      date      station  ...   latitude township
# 17161 2017-01-01 00:13:00  火警-山林田野(平地)  ...  24.936866   鶯歌區二甲里
# 17162 2017-01-01 00:15:00      火警-集合住宅  ...  24.929874   三峽區介壽里
# 17163 2017-01-01 00:54:00      火警-集合住宅  ...  25.007928   板橋區流芳里
# 17164 2017-01-01 01:44:00      火警-集合住宅  ...  25.062100   汐止區文化里
# 17165 2017-01-01 01:59:00     火警-警報器作響  ...  25.076035   汐止區建成里
# ...                   ...          ...  ...        ...      ...
# 24085 2017-12-31 17:14:00      火警-集合住宅  ...  24.990417   中和區錦盛里
# 24086 2017-12-31 18:40:00      火警-集合住宅  ...  25.048063   汐止區東勢里
# 24087 2017-12-31 20:09:00      火警-查看案件  ...  25.076529   三重區福隆里
# 24088 2017-12-31 20:44:00      火警-查看案件  ...  24.997367   永和區民族里
# 24089 2017-12-31 22:09:00      火警-查看案件  ...  25.000317   板橋區龍安里
#
# [6929 rows x 7 columns]

# %%
#let's plot the points for 2015
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df15.longitude, df15.latitude, zorder=1, alpha= 0.2, c='r', s=10)
ax.set_title('Fire Incidents in NTPC, 2015, Spatial Domain')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
# Out:
# (24.77511693, 25.29717505)

# %%
#let's plot the points for 2016
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df16.longitude, df16.latitude, zorder=1, alpha= 0.2, c='g', s=10)
ax.set_title('Fire Incidents in NTPC, 2016, Spatial Domain')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
# Out:
# (24.77511693, 25.29717505)

# %%
#let's plot the points for 2017
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df17.longitude, df17.latitude, zorder=1, alpha= 0.2, c='b', s=10)
ax.set_title('Fire Incidents in NTPC, 2017, Spatial Domain')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
# Out:
# (24.77511693, 25.29717505)

# %%
#Extraction of the temporal domain
maxlimit = len(df)
ones = np.ones(maxlimit, dtype="uint32")
dftemp = pd.DataFrame(df.date)
dftemp['freq'] = ones

# %%
dftemp
# Out:
#                      date  freq
# 0     2015-01-01 00:13:00     1
# 1     2015-01-01 00:16:00     1
# 2     2015-01-01 00:48:00     1
# 3     2015-01-01 00:56:00     1
# 4     2015-01-01 01:04:00     1
# ...                   ...   ...
# 24085 2017-12-31 17:14:00     1
# 24086 2017-12-31 18:40:00     1
# 24087 2017-12-31 20:09:00     1
# 24088 2017-12-31 20:44:00     1
# 24089 2017-12-31 22:09:00     1
#
# [24090 rows x 2 columns]

# %%
#when running this block, we will obtain the monthly frequency to be used in the temporal domain (a.k.a. time series).
dftempday = dftemp.groupby(pd.Grouper(key="date", freq="1D")).count()
dftempweek = dftemp.groupby(pd.Grouper(key="date", freq="1W")).count()
dftempmonth = dftemp.groupby(pd.Grouper(key="date", freq="1M")).count()

# %%
dftempday
# Out:
#             freq
# date
# 2015-01-01    34
# 2015-01-02    25
# 2015-01-03    24
# 2015-01-04    34
# 2015-01-05    28
# ...          ...
# 2017-12-27    13
# 2017-12-28    19
# 2017-12-29    19
# 2017-12-30     6
# 2017-12-31     8
#
# [1096 rows x 1 columns]

# %%
dftempweek
# Out:
#             freq
# date
# 2015-01-04   117
# 2015-01-11   163
# 2015-01-18   141
# 2015-01-25   210
# 2015-02-01   174
# ...          ...
# 2017-12-03   125
# 2017-12-10   109
# 2017-12-17   105
# 2017-12-24   139
# 2017-12-31   100
#
# [157 rows x 1 columns]

# %%
dftempmonth
# Out:
#             freq
# date
# 2015-01-31   778
# 2015-02-28   776
# 2015-03-31   733
# 2015-04-30   844
# 2015-05-31   681
# 2015-06-30   677
# 2015-07-31   718
# 2015-08-31  1030
# 2015-09-30   792
# 2015-10-31   699
# 2015-11-30   680
# 2015-12-31   651
# 2016-01-31   688
# 2016-02-29   711
# 2016-03-31   752
# 2016-04-30   671
# 2016-05-31   652
# 2016-06-30   663
# 2016-07-31   666
# 2016-08-31   748
# 2016-09-30   674
# 2016-10-31   666
# 2016-11-30   635
# 2016-12-31   576
# 2017-01-31   638
# 2017-02-28   564
# 2017-03-31   519
# 2017-04-30   646
# 2017-05-31   509
# 2017-06-30   541
# 2017-07-31   610
# 2017-08-31   740
# 2017-09-30   576
# 2017-10-31   527
# 2017-11-30   553
# 2017-12-31   506

# %%
y = dftempmonth['freq']
x = dftempmonth.index
plt.rcParams["figure.figsize"] = (16,9)
plt.plot(x, y, color='r', label='monthly frequency') 
plt.xlabel('date')
plt.ylabel('incidents')
plt.title('Monthly Temporal Domain')
plt.legend() 
plt.show()

# %%
y = dftempweek['freq']
x = dftempweek.index
plt.rcParams["figure.figsize"] = (16,9)
plt.plot(x, y, color='g', label='weekly frequency')
plt.xlabel('date')
plt.ylabel('incidents')
plt.title('Weekly Temporal Domain')
plt.legend() 
plt.show()

# %%
y = dftempday['freq']
x = dftempday.index
plt.rcParams["figure.figsize"] = (16,9)
plt.plot(x, y, color='b', label='daily frequency') 
plt.xlabel('date')
plt.ylabel('incidents')
plt.title('Daily Temporal Domain')
plt.legend() 
plt.show()

# %% [markdown]
# #Keras LSTM MODEL

# %%
# LSTM for international airline passengers problem with regression framing
import numpy
import matplotlib.pyplot as plt
import pandas as pd
import math
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Convert dataset to matrix

# %%
tseries = dftempday['freq'].to_numpy()
tseries
# Out:
# array([34, 25, 24, ..., 19,  6,  8])

# %%
plt.plot(tseries)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
plt.ylabel('#of incidents')
plt.title('Number of daily fire incidents in NTPC Taiwan, 2015-2017')
plt.show()

# %%
dftensor=pd.DataFrame(tseries) #forward dataframe
dftensor=np.array(dftensor) #convert to tensor
dftensor #display dataframe
# Out:
# array([[34],
#        [25],
#        [24],
#        ...,
#        [19],
#        [ 6],
#        [ 8]])

# %%
dftensor=np.array(dftensor)

# %% [markdown]
# Train-test split

# %%
train_size = int(len(dftensor) * 0.8)
test_size = len(dftensor) - train_size
train, test = dftensor[0:train_size,:], dftensor[train_size:len(dftensor),:]

# %% [markdown]
# Form dataset matrix

# %%
def create_dataset(df, previous=1):
    dataX, dataY = [], []
    for i in range(len(df)-previous-1):
        a = df[i:(i+previous), 0]
        dataX.append(a)
        dataY.append(df[i + previous, 0])
    return np.array(dataX), np.array(dataY)

# %%
dftensor
# Out:
# array([[34],
#        [25],
#        [24],
#        ...,
#        [19],
#        [ 6],
#        [ 8]])

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
train = scaler.fit_transform(train)
#train

# %%
test = scaler.fit_transform(test)
#test

# %% [markdown]
# Configure LSTM model

# %%
# Lookback period
lookback = 5
X_train, Y_train = create_dataset(train, lookback)
X_test, Y_test = create_dataset(test, lookback)

# %%
#X_train

# %%
#Y_train

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
#X_train.shape[0]

# %%
X_test.shape
# Out:
# (214, 1, 5)

# %%
X_train.shape
# Out:
# (870, 1, 5)

# %% [markdown]
# #LSTM - The model
# We have reached the final step - design, fit, and train the LSTM model. Our LSTM layer is 4-noded 1-layered, plus a dense output layer with MSE as loss function, adam as the optimiser, and trained for 100 epochs.

# %%
# Generate LSTM network
model = tf.keras.Sequential()
model.add(LSTM(4, activation = 'sigmoid', input_shape=(1, lookback)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
history=model.fit(X_train, Y_train, validation_split=0.2, epochs=100, batch_size=1, verbose=2)

# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/100
# 696/696 - 6s - loss: 0.0041 - val_loss: 0.0017 - 6s/epoch - 8ms/step
# Epoch 2/100
# 696/696 - 3s - loss: 0.0028 - val_loss: 0.0023 - 3s/epoch - 4ms/step
# Epoch 3/100
# 696/696 - 3s - loss: 0.0028 - val_loss: 0.0017 - 3s/epoch - 4ms/step
# Epoch 4/100
# 696/696 - 3s - loss: 0.0027 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 5/100
# 696/696 - 3s - loss: 0.0026 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 6/100
# 696/696 - 3s - loss: 0.0026 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 7/100
# 696/696 - 3s - loss: 0.0026 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 8/100
# 696/696 - 3s - loss: 0.0026 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 9/100
# 696/696 - 3s - loss: 0.0025 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 10/100
# 696/696 - 3s - loss: 0.0025 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 11/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 12/100
# 696/696 - 3s - loss: 0.0025 - val_loss: 0.0017 - 3s/epoch - 4ms/step
# Epoch 13/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 14/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 15/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 16/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 17/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 18/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 19/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 20/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 21/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 22/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 23/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0016 - 3s/epoch - 4ms/step
# Epoch 24/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 25/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 26/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 27/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 28/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 29/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 30/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 31/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 32/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 33/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 34/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0022 - 3s/epoch - 4ms/step
# Epoch 35/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 36/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 37/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 38/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 39/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 40/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 41/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0011 - 3s/epoch - 4ms/step
# Epoch 42/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 43/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 44/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 45/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 46/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0016 - 3s/epoch - 4ms/step
# Epoch 47/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 48/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 49/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0011 - 3s/epoch - 4ms/step
# Epoch 50/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 51/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0016 - 3s/epoch - 4ms/step
# Epoch 52/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 53/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 54/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0020 - 3s/epoch - 4ms/step
# Epoch 55/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 56/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0020 - 3s/epoch - 4ms/step
# Epoch 57/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 58/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0011 - 3s/epoch - 4ms/step
# Epoch 59/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 60/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 61/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 62/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 63/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 64/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 65/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 66/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0026 - 3s/epoch - 4ms/step
# Epoch 67/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 68/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 69/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 70/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 71/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 72/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0035 - 3s/epoch - 4ms/step
# Epoch 73/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 74/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 75/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 76/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 77/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 78/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 79/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 80/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 81/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 82/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 83/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0019 - 3s/epoch - 4ms/step
# Epoch 84/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 85/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 86/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 87/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 88/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 89/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 90/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 91/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 92/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0011 - 3s/epoch - 4ms/step
# Epoch 93/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 94/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0015 - 3s/epoch - 4ms/step
# Epoch 95/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 96/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0012 - 3s/epoch - 4ms/step
# Epoch 97/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 98/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 99/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# Epoch 100/100
# 696/696 - 3s - loss: 0.0024 - val_loss: 0.0014 - 3s/epoch - 4ms/step
# dict_keys(['loss', 'val_loss'])

# %% [markdown]
# #LSTM - Prediction
# Once we have trained our model, we can start doing predictions. Then, manipulate the post-action data.

# %%
# Generate predictions
trainpred = model.predict(X_train)
testpred = model.predict(X_test)

# %%
# Convert predictions back to normal values
trainpred = scaler.inverse_transform(trainpred)
Y_train = scaler.inverse_transform([Y_train])
testpred = scaler.inverse_transform(testpred)
Y_test = scaler.inverse_transform([Y_test])
predictions = testpred

# %%
Y_train.shape
# Out:
# (1, 870)

# %%
Y_test.shape
# Out:
# (1, 214)

# %%
X_train.shape
# Out:
# (870, 1, 5)

# %%
X_test.shape
# Out:
# (214, 1, 5)

# %% [markdown]
# #Screen Prediction Accuracy on Test Data
# Once we have reviewed the input train-test data for the prediction - we can carry it out now.

# %%
# calculate RMSE
trainScore = math.sqrt(mean_squared_error(Y_train[0], trainpred[:,0]))
print('Train Score: %f RMSE' % (trainScore))
valScore = math.sqrt(mean_squared_error(Y_test[0], testpred[:,0]))
print('Test Score: %f RMSE' % (valScore))
# Out:
# Train Score: 2.791914 RMSE
# Test Score: 7.400346 RMSE

# %%
# Train predictions
trainpredPlot = np.empty_like(dftempday)
trainpredPlot[:, :] = np.nan
trainpredPlot[lookback:len(trainpred)+lookback, :] = trainpred

# %%
# Test predictions
testpredPlot = np.empty_like(dftempday)
testpredPlot[:, :] = np.nan
testpredPlot[len(trainpred)+(lookback*2)+1:len(dftempday)-1, :] = testpred

# %%
Y_test=Y_test.reshape(-1)
Y_test.shape
Y_test=pd.Series(Y_test)

# %%
Y_test
# Out:
# 0      21.0
# 1      22.0
# 2      19.0
# 3      25.0
# 4      33.0
#        ...
# 209    16.0
# 210    13.0
# 211    19.0
# 212    19.0
# 213     6.0
# Length: 214, dtype: float64

# %%
predictions=predictions.reshape(-1)
predictions.shape
predictions=pd.Series(predictions)

# %%
predictions
# Out:
# 0      15.430725
# 1      15.514477
# 2      15.815342
# 3      15.210504
# 4      16.866001
#          ...
# 209    14.912234
# 210    14.175966
# 211    12.765971
# 212    14.515946
# 213    14.835412
# Length: 214, dtype: float32

# %% [markdown]
# #LSTM - Finalisation
# As we have just carried out the prediction, let's evaluate the performance in terms of several metrics (mda, rmse) and visualise the prediction graph

# %%
import numpy as np

def mda(actual: np.ndarray, predicted: np.ndarray):
    """ Mean Directional Accuracy """
    return np.mean((np.sign(actual[1:] - actual[:-1]) == np.sign(predicted[1:] - predicted[:-1])).astype(int))

# %%
mda(Y_test, predictions)
# Out:
# 0.9906542056074766

# %% [markdown]
# Test metrics

# %%
# https://machinelearningmastery.com/time-series-forecasting-performance-measures-with-python/

mse = mean_squared_error(Y_test, predictions)
mae = metrics.mean_absolute_error(Y_test, predictions)
mape = metrics.mean_absolute_percentage_error(Y_test, predictions)
rmse = sqrt(mse)
print('RMSE: %f' % rmse)
print('MSE: %f' % mse)
print('MAE: %f' % mae)
print('MAPE: %f' % mape)
# Out:
# RMSE: 7.400346
# MSE: 54.765124
# MAE: 5.510089
# MAPE: 0.276246

# %% [markdown]
# train metrics

# %%
trmse = mean_squared_error(Y_train[0], trainpred[:,0])
trmae = metrics.mean_absolute_error(Y_train[0], trainpred[:,0])
trmape = metrics.mean_absolute_percentage_error(Y_train[0], trainpred[:,0])
trrmse = sqrt(trmse)
print('RMSE: %f' % trrmse)
print('MSE: %f' % trmse)
print('MAE: %f' % trmae)
print('MAPE: %f' % trmape)
# Out:
# RMSE: 2.791914
# MSE: 7.794785
# MAE: 1.639144
# MAPE: 0.149845

# %%
np.mean(Y_test)
# Out:
# 19.0

# %%
plt.plot(Y_test)
plt.plot(predictions)
plt.xlabel('Days since Jan 1, 2015')
plt.ylabel('# of daily incidents')
plt.title("Test vs. Prediction")
plt.show()
