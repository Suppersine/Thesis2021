# %% [markdown]
# #Read the data

# %%
from zipfile import ZipFile
import os, glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from google.colab.patches import cv2_imshow

# %%
# !wget https://www.dropbox.com/s/gtvw3nqbderxigb/datafig28.zip
# Out:
# --2022-01-13 08:35:05--  https://www.dropbox.com/s/gtvw3nqbderxigb/datafig28.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/gtvw3nqbderxigb/datafig28.zip [following]
# --2022-01-13 08:35:05--  https://www.dropbox.com/s/raw/gtvw3nqbderxigb/datafig28.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uccd6921650e0e025ec9aa0cb6f3.dl.dropboxusercontent.com/cd/0/inline/BdtgKGKCwV7rVM9C_lpV2DaTGMvVIGrQyMBqhJ4A7QHYpPDwEKdE46xggY6DhjGbuJFoTXLdT-_rD7cIsoOxyjYl5RUd3GySufb8IzIxvbpr0S5EcW6M2ujhgCjaJ40UdoYBa66gQIz8_SP4xnXwiAfo/file# [following]
# --2022-01-13 08:35:05--  https://uccd6921650e0e025ec9aa0cb6f3.dl.dropboxusercontent.com/cd/0/inline/BdtgKGKCwV7rVM9C_lpV2DaTGMvVIGrQyMBqhJ4A7QHYpPDwEKdE46xggY6DhjGbuJFoTXLdT-_rD7cIsoOxyjYl5RUd3GySufb8IzIxvbpr0S5EcW6M2ujhgCjaJ40UdoYBa66gQIz8_SP4xnXwiAfo/file
# Resolving uccd6921650e0e025ec9aa0cb6f3.dl.dropboxusercontent.com (uccd6921650e0e025ec9aa0cb6f3.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:601b:15::a27d:80f
# Connecting to uccd6921650e0e025ec9aa0cb6f3.dl.dropboxusercontent.com (uccd6921650e0e025ec9aa0cb6f3.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BdtGqFrw5MRw6ooVJRFXUKL_qI-fSAcg_SLdhYaj2U-Rb3FnZIgXAGHf1p8Eu4dpaiU3aEbdQYvaR7e9tP2TsfaogQJFCVDu40z0ZCS_QwbbnjPFRed0_VGSein15inDqbwG8necKIU5g50d7Vi0cJB6zjnSQQiW4qKO3eglbPJ9HinHw1_-wdBE8cuNfpfnnrsHU6_4BgCbnyQmyWab4IPbEedXgj62yf1YhW51brnt0ayTfNDQRYCP0xXDT4uqrBH4-rEhYBNUzb8aXZduRNFIhH23WYK-TqfUp63jCHhportyI9ms2-kh1bZyow8_-TFq6k2ZJmvW8QWULd_DYBSesirCF8XTfPBbCO9nisiR8eGOvXXhd-FWmgvVk3eH_Ms/file [following]
# --2022-01-13 08:35:06--  https://uccd6921650e0e025ec9aa0cb6f3.dl.dropboxusercontent.com/cd/0/inline2/BdtGqFrw5MRw6ooVJRFXUKL_qI-fSAcg_SLdhYaj2U-Rb3FnZIgXAGHf1p8Eu4dpaiU3aEbdQYvaR7e9tP2TsfaogQJFCVDu40z0ZCS_QwbbnjPFRed0_VGSein15inDqbwG8necKIU5g50d7Vi0cJB6zjnSQQiW4qKO3eglbPJ9HinHw1_-wdBE8cuNfpfnnrsHU6_4BgCbnyQmyWab4IPbEedXgj62yf1YhW51brnt0ayTfNDQRYCP0xXDT4uqrBH4-rEhYBNUzb8aXZduRNFIhH23WYK-TqfUp63jCHhportyI9ms2-kh1bZyow8_-TFq6k2ZJmvW8QWULd_DYBSesirCF8XTfPBbCO9nisiR8eGOvXXhd-FWmgvVk3eH_Ms/file
# Reusing existing connection to uccd6921650e0e025ec9aa0cb6f3.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 34548 (34K) [application/zip]
# Saving to: ‘datafig28.zip’
#
# datafig28.zip       100%[===================>]  33.74K  --.-KB/s    in 0.02s
#
# 2022-01-13 08:35:06 (1.38 MB/s) - ‘datafig28.zip’ saved [34548/34548]

# %%
with ZipFile("datafig28.zip","r") as zip_ref:
    zip_ref.extractall()

# %%
def imageread(directory, mode=all):
  if mode == "all":
    directory = directory+'all/'
  elif mode == "train":
    directory = directory+'train/'
  elif mode == "test":
    directory = directory+'test/'
  else:
    print("ERROR, You did not select a mode; must be one of these: all, train, test")

  modelen = next(os.walk(directory))[2] #dir is your directory path as string
  modelen = len(modelen)
  print(modelen)
  picmat = np.zeros([modelen,28,28])
  i = 0

  if mode != None:
    for files in os.scandir(directory):
      #print(files.path)
      imageArray = cv2.imread(files.path, cv2.COLOR_BGR2GRAY)
      picmat[i] = imageArray
      #cv2_imshow(picmat[i])
      i+=1

  return picmat
    
all3darr = imageread('/content/datafig28/', 'all')
train3darr = imageread('/content/datafig28/', 'train')
test3darr = imageread('/content/datafig28/', 'test')
plt.imshow(all3darr[0])
# Out:
# 36
# 24
# 12

# %% [markdown]
# #Define the model (TFK-LSGAN)

# %%
from numpy import expand_dims
from numpy import zeros
from numpy import ones
from numpy.random import randn
from numpy.random import randint
import tensorflow as tf
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.initializers import RandomNormal
from matplotlib import pyplot

# define the standalone discriminator model
def define_discriminator(in_shape=(28,28,1)):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# define model
	model = Sequential()
	# downsample to 14x14
	model.add(Conv2D(64, (4,4), strides=(2,2), padding='same', kernel_initializer=init, input_shape=in_shape))
	model.add(BatchNormalization())
	model.add(LeakyReLU(alpha=0.2))
	# downsample to 7x7
	model.add(Conv2D(128, (4,4), strides=(2,2), padding='same', kernel_initializer=init))
	model.add(BatchNormalization())
	model.add(LeakyReLU(alpha=0.2))
	# classifier
	model.add(Flatten())
	model.add(Dense(1, activation='linear', kernel_initializer=init))
	# compile model with L2 loss
	model.compile(loss='mse', optimizer=Adam(learning_rate=0.001, beta_1=0.5))
	return model

# define the standalone generator model
def define_generator(latent_dim):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# define model
	model = Sequential()
	# foundation for 7x7 image
	n_nodes = 256 * 7 * 7
	model.add(Dense(n_nodes, kernel_initializer=init, input_dim=latent_dim))
	model.add(BatchNormalization())
	model.add(Activation('relu'))
	model.add(Reshape((7, 7, 256)))
	# upsample to 14x14
	model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same', kernel_initializer=init))
	model.add(BatchNormalization())
	model.add(Activation('relu'))
	# upsample to 28x28
	model.add(Conv2DTranspose(64, (4,4), strides=(2,2), padding='same', kernel_initializer=init))
	model.add(BatchNormalization())
	model.add(Activation('relu'))
	# output 28x28x1
	model.add(Conv2D(1, (7,7), padding='same', kernel_initializer=init))
	model.add(Activation('tanh'))
	return model

# define the combined generator and discriminator model, for updating the generator
def define_gan(generator, discriminator):
	# make weights in the discriminator not trainable
	for layer in discriminator.layers:
		if not isinstance(layer, BatchNormalization):
			layer.trainable = False
	# connect them
	model = Sequential()
	# add generator
	model.add(generator)
	# add the discriminator
	model.add(discriminator)
	# compile model with L2 loss
	model.compile(loss='mse', optimizer=Adam(learning_rate=0.001, beta_1=0.5))
	return model

# load our images #LOAD RAW IMAGES
def load_real_samples():
	# load dataset
	trainX = train3darr
	# expand to 3d, e.g. add channels
	X = expand_dims(trainX, axis=-1)
	# convert from ints to floats
	X = X.astype('float32')
	# scale from [0,255] to [-1,1] (activation = tanh)
	X = (X - 127.5) / 127.5
	return X

# # select real samples
def generate_real_samples(dataset, n_samples):
	# choose random instances
	ix = randint(0, dataset.shape[0], n_samples)
	# select images
	X = dataset[ix]
	# generate class labels
	y = ones((n_samples, 1))
	return X, y

# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples):
	# generate points in the latent space
	x_input = randn(latent_dim * n_samples)
	# reshape into a batch of inputs for the network
	x_input = x_input.reshape(n_samples, latent_dim)
	return x_input

# use the generator to generate n fake examples, with class labels
def generate_fake_samples(generator, latent_dim, n_samples):
	# generate points in latent space
	x_input = generate_latent_points(latent_dim, n_samples)
	# predict outputs
	X = generator.predict(x_input)
	# create class labels
	y = zeros((n_samples, 1))
	return X, y

# generate samples and save as a plot and save the model
def summarize_performance(step, g_model, latent_dim, n_samples=12):
	# prepare fake examples
	X, _ = generate_fake_samples(g_model, latent_dim, n_samples)
	# scale from [-1,1] to [0,1]
	X = (X + 1) / 2.0
	# plot images
	for i in range(3 * 4):
		# define subplot
		pyplot.subplot(3, 4, 1 + i)
		# turn off axis
		pyplot.axis('off')
		# plot raw pixel data
		pyplot.imshow(X[i, :, :, 0], cmap='gray_r')
	# save plot to file
	filename1 = 'generated_plot_%06d.png' % (step+1)
	pyplot.savefig(filename1)
	pyplot.close()
	# save the generator model
	filename2 = 'model_%06d.h5' % (step+1)
	g_model.save(filename2)
	print('Saved %s and %s' % (filename1, filename2))
  

# create a line plot of loss for the gan and save to file
def plot_history(d1_hist, d2_hist, g_hist):
	pyplot.plot(d1_hist, label='dloss1')
	pyplot.plot(d2_hist, label='dloss2')
	pyplot.plot(g_hist, label='gloss')
	pyplot.legend()
	filename = 'plot_line_plot_loss.png'
	pyplot.savefig(filename)
	pyplot.close()
	print('Saved %s' % (filename))

# train the generator and discriminator
def train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs=100, n_batch=12):
	# calculate the number of batches per training epoch
	bat_per_epo = int(dataset.shape[0] / n_batch)
	# calculate the number of training iterations
	n_steps = bat_per_epo * n_epochs
	# calculate the size of half a batch of samples
	half_batch = int(n_batch / 2)
	# lists for storing loss, for plotting later
	d1_hist, d2_hist, g_hist = list(), list(), list()
	# manually enumerate epochs
	for i in range(n_steps):
		# prepare real and fake samples
		X_real, y_real = generate_real_samples(dataset, half_batch)
		X_fake, y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
		print(X_fake.shape)
		# update discriminator model
		d_loss1 = d_model.train_on_batch(X_real, y_real)
		d_loss2 = d_model.train_on_batch(X_fake, y_fake)
		# update the generator via the discriminator's error
		z_input = generate_latent_points(latent_dim, n_batch)
		y_real2 = ones((n_batch, 1))
		g_loss = gan_model.train_on_batch(z_input, y_real2)
		# summarize loss on this batch
		print('>%d, d1=%.3f, d2=%.3f g=%.3f' % (i+1, d_loss1, d_loss2, g_loss))
		# record history
		d1_hist.append(d_loss1)
		d2_hist.append(d_loss2)
		g_hist.append(g_loss)
		# evaluate the model performance every 'epoch'
		if (i+1) % (bat_per_epo * 1) == 0:
			summarize_performance(i, g_model, latent_dim)
	# create line plot of training history
	plot_history(d1_hist, d2_hist, g_hist)

# size of the latent space
latent_dim = 100
# create the discriminator
discriminator = define_discriminator()
# create the generator
generator = define_generator(latent_dim)
# create the gan
gan_model = define_gan(generator, discriminator)
# load image data
dataset = load_real_samples()
print(dataset.shape)
# train model
train(generator, discriminator, gan_model, dataset, latent_dim)
# Out:
# (24, 28, 28, 1)
# (6, 28, 28, 1)
# >1, d1=5.092, d2=0.128 g=6.618
# (6, 28, 28, 1)
# >2, d1=361.363, d2=9.912 g=0.875
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000002.png and model_000002.h5
# (6, 28, 28, 1)
# >3, d1=2.018, d2=2.087 g=2.336
# (6, 28, 28, 1)
# >4, d1=21.955, d2=6.637 g=2.331
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000004.png and model_000004.h5
# (6, 28, 28, 1)
# >5, d1=0.066, d2=3.602 g=0.908
# (6, 28, 28, 1)
# >6, d1=1.799, d2=3.343 g=3.191
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000006.png and model_000006.h5
# (6, 28, 28, 1)
# >7, d1=0.221, d2=6.865 g=2.419
# (6, 28, 28, 1)
# >8, d1=0.179, d2=10.134 g=1.931
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000008.png and model_000008.h5
# (6, 28, 28, 1)
# >9, d1=0.166, d2=7.971 g=0.407
# (6, 28, 28, 1)
# >10, d1=0.045, d2=3.574 g=0.147
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000010.png and model_000010.h5
# (6, 28, 28, 1)
# >11, d1=0.044, d2=0.769 g=0.036
# (6, 28, 28, 1)
# >12, d1=0.114, d2=0.058 g=0.110
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000012.png and model_000012.h5
# (6, 28, 28, 1)
# >13, d1=0.202, d2=0.210 g=0.109
# (6, 28, 28, 1)
# >14, d1=0.029, d2=0.042 g=0.089
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000014.png and model_000014.h5
# (6, 28, 28, 1)
# >15, d1=0.051, d2=0.135 g=0.073
# (6, 28, 28, 1)
# >16, d1=0.049, d2=0.368 g=0.119
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000016.png and model_000016.h5
# (6, 28, 28, 1)
# >17, d1=0.138, d2=0.536 g=0.150
# (6, 28, 28, 1)
# >18, d1=0.206, d2=0.565 g=0.173
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000018.png and model_000018.h5
# (6, 28, 28, 1)
# >19, d1=0.480, d2=0.650 g=0.345
# (6, 28, 28, 1)
# >20, d1=0.799, d2=0.532 g=0.102
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000020.png and model_000020.h5
# (6, 28, 28, 1)
# >21, d1=1.214, d2=0.272 g=0.213
# (6, 28, 28, 1)
# >22, d1=0.866, d2=0.197 g=0.088
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000022.png and model_000022.h5
# (6, 28, 28, 1)
# >23, d1=0.773, d2=0.256 g=0.484
# (6, 28, 28, 1)
# >24, d1=0.691, d2=0.693 g=0.660
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000024.png and model_000024.h5
# (6, 28, 28, 1)
# >25, d1=0.534, d2=2.032 g=1.445
# (6, 28, 28, 1)
# >26, d1=0.677, d2=3.900 g=1.325
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000026.png and model_000026.h5
# (6, 28, 28, 1)
# >27, d1=1.328, d2=5.626 g=2.371
# (6, 28, 28, 1)
# >28, d1=1.993, d2=5.593 g=0.537
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000028.png and model_000028.h5
# (6, 28, 28, 1)
# >29, d1=3.093, d2=4.095 g=1.015
# (6, 28, 28, 1)
# >30, d1=3.792, d2=1.352 g=0.042
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000030.png and model_000030.h5
# (6, 28, 28, 1)
# >31, d1=4.560, d2=0.102 g=0.354
# (6, 28, 28, 1)
# >32, d1=2.077, d2=0.079 g=0.056
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000032.png and model_000032.h5
# (6, 28, 28, 1)
# >33, d1=0.611, d2=0.065 g=0.068
# (6, 28, 28, 1)
# >34, d1=0.185, d2=0.087 g=0.021
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000034.png and model_000034.h5
# (6, 28, 28, 1)
# >35, d1=0.117, d2=0.143 g=0.019
# (6, 28, 28, 1)
# >36, d1=0.051, d2=0.091 g=0.021
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000036.png and model_000036.h5
# (6, 28, 28, 1)
# >37, d1=0.025, d2=0.176 g=0.139
# (6, 28, 28, 1)
# >38, d1=0.024, d2=0.190 g=0.099
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000038.png and model_000038.h5
# (6, 28, 28, 1)
# >39, d1=0.125, d2=0.042 g=0.012
# (6, 28, 28, 1)
# >40, d1=0.194, d2=0.014 g=0.058
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000040.png and model_000040.h5
# (6, 28, 28, 1)
# >41, d1=0.097, d2=0.081 g=0.025
# (6, 28, 28, 1)
# >42, d1=0.005, d2=0.020 g=0.040
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000042.png and model_000042.h5
# (6, 28, 28, 1)
# >43, d1=0.026, d2=0.034 g=0.060
# (6, 28, 28, 1)
# >44, d1=0.062, d2=0.065 g=0.113
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000044.png and model_000044.h5
# (6, 28, 28, 1)
# >45, d1=0.077, d2=0.071 g=0.019
# (6, 28, 28, 1)
# >46, d1=0.082, d2=0.136 g=0.084
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000046.png and model_000046.h5
# (6, 28, 28, 1)
# >47, d1=0.108, d2=0.009 g=0.038
# (6, 28, 28, 1)
# >48, d1=0.061, d2=0.041 g=0.075
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000048.png and model_000048.h5
# (6, 28, 28, 1)
# >49, d1=0.024, d2=0.185 g=0.194
# (6, 28, 28, 1)
# >50, d1=0.056, d2=0.427 g=0.369
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000050.png and model_000050.h5
# (6, 28, 28, 1)
# >51, d1=0.285, d2=0.489 g=0.301
# (6, 28, 28, 1)
# >52, d1=0.689, d2=0.472 g=0.501
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000052.png and model_000052.h5
# (6, 28, 28, 1)
# >53, d1=1.180, d2=0.096 g=0.127
# (6, 28, 28, 1)
# >54, d1=1.526, d2=0.044 g=0.038
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000054.png and model_000054.h5
# (6, 28, 28, 1)
# >55, d1=1.717, d2=0.300 g=0.014
# (6, 28, 28, 1)
# >56, d1=1.831, d2=1.223 g=0.212
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000056.png and model_000056.h5
# (6, 28, 28, 1)
# >57, d1=1.367, d2=3.384 g=0.548
# (6, 28, 28, 1)
# >58, d1=0.645, d2=7.145 g=1.673
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000058.png and model_000058.h5
# (6, 28, 28, 1)
# >59, d1=0.063, d2=9.304 g=2.312
# (6, 28, 28, 1)
# >60, d1=1.583, d2=6.783 g=0.901
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000060.png and model_000060.h5
# (6, 28, 28, 1)
# >61, d1=4.626, d2=2.758 g=1.322
# (6, 28, 28, 1)
# >62, d1=5.821, d2=0.260 g=0.022
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000062.png and model_000062.h5
# (6, 28, 28, 1)
# >63, d1=4.438, d2=0.151 g=0.535
# (6, 28, 28, 1)
# >64, d1=1.575, d2=0.369 g=0.216
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000064.png and model_000064.h5
# (6, 28, 28, 1)
# >65, d1=0.388, d2=0.277 g=0.372
# (6, 28, 28, 1)
# >66, d1=0.108, d2=0.085 g=0.090
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000066.png and model_000066.h5
# (6, 28, 28, 1)
# >67, d1=0.045, d2=0.068 g=0.351
# (6, 28, 28, 1)
# >68, d1=0.149, d2=0.077 g=0.129
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000068.png and model_000068.h5
# (6, 28, 28, 1)
# >69, d1=0.573, d2=0.134 g=0.067
# (6, 28, 28, 1)
# >70, d1=0.950, d2=0.560 g=0.015
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000070.png and model_000070.h5
# (6, 28, 28, 1)
# >71, d1=0.678, d2=0.960 g=0.082
# (6, 28, 28, 1)
# >72, d1=0.083, d2=0.976 g=0.103
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000072.png and model_000072.h5
# (6, 28, 28, 1)
# >73, d1=0.150, d2=0.529 g=0.180
# (6, 28, 28, 1)
# >74, d1=0.707, d2=0.137 g=0.082
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000074.png and model_000074.h5
# (6, 28, 28, 1)
# >75, d1=0.761, d2=0.028 g=0.084
# (6, 28, 28, 1)
# >76, d1=0.496, d2=0.039 g=0.021
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000076.png and model_000076.h5
# (6, 28, 28, 1)
# >77, d1=0.303, d2=0.142 g=0.011
# (6, 28, 28, 1)
# >78, d1=0.152, d2=0.296 g=0.021
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000078.png and model_000078.h5
# (6, 28, 28, 1)
# >79, d1=0.020, d2=0.196 g=0.030
# (6, 28, 28, 1)
# >80, d1=0.011, d2=0.095 g=0.016
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000080.png and model_000080.h5
# (6, 28, 28, 1)
# >81, d1=0.055, d2=0.044 g=0.056
# (6, 28, 28, 1)
# >82, d1=0.104, d2=0.025 g=0.045
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000082.png and model_000082.h5
# (6, 28, 28, 1)
# >83, d1=0.137, d2=0.043 g=0.082
# (6, 28, 28, 1)
# >84, d1=0.128, d2=0.029 g=0.025
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000084.png and model_000084.h5
# (6, 28, 28, 1)
# >85, d1=0.027, d2=0.050 g=0.023
# (6, 28, 28, 1)
# >86, d1=0.021, d2=0.048 g=0.027
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000086.png and model_000086.h5
# (6, 28, 28, 1)
# >87, d1=0.031, d2=0.029 g=0.013
# (6, 28, 28, 1)
# >88, d1=0.019, d2=0.048 g=0.055
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000088.png and model_000088.h5
# (6, 28, 28, 1)
# >89, d1=0.037, d2=0.052 g=0.015
# (6, 28, 28, 1)
# >90, d1=0.099, d2=0.020 g=0.021
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000090.png and model_000090.h5
# (6, 28, 28, 1)
# >91, d1=0.089, d2=0.011 g=0.011
# (6, 28, 28, 1)
# >92, d1=0.038, d2=0.023 g=0.015
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000092.png and model_000092.h5
# (6, 28, 28, 1)
# >93, d1=0.045, d2=0.032 g=0.010
# (6, 28, 28, 1)
# >94, d1=0.050, d2=0.075 g=0.009
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000094.png and model_000094.h5
# (6, 28, 28, 1)
# >95, d1=0.028, d2=0.187 g=0.064
# (6, 28, 28, 1)
# >96, d1=0.008, d2=0.231 g=0.037
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000096.png and model_000096.h5
# (6, 28, 28, 1)
# >97, d1=0.069, d2=0.169 g=0.091
# (6, 28, 28, 1)
# >98, d1=0.269, d2=0.051 g=0.031
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000098.png and model_000098.h5
# (6, 28, 28, 1)
# >99, d1=0.490, d2=0.017 g=0.032
# (6, 28, 28, 1)
# >100, d1=0.410, d2=0.202 g=0.013
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000100.png and model_000100.h5
# (6, 28, 28, 1)
# >101, d1=0.227, d2=0.577 g=0.156
# (6, 28, 28, 1)
# >102, d1=0.057, d2=1.248 g=0.518
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000102.png and model_000102.h5
# (6, 28, 28, 1)
# >103, d1=0.099, d2=1.696 g=0.475
# (6, 28, 28, 1)
# >104, d1=0.748, d2=1.548 g=1.379
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000104.png and model_000104.h5
# (6, 28, 28, 1)
# >105, d1=2.736, d2=0.508 g=0.415
# (6, 28, 28, 1)
# >106, d1=5.587, d2=0.038 g=0.710
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000106.png and model_000106.h5
# (6, 28, 28, 1)
# >107, d1=6.147, d2=1.548 g=0.020
# (6, 28, 28, 1)
# >108, d1=4.603, d2=4.894 g=0.086
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000108.png and model_000108.h5
# (6, 28, 28, 1)
# >109, d1=0.778, d2=7.014 g=1.240
# (6, 28, 28, 1)
# >110, d1=0.255, d2=4.567 g=0.240
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000110.png and model_000110.h5
# (6, 28, 28, 1)
# >111, d1=1.686, d2=1.349 g=0.859
# (6, 28, 28, 1)
# >112, d1=2.107, d2=0.055 g=0.023
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000112.png and model_000112.h5
# (6, 28, 28, 1)
# >113, d1=1.434, d2=0.054 g=0.392
# (6, 28, 28, 1)
# >114, d1=0.464, d2=0.097 g=0.048
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000114.png and model_000114.h5
# (6, 28, 28, 1)
# >115, d1=0.069, d2=0.043 g=0.083
# (6, 28, 28, 1)
# >116, d1=0.062, d2=0.021 g=0.017
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000116.png and model_000116.h5
# (6, 28, 28, 1)
# >117, d1=0.162, d2=0.063 g=0.023
# (6, 28, 28, 1)
# >118, d1=0.158, d2=0.162 g=0.016
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000118.png and model_000118.h5
# (6, 28, 28, 1)
# >119, d1=0.076, d2=0.072 g=0.038
# (6, 28, 28, 1)
# >120, d1=0.005, d2=0.011 g=0.011
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000120.png and model_000120.h5
# (6, 28, 28, 1)
# >121, d1=0.039, d2=0.015 g=0.006
# (6, 28, 28, 1)
# >122, d1=0.057, d2=0.045 g=0.003
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000122.png and model_000122.h5
# (6, 28, 28, 1)
# >123, d1=0.017, d2=0.103 g=0.087
# (6, 28, 28, 1)
# >124, d1=0.027, d2=0.055 g=0.005
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000124.png and model_000124.h5
# (6, 28, 28, 1)
# >125, d1=0.050, d2=0.025 g=0.049
# (6, 28, 28, 1)
# >126, d1=0.023, d2=0.009 g=0.013
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000126.png and model_000126.h5
# (6, 28, 28, 1)
# >127, d1=0.007, d2=0.011 g=0.043
# (6, 28, 28, 1)
# >128, d1=0.012, d2=0.002 g=0.030
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000128.png and model_000128.h5
# (6, 28, 28, 1)
# >129, d1=0.008, d2=0.042 g=0.009
# (6, 28, 28, 1)
# >130, d1=0.013, d2=0.085 g=0.032
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000130.png and model_000130.h5
# (6, 28, 28, 1)
# >131, d1=0.003, d2=0.098 g=0.047
# (6, 28, 28, 1)
# >132, d1=0.028, d2=0.082 g=0.087
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000132.png and model_000132.h5
# (6, 28, 28, 1)
# >133, d1=0.070, d2=0.034 g=0.017
# (6, 28, 28, 1)
# >134, d1=0.119, d2=0.010 g=0.041
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000134.png and model_000134.h5
# (6, 28, 28, 1)
# >135, d1=0.264, d2=0.123 g=0.064
# (6, 28, 28, 1)
# >136, d1=0.316, d2=0.523 g=0.014
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000136.png and model_000136.h5
# (6, 28, 28, 1)
# >137, d1=0.035, d2=0.616 g=0.143
# (6, 28, 28, 1)
# >138, d1=0.181, d2=0.150 g=0.019
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000138.png and model_000138.h5
# (6, 28, 28, 1)
# >139, d1=0.685, d2=0.067 g=0.026
# (6, 28, 28, 1)
# >140, d1=0.697, d2=0.743 g=0.109
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000140.png and model_000140.h5
# (6, 28, 28, 1)
# >141, d1=0.197, d2=1.566 g=0.305
# (6, 28, 28, 1)
# >142, d1=0.056, d2=1.150 g=0.558
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000142.png and model_000142.h5
# (6, 28, 28, 1)
# >143, d1=0.674, d2=0.360 g=0.052
# (6, 28, 28, 1)
# >144, d1=1.191, d2=0.006 g=0.540
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000144.png and model_000144.h5
# (6, 28, 28, 1)
# >145, d1=0.995, d2=0.337 g=0.311
# (6, 28, 28, 1)
# >146, d1=0.284, d2=0.772 g=0.099
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000146.png and model_000146.h5
# (6, 28, 28, 1)
# >147, d1=0.012, d2=0.750 g=0.584
# (6, 28, 28, 1)
# >148, d1=0.467, d2=0.135 g=0.031
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000148.png and model_000148.h5
# (6, 28, 28, 1)
# >149, d1=0.856, d2=0.013 g=0.191
# (6, 28, 28, 1)
# >150, d1=0.973, d2=0.459 g=0.603
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000150.png and model_000150.h5
# (6, 28, 28, 1)
# >151, d1=0.676, d2=2.500 g=0.710
# (6, 28, 28, 1)
# >152, d1=0.008, d2=5.082 g=4.901
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000152.png and model_000152.h5
# (6, 28, 28, 1)
# >153, d1=2.103, d2=3.246 g=1.254
# (6, 28, 28, 1)
# >154, d1=6.587, d2=0.574 g=3.289
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000154.png and model_000154.h5
# (6, 28, 28, 1)
# >155, d1=7.114, d2=0.463 g=0.151
# (6, 28, 28, 1)
# >156, d1=3.508, d2=2.161 g=1.180
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000156.png and model_000156.h5
# (6, 28, 28, 1)
# >157, d1=0.289, d2=8.282 g=12.018
# (6, 28, 28, 1)
# >158, d1=2.610, d2=12.787 g=2.341
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000158.png and model_000158.h5
# (6, 28, 28, 1)
# >159, d1=12.148, d2=4.674 g=5.231
# (6, 28, 28, 1)
# >160, d1=10.601, d2=0.400 g=0.007
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000160.png and model_000160.h5
# (6, 28, 28, 1)
# >161, d1=3.929, d2=0.018 g=1.259
# (6, 28, 28, 1)
# >162, d1=0.251, d2=0.002 g=0.425
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000162.png and model_000162.h5
# (6, 28, 28, 1)
# >163, d1=0.020, d2=0.054 g=0.820
# (6, 28, 28, 1)
# >164, d1=0.087, d2=0.007 g=0.447
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000164.png and model_000164.h5
# (6, 28, 28, 1)
# >165, d1=0.033, d2=0.019 g=0.605
# (6, 28, 28, 1)
# >166, d1=0.012, d2=0.021 g=0.412
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000166.png and model_000166.h5
# (6, 28, 28, 1)
# >167, d1=0.090, d2=0.067 g=0.397
# (6, 28, 28, 1)
# >168, d1=0.065, d2=0.050 g=0.135
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000168.png and model_000168.h5
# (6, 28, 28, 1)
# >169, d1=0.138, d2=0.004 g=0.234
# (6, 28, 28, 1)
# >170, d1=0.108, d2=0.056 g=0.204
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000170.png and model_000170.h5
# (6, 28, 28, 1)
# >171, d1=0.031, d2=0.069 g=0.076
# (6, 28, 28, 1)
# >172, d1=0.046, d2=0.053 g=0.250
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000172.png and model_000172.h5
# (6, 28, 28, 1)
# >173, d1=0.052, d2=0.022 g=0.055
# (6, 28, 28, 1)
# >174, d1=0.056, d2=0.028 g=0.262
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000174.png and model_000174.h5
# (6, 28, 28, 1)
# >175, d1=0.101, d2=0.005 g=0.162
# (6, 28, 28, 1)
# >176, d1=0.043, d2=0.008 g=0.147
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000176.png and model_000176.h5
# (6, 28, 28, 1)
# >177, d1=0.026, d2=0.002 g=0.210
# (6, 28, 28, 1)
# >178, d1=0.039, d2=0.002 g=0.098
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000178.png and model_000178.h5
# (6, 28, 28, 1)
# >179, d1=0.010, d2=0.001 g=0.172
# (6, 28, 28, 1)
# >180, d1=0.034, d2=0.004 g=0.107
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000180.png and model_000180.h5
# (6, 28, 28, 1)
# >181, d1=0.022, d2=0.007 g=0.100
# (6, 28, 28, 1)
# >182, d1=0.055, d2=0.005 g=0.233
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000182.png and model_000182.h5
# (6, 28, 28, 1)
# >183, d1=0.067, d2=0.020 g=0.155
# (6, 28, 28, 1)
# >184, d1=0.033, d2=0.027 g=0.098
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000184.png and model_000184.h5
# (6, 28, 28, 1)
# >185, d1=0.017, d2=0.052 g=0.304
# (6, 28, 28, 1)
# >186, d1=0.031, d2=0.006 g=0.112
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000186.png and model_000186.h5
# (6, 28, 28, 1)
# >187, d1=0.025, d2=0.003 g=0.118
# (6, 28, 28, 1)
# >188, d1=0.047, d2=0.039 g=0.285
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000188.png and model_000188.h5
# (6, 28, 28, 1)
# >189, d1=0.020, d2=0.184 g=0.056
# (6, 28, 28, 1)
# >190, d1=0.027, d2=0.625 g=1.827
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000190.png and model_000190.h5
# (6, 28, 28, 1)
# >191, d1=0.453, d2=0.852 g=0.765
# (6, 28, 28, 1)
# >192, d1=1.502, d2=0.576 g=2.790
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000192.png and model_000192.h5
# (6, 28, 28, 1)
# >193, d1=1.663, d2=0.115 g=0.042
# (6, 28, 28, 1)
# >194, d1=0.694, d2=0.112 g=1.440
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000194.png and model_000194.h5
# (6, 28, 28, 1)
# >195, d1=0.311, d2=0.087 g=0.034
# (6, 28, 28, 1)
# >196, d1=0.225, d2=0.124 g=1.248
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000196.png and model_000196.h5
# (6, 28, 28, 1)
# >197, d1=0.279, d2=0.092 g=0.023
# (6, 28, 28, 1)
# >198, d1=0.357, d2=0.048 g=1.101
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000198.png and model_000198.h5
# (6, 28, 28, 1)
# >199, d1=0.263, d2=0.038 g=0.621
# (6, 28, 28, 1)
# >200, d1=0.016, d2=0.172 g=0.004
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000200.png and model_000200.h5
# Saved plot_line_plot_loss.png

# %% [markdown]
# Calculate Train Metrics

# %%
def reverse_tanh(nparray, maxcolour=44): #44 stands for maximum colour magnitude of a monthly raster, whilst 11 stands for the daily one.
  nparray = nparray.astype('float32')
  coeff = float(0.5*maxcolour)
  ones = np.ones_like(nparray)
  new_arr = (nparray + ones)*(coeff)
  return new_arr

# %%
gt, _ = generate_real_samples(dataset, 24)
pred, _= generate_fake_samples(generator, latent_dim, 24)

# %%
#Alternatively, you can try this block instead of the simple "pred,_"
"""from keras.models import load_model
from numpy.random import randn
from matplotlib import pyplot
 
# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples):
	# generate points in the latent space
	x_input = randn(latent_dim * n_samples)
	# reshape into a batch of inputs for the network
	x_input = x_input.reshape(n_samples, latent_dim)
	return x_input
 
# create a plot of generated images (reversed grayscale)
def plot_generated(examples, n):
	# plot images
	for i in range(n * n):
		# define subplot
		pyplot.subplot(n, n, 1 + i)
		# turn off axis
		pyplot.axis('off')
		# plot raw pixel data
		pyplot.imshow(examples[i, :, :, 0], cmap='gray_r')
	pyplot.show()
 
# load model
model = load_model('/content/model_000200.h5')
# generate images
latent_points = generate_latent_points(100, 100)
# generate images
X = model.predict(latent_points)
# plot the result
plot_generated(X, 3)
# randomise X to calculate metrics
selectseq1 = np.random.choice(100, 24, replace=False)
selectseq2 = np.random.choice(100, 12, replace=False)
pred1 = np.zeros([24,28,28,1])
pred2 = np.zeros([24,28,28,1])
for i in range (0,24,1):
  pred1[i,:,:,:] = X[selectseq1[i],:,:,:]
for i in range (0,12,1):
  pred2[i,:,:,:] = X[selectseq2[i],:,:,:]"""
# Out:
# "from keras.models import load_model\nfrom numpy.random import randn\nfrom matplotlib import pyplot\n \n# generate points in latent space as input for the generator\ndef generate_latent_points(latent_dim, n_samples):\n\t# generate points in the latent space\n\tx_input = randn(latent_dim * n_samples)\n\t# reshape into a batch of inputs for the network\n\tx_input = x_input.reshape(n_samples, latent_dim)\n\treturn x_input\n \n# create a plot of generated images (reversed grayscale)\ndef plot_generated(examples, n):\n\t# plot images\n\tfor i in range(n * n):\n\t\t# define subplot\n\t\tpyplot.subplot(n, n, 1 + i)\n\t\t# turn off axis\n\t\tpyplot.axis('off')\n\t\t# plot raw pixel data\n\t\tpyplot.imshow(examples[i, :, :, 0], cmap='gray_r')\n\tpyplot.show()\n \n# load model\nmodel = load_model('/content/model_000200.h5')\n# generate images\nlatent_points = generate_latent_points(100, 100)\n# generate images\nX = model.predict(latent_points)\n# plot the result\nplot_generated(X, 3)\n# randomise X to calculate metrics\nselectseq1 = np.random.choice(100, 24, replace=False)\nselectseq2 = np.random.choice(100, 12, replace=False)\npred1 = np.zeros([24,28,28,1])\npred2 = np.zeros([24,28,28,1])\nfor i in range (0,24,1):\n  pred1[i,:,:,:] = X[selectseq1[i],:,:,:]\nfor i in range (0,12,1):\n  pred2[i,:,:,:] = X[selectseq2[i],:,:,:]"

# %%
pred = pred.reshape(24,28,28)
fig, axs = plt.subplots(2, 3)
axs[0, 0].imshow(pred[0], cmap='gray')
axs[0, 1].imshow(pred[1], cmap='gray')
axs[0, 2].imshow(pred[2], cmap='gray')
axs[1, 0].imshow(pred[3], cmap='gray')
axs[1, 1].imshow(pred[4], cmap='gray')
axs[1, 2].imshow(pred[5], cmap='gray')

# %%
print("GT:", gt.shape, "||", gt.min(), "||", gt.max())
print("GT:", pred.shape, "||", pred.min(), "||", pred.max())
gt = gt.reshape(24,784)
gt = reverse_tanh(gt)
pred = pred.reshape(24,784)
pred = reverse_tanh(pred)
print("GT:", gt.shape, "||", gt.min(), "||", gt.max())
print("GT:", pred.shape, "||", pred.min(), "||", pred.max())
# Out:
# GT: (24, 28, 28, 1) || -1.0 || 1.0
# GT: (24, 28, 28) || -0.99925935 || 0.9982771
# GT: (24, 784) || 0.0 || 44.0
# GT: (24, 784) || 0.016294241 || 43.962097

# %%
from sklearn import metrics
from math import sqrt

mae = metrics.mean_absolute_error(gt, pred)
mse = metrics.mean_squared_error(gt, pred)
mape = metrics.mean_absolute_percentage_error(gt, pred)
rmse = sqrt(mse)

print('MSE=', mse, '...RMSE=', rmse, '...MAE=', mae, '...MAPE=', mape)
# Out:
# MSE= 197.77995 ...RMSE= 14.063426076277775 ...MAE= 7.245772 ...MAPE= 2.6400028e+16

# %% [markdown]
# Calculate Test Metrics

# %%
def load_test_samples():
	# load dataset
	testX = test3darr
	# expand to 3d, e.g. add channels
	X = expand_dims(testX, axis=-1)
	# convert from ints to floats
	X = X.astype('float32')
	# scale from [0,255] to [-1,1]
	X = (X - 127.5) / 127.5
	return X

# %%
testd = load_test_samples()
print(testd.shape)
# Out:
# (12, 28, 28, 1)

# %%
gt, _ = generate_real_samples(testd, 12)
pred, _= generate_fake_samples(generator, latent_dim, 12)

# %%
pred = pred.reshape(12,28,28)
fig, axs = plt.subplots(2, 3)
axs[0, 0].imshow(pred[0], cmap='gray')
axs[0, 1].imshow(pred[1], cmap='gray')
axs[0, 2].imshow(pred[2], cmap='gray')
axs[1, 0].imshow(pred[3], cmap='gray')
axs[1, 1].imshow(pred[4], cmap='gray')
axs[1, 2].imshow(pred[5], cmap='gray')

# %%
print("GT:", gt.shape, "||", gt.min(), "||", gt.max())
print("GT:", pred.shape, "||", pred.min(), "||", pred.max())
gt = gt.reshape(12,784)
gt = reverse_tanh(gt)
pred = pred.reshape(12,784)
pred = reverse_tanh(pred)
print("GT:", gt.shape, "||", gt.min(), "||", gt.max())
print("GT:", pred.shape, "||", pred.min(), "||", pred.max())
# Out:
# GT: (12, 28, 28, 1) || -1.0 || 0.8666667
# GT: (12, 28, 28) || -0.99923617 || 0.9968905
# GT: (12, 784) || 0.0 || 41.066666
# GT: (12, 784) || 0.016804338 || 43.93159

# %%
from sklearn import metrics
from math import sqrt

mae = metrics.mean_absolute_error(gt, pred)
mse = metrics.mean_squared_error(gt, pred)
mape = metrics.mean_absolute_percentage_error(gt, pred)
rmse = sqrt(mse)

print('MSE=', mse, '...RMSE=', rmse, '...MAE=', mae, '...MAPE=', mape)
# Out:
# MSE= 194.74649 ...RMSE= 13.955159994730108 ...MAE= 7.1890564 ...MAPE= 2.6341962e+16
