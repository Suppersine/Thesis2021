# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !wget https://www.dropbox.com/s/jpw4fyv6mh31ql4/NTP2015-2017fire.txt
# Out:
# --2022-01-02 15:09:11--  https://www.dropbox.com/s/jpw4fyv6mh31ql4/NTP2015-2017fire.txt
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/jpw4fyv6mh31ql4/NTP2015-2017fire.txt [following]
# --2022-01-02 15:09:11--  https://www.dropbox.com/s/raw/jpw4fyv6mh31ql4/NTP2015-2017fire.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucf58aa74caef9704a7d1ac5e964.dl.dropboxusercontent.com/cd/0/inline/BdBJsa3JGjMz1J-tTtiYTfW_0qApRTZtN41Q__ijsn8UYYfOSkAj_O7CqeYIMZv96Uq_SRXLA0wRvQfyg9sGEG1yEnbFXfuufNbGf48YY4a7eLkvncLIoP3lUwlBhVUmWbXqCYqQQUEpEa7xTSbXQxsH/file# [following]
# --2022-01-02 15:09:12--  https://ucf58aa74caef9704a7d1ac5e964.dl.dropboxusercontent.com/cd/0/inline/BdBJsa3JGjMz1J-tTtiYTfW_0qApRTZtN41Q__ijsn8UYYfOSkAj_O7CqeYIMZv96Uq_SRXLA0wRvQfyg9sGEG1yEnbFXfuufNbGf48YY4a7eLkvncLIoP3lUwlBhVUmWbXqCYqQQUEpEa7xTSbXQxsH/file
# Resolving ucf58aa74caef9704a7d1ac5e964.dl.dropboxusercontent.com (ucf58aa74caef9704a7d1ac5e964.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:601b:15::a27d:80f
# Connecting to ucf58aa74caef9704a7d1ac5e964.dl.dropboxusercontent.com (ucf58aa74caef9704a7d1ac5e964.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3884193 (3.7M) [text/plain]
# Saving to: ‘NTP2015-2017fire.txt’
#
# NTP2015-2017fire.tx 100%[===================>]   3.70M  21.6MB/s    in 0.2s
#
# 2022-01-02 15:09:12 (21.6 MB/s) - ‘NTP2015-2017fire.txt’ saved [3884193/3884193]

# %%
# %cd /content/
#df = pd.read_csv('/content/gdrive/MyDrive/dlku/NTP2015fire-Jan.txt', sep='\t', header=None)
df = pd.read_csv('NTP2015-2017fire.txt', sep='\t', header=None)
df.columns = ["date", "station", "addr1", "addr2", "longitude", "latitude", "township"]
# Out:
# /content

# %%
df
# Out:
#                    date  station  ...   latitude township
# 0         2015/1/1 0:13  火警-瓦斯漏氣  ...  25.000569   板橋區廣德里
# 1         2015/1/1 0:16    火警-倉庫  ...  25.084172   三重區富華里
# 2         2015/1/1 0:48  火警-查看案件  ...  25.136422   淡水區民權里
# 3         2015/1/1 0:56  火警-查看案件  ...  25.031506   新莊區泰豐里
# 4         2015/1/1 1:04    火警-汽車  ...  24.982273   樹林區和平里
# ...                 ...      ...  ...        ...      ...
# 24085  2017/12/31 17:14  火警-集合住宅  ...  24.990417   中和區錦盛里
# 24086  2017/12/31 18:40  火警-集合住宅  ...  25.048063   汐止區東勢里
# 24087  2017/12/31 20:09  火警-查看案件  ...  25.076529   三重區福隆里
# 24088  2017/12/31 20:44  火警-查看案件  ...  24.997367   永和區民族里
# 24089  2017/12/31 22:09  火警-查看案件  ...  25.000317   板橋區龍安里
#
# [24090 rows x 7 columns]

# %%
#set date time format
df['date'] = pd.to_datetime(df.date, format='%Y-%m-%d %H:%M:%S')

# %%
df
# Out:
#                      date  station  ...   latitude township
# 0     2015-01-01 00:13:00  火警-瓦斯漏氣  ...  25.000569   板橋區廣德里
# 1     2015-01-01 00:16:00    火警-倉庫  ...  25.084172   三重區富華里
# 2     2015-01-01 00:48:00  火警-查看案件  ...  25.136422   淡水區民權里
# 3     2015-01-01 00:56:00  火警-查看案件  ...  25.031506   新莊區泰豐里
# 4     2015-01-01 01:04:00    火警-汽車  ...  24.982273   樹林區和平里
# ...                   ...      ...  ...        ...      ...
# 24085 2017-12-31 17:14:00  火警-集合住宅  ...  24.990417   中和區錦盛里
# 24086 2017-12-31 18:40:00  火警-集合住宅  ...  25.048063   汐止區東勢里
# 24087 2017-12-31 20:09:00  火警-查看案件  ...  25.076529   三重區福隆里
# 24088 2017-12-31 20:44:00  火警-查看案件  ...  24.997367   永和區民族里
# 24089 2017-12-31 22:09:00  火警-查看案件  ...  25.000317   板橋區龍安里
#
# [24090 rows x 7 columns]

# %%
#extract only numerical/quantitative data
dften = df[["date", "longitude", "latitude"]]

# %%
dften
# Out:
#                      date   longitude   latitude
# 0     2015-01-01 00:13:00  121.466281  25.000569
# 1     2015-01-01 00:16:00  121.491579  25.084172
# 2     2015-01-01 00:48:00  121.460224  25.136422
# 3     2015-01-01 00:56:00  121.450333  25.031506
# 4     2015-01-01 01:04:00  121.420005  24.982273
# ...                   ...         ...        ...
# 24085 2017-12-31 17:14:00  121.493909  24.990417
# 24086 2017-12-31 18:40:00  121.621682  25.048063
# 24087 2017-12-31 20:09:00  121.490806  25.076529
# 24088 2017-12-31 20:44:00  121.519391  24.997367
# 24089 2017-12-31 22:09:00  121.442237  25.000317
#
# [24090 rows x 3 columns]

# %%
BBox = ((dften.longitude.min(),   dften.longitude.max(),      
         dften.latitude.min(), dften.latitude.max()))

# %%
#Print out the coordinates, and go to Openstreetmap website to draw a map.
BBox
# Out:
# (121.2868855, 122.0030709, 24.77511693, 25.29717505)

# %%
#download the map we have just drawn
# !wget https://www.dropbox.com/s/dw6dp3zyx063zjt/ntpcmap.png
# !wget https://www.dropbox.com/s/vb5g8ndd3l2o0eh/ntpcmaplrg.png
# Out:
# --2022-01-02 15:09:13--  https://www.dropbox.com/s/dw6dp3zyx063zjt/ntpcmap.png
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/dw6dp3zyx063zjt/ntpcmap.png [following]
# --2022-01-02 15:09:13--  https://www.dropbox.com/s/raw/dw6dp3zyx063zjt/ntpcmap.png
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc701bb3b88c64739538874eef73.dl.dropboxusercontent.com/cd/0/inline/BdCJ6YVtyKOk40F_oqD-t1e-J--1UvQMMPNDoU8AB-WdwFaRoWyNafkBXBRPLLNFObO8TUUqoGN2TP_2WXldRAMcVrs4c911RXchCrL691bBX7tDBT3YIBRIHk1WHlzWyucjsQqQqQUboU6JI6LOWpvp/file# [following]
# --2022-01-02 15:09:13--  https://uc701bb3b88c64739538874eef73.dl.dropboxusercontent.com/cd/0/inline/BdCJ6YVtyKOk40F_oqD-t1e-J--1UvQMMPNDoU8AB-WdwFaRoWyNafkBXBRPLLNFObO8TUUqoGN2TP_2WXldRAMcVrs4c911RXchCrL691bBX7tDBT3YIBRIHk1WHlzWyucjsQqQqQUboU6JI6LOWpvp/file
# Resolving uc701bb3b88c64739538874eef73.dl.dropboxusercontent.com (uc701bb3b88c64739538874eef73.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6018:15::a27d:30f
# Connecting to uc701bb3b88c64739538874eef73.dl.dropboxusercontent.com (uc701bb3b88c64739538874eef73.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1828678 (1.7M) [image/png]
# Saving to: ‘ntpcmap.png’
#
# ntpcmap.png         100%[===================>]   1.74M  --.-KB/s    in 0.1s
#
# 2022-01-02 15:09:14 (12.8 MB/s) - ‘ntpcmap.png’ saved [1828678/1828678]
#
# --2022-01-02 15:09:14--  https://www.dropbox.com/s/vb5g8ndd3l2o0eh/ntpcmaplrg.png
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/vb5g8ndd3l2o0eh/ntpcmaplrg.png [following]
# --2022-01-02 15:09:14--  https://www.dropbox.com/s/raw/vb5g8ndd3l2o0eh/ntpcmaplrg.png
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc90ab4ab43adbbbc28ced72aa9.dl.dropboxusercontent.com/cd/0/inline/BdAGF0Fyactlyud4Q8OZ2yBIKew8CoWL-r_PFtYtXYxBTN5naNmfZT4sHGPpJWO8LsHL9mOl-rB7e2r4HbZzFOZISsUtsq-ot_369U93Zit2o_yoJh-1UHQlTRpZp8fxW2z05zjr8JYVYChrBSejscaY/file# [following]
# --2022-01-02 15:09:14--  https://ucc90ab4ab43adbbbc28ced72aa9.dl.dropboxusercontent.com/cd/0/inline/BdAGF0Fyactlyud4Q8OZ2yBIKew8CoWL-r_PFtYtXYxBTN5naNmfZT4sHGPpJWO8LsHL9mOl-rB7e2r4HbZzFOZISsUtsq-ot_369U93Zit2o_yoJh-1UHQlTRpZp8fxW2z05zjr8JYVYChrBSejscaY/file
# Resolving ucc90ab4ab43adbbbc28ced72aa9.dl.dropboxusercontent.com (ucc90ab4ab43adbbbc28ced72aa9.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:601b:15::a27d:80f
# Connecting to ucc90ab4ab43adbbbc28ced72aa9.dl.dropboxusercontent.com (ucc90ab4ab43adbbbc28ced72aa9.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1237701 (1.2M) [image/png]
# Saving to: ‘ntpcmaplrg.png’
#
# ntpcmaplrg.png      100%[===================>]   1.18M  --.-KB/s    in 0.06s
#
# 2022-01-02 15:09:15 (19.6 MB/s) - ‘ntpcmaplrg.png’ saved [1237701/1237701]

# %%
map = plt.imread('ntpcmap.png')
maplrg =  plt.imread('ntpcmaplrg.png')

# %%
f, axarr = plt.subplots(2)
axarr[0].imshow(map)
axarr[1].imshow(maplrg)

# %%
#let's plot the points
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(dften.longitude, dften.latitude, zorder=1, alpha= 0.2, c='k', s=10)
ax.set_title('Fire Incidents in NTPC, 2015-2017, Spatial Domain')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
# Out:
# (24.77511693, 25.29717505)

# %%
#split dataframe into 3 years
df15 = df[df['date'].dt.year == 2015]
df16 = df[df['date'].dt.year == 2016]
df17 = df[df['date'].dt.year == 2017]

# %%
df15
# Out:
#                     date  station  ...   latitude township
# 0    2015-01-01 00:13:00  火警-瓦斯漏氣  ...  25.000569   板橋區廣德里
# 1    2015-01-01 00:16:00    火警-倉庫  ...  25.084172   三重區富華里
# 2    2015-01-01 00:48:00  火警-查看案件  ...  25.136422   淡水區民權里
# 3    2015-01-01 00:56:00  火警-查看案件  ...  25.031506   新莊區泰豐里
# 4    2015-01-01 01:04:00    火警-汽車  ...  24.982273   樹林區和平里
# ...                  ...      ...  ...        ...      ...
# 9054 2015-12-31 21:41:00   火警-透天厝  ...  24.994490   中和區秀明里
# 9055 2015-12-31 21:46:00  火警-集合住宅  ...  25.016660   樹林區三福里
# 9056 2015-12-31 22:37:00  火警-查看案件  ...  25.070749   林口區東勢里
# 9057 2015-12-31 22:45:00  火警-查看案件  ...  25.097674   蘆洲區保新里
# 9058 2015-12-31 23:32:00  火警-查看案件  ...  24.989496   中和區錦中里
#
# [9059 rows x 7 columns]

# %%
df16
# Out:
#                      date      station  ...   latitude township
# 9059  2016-01-01 01:10:00      火警-查看案件  ...  25.047863   泰山區明志里
# 9060  2016-01-01 01:18:00      火警-查看案件  ...  25.145268   淡水區八勢里
# 9061  2016-01-01 01:27:00      火警-查看案件  ...  25.013844   永和區下溪里
# 9062  2016-01-01 03:30:00      火警-查看案件  ...  25.093751   蘆洲區南港里
# 9063  2016-01-01 03:47:00        火警-汽車  ...  24.994834   樹林區潭底里
# ...                   ...          ...  ...        ...      ...
# 17156 2016-12-31 19:50:00      火警-集合住宅  ...  25.032542   板橋區溪頭里
# 17157 2016-12-31 21:51:00      火警-查看案件  ...  24.997751   板橋區崑崙里
# 17158 2016-12-31 22:30:00      火警-集合住宅  ...  25.018254   板橋區新民里
# 17159 2016-12-31 22:52:00      火警-查看案件  ...  25.072460   林口區西林里
# 17160 2016-12-31 23:13:00  火警-山林田野(平地)  ...  25.145268   淡水區八勢里
#
# [8102 rows x 7 columns]

# %%
df17
# Out:
#                      date      station  ...   latitude township
# 17161 2017-01-01 00:13:00  火警-山林田野(平地)  ...  24.936866   鶯歌區二甲里
# 17162 2017-01-01 00:15:00      火警-集合住宅  ...  24.929874   三峽區介壽里
# 17163 2017-01-01 00:54:00      火警-集合住宅  ...  25.007928   板橋區流芳里
# 17164 2017-01-01 01:44:00      火警-集合住宅  ...  25.062100   汐止區文化里
# 17165 2017-01-01 01:59:00     火警-警報器作響  ...  25.076035   汐止區建成里
# ...                   ...          ...  ...        ...      ...
# 24085 2017-12-31 17:14:00      火警-集合住宅  ...  24.990417   中和區錦盛里
# 24086 2017-12-31 18:40:00      火警-集合住宅  ...  25.048063   汐止區東勢里
# 24087 2017-12-31 20:09:00      火警-查看案件  ...  25.076529   三重區福隆里
# 24088 2017-12-31 20:44:00      火警-查看案件  ...  24.997367   永和區民族里
# 24089 2017-12-31 22:09:00      火警-查看案件  ...  25.000317   板橋區龍安里
#
# [6929 rows x 7 columns]

# %%
#let's plot the points for 2015
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df15.longitude, df15.latitude, zorder=1, alpha= 0.2, c='r', s=10)
ax.set_title('Fire Incidents in NTPC, 2015, Spatial Domain')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
# Out:
# (24.77511693, 25.29717505)

# %%
#let's plot the points for 2016
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df16.longitude, df16.latitude, zorder=1, alpha= 0.2, c='g', s=10)
ax.set_title('Fire Incidents in NTPC, 2016, Spatial Domain')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
# Out:
# (24.77511693, 25.29717505)

# %%
#let's plot the points for 2017
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df17.longitude, df17.latitude, zorder=1, alpha= 0.2, c='b', s=10)
ax.set_title('Fire Incidents in NTPC, 2017, Spatial Domain')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
# Out:
# (24.77511693, 25.29717505)

# %%
#Extraction of the temporal domain
maxlimit = len(df)
ones = np.ones(maxlimit, dtype="uint32")
dftemp = pd.DataFrame(df.date)
dftemp['freq'] = ones

# %%
dftemp
# Out:
#                      date  freq
# 0     2015-01-01 00:13:00     1
# 1     2015-01-01 00:16:00     1
# 2     2015-01-01 00:48:00     1
# 3     2015-01-01 00:56:00     1
# 4     2015-01-01 01:04:00     1
# ...                   ...   ...
# 24085 2017-12-31 17:14:00     1
# 24086 2017-12-31 18:40:00     1
# 24087 2017-12-31 20:09:00     1
# 24088 2017-12-31 20:44:00     1
# 24089 2017-12-31 22:09:00     1
#
# [24090 rows x 2 columns]

# %%
#when running this block, we will obtain the monthly frequency to be used in the temporal domain (a.k.a. time series).
dftempday = dftemp.groupby(pd.Grouper(key="date", freq="1D")).count()
dftempweek = dftemp.groupby(pd.Grouper(key="date", freq="1W")).count()
dftempmonth = dftemp.groupby(pd.Grouper(key="date", freq="1M")).count()

# %%
dftempday
# Out:
#             freq
# date
# 2015-01-01    34
# 2015-01-02    25
# 2015-01-03    24
# 2015-01-04    34
# 2015-01-05    28
# ...          ...
# 2017-12-27    13
# 2017-12-28    19
# 2017-12-29    19
# 2017-12-30     6
# 2017-12-31     8
#
# [1096 rows x 1 columns]

# %%
dftempweek
# Out:
#             freq
# date
# 2015-01-04   117
# 2015-01-11   163
# 2015-01-18   141
# 2015-01-25   210
# 2015-02-01   174
# ...          ...
# 2017-12-03   125
# 2017-12-10   109
# 2017-12-17   105
# 2017-12-24   139
# 2017-12-31   100
#
# [157 rows x 1 columns]

# %%
dftempmonth
# Out:
#             freq
# date
# 2015-01-31   778
# 2015-02-28   776
# 2015-03-31   733
# 2015-04-30   844
# 2015-05-31   681
# 2015-06-30   677
# 2015-07-31   718
# 2015-08-31  1030
# 2015-09-30   792
# 2015-10-31   699
# 2015-11-30   680
# 2015-12-31   651
# 2016-01-31   688
# 2016-02-29   711
# 2016-03-31   752
# 2016-04-30   671
# 2016-05-31   652
# 2016-06-30   663
# 2016-07-31   666
# 2016-08-31   748
# 2016-09-30   674
# 2016-10-31   666
# 2016-11-30   635
# 2016-12-31   576
# 2017-01-31   638
# 2017-02-28   564
# 2017-03-31   519
# 2017-04-30   646
# 2017-05-31   509
# 2017-06-30   541
# 2017-07-31   610
# 2017-08-31   740
# 2017-09-30   576
# 2017-10-31   527
# 2017-11-30   553
# 2017-12-31   506

# %%
y = dftempmonth['freq']
x = dftempmonth.index
plt.rcParams["figure.figsize"] = (16,9)
plt.plot(x, y, color='r', label='monthly frequency') 
plt.xlabel('date')
plt.ylabel('incidents')
plt.title('Monthly Temporal Domain')
plt.legend() 
plt.show()

# %%
y = dftempweek['freq']
x = dftempweek.index
plt.rcParams["figure.figsize"] = (16,9)
plt.plot(x, y, color='g', label='weekly frequency')
plt.xlabel('date')
plt.ylabel('incidents')
plt.title('Weekly Temporal Domain')
plt.legend() 
plt.show()

# %%
y = dftempday['freq']
x = dftempday.index
plt.rcParams["figure.figsize"] = (16,9)
plt.plot(x, y, color='b', label='daily frequency') 
plt.xlabel('date')
plt.ylabel('incidents')
plt.title('Daily Temporal Domain')
plt.legend() 
plt.show()

# %% [markdown]
# #Keras LSTM MODEL

# %%
# LSTM for international airline passengers problem with regression framing
import numpy
import matplotlib.pyplot as plt
import pandas as pd
import math
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn import metrics

# %% [markdown]
# Convert dataset to matrix

# %%
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return numpy.array(dataX), numpy.array(dataY)

# fix random seed for reproducibility
numpy.random.seed(7)

# %% [markdown]
# Data preparation & train-test split

# %%
# load the dataset
#dataframe = pd.read_csv('uberday.csv', usecols=[1], engine='python')
dataframe = dftempday
dataset = dataframe.values
dataset = dataset.astype('float32')

dataplot = dataframe.copy()
#training_set = pd.read_csv('shampoo.csv')

#dataplot = dataplot.iloc[:,1:2].values

#plt.plot(training_set, label = 'Shampoo Sales Data')
plt.plot(dataplot, label = 'Taxi Daily Ridership Data (104/01-08)')
plt.show()

# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# split into train and test sets
#here, you can change the test size to make future prediction
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %% [markdown]
# Model design & training

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
history = model.fit(trainX, trainY, validation_split=0.2, epochs=100, batch_size=1, verbose=2)

# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# Epoch 1/100
# 585/585 - 10s - loss: 0.0029 - val_loss: 0.0018 - 10s/epoch - 17ms/step
# Epoch 2/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0015 - 2s/epoch - 4ms/step
# Epoch 3/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 4/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 5/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 6/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 7/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 8/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0016 - 2s/epoch - 4ms/step
# Epoch 9/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 10/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 11/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 12/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 13/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 14/100
# 585/585 - 2s - loss: 0.0025 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 15/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 16/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0014 - 2s/epoch - 4ms/step
# Epoch 17/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 18/100
# 585/585 - 2s - loss: 0.0025 - val_loss: 0.0018 - 2s/epoch - 4ms/step
# Epoch 19/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 20/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 21/100
# 585/585 - 2s - loss: 0.0025 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 22/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 3ms/step
# Epoch 23/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 24/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 25/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 26/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 27/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 28/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 29/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 30/100
# 585/585 - 2s - loss: 0.0025 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 31/100
# 585/585 - 2s - loss: 0.0025 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 32/100
# 585/585 - 2s - loss: 0.0025 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 33/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 34/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 35/100
# 585/585 - 2s - loss: 0.0025 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 36/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 37/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 38/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 39/100
# 585/585 - 2s - loss: 0.0025 - val_loss: 0.0014 - 2s/epoch - 4ms/step
# Epoch 40/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 41/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 42/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 43/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 44/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 45/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 46/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 47/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 48/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0015 - 2s/epoch - 4ms/step
# Epoch 49/100
# 585/585 - 3s - loss: 0.0026 - val_loss: 0.0012 - 3s/epoch - 5ms/step
# Epoch 50/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0014 - 2s/epoch - 4ms/step
# Epoch 51/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 52/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 53/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 54/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 55/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 56/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 57/100
# 585/585 - 2s - loss: 0.0025 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 58/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 59/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 60/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 61/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 62/100
# 585/585 - 2s - loss: 0.0025 - val_loss: 0.0019 - 2s/epoch - 4ms/step
# Epoch 63/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0014 - 2s/epoch - 4ms/step
# Epoch 64/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 65/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0016 - 2s/epoch - 4ms/step
# Epoch 66/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0016 - 2s/epoch - 4ms/step
# Epoch 67/100
# 585/585 - 2s - loss: 0.0025 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 68/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 69/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 70/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0017 - 2s/epoch - 4ms/step
# Epoch 71/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 72/100
# 585/585 - 2s - loss: 0.0025 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 73/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 74/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 75/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 76/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 77/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 78/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 79/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0015 - 2s/epoch - 4ms/step
# Epoch 80/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 81/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0017 - 2s/epoch - 4ms/step
# Epoch 82/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 83/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 84/100
# 585/585 - 2s - loss: 0.0025 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 85/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 86/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 87/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 88/100
# 585/585 - 2s - loss: 0.0025 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 89/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0016 - 2s/epoch - 4ms/step
# Epoch 90/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 91/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 3ms/step
# Epoch 92/100
# 585/585 - 2s - loss: 0.0025 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 93/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 94/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 95/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 96/100
# 585/585 - 2s - loss: 0.0025 - val_loss: 0.0015 - 2s/epoch - 4ms/step
# Epoch 97/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 98/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 99/100
# 585/585 - 3s - loss: 0.0026 - val_loss: 0.0013 - 3s/epoch - 4ms/step
# Epoch 100/100
# 585/585 - 2s - loss: 0.0026 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# dict_keys(['loss', 'val_loss'])

# %% [markdown]
# Make prediction & calculate RMSE

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

trmse = mean_squared_error(trainY[0], trainPredict[:,0])
trmae = metrics.mean_absolute_error(trainY[0], trainPredict[:,0])
trmape = metrics.mean_absolute_percentage_error(trainY[0], trainPredict[:,0])

# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %f RMSE' % (trainScore))
print('Train Score: %f MSE' % (trmse))
print('Train Score: %f MAE' % (trmae))
print('Train Score: %f MAPE' % (trmape))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %f RMSE' % (testScore))
mse = mean_squared_error(testY[0], testPredict[:,0])
mae = metrics.mean_absolute_error(testY[0], testPredict[:,0])
mape = metrics.mean_absolute_percentage_error(testY[0], testPredict[:,0])
print('Test Score: %f MSE' % (mse))
print('Test Score: %f MAE' % (mae))
print('Test Score: %f MAPE' % (mape))
# Out:
# Train Score: 9.573902 RMSE
# Train Score: 91.659602 MSE
# Train Score: 5.220221 MAE
# Train Score: 0.238248 MAPE
# Test Score: 6.931456 RMSE
# Test Score: 48.045088 MSE
# Test Score: 5.168260 MAE
# Test Score: 0.349586 MAPE

# %% [markdown]
# Test & Prediction Plot

# %%
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
