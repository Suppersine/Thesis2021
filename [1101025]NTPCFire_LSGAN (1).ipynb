# %% [markdown]
# #Read the data

# %%
from zipfile import ZipFile
import os, glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from google.colab.patches import cv2_imshow

# %%
# !wget https://www.dropbox.com/s/gtvw3nqbderxigb/datafig28.zip
# Out:
# --2021-12-27 07:37:05--  https://www.dropbox.com/s/gtvw3nqbderxigb/datafig28.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/gtvw3nqbderxigb/datafig28.zip [following]
# --2021-12-27 07:37:05--  https://www.dropbox.com/s/raw/gtvw3nqbderxigb/datafig28.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucd080ba894f01a2033a01ccf5b5.dl.dropboxusercontent.com/cd/0/inline/Bcq70-RAvNXbrKkpJ7Q9nDByZ0MyngbelKyT6dqrWwRvJFckrLevUm_pJZXRBC5gBeowhz7z5U05DxajIczZniyYuzeK4DPzGp_MIdFbhp8Gl9Kvhejvuv9-f5R36h3naymHNYTVD1Z8tHnrZDEacYPe/file# [following]
# --2021-12-27 07:37:05--  https://ucd080ba894f01a2033a01ccf5b5.dl.dropboxusercontent.com/cd/0/inline/Bcq70-RAvNXbrKkpJ7Q9nDByZ0MyngbelKyT6dqrWwRvJFckrLevUm_pJZXRBC5gBeowhz7z5U05DxajIczZniyYuzeK4DPzGp_MIdFbhp8Gl9Kvhejvuv9-f5R36h3naymHNYTVD1Z8tHnrZDEacYPe/file
# Resolving ucd080ba894f01a2033a01ccf5b5.dl.dropboxusercontent.com (ucd080ba894f01a2033a01ccf5b5.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:601b:15::a27d:80f
# Connecting to ucd080ba894f01a2033a01ccf5b5.dl.dropboxusercontent.com (ucd080ba894f01a2033a01ccf5b5.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Bcr8hLDsr5sGjXVwXUdXtlRkvz1_DN7uBGGMZOEEExswt1nJVpg7HGq-EI68Dwc27V_GEvdq_u1DzImL22wrFCf0Ew6zrOdWrOpAa_B_oqCNbrpEdmPt02zj0VcKODqjGshCPA7eWwM6yHvIbRNCz-tL-YrEGXwxZSjqD7KlkibaMt1bhI2ShQVhBEELFk9vEo30ALhkaXSIUYROFC5ZW-5yosxKilbMG0NnzWN39yM1eqAwbiAP38oOa-GXdLseg2f6rSJPA0gvnrgKaBU4yVMDc4jEeUtefaySRboGCr1483AH1BsWUSB3iBJxBe6bbALybc0DkLq1FBWrJQt-rU1K2-c234yo38Xo_RZLAzb6F0AHBlVsqcOJQMuJjcGITQE/file [following]
# --2021-12-27 07:37:06--  https://ucd080ba894f01a2033a01ccf5b5.dl.dropboxusercontent.com/cd/0/inline2/Bcr8hLDsr5sGjXVwXUdXtlRkvz1_DN7uBGGMZOEEExswt1nJVpg7HGq-EI68Dwc27V_GEvdq_u1DzImL22wrFCf0Ew6zrOdWrOpAa_B_oqCNbrpEdmPt02zj0VcKODqjGshCPA7eWwM6yHvIbRNCz-tL-YrEGXwxZSjqD7KlkibaMt1bhI2ShQVhBEELFk9vEo30ALhkaXSIUYROFC5ZW-5yosxKilbMG0NnzWN39yM1eqAwbiAP38oOa-GXdLseg2f6rSJPA0gvnrgKaBU4yVMDc4jEeUtefaySRboGCr1483AH1BsWUSB3iBJxBe6bbALybc0DkLq1FBWrJQt-rU1K2-c234yo38Xo_RZLAzb6F0AHBlVsqcOJQMuJjcGITQE/file
# Reusing existing connection to ucd080ba894f01a2033a01ccf5b5.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 34548 (34K) [application/zip]
# Saving to: ‘datafig28.zip’
#
# datafig28.zip       100%[===================>]  33.74K  --.-KB/s    in 0.02s
#
# 2021-12-27 07:37:06 (1.37 MB/s) - ‘datafig28.zip’ saved [34548/34548]

# %%
with ZipFile("datafig28.zip","r") as zip_ref:
    zip_ref.extractall()

# %%
def imageread(directory, mode=all):
  if mode == "all":
    directory = directory+'all/'
  elif mode == "train":
    directory = directory+'train/'
  elif mode == "test":
    directory = directory+'test/'
  else:
    print("ERROR, You did not select a mode; must be one of these: all, train, test")

  modelen = next(os.walk(directory))[2] #dir is your directory path as string
  modelen = len(modelen)
  print(modelen)
  picmat = np.zeros([modelen,28,28])
  i = 0

  if mode != None:
    for files in os.scandir(directory):
      #print(files.path)
      imageArray = cv2.imread(files.path, cv2.COLOR_BGR2GRAY)
      picmat[i] = imageArray
      #cv2_imshow(picmat[i])
      i+=1

  return picmat
    
all3darr = imageread('/content/datafig28/', 'all')
train3darr = imageread('/content/datafig28/', 'train')
test3darr = imageread('/content/datafig28/', 'test')
plt.imshow(all3darr[0])
# Out:
# 36
# 24
# 12

# %% [markdown]
# #Define the model (TFK-LSGAN)

# %%
# example of lsgan for mnist
from numpy import expand_dims
from numpy import zeros
from numpy import ones
from numpy.random import randn
from numpy.random import randint
import tensorflow as tf
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.initializers import RandomNormal
from matplotlib import pyplot

# define the standalone discriminator model
def define_discriminator(in_shape=(28,28,1)):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# define model
	model = Sequential()
	# downsample to 14x14
	model.add(Conv2D(64, (4,4), strides=(2,2), padding='same', kernel_initializer=init, input_shape=in_shape))
	model.add(BatchNormalization())
	model.add(LeakyReLU(alpha=0.2))
	# downsample to 7x7
	model.add(Conv2D(128, (4,4), strides=(2,2), padding='same', kernel_initializer=init))
	model.add(BatchNormalization())
	model.add(LeakyReLU(alpha=0.2))
	# classifier
	model.add(Flatten())
	model.add(Dense(1, activation='linear', kernel_initializer=init))
	# compile model with L2 loss
	model.compile(loss='mse', optimizer=Adam(learning_rate=0.001, beta_1=0.5))
	return model

# define the standalone generator model
def define_generator(latent_dim):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# define model
	model = Sequential()
	# foundation for 7x7 image
	n_nodes = 256 * 7 * 7
	model.add(Dense(n_nodes, kernel_initializer=init, input_dim=latent_dim))
	model.add(BatchNormalization())
	model.add(Activation('relu'))
	model.add(Reshape((7, 7, 256)))
	# upsample to 14x14
	model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same', kernel_initializer=init))
	model.add(BatchNormalization())
	model.add(Activation('relu'))
	# upsample to 28x28
	model.add(Conv2DTranspose(64, (4,4), strides=(2,2), padding='same', kernel_initializer=init))
	model.add(BatchNormalization())
	model.add(Activation('relu'))
	# output 28x28x1
	model.add(Conv2D(1, (7,7), padding='same', kernel_initializer=init))
	model.add(Activation('tanh'))
	return model

# define the combined generator and discriminator model, for updating the generator
def define_gan(generator, discriminator):
	# make weights in the discriminator not trainable
	for layer in discriminator.layers:
		if not isinstance(layer, BatchNormalization):
			layer.trainable = False
	# connect them
	model = Sequential()
	# add generator
	model.add(generator)
	# add the discriminator
	model.add(discriminator)
	# compile model with L2 loss
	model.compile(loss='mse', optimizer=Adam(learning_rate=0.001, beta_1=0.5))
	return model

# load our images #LOAD RAW IMAGES
def load_real_samples():
	# load dataset
	trainX = train3darr
	# expand to 3d, e.g. add channels
	X = expand_dims(trainX, axis=-1)
	# convert from ints to floats
	X = X.astype('float32')
	# scale from [0,255] to [-1,1]
	X = (X - 127.5) / 127.5
	return X

# load test images #LOAD RAW IMAGES
def load_real_samples():
	# load dataset
	trainX = test3darr
	# expand to 3d, e.g. add channels
	X = expand_dims(trainX, axis=-1)
	# convert from ints to floats
	X = X.astype('float32')
	# scale from [0,255] to [-1,1]
	X = (X - 127.5) / 127.5
	return X

# # select real samples
def generate_real_samples(dataset, n_samples):
	# choose random instances
	ix = randint(0, dataset.shape[0], n_samples)
	# select images
	X = dataset[ix]
	# generate class labels
	y = ones((n_samples, 1))
	return X, y

# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples):
	# generate points in the latent space
	x_input = randn(latent_dim * n_samples)
	# reshape into a batch of inputs for the network
	x_input = x_input.reshape(n_samples, latent_dim)
	return x_input

# use the generator to generate n fake examples, with class labels
def generate_fake_samples(generator, latent_dim, n_samples):
	# generate points in latent space
	x_input = generate_latent_points(latent_dim, n_samples)
	# predict outputs
	X = generator.predict(x_input)
	# create class labels
	y = zeros((n_samples, 1))
	return X, y

# generate samples and save as a plot and save the model
def summarize_performance(step, g_model, latent_dim, n_samples=12):
	# prepare fake examples
	X, _ = generate_fake_samples(g_model, latent_dim, n_samples)
	# scale from [-1,1] to [0,1]
	X = (X + 1) / 2.0
	# plot images
	for i in range(3 * 4):
		# define subplot
		pyplot.subplot(3, 4, 1 + i)
		# turn off axis
		pyplot.axis('off')
		# plot raw pixel data
		pyplot.imshow(X[i, :, :, 0], cmap='gray_r')
	# save plot to file
	filename1 = 'generated_plot_%06d.png' % (step+1)
	pyplot.savefig(filename1)
	pyplot.close()
	# save the generator model
	filename2 = 'model_%06d.h5' % (step+1)
	g_model.save(filename2)
	print('Saved %s and %s' % (filename1, filename2))
  

# create a line plot of loss for the gan and save to file
def plot_history(d1_hist, d2_hist, g_hist):
	pyplot.plot(d1_hist, label='dloss1')
	pyplot.plot(d2_hist, label='dloss2')
	pyplot.plot(g_hist, label='gloss')
	pyplot.legend()
	filename = 'plot_line_plot_loss.png'
	pyplot.savefig(filename)
	pyplot.close()
	print('Saved %s' % (filename))

# train the generator and discriminator
def train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs=100, n_batch=12):
	# calculate the number of batches per training epoch
	bat_per_epo = int(dataset.shape[0] / n_batch)
	# calculate the number of training iterations
	n_steps = bat_per_epo * n_epochs
	# calculate the size of half a batch of samples
	half_batch = int(n_batch / 2)
	# lists for storing loss, for plotting later
	d1_hist, d2_hist, g_hist = list(), list(), list()
	# manually enumerate epochs
	for i in range(n_steps):
		# prepare real and fake samples
		X_real, y_real = generate_real_samples(dataset, half_batch)
		X_fake, y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
		print(X_fake.shape)
		# update discriminator model
		d_loss1 = d_model.train_on_batch(X_real, y_real)
		d_loss2 = d_model.train_on_batch(X_fake, y_fake)
		# update the generator via the discriminator's error
		z_input = generate_latent_points(latent_dim, n_batch)
		y_real2 = ones((n_batch, 1))
		g_loss = gan_model.train_on_batch(z_input, y_real2)
		# summarize loss on this batch
		print('>%d, d1=%.3f, d2=%.3f g=%.3f' % (i+1, d_loss1, d_loss2, g_loss))
		# record history
		d1_hist.append(d_loss1)
		d2_hist.append(d_loss2)
		g_hist.append(g_loss)
		# evaluate the model performance every 'epoch'
		if (i+1) % (bat_per_epo * 1) == 0:
			summarize_performance(i, g_model, latent_dim)
	# create line plot of training history
	plot_history(d1_hist, d2_hist, g_hist)

# size of the latent space
latent_dim = 100
# create the discriminator
discriminator = define_discriminator()
# create the generator
generator = define_generator(latent_dim)
# create the gan
gan_model = define_gan(generator, discriminator)
# load image data
dataset = load_real_samples()
print(dataset.shape)
# train model
train(generator, discriminator, gan_model, dataset, latent_dim)
# Out:
# (12, 28, 28, 1)
# (6, 28, 28, 1)
# >1, d1=2.078, d2=0.289 g=1.204
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000001.png and model_000001.h5
# (6, 28, 28, 1)
# >2, d1=348.417, d2=8.105 g=1.137
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000002.png and model_000002.h5
# (6, 28, 28, 1)
# >3, d1=3.334, d2=4.630 g=1.273
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000003.png and model_000003.h5
# (6, 28, 28, 1)
# >4, d1=23.619, d2=4.412 g=1.458
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000004.png and model_000004.h5
# (6, 28, 28, 1)
# >5, d1=0.315, d2=1.554 g=0.609
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000005.png and model_000005.h5
# (6, 28, 28, 1)
# >6, d1=1.874, d2=0.847 g=0.820
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000006.png and model_000006.h5
# (6, 28, 28, 1)
# >7, d1=0.094, d2=1.455 g=1.430
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000007.png and model_000007.h5
# (6, 28, 28, 1)
# >8, d1=0.167, d2=7.435 g=15.799
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000008.png and model_000008.h5
# (6, 28, 28, 1)
# >9, d1=0.015, d2=36.964 g=1.209
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000009.png and model_000009.h5
# (6, 28, 28, 1)
# >10, d1=0.492, d2=24.055 g=0.056
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000010.png and model_000010.h5
# (6, 28, 28, 1)
# >11, d1=0.167, d2=1.076 g=1.669
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000011.png and model_000011.h5
# (6, 28, 28, 1)
# >12, d1=0.023, d2=0.302 g=0.290
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000012.png and model_000012.h5
# (6, 28, 28, 1)
# >13, d1=0.104, d2=0.175 g=0.285
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000013.png and model_000013.h5
# (6, 28, 28, 1)
# >14, d1=0.070, d2=0.082 g=0.267
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000014.png and model_000014.h5
# (6, 28, 28, 1)
# >15, d1=0.028, d2=0.059 g=0.182
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000015.png and model_000015.h5
# (6, 28, 28, 1)
# >16, d1=0.007, d2=0.037 g=0.209
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000016.png and model_000016.h5
# (6, 28, 28, 1)
# >17, d1=0.106, d2=0.085 g=0.082
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000017.png and model_000017.h5
# (6, 28, 28, 1)
# >18, d1=0.119, d2=0.067 g=0.158
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000018.png and model_000018.h5
# (6, 28, 28, 1)
# >19, d1=0.014, d2=0.054 g=0.182
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000019.png and model_000019.h5
# (6, 28, 28, 1)
# >20, d1=0.030, d2=0.024 g=0.034
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000020.png and model_000020.h5
# (6, 28, 28, 1)
# >21, d1=0.027, d2=0.076 g=0.079
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000021.png and model_000021.h5
# (6, 28, 28, 1)
# >22, d1=0.009, d2=0.117 g=0.027
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000022.png and model_000022.h5
# (6, 28, 28, 1)
# >23, d1=0.011, d2=0.307 g=0.061
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000023.png and model_000023.h5
# (6, 28, 28, 1)
# >24, d1=0.036, d2=0.213 g=0.060
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000024.png and model_000024.h5
# (6, 28, 28, 1)
# >25, d1=0.127, d2=0.420 g=0.188
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000025.png and model_000025.h5
# (6, 28, 28, 1)
# >26, d1=0.161, d2=0.661 g=0.069
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000026.png and model_000026.h5
# (6, 28, 28, 1)
# >27, d1=0.091, d2=0.915 g=0.277
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000027.png and model_000027.h5
# (6, 28, 28, 1)
# >28, d1=0.030, d2=0.935 g=0.116
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000028.png and model_000028.h5
# (6, 28, 28, 1)
# >29, d1=0.025, d2=1.462 g=0.644
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000029.png and model_000029.h5
# (6, 28, 28, 1)
# >30, d1=0.026, d2=2.354 g=0.554
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000030.png and model_000030.h5
# (6, 28, 28, 1)
# >31, d1=0.004, d2=2.830 g=0.770
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000031.png and model_000031.h5
# (6, 28, 28, 1)
# >32, d1=0.032, d2=2.452 g=0.028
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000032.png and model_000032.h5
# (6, 28, 28, 1)
# >33, d1=0.183, d2=1.372 g=0.185
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000033.png and model_000033.h5
# (6, 28, 28, 1)
# >34, d1=0.429, d2=0.535 g=0.044
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000034.png and model_000034.h5
# (6, 28, 28, 1)
# >35, d1=0.885, d2=0.204 g=0.069
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000035.png and model_000035.h5
# (6, 28, 28, 1)
# >36, d1=1.550, d2=0.076 g=0.030
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000036.png and model_000036.h5
# (6, 28, 28, 1)
# >37, d1=2.570, d2=0.099 g=0.024
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000037.png and model_000037.h5
# (6, 28, 28, 1)
# >38, d1=2.806, d2=0.536 g=0.140
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000038.png and model_000038.h5
# (6, 28, 28, 1)
# >39, d1=4.092, d2=0.991 g=0.113
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000039.png and model_000039.h5
# (6, 28, 28, 1)
# >40, d1=5.335, d2=2.392 g=0.855
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000040.png and model_000040.h5
# (6, 28, 28, 1)
# >41, d1=5.494, d2=5.124 g=0.841
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000041.png and model_000041.h5
# (6, 28, 28, 1)
# >42, d1=3.050, d2=5.308 g=0.522
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000042.png and model_000042.h5
# (6, 28, 28, 1)
# >43, d1=1.661, d2=4.678 g=0.006
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000043.png and model_000043.h5
# (6, 28, 28, 1)
# >44, d1=0.577, d2=2.807 g=0.142
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000044.png and model_000044.h5
# (6, 28, 28, 1)
# >45, d1=0.224, d2=1.100 g=0.110
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000045.png and model_000045.h5
# (6, 28, 28, 1)
# >46, d1=0.056, d2=0.260 g=0.038
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000046.png and model_000046.h5
# (6, 28, 28, 1)
# >47, d1=0.097, d2=0.065 g=0.084
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000047.png and model_000047.h5
# (6, 28, 28, 1)
# >48, d1=0.396, d2=0.087 g=0.073
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000048.png and model_000048.h5
# (6, 28, 28, 1)
# >49, d1=0.584, d2=0.107 g=0.030
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000049.png and model_000049.h5
# (6, 28, 28, 1)
# >50, d1=0.524, d2=0.169 g=0.047
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000050.png and model_000050.h5
# (6, 28, 28, 1)
# >51, d1=0.389, d2=0.239 g=0.036
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000051.png and model_000051.h5
# (6, 28, 28, 1)
# >52, d1=0.199, d2=0.377 g=0.157
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000052.png and model_000052.h5
# (6, 28, 28, 1)
# >53, d1=0.050, d2=0.439 g=0.060
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000053.png and model_000053.h5
# (6, 28, 28, 1)
# >54, d1=0.012, d2=0.366 g=0.127
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000054.png and model_000054.h5
# (6, 28, 28, 1)
# >55, d1=0.037, d2=0.227 g=0.024
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000055.png and model_000055.h5
# (6, 28, 28, 1)
# >56, d1=0.025, d2=0.063 g=0.019
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000056.png and model_000056.h5
# (6, 28, 28, 1)
# >57, d1=0.050, d2=0.019 g=0.022
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000057.png and model_000057.h5
# (6, 28, 28, 1)
# >58, d1=0.099, d2=0.036 g=0.011
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000058.png and model_000058.h5
# (6, 28, 28, 1)
# >59, d1=0.096, d2=0.030 g=0.060
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000059.png and model_000059.h5
# (6, 28, 28, 1)
# >60, d1=0.092, d2=0.036 g=0.072
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000060.png and model_000060.h5
# (6, 28, 28, 1)
# >61, d1=0.134, d2=0.042 g=0.011
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000061.png and model_000061.h5
# (6, 28, 28, 1)
# >62, d1=0.257, d2=0.047 g=0.035
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000062.png and model_000062.h5
# (6, 28, 28, 1)
# >63, d1=0.439, d2=0.018 g=0.039
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000063.png and model_000063.h5
# (6, 28, 28, 1)
# >64, d1=0.742, d2=0.038 g=0.006
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000064.png and model_000064.h5
# (6, 28, 28, 1)
# >65, d1=0.895, d2=0.185 g=0.162
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000065.png and model_000065.h5
# (6, 28, 28, 1)
# >66, d1=1.123, d2=0.876 g=0.178
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000066.png and model_000066.h5
# (6, 28, 28, 1)
# >67, d1=1.349, d2=1.913 g=0.346
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000067.png and model_000067.h5
# (6, 28, 28, 1)
# >68, d1=1.404, d2=3.193 g=0.465
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000068.png and model_000068.h5
# (6, 28, 28, 1)
# >69, d1=0.999, d2=4.486 g=0.601
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000069.png and model_000069.h5
# (6, 28, 28, 1)
# >70, d1=0.495, d2=4.489 g=0.209
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000070.png and model_000070.h5
# (6, 28, 28, 1)
# >71, d1=0.089, d2=3.748 g=0.437
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000071.png and model_000071.h5
# (6, 28, 28, 1)
# >72, d1=0.021, d2=2.633 g=0.074
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000072.png and model_000072.h5
# (6, 28, 28, 1)
# >73, d1=0.131, d2=2.094 g=0.678
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000073.png and model_000073.h5
# (6, 28, 28, 1)
# >74, d1=0.260, d2=1.434 g=0.007
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000074.png and model_000074.h5
# (6, 28, 28, 1)
# >75, d1=0.369, d2=0.830 g=0.255
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000075.png and model_000075.h5
# (6, 28, 28, 1)
# >76, d1=0.412, d2=0.377 g=0.008
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000076.png and model_000076.h5
# (6, 28, 28, 1)
# >77, d1=0.703, d2=0.266 g=0.318
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000077.png and model_000077.h5
# (6, 28, 28, 1)
# >78, d1=1.582, d2=0.208 g=0.036
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000078.png and model_000078.h5
# (6, 28, 28, 1)
# >79, d1=2.834, d2=0.053 g=0.140
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000079.png and model_000079.h5
# (6, 28, 28, 1)
# >80, d1=3.102, d2=0.015 g=0.006
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000080.png and model_000080.h5
# (6, 28, 28, 1)
# >81, d1=3.156, d2=0.061 g=0.083
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000081.png and model_000081.h5
# (6, 28, 28, 1)
# >82, d1=2.520, d2=0.126 g=0.012
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000082.png and model_000082.h5
# (6, 28, 28, 1)
# >83, d1=1.918, d2=0.186 g=0.009
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000083.png and model_000083.h5
# (6, 28, 28, 1)
# >84, d1=1.248, d2=0.416 g=0.131
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000084.png and model_000084.h5
# (6, 28, 28, 1)
# >85, d1=0.694, d2=0.894 g=0.206
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000085.png and model_000085.h5
# (6, 28, 28, 1)
# >86, d1=0.084, d2=1.023 g=0.167
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000086.png and model_000086.h5
# (6, 28, 28, 1)
# >87, d1=0.052, d2=1.092 g=0.173
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000087.png and model_000087.h5
# (6, 28, 28, 1)
# >88, d1=0.108, d2=1.043 g=0.113
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000088.png and model_000088.h5
# (6, 28, 28, 1)
# >89, d1=0.134, d2=0.690 g=0.034
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000089.png and model_000089.h5
# (6, 28, 28, 1)
# >90, d1=0.384, d2=0.380 g=0.112
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000090.png and model_000090.h5
# (6, 28, 28, 1)
# >91, d1=0.802, d2=0.177 g=0.015
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000091.png and model_000091.h5
# (6, 28, 28, 1)
# >92, d1=0.951, d2=0.043 g=0.027
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000092.png and model_000092.h5
# (6, 28, 28, 1)
# >93, d1=0.628, d2=0.024 g=0.002
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000093.png and model_000093.h5
# (6, 28, 28, 1)
# >94, d1=0.346, d2=0.036 g=0.039
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000094.png and model_000094.h5
# (6, 28, 28, 1)
# >95, d1=0.121, d2=0.004 g=0.004
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000095.png and model_000095.h5
# (6, 28, 28, 1)
# >96, d1=0.022, d2=0.052 g=0.040
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000096.png and model_000096.h5
# (6, 28, 28, 1)
# >97, d1=0.119, d2=0.158 g=0.041
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000097.png and model_000097.h5
# (6, 28, 28, 1)
# >98, d1=0.111, d2=0.292 g=0.072
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000098.png and model_000098.h5
# (6, 28, 28, 1)
# >99, d1=0.056, d2=0.347 g=0.041
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000099.png and model_000099.h5
# (6, 28, 28, 1)
# >100, d1=0.021, d2=0.320 g=0.060
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved generated_plot_000100.png and model_000100.h5
# Saved plot_line_plot_loss.png

# %%
gt, _ = generate_real_samples(dataset, 6)
pred, _= generate_fake_samples(generator, latent_dim, 6)

# %%
pred = pred.reshape(6,28,28)
fig, axs = plt.subplots(2, 3)
axs[0, 0].imshow(pred[0], cmap='gray')
axs[0, 1].imshow(pred[1], cmap='gray')
axs[0, 2].imshow(pred[2], cmap='gray')
axs[1, 0].imshow(pred[3], cmap='gray')
axs[1, 1].imshow(pred[4], cmap='gray')
axs[1, 2].imshow(pred[5], cmap='gray')

# %%
gt = gt.reshape(6,784)
pred = pred.reshape(6,784)

# %%
from sklearn import metrics
from math import sqrt

mae = metrics.mean_absolute_error(gt, pred)
mse = metrics.mean_squared_error(gt, pred)
mape = metrics.mean_absolute_percentage_error(gt, pred)
rmse = sqrt(mse)

print('MSE=', mse, '...RMSE=', rmse, '...MAE=', mae, '...MAPE=', mape)
# Out:
# MSE= 1.5672921 ...RMSE= 1.2519153702350059 ...MAE= 1.0953237 ...MAPE= 1.4709859
